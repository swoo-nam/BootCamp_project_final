# %% [markdown]
# <a href="https://colab.research.google.com/github/swoo-nam/project_final_team1/blob/main/%EC%9D%B4%EC%86%8C%ED%98%84_%EC%84%9C%EB%B9%84%EC%8A%A42_%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%A0%95%EC%A0%9C%EC%A0%95%EB%A6%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import torch
from tqdm.auto import tqdm
import random
import os
import re

def reset_seeds(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

DATA_PATH = "/content/drive/MyDrive/Final_Project/data/"
SEED = 42

device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cpu'

# %% [markdown]
# # 요기요 데이터셋 불러오기

# %%
train = pd.read_csv(f"{DATA_PATH}yogiyo_reviews_0908.csv")
train.head()
# Out:
#                    가게이름                                               고객리뷰  \
# 0  1988응답하라추억의옛날도시락-방이점                          맛있게 잘먹었습니다 묵사발도 시원하니 맛있네요
# 1  1988응답하라추억의옛날도시락-방이점                        기름 있는 부분이 생각보다 많아요! 참고하세요:)
# 2  1988응답하라추억의옛날도시락-방이점  양도 푸짐하고  맛있습니다!  청국장 냄새 많이 안나고 콩도 많이 들어있어서 좋았습니다!
# 3  1988응답하라추억의옛날도시락-방이점                                        ..,........
# 4  1988응답하라추억의옛날도시락-방이점  냉면을 따로 시키고 미니냉면을 합친것인데 양이 좀 적어보이고. 김치정식도 양이 적어...
#
#    별점  맛별점  양별점  배달별점                                               사장댓글  \
# 0   5  5.0  5.0   5.0  즐거운 순간을 저희와 함께해주셔서 감사합니다💖 \n\n보람차게 일할 수 있게 해 주...
# 1   5  5.0  5.0   5.0  소중한 의견 남겨 주셔서 감사합니다. 잘 새겨 듣고 앞으로 더욱 더 개선 할 수 있...
# 2   5  5.0  5.0   5.0  늘 최고의 메뉴를 제공해드리고 싶습니다!😄 \n\n맛있는 메뉴를 넉넉하게 먹을 수 ...
# 3   5  5.0  5.0   5.0  저희 매장과 함께 편안한 시간 되셨을까요? \n\n1. 고객을 생각하는 마음 \n2...
# 4   5  5.0  4.0   5.0  이번 주문을 통해 한걸음 더 가까워진 것 같아 기분이 좋아요!😁\n\n고객님의 행복...
#
#                                                   메뉴
# 0                                        [직화]삼겹옛날도시락
# 1                                   [직화]삼겹옛날도시락,볶음김치
# 2                           [직화]삼겹옛날도시락,우삼겹청국장찌개＋대접밥
# 3                                            삼겹정찬도시락
# 4  갈비옛날도시락＋미니냉면＋（서비스）콜라,스팸옛날도시락＋김찌 정식＋（서비스）콜라,부드러...

# %%
for i in range(1, 6):
    num_rating = train[train['별점'] == i].shape[0]
    print(f"별점 {i}점 개수: {num_rating}, {num_rating / train.shape[0] * 100}%")
# Out:
# 별점 1점 개수: 220, 0.5923532579429186%
# 별점 2점 개수: 137, 0.36887452880990845%
# 별점 3점 개수: 385, 1.0366182014001075%
# 별점 4점 개수: 1234, 3.3225632740980076%
# 별점 5점 개수: 35164, 94.67959073774905%

# %% [markdown]
# # 데이터 전처리

# %% [markdown]
# ## 1_특수문자 제거

# %%
review_list = []
for review in train['고객리뷰']:
    if isinstance(review, str):
        pat = re.compile("[^a-zA-Z가-힣0-9.,~?!]")
        result = pat.sub(" ", review)

        result = re.sub(r'\.{2,}', '.', result)
        result = re.sub(r'\,{2,}', ',', result)
        result = re.sub(r'\~{2,}', '~', result)
        result = re.sub(r'\!{2,}', '!', result)
        result = re.sub(r'\?{2,}', '?', result)
        result = re.sub(" +", " ", result)
        review_list.append(result)
    else:
        review_list.append("")

train['고객리뷰'] = review_list
train.head()
# Out:
#                    가게이름                                               고객리뷰  \
# 0  1988응답하라추억의옛날도시락-방이점                          맛있게 잘먹었습니다 묵사발도 시원하니 맛있네요
# 1  1988응답하라추억의옛날도시락-방이점                         기름 있는 부분이 생각보다 많아요! 참고하세요
# 2  1988응답하라추억의옛날도시락-방이점    양도 푸짐하고 맛있습니다! 청국장 냄새 많이 안나고 콩도 많이 들어있어서 좋았습니다!
# 3  1988응답하라추억의옛날도시락-방이점                                                .,.
# 4  1988응답하라추억의옛날도시락-방이점  냉면을 따로 시키고 미니냉면을 합친것인데 양이 좀 적어보이고. 김치정식도 양이 적어...
#
#    별점  맛별점  양별점  배달별점                                               사장댓글  \
# 0   5  5.0  5.0   5.0  즐거운 순간을 저희와 함께해주셔서 감사합니다💖 \n\n보람차게 일할 수 있게 해 주...
# 1   5  5.0  5.0   5.0  소중한 의견 남겨 주셔서 감사합니다. 잘 새겨 듣고 앞으로 더욱 더 개선 할 수 있...
# 2   5  5.0  5.0   5.0  늘 최고의 메뉴를 제공해드리고 싶습니다!😄 \n\n맛있는 메뉴를 넉넉하게 먹을 수 ...
# 3   5  5.0  5.0   5.0  저희 매장과 함께 편안한 시간 되셨을까요? \n\n1. 고객을 생각하는 마음 \n2...
# 4   5  5.0  4.0   5.0  이번 주문을 통해 한걸음 더 가까워진 것 같아 기분이 좋아요!😁\n\n고객님의 행복...
#
#                                                   메뉴
# 0                                        [직화]삼겹옛날도시락
# 1                                   [직화]삼겹옛날도시락,볶음김치
# 2                           [직화]삼겹옛날도시락,우삼겹청국장찌개＋대접밥
# 3                                            삼겹정찬도시락
# 4  갈비옛날도시락＋미니냉면＋（서비스）콜라,스팸옛날도시락＋김찌 정식＋（서비스）콜라,부드러...

# %%
reply_list = []
for reply in train['사장댓글']:
    if isinstance(reply, str):
        pat = re.compile("[^a-zA-Z가-힣0-9.,~?!]")
        result = pat.sub(" ", reply)

        result = re.sub(r'\.{2,}', '.', result)
        result = re.sub(r'\,{2,}', ',', result)
        result = re.sub(r'\~{2,}', '~', result)
        result = re.sub(r'\!{2,}', '!', result)
        result = re.sub(r'\?{2,}', '?', result)
        result = re.sub(" +", " ", result)
        reply_list.append(result)
    else:
        reply_list.append("")

train['사장댓글'] = reply_list
train.head()
# Out:
#                    가게이름                                               고객리뷰  \
# 0  1988응답하라추억의옛날도시락-방이점                          맛있게 잘먹었습니다 묵사발도 시원하니 맛있네요
# 1  1988응답하라추억의옛날도시락-방이점                         기름 있는 부분이 생각보다 많아요! 참고하세요
# 2  1988응답하라추억의옛날도시락-방이점    양도 푸짐하고 맛있습니다! 청국장 냄새 많이 안나고 콩도 많이 들어있어서 좋았습니다!
# 3  1988응답하라추억의옛날도시락-방이점                                                .,.
# 4  1988응답하라추억의옛날도시락-방이점  냉면을 따로 시키고 미니냉면을 합친것인데 양이 좀 적어보이고. 김치정식도 양이 적어...
#
#    별점  맛별점  양별점  배달별점                                               사장댓글  \
# 0   5  5.0  5.0   5.0  즐거운 순간을 저희와 함께해주셔서 감사합니다 보람차게 일할 수 있게 해 주셔서 감사...
# 1   5  5.0  5.0   5.0  소중한 의견 남겨 주셔서 감사합니다. 잘 새겨 듣고 앞으로 더욱 더 개선 할 수 있...
# 2   5  5.0  5.0   5.0  늘 최고의 메뉴를 제공해드리고 싶습니다! 맛있는 메뉴를 넉넉하게 먹을 수 있는 것보...
# 3   5  5.0  5.0   5.0  저희 매장과 함께 편안한 시간 되셨을까요? 1. 고객을 생각하는 마음 2. 더 나은...
# 4   5  5.0  4.0   5.0  이번 주문을 통해 한걸음 더 가까워진 것 같아 기분이 좋아요! 고객님의 행복한 시간...
#
#                                                   메뉴
# 0                                        [직화]삼겹옛날도시락
# 1                                   [직화]삼겹옛날도시락,볶음김치
# 2                           [직화]삼겹옛날도시락,우삼겹청국장찌개＋대접밥
# 3                                            삼겹정찬도시락
# 4  갈비옛날도시락＋미니냉면＋（서비스）콜라,스팸옛날도시락＋김찌 정식＋（서비스）콜라,부드러...

# %% [markdown]
# ##2_고객ID -> 고객님

# %%
train['고객리뷰'] = train['고객리뷰'].astype(str)
train['사장댓글'] = train['사장댓글'].astype(str)

# %%
train['사장댓글'] = train['사장댓글'].str.replace(r'\w+\s* 님', '고객님', regex=True)

# %% [markdown]
# ## 띄어쓰기/맞춤법

# %%
# !pip install git+https://github.com/ssut/py-hanspell.git
# Out:
# Collecting git+https://github.com/ssut/py-hanspell.git
#   Cloning https://github.com/ssut/py-hanspell.git to /tmp/pip-req-build-ogsn_qy1
#   Running command git clone --filter=blob:none --quiet https://github.com/ssut/py-hanspell.git /tmp/pip-req-build-ogsn_qy1
#   Resolved https://github.com/ssut/py-hanspell.git to commit fdc6ca50c19f1c85971437a072d89d4e5ce024b8
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from py-hanspell==1.1) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->py-hanspell==1.1) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->py-hanspell==1.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->py-hanspell==1.1) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->py-hanspell==1.1) (2023.7.22)
# Building wheels for collected packages: py-hanspell
#   Building wheel for py-hanspell (setup.py) ... done
#   Created wheel for py-hanspell: filename=py_hanspell-1.1-py3-none-any.whl size=4813 sha256=369b5290ea33209fbb35083d991a783e5800a9ca94ecae6d73e38967052700c1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hy52o4my/wheels/2e/43/cc/753c9e1d91affb9ea40e186cea5654fb9231deb454da6724e5
# Successfully built py-hanspell
# Installing collected packages: py-hanspell
# Successfully installed py-hanspell-1.1

# %%
from hanspell import spell_checker

def correct_spell(text):
    if isinstance(text, str):  # 입력 데이터가 문자열인 경우에만 맞춤법 검사 수행
        corrected_text = spell_checker.check(text).checked
        return corrected_text
    else:
        return text

# %%
# corrected_review = []
# for review in tqdm(train['고객리뷰']):
#     tmp = correct_spell(review)
#     corrected_review.append(tmp)

# %%
# train["corrected_review"] = corrected_review

# %%
corrected_reply = []
for review in tqdm(train['사장댓글']):
    tmp = correct_spell(review)
    corrected_reply.append(tmp)
# Out:
#   0%|          | 0/37140 [00:00<?, ?it/s]

# %%
train["corrected_reply"] = corrected_reply

# %%
train.head()
# Out:
#                    가게이름                                               고객리뷰  \
# 0  1988응답하라추억의옛날도시락-방이점                          맛있게 잘먹었습니다 묵사발도 시원하니 맛있네요
# 1  1988응답하라추억의옛날도시락-방이점                         기름 있는 부분이 생각보다 많아요! 참고하세요
# 2  1988응답하라추억의옛날도시락-방이점    양도 푸짐하고 맛있습니다! 청국장 냄새 많이 안나고 콩도 많이 들어있어서 좋았습니다!
# 3  1988응답하라추억의옛날도시락-방이점                                                .,.
# 4  1988응답하라추억의옛날도시락-방이점  냉면을 따로 시키고 미니냉면을 합친것인데 양이 좀 적어보이고. 김치정식도 양이 적어...
#
#    별점  맛별점  양별점  배달별점                                               사장댓글  \
# 0   5  5.0  5.0   5.0  즐거운 순간을 저희와 함께해주셔서 감사합니다 보람차게 일할 수 있게 해 주셔서 감사...
# 1   5  5.0  5.0   5.0  소중한 의견 남겨 주셔서 감사합니다. 잘 새겨 듣고 앞으로 더욱 더 개선 할 수 있...
# 2   5  5.0  5.0   5.0  늘 최고의 메뉴를 제공해드리고 싶습니다! 맛있는 메뉴를 넉넉하게 먹을 수 있는 것보...
# 3   5  5.0  5.0   5.0  저희 매장과 함께 편안한 시간 되셨을까요? 1. 고객을 생각하는 마음 2. 더 나은...
# 4   5  5.0  4.0   5.0  이번 주문을 통해 한걸음 더 가까워진 것 같아 기분이 좋아요! 고객님의 행복한 시간...
#
#                                                   메뉴 branch  \
# 0                                        [직화]삼겹옛날도시락
# 1                                   [직화]삼겹옛날도시락,볶음김치
# 2                           [직화]삼겹옛날도시락,우삼겹청국장찌개＋대접밥
# 3                                            삼겹정찬도시락
# 4  갈비옛날도시락＋미니냉면＋（서비스）콜라,스팸옛날도시락＋김찌 정식＋（서비스）콜라,부드러...
#
#                                      corrected_reply
# 0  즐거운 순간을 저희와 함께해 주셔서 감사합니다 보람차게 일할 수 있게 해 주셔서 감...
# 1  소중한 의견 남겨 주셔서 감사합니다. 잘 새겨듣고 앞으로 더욱더 개선할 수 있도록 ...
# 2  늘 최고의 메뉴를 제공해 드리고 싶습니다! 맛있는 메뉴를 넉넉하게 먹을 수 있는 것...
# 3  저희 매장과 함께 편안한 시간 되셨을까요? 1. 고객을 생각하는 마음 2. 더 나은...
# 4  이번 주문을 통해 한걸음 더 가까워진 것 같아 기분이 좋아요! 고객님의 행복한 시간...

# %%
train_df = train[['고객리뷰','corrected_reply']]
train_df.head()
# Out:
#                                                 고객리뷰  \
# 0                          맛있게 잘먹었습니다 묵사발도 시원하니 맛있네요
# 1                         기름 있는 부분이 생각보다 많아요! 참고하세요
# 2    양도 푸짐하고 맛있습니다! 청국장 냄새 많이 안나고 콩도 많이 들어있어서 좋았습니다!
# 3                                                .,.
# 4  냉면을 따로 시키고 미니냉면을 합친것인데 양이 좀 적어보이고. 김치정식도 양이 적어...
#
#                                      corrected_reply
# 0  즐거운 순간을 저희와 함께해 주셔서 감사합니다 보람차게 일할 수 있게 해 주셔서 감...
# 1  소중한 의견 남겨 주셔서 감사합니다. 잘 새겨듣고 앞으로 더욱더 개선할 수 있도록 ...
# 2  늘 최고의 메뉴를 제공해 드리고 싶습니다! 맛있는 메뉴를 넉넉하게 먹을 수 있는 것...
# 3  저희 매장과 함께 편안한 시간 되셨을까요? 1. 고객을 생각하는 마음 2. 더 나은...
# 4  이번 주문을 통해 한걸음 더 가까워진 것 같아 기분이 좋아요! 고객님의 행복한 시간...

# %%
train_df
# Out:
#                                                     고객리뷰  \
# 0                              맛있게 잘먹었습니다 묵사발도 시원하니 맛있네요
# 1                             기름 있는 부분이 생각보다 많아요! 참고하세요
# 2        양도 푸짐하고 맛있습니다! 청국장 냄새 많이 안나고 콩도 많이 들어있어서 좋았습니다!
# 3                                                    .,.
# 4      냉면을 따로 시키고 미니냉면을 합친것인데 양이 좀 적어보이고. 김치정식도 양이 적어...
# ...                                                  ...
# 37135  맛있어요 저번에주문하고 맛있어서또주문핰건데 늦은시간에시켜서그렄지 국물이 엄청 걸쭉하...
# 37136                                         맛있어요 또시킬게요
# 37137                           정말 맛있게 잘먹었어요!자주 시켜 먹을께요!
# 37138  와우. 여기뭐죠 주변에서 맛있다고 먹어보라해서 시켰는데 육수가 일단 시원칼칼하니 조...
# 37139  제발 양파추가 선택란 하나 만들어주세요. 단무지대신 양파달라고 요청써놨지만 바쁠때 ...
#
#                                          corrected_reply store branch food
# 0      즐거운 순간을 저희와 함께해 주셔서 감사합니다 보람차게 일할 수 있게 해 주셔서 감...
# 1      소중한 의견 남겨 주셔서 감사합니다. 잘 새겨듣고 앞으로 더욱더 개선할 수 있도록 ...
# 2      늘 최고의 메뉴를 제공해 드리고 싶습니다! 맛있는 메뉴를 넉넉하게 먹을 수 있는 것...
# 3      저희 매장과 함께 편안한 시간 되셨을까요? 1. 고객을 생각하는 마음 2. 더 나은...
# 4      이번 주문을 통해 한걸음 더 가까워진 것 같아 기분이 좋아요! 고객님의 행복한 시간...
# ...                                                  ...   ...    ...  ...
# 37135  고객님 안녕하세요 짬뽕과입니다~ 소중한 리뷰 너무 감사합니다! 재주문해 주셨는데 국...   짬뽕과          짬뽕
# 37136  고객님 안녕하오 짬뽕과입니다! 소중한 리뷰 남겨주셔 서 정말 달 감사합니다! 만족스...   짬뽕과          짬뽕
# 37137  고객님 안녕하세요 짬뽕과입니다~ 맛있게 드셨다는 말씀에 힘이 나는 거 같습니다 항상...   짬뽕과          짬뽕
# 37138  고객님 안녕하세요 짬뽕과입니다! 맛있게 드셔주시고 정성스러운 사진 리뷰까지 정말 감...   짬뽕과          짬뽕
# 37139  고객님 안녕하세요 우선 소중한 리뷰 감사합니다 배달이 몰리는 시간대여서 실수가 있었...
#
# [37140 rows x 5 columns]

# %% [markdown]
# ##3_가게명 키워드 컬럼화

# %%
store_list = train['가게이름']
store_list = (store_list.str.split('-')).str.get(0)
store_list
# Out:
# 0        1988응답하라추억의옛날도시락
# 1        1988응답하라추억의옛날도시락
# 2        1988응답하라추억의옛날도시락
# 3        1988응답하라추억의옛날도시락
# 4        1988응답하라추억의옛날도시락
#                ...
# 37135                 짬뽕관
# 37136                 짬뽕관
# 37137                 짬뽕관
# 37138                 짬뽕관
# 37139                 짬뽕관
# Name: 가게이름, Length: 37140, dtype: object

# %%
tmp = list(set(store_list.replace("[^가-힣a-zA-Z0-9 ]"," ",regex=True)))
tmp
# Out:
# ['올데이케밥 샐러드',
#  '밈피자',
#  '최가네한쌈',
#  '모모타코야키 카페',
#  '저팔계 중국 마라탕 덮밥 요리 전문점',
#  '피제이피자',
#  '청년치킨',
#  '땡초곱창막창',
#  '이화수육개장',
#  '빅스타피자',
#  'OK반점',
#  '고기혁명',
#  '구구족',
#  '프레드피자',
#  '떡형',
#  '안녕 닭',
#  '미친피자',
#  '누보닭갈비',
#  '코브라독스',
#  '용문',
#  '행복한찜닭',
#  '대찌 대파생고기김치찌개 정육왕국물두루치기',
#  '부성초밥',
#  '비오키친',
#  '스시사소우',
#  '명작파스타',
#  '최고남제육명가',
#  '올데이파스타',
#  '탕화쿵푸 마라탕 가오점',
#  '김포불닭발',
#  '송파만다린',
#  '닭장수섭삼계탕 전기구이통닭',
#  '봉명동내커피',
#  '탐나는피자',
#  '짚신스시',
#  '우리집반찬도시락',
#  '더팔당매운오징어 닭발 김치찜',
#  '본점 장충왕족발보쌈',
#  '자성당',
#  '이태리면가게',
#  '짬뽕관',
#  '1989마라탕',
#  '쇼부덮밥',
#  '피자이탈리',
#  '떡깨비',
#  '삼다수',
#  '홍스족발',
#  '여왕의브런치',
#  '한식세끼1인김치찜 김치찌개',
#  '초밥대통령',
#  '39도시락',
#  '꼬알라파이',
#  '걸작떡볶이',
#  '진지덮밥',
#  '모어댄버터',
#  '미락칼국수',
#  '오늘은 분식',
#  '병천토속순대',
#  '랜돌프뉴욕페페로니',
#  '과일에반하다',
#  '빽다방',
#  '홍싸롱',
#  '배달의쌀국수',
#  '상무초밥',
#  '백소정',
#  '콩샌전북대점',
#  '손수경의육회담은연어',
#  '삽교원조두리곱창',
#  '어시장',
#  '라화방마라탕',
#  '팔도한마당순대',
#  '냉면 숯불고기전문점줄벼락',
#  '큰아들백순대',
#  '짜글이가돼었소',
#  '마라하오',
#  '보돌미역',
#  '더티베지',
#  '맘스터치 대덕테크노벨리점',
#  '마라쿡',
#  '피자프라텔로',
#  '부산오빠1인국밥',
#  '잭아저씨족발보쌈',
#  '수상한삼겹살',
#  '텐텐마라탕',
#  '카페봄봄',
#  '전금례닭볶음탕',
#  '부대찌개자신있는집',
#  '수제죽전문점',
#  '나인곱창',
#  '킹프레소빅와플',
#  '도우라이크피자',
#  '써브웨이',
#  '롱쓰부대찌개',
#  '짱닭치킨',
#  '폴트버거',
#  '띵하오차이',
#  '왕빈자삼파전',
#  '헬로팬닭갈비 마약볶음밥',
#  '국수나무',
#  '홍대개미 ',
#  '천년닭강정',
#  '울진죽변항',
#  '땅끝수산',
#  '감성커피',
#  '피자스웨그',
#  '당치땡',
#  '육회 연어',
#  'GTS버거',
#  '고기잔뜩짜글이찌개 부대찌개',
#  '야키토리 카마쿠라',
#  '고씨네카레',
#  '스시리',
#  '윤희횟집',
#  '놀부보쌈족발',
#  '박가부대',
#  '후스폭립',
#  '수피자',
#  '워커스커피 로스터스',
#  '인생아구찜',
#  '플러스82',
#  '대한냉면',
#  '깨돌이김밥',
#  '마라의신마라탕 마라샹궈',
#  '이배달 마약삼겹떡볶이 상당구점',
#  '무국적식탁',
#  '빕스얌딜리버리',
#  '덮덮밥',
#  '유쾌한꼬막 한끼끝판왕',
#  '이끌림마라탕',
#  '호랑이초밥',
#  '조형훈족발보쌈',
#  '7번가피자',
#  '혼밥대왕',
#  '닭강점',
#  '황궁쟁반짜장',
#  '갈비민족',
#  '도야짬뽕 계림점',
#  '고돼지',
#  '이토우야',
#  '돈까스회관',
#  '직화삼겹직구삼',
#  '춘리마라탕',
#  '창타이누들',
#  '청춘식당묵은지김치찜',
#  '손이가시래기감자탕',
#  '순살만공격',
#  '고기듬뿍미트박스',
#  '1988응답하라추억의옛날도시락',
#  '알촌',
#  '원할머니보쌈',
#  '공주닭발',
#  '구래상회',
#  '뜸들이다',
#  '시민보쌈족발 감자탕',
#  '승도리네곱도리탕',
#  '카산도',
#  '토핑폭탄김치찜 김치찌개',
#  '수락',
#  '우시장국밥',
#  '신자매김치찜 김치찌개',
#  '고기듬뿍대왕비빔밥',
#  '피자보이시나',
#  '인생제육',
#  '놀부 부대찌개']

# %% [markdown]
# - 띄어쓰기 있을 경우 띄어쓰기 없앤 가게명 (ex)놀부부대찌개

# %%
tmp2 = [''.join(store.split()) for store in tmp]
tmp2
# Out:
# ['올데이케밥샐러드',
#  '밈피자',
#  '최가네한쌈',
#  '모모타코야키카페',
#  '저팔계중국마라탕덮밥요리전문점',
#  '피제이피자',
#  '청년치킨',
#  '땡초곱창막창',
#  '이화수육개장',
#  '빅스타피자',
#  'OK반점',
#  '고기혁명',
#  '구구족',
#  '프레드피자',
#  '떡형',
#  '안녕닭',
#  '미친피자',
#  '누보닭갈비',
#  '코브라독스',
#  '용문',
#  '행복한찜닭',
#  '대찌대파생고기김치찌개정육왕국물두루치기',
#  '부성초밥',
#  '비오키친',
#  '스시사소우',
#  '명작파스타',
#  '최고남제육명가',
#  '올데이파스타',
#  '탕화쿵푸마라탕가오점',
#  '김포불닭발',
#  '송파만다린',
#  '닭장수섭삼계탕전기구이통닭',
#  '봉명동내커피',
#  '탐나는피자',
#  '짚신스시',
#  '우리집반찬도시락',
#  '더팔당매운오징어닭발김치찜',
#  '본점장충왕족발보쌈',
#  '자성당',
#  '이태리면가게',
#  '짬뽕관',
#  '1989마라탕',
#  '쇼부덮밥',
#  '피자이탈리',
#  '떡깨비',
#  '삼다수',
#  '홍스족발',
#  '여왕의브런치',
#  '한식세끼1인김치찜김치찌개',
#  '초밥대통령',
#  '39도시락',
#  '꼬알라파이',
#  '걸작떡볶이',
#  '진지덮밥',
#  '모어댄버터',
#  '미락칼국수',
#  '오늘은분식',
#  '병천토속순대',
#  '랜돌프뉴욕페페로니',
#  '과일에반하다',
#  '빽다방',
#  '홍싸롱',
#  '배달의쌀국수',
#  '상무초밥',
#  '백소정',
#  '콩샌전북대점',
#  '손수경의육회담은연어',
#  '삽교원조두리곱창',
#  '어시장',
#  '라화방마라탕',
#  '팔도한마당순대',
#  '냉면숯불고기전문점줄벼락',
#  '큰아들백순대',
#  '짜글이가돼었소',
#  '마라하오',
#  '보돌미역',
#  '더티베지',
#  '맘스터치대덕테크노벨리점',
#  '마라쿡',
#  '피자프라텔로',
#  '부산오빠1인국밥',
#  '잭아저씨족발보쌈',
#  '수상한삼겹살',
#  '텐텐마라탕',
#  '카페봄봄',
#  '전금례닭볶음탕',
#  '부대찌개자신있는집',
#  '수제죽전문점',
#  '나인곱창',
#  '킹프레소빅와플',
#  '도우라이크피자',
#  '써브웨이',
#  '롱쓰부대찌개',
#  '짱닭치킨',
#  '폴트버거',
#  '띵하오차이',
#  '왕빈자삼파전',
#  '헬로팬닭갈비마약볶음밥',
#  '국수나무',
#  '홍대개미',
#  '천년닭강정',
#  '울진죽변항',
#  '땅끝수산',
#  '감성커피',
#  '피자스웨그',
#  '당치땡',
#  '육회연어',
#  'GTS버거',
#  '고기잔뜩짜글이찌개부대찌개',
#  '야키토리카마쿠라',
#  '고씨네카레',
#  '스시리',
#  '윤희횟집',
#  '놀부보쌈족발',
#  '박가부대',
#  '후스폭립',
#  '수피자',
#  '워커스커피로스터스',
#  '인생아구찜',
#  '플러스82',
#  '대한냉면',
#  '깨돌이김밥',
#  '마라의신마라탕마라샹궈',
#  '이배달마약삼겹떡볶이상당구점',
#  '무국적식탁',
#  '빕스얌딜리버리',
#  '덮덮밥',
#  '유쾌한꼬막한끼끝판왕',
#  '이끌림마라탕',
#  '호랑이초밥',
#  '조형훈족발보쌈',
#  '7번가피자',
#  '혼밥대왕',
#  '닭강점',
#  '황궁쟁반짜장',
#  '갈비민족',
#  '도야짬뽕계림점',
#  '고돼지',
#  '이토우야',
#  '돈까스회관',
#  '직화삼겹직구삼',
#  '춘리마라탕',
#  '창타이누들',
#  '청춘식당묵은지김치찜',
#  '손이가시래기감자탕',
#  '순살만공격',
#  '고기듬뿍미트박스',
#  '1988응답하라추억의옛날도시락',
#  '알촌',
#  '원할머니보쌈',
#  '공주닭발',
#  '구래상회',
#  '뜸들이다',
#  '시민보쌈족발감자탕',
#  '승도리네곱도리탕',
#  '카산도',
#  '토핑폭탄김치찜김치찌개',
#  '수락',
#  '우시장국밥',
#  '신자매김치찜김치찌개',
#  '고기듬뿍대왕비빔밥',
#  '피자보이시나',
#  '인생제육',
#  '놀부부대찌개']

# %% [markdown]
# - 띄어쓰기한 가게명

# %%
from hanspell import spell_checker

corrected_store = []
for name in tmp:
    hanspell_sent = spell_checker.check(name)
    corrected_store.append(hanspell_sent.checked)

corrected_store
# Out:
# ['올 데이 케밥 샐러드',
#  '밈이 피자',
#  '최가네 한 쌈',
#  '모모 다코야키 카페',
#  '저팔계 중국 마라탕 덮밥 요리 전문점',
#  '피제이 피자',
#  '청년 치킨',
#  '땡초 곱창 막창',
#  '이화수 육개장',
#  '빅스타 피자',
#  'OK 반점',
#  '고기 혁명',
#  '구구족',
#  '프레드 피자',
#  '떡 형',
#  '안녕 닭',
#  '미친 피자',
#  '누보 닭갈비',
#  '코브라 독습',
#  '용문',
#  '행복한 찜닭',
#  '대치 대파 생고기 김치찌개 정육 왕국 물 두루치기',
#  '부성 초밥',
#  '비 오키친',
#  '스시가 소우',
#  '명작 파스타',
#  '최고 날제육 명가',
#  '올 데이 파스타',
#  '탕화 쿵후 마라탕 가오점',
#  '김포 불 닭발',
#  '송파 만다린',
#  '닭 장수 섭 삼계탕 전기구이 통닭',
#  '봉명동 내 커피',
#  '탐나는 피자',
#  '짚신 스시',
#  '우리 집 반찬도시락',
#  '더 팔당 매운 오징어 닭발 김치찜',
#  '본점 장충 왕족발보쌈',
#  '자 성당',
#  '이태리면 가게',
#  '짬뽕과',
#  '1989마라탕',
#  '승부 덮밥',
#  '피자 이탈리',
#  '떡 깨비',
#  '삼다수',
#  '홍수 족발',
#  '여왕의 브런치',
#  '한식 세 끼 1인 김치찜 김치찌개',
#  '초밥 대통령',
#  '39도시락',
#  '코알라 파이',
#  '걸작 떡볶이',
#  '진지 덮밥',
#  '모어 덴버 터',
#  '미락 칼국수',
#  '오늘은 분식',
#  '병천 토속 순대',
#  '랜돌프 뉴욕 페퍼로니',
#  '과일에 반하다',
#  '빽다방',
#  '홍싸롱',
#  '배달의 쌀국수',
#  '상무 초밥',
#  '백 소장',
#  '콩 샌 전북대점',
#  '손수경의 육회 담은 연어',
#  '삽교 원조 두리 곱창',
#  '어시장',
#  '라화방마라탕',
#  '팔도 한마당 순대',
#  '냉면 숯불고기전문점줄벼락',
#  '큰아들 백순대',
#  '짜 글이가 되었소',
#  '마라하오',
#  '보도로 미역',
#  '더티 베지',
#  '맘스터치 대덕테크노벨리점',
#  '마라 쿡',
#  '피자 프라 텔로',
#  '부산 오빠 1인 국밥',
#  '잭 아저씨 족발보쌈',
#  '수상한 삼겹살',
#  '텐텐 마라탕',
#  '카페 봄봄',
#  '전금례닭볶음탕',
#  '부대찌개 자신 있는 집',
#  '수제 죽 전문점',
#  '나인 곱창',
#  '킹 프레 소빅 와 플',
#  '도우 라이크 피자',
#  '써브웨이',
#  '롱 쓰 부대찌개',
#  '장닭 치킨',
#  '폴트 버거',
#  '띵하오 차이',
#  '왕 빈자 삼파전',
#  '헬로 팬 닭갈비 마약 볶음밥',
#  '국수나무',
#  '홍대 개미 ',
#  '천년 닭강정',
#  '울진 죽변항',
#  '땅끝 수산',
#  '감성 커피',
#  '피자 스웨이',
#  '당치 땡',
#  '육회 연어',
#  'GTS 버거',
#  '고기 잔뜩 짜 글이 찌개 부대찌개',
#  '야키토리 가마쿠라',
#  '고씨네 카레',
#  '스시 리',
#  '윤희 횟집',
#  '놀부보쌈족발',
#  '박가 부대',
#  '후스 폭립',
#  '수비자',
#  '워커스 커피 로프터스',
#  '인생 아귀찜',
#  '플러스 82',
#  '대한 냉면',
#  '깨돌이 김밥',
#  '마라의 신 마라탕 마라샹궈',
#  '이 배달 마약 삼겹 떡볶이 상당구점',
#  '뭇국적 식탁',
#  '빕스얌딜리버리',
#  '덮덮밥',
#  '유쾌한 꼬막 한 끼 끝판왕',
#  '이끌림 마라탕',
#  '호랑이 초밥',
#  '조형 훈 족발보쌈',
#  '7번가 피자',
#  '혼밥 대왕',
#  '닭 강점',
#  '황궁쟁반짜장',
#  '갈비 민족',
#  '도야 짬뽕 계림점',
#  '고 돼지',
#  '이토야',
#  '돈가스 회관',
#  '직화 삼겹 직구 삼',
#  '춘리 마라탕',
#  '창 타이 누들',
#  '청춘 식당 묵은 지 김치찜',
#  '손이 가시에 기 감자탕',
#  '순 살만 공격',
#  '고기 듬뿍 미트 박스',
#  '1988응답하라 추억의 옛날 도시락',
#  '알촌',
#  '원 할머니보쌈',
#  '공주 닭발',
#  '구래 상회',
#  '뜸 들이다',
#  '시민 보쌈족발 감자탕',
#  '승도리네곱도리탕',
#  '카산도',
#  '토핑 폭탄 김치찜 김치찌개',
#  '수락',
#  '우시장 국밥',
#  '신 자매 김치찜 김치찌개',
#  '고기 듬뿍 대왕 비빔밥',
#  '피자 보이 시나',
#  '인생 제육',
#  '놀부 부대찌개']

# %%
short_name = []
for name in store_list:
    for length in [4, 3, 2]:
        cut = name[:length]
        short_name.append(cut)
    if name[0].isdigit(): # 숫자로 시작하면 텍스트가 나오는 부분까지 추출
        cut = name[:6]
        short_name.append(cut)

short_name = [name for name in short_name if not name.isdigit()] # 숫자로만 되어 있는 키워드 삭제
short_name = list(set(short_name))
short_name = sorted(short_name, reverse=True, key=len)
print(len(short_name), short_name)
# Out:
# 448 ['1989마라', '1988응답', '7번가피자', '39도시락', '스시사소', '청년치킨', '우시장국', '코브라독', '탕화쿵푸', '닭장수섭', '과일에반', '도우라이', '승도리네', '쇼부덮밥', '이배달 ', '텐텐마라', '손수경의', '오늘은 ', '이끌림마', '띵하오차', '도야짬뽕', '부대찌개', '39도시', '헬로팬닭', '홍대개미', '손이가시', '돈까스회', '7번가피', '송파만다', '한식세끼', '나인곱창', '써브웨이', '봉명동내', '폴트버거', '인생아구', '모어댄버', '최가네한', '토핑폭탄', '김포불닭', '놀부 부', '부산오빠', '박가부대', '랜돌프뉴', '잭아저씨', '짜글이가', '명작파스', '구래상회', '뜸들이다', '큰아들백', '워커스커', '라화방마', '깨돌이김', '직화삼겹', '춘리마라', '올데이파', '우리집반', '걸작떡볶', '유쾌한꼬', '피자스웨', '홍스족발', '원할머니', '킹프레소', '순살만공', '더팔당매', '보돌미역', '카페봄봄', '짱닭치킨', '국수나무', '땅끝수산', '꼬알라파', '대한냉면', '혼밥대왕', '갈비민족', '행복한찜', '황궁쟁반', '빕스얌딜', '안녕,닭', '병천토속', '맘스터치', '비오키친', '야키토리', '고기잔뜩', '팔도한마', '올데이케', '상무초밥', '놀부보쌈', '여왕의브', '청춘식당', '삽교원조', '마라하오', '플러스8', '피제이피', '수제죽전', '탐나는피', '신자매김', '피자이탈', '프레드피', '모모타코', '이태리면', '울진죽변', '땡초곱창', '창타이누', '이화수육', '피자보이', '이토우야', '저팔계&', '피자프라', '전금례닭', '호랑이초', '공주닭발', '인생제육', 'GTS버', 'OK반점', '고기혁명', '미친피자', '천년닭강', '육회&연', '부성초밥', '초밥대통', '본점 장', '짚신스시', '대찌 대', '조형훈족', '빅스타피', '진지덮밥', '최고남제', '마라의신', '더티베지', '누보닭갈', '왕빈자삼', '감성커피', '콩샌전북', '윤희횟집', '무국적식', '후스폭립', '고기듬뿍', '롱쓰부대', '미락칼국', '냉면&숯', '시민보쌈', '배달의쌀', '고씨네카', '수상한삼', '박가부', '폴트버', '냉면&', 'GTS', '자성당', '김포불', '홍스족', '떡깨비', '걸작떡', '빅스타', '공주닭', '더티베', '나인곱', '무국적', '더팔당', '진지덮', '마라하', '야키토', '당치땡', '이토우', '조형훈', '갈비민', '청춘식', '덮덮밥', '보돌미', '고기혁', '배달의', '모어댄', '혼밥대', '놀부보', '여왕의', '카산도', '대한냉', '밈피자', '콩샌전', '송파만', '랜돌프', '도야짬', '창타이', '비오키', '뜸들이', '초밥대', '미친피', '이끌림', '이태리', '잭아저', '부성초', '신자매', '왕빈자', '본점 ', '대찌 ', '병천토', '국수나', '어시장', '시민보', '짱닭치', '최가네', '짜글이', '롱쓰부', '고씨네', '수제죽', '승도리', '행복한', '유쾌한', '고기듬', '7번가', '깨돌이', '이배달', '수피자', '수상한', '피자프', '닭강점', '올데이', '우리집', '명작파', '인생아', '쇼부덮', '울진죽', '모모타', '춘리마', '오늘은', '플러스', '도우라', '구래상', '누보닭', '이화수', '놀부 ', '킹프레', '미락칼', '황궁쟁', '마라의', '순살만', '피자이', '짬뽕관', '삼다수', '육회&', '천년닭', '우시장', '윤희횟', '원할머', '땅끝수', '고기잔', '안녕,', '후스폭', '마라쿡', '피자보', '헬로팬', '탕화쿵', '닭장수', '부대찌', '탐나는', '짚신스', '라화방', '고돼지', '피자스', '감성커', '써브웨', '워커스', '프레드', '피제이', '봉명동', '구구족', '스시사', '상무초', '손이가', '맘스터', 'OK반', '꼬알라', '손수경', '전금례', '빽다방', '홍싸롱', '백소정', '빕스얌', '부산오', '직화삼', '땡초곱', '저팔계', '삽교원', '청년치', '팔도한', '한식세', '39도', '스시리', '토핑폭', '호랑이', '코브라', '홍대개', '큰아들', '인생제', '띵하오', '카페봄', '텐텐마', '최고남', '과일에', '돈까스', '여왕', '혼밥', '우시', '떡형', '프레', '수제', '구래', '이토', '윤희', '땡초', '띵하', '킹프', '카페', '부산', '손수', '이배', '삼다', '홍싸', '유쾌', '뜸들', '인생', '순살', '육회', '닭장', '보돌', '워커', '라화', '롱쓰', '떡깨', '탐나', '올데', '신자', '알촌', '감성', '손이', '고씨', '토핑', '미친', '짱닭', '짜글', '홍대', '마라', '명작', '초밥', '대한', '황궁', '시민', '팔도', '이화', '밈피', '비오', '한식', '더티', '갈비', '수피', '냉면', '플러', '잭아', '스시', '빅스', '창타', '본점', '천년', '카산', '후스', '도우', '조형', '맘스', '용문', '부대', '국수', '콩샌', '야키', '대찌', '수상', '상무', '승도', '빽다', '쇼부', '텐텐', '짬뽕', '우리', '삽교', '전금', '랜돌', '호랑', '저팔', '오늘', '최고', '돈까', '행복', '빕스', '봉명', '고기', '김포', '도야', 'OK', '이끌', '박가', '병천', '배달', '코브', '깨돌', '진지', '수락', '7번', '써브', '나인', '청년', '안녕', '피자', '어시', '자성', '당치', '짚신', '과일', '미락', '닭강', '부성', '땅끝', '모모', 'GT', '모어', '무국', '공주', '큰아', '폴트', '누보', '왕빈', '직화', '원할', '걸작', '최가', '송파', '춘리', '고돼', '더팔', '구구', '백소', '울진', '꼬알', '탕화', '덮덮', '헬로', '이태', '피제', '청춘', '홍스', '놀부']

# %%
# short_name 에서 가게명 이외 일상용어로 사용되는 키워드는 제거
drop_name = ['오늘은 ', '고기잔뜩', '돈까스회', '부대찌개', '야키토리', '한식세끼', '이태리면', '모어댄버', '손이가시', '부산오빠', '고기듬뿍', '이태리', '손이가', '부산오', '저팔계', '수제죽', '청춘식', '피자이', '수상한', '안녕,', '행복한', '피자보', '탐나는', '오늘은', '짜글이', '이화수', '울진죽', '피자스', '여왕의', '배달의', '플러스', '봉명동', '최가네', '우리집', '과일에', '인생아', '호랑이', '국수나', '미친피', '뜸들이', '이배달', '어시장', '본점 ', '이끌림', '삼다수', '유쾌한', '명작파', '놀부 ', '돈까스', '큰아들', '구구족', '39도', '육회&', '빕스얌', '송파만', '대찌 ', '감성커', '상무초', '시민보', '땅끝수', '올데이', '홍대개', '모어댄', '혼밥대', '손이', '팔도', '명작', 'GT', '모모', '이화', '당치', '수락', '땅끝', '이끌', '청년', '신자', '짬뽕', '상무', '유쾌', '짱닭', '오늘', '더티', '수상', '닭장', '봉명', '부성', '행복', '놀부', '빕스', '누보', '도야', '이태', '왕빈', '미친', '저팔', '청춘', '전금', '박가', '어시', '부대', '토핑', '감성', '순살', '빅스', '고씨', '떡형', '대한', '콩샌', '쇼부', '이배', '대찌', '최가', '자성', '탐나', '플러', '우리', '부산', '진지', '한식', '여왕', '스시', '원할', '승도', 'OK', '더팔', '초밥', '모어', '송파', '카페', '김포', '고돼', '땡초', '시민', '배달', '고기', '홍대', '혼밥', '잭아', '삽교', '병천', '워커', '직화', '큰아', '홍싸', '후스', '도우', '무국', '홍스', '본점', '안녕', '육회', '인생', '냉면', '짚신', '황궁', '울진', '손수', '과일', '피자', '갈비', '조형', '걸작', '공주', '천년', '수제', '나인', '삼다', '써브', '7번', '국수', '헬로', '구구', '야키', '뜸들', '구래', '우시', '최고']
short_name = [col for col in short_name if col not in drop_name]
print(len(short_name), short_name)
# Out:
# 271 ['1989마라', '1988응답', '7번가피자', '39도시락', '스시사소', '청년치킨', '우시장국', '코브라독', '탕화쿵푸', '닭장수섭', '과일에반', '도우라이', '승도리네', '쇼부덮밥', '이배달 ', '텐텐마라', '손수경의', '이끌림마', '띵하오차', '도야짬뽕', '39도시', '헬로팬닭', '홍대개미', '7번가피', '송파만다', '나인곱창', '써브웨이', '봉명동내', '폴트버거', '인생아구', '최가네한', '토핑폭탄', '김포불닭', '놀부 부', '박가부대', '랜돌프뉴', '잭아저씨', '짜글이가', '명작파스', '구래상회', '뜸들이다', '큰아들백', '워커스커', '라화방마', '깨돌이김', '직화삼겹', '춘리마라', '올데이파', '우리집반', '걸작떡볶', '유쾌한꼬', '피자스웨', '홍스족발', '원할머니', '킹프레소', '순살만공', '더팔당매', '보돌미역', '카페봄봄', '짱닭치킨', '국수나무', '땅끝수산', '꼬알라파', '대한냉면', '혼밥대왕', '갈비민족', '행복한찜', '황궁쟁반', '빕스얌딜', '안녕,닭', '병천토속', '맘스터치', '비오키친', '팔도한마', '올데이케', '상무초밥', '놀부보쌈', '여왕의브', '청춘식당', '삽교원조', '마라하오', '플러스8', '피제이피', '수제죽전', '탐나는피', '신자매김', '피자이탈', '프레드피', '모모타코', '울진죽변', '땡초곱창', '창타이누', '이화수육', '피자보이', '이토우야', '저팔계&', '피자프라', '전금례닭', '호랑이초', '공주닭발', '인생제육', 'GTS버', 'OK반점', '고기혁명', '미친피자', '천년닭강', '육회&연', '부성초밥', '초밥대통', '본점 장', '짚신스시', '대찌 대', '조형훈족', '빅스타피', '진지덮밥', '최고남제', '마라의신', '더티베지', '누보닭갈', '왕빈자삼', '감성커피', '콩샌전북', '윤희횟집', '무국적식', '후스폭립', '롱쓰부대', '미락칼국', '냉면&숯', '시민보쌈', '배달의쌀', '고씨네카', '수상한삼', '박가부', '폴트버', '냉면&', 'GTS', '자성당', '김포불', '홍스족', '떡깨비', '걸작떡', '빅스타', '공주닭', '더티베', '나인곱', '무국적', '더팔당', '진지덮', '마라하', '야키토', '당치땡', '이토우', '조형훈', '갈비민', '덮덮밥', '보돌미', '고기혁', '놀부보', '카산도', '대한냉', '밈피자', '콩샌전', '랜돌프', '도야짬', '창타이', '비오키', '초밥대', '잭아저', '부성초', '신자매', '왕빈자', '병천토', '짱닭치', '롱쓰부', '고씨네', '승도리', '고기듬', '7번가', '깨돌이', '수피자', '피자프', '닭강점', '쇼부덮', '모모타', '춘리마', '도우라', '구래상', '누보닭', '킹프레', '미락칼', '황궁쟁', '마라의', '순살만', '짬뽕관', '천년닭', '우시장', '윤희횟', '원할머', '고기잔', '후스폭', '마라쿡', '헬로팬', '탕화쿵', '닭장수', '부대찌', '짚신스', '라화방', '고돼지', '써브웨', '워커스', '프레드', '피제이', '스시사', '맘스터', 'OK반', '꼬알라', '손수경', '전금례', '빽다방', '홍싸롱', '백소정', '직화삼', '땡초곱', '삽교원', '청년치', '팔도한', '한식세', '스시리', '토핑폭', '코브라', '인생제', '띵하오', '카페봄', '텐텐마', '최고남', '프레', '이토', '윤희', '띵하', '킹프', '보돌', '라화', '롱쓰', '떡깨', '올데', '알촌', '짜글', '마라', '밈피', '비오', '수피', '창타', '카산', '맘스', '용문', '빽다', '텐텐', '랜돌', '호랑', '돈까', '코브', '깨돌', '미락', '닭강', '폴트', '춘리', '백소', '꼬알', '탕화', '덮덮', '피제']

# %% [markdown]
# - 띄어쓰기 기준으로 음식점 이름 쪼개보기

# %%
short_name2 = []
for store in corrected_store:
    tmp = store.split(' ')
    short_name2.extend(tmp)

short_name2 = list(set(short_name2)) # 중복 제거

# %%
len(short_name2)
# Out:
# 332

# %% [markdown]
# - 쪼개진 short_name 확인해서 음식점 이름으로 쓰일만한 것 남기기

# %%
short_name2 = ['두리',
 '구구족',
 '랜돌프',
 '글이가',
 '팔당',
 '부성',
 '빈자',
 '베지',
 '시나',
 '알촌',
 '승도리네곱도리탕',
 '스웨이',
 '삼파전',
 '홍싸롱',
 '프레드',
 '빕스얌딜리버리',
 '피제이',
 '깨돌이',
 '소빅',
 '이토야',
 '춘리',
 '프라',
 '삽교',
 'GTS',
 '윤희',
 '1989마라탕',
 '써브웨이',
 '날제육',
 '냉면숯불고기전문점줄벼락',
 '탕화',
 '미락',
 '덮덮밥',
 '살만',
 '소우',
 '스시가',
 '폴트',
 '프레',
 '마라의신마라탕마라샹궈',
 '마라하오',
 '이태리면',
 '백순대',
 '이화수',
 '후스',
 '황궁쟁반짜장',
 '국수나무',
 '카산도',
 '박가',
 '덴버',
 '텔로',
 '고씨네',
 '우시장',
 '할머니보쌈',
 '독습',
 '오키친',
 '도야',
 '39도시락',
 '빽다방',
 '보도로',
 '라화방마라탕',
 '수비자',
 '뭇국적',
 '빅스타',
 '라이크',
 '죽변항',
 '손수경의',
 '용문',
 '깨비',
 '텐텐',
 '띵하오',
 '당치',
 '놀부보쌈족발',
 '1988응답하라',
 '최가네',
 '조형',
 '만다린',
 '7번가',
 '봄봄',
 '전금례닭볶음탕',
 '밈이',
 '쿵후',
 '누보',
 '글이',
 '워커스']

# %%
store = tmp + corrected_store + tmp2 + short_name + short_name2

# %%
store_list = list(set(store))
store_list
# Out:
# ['스시사소',
#  '박가부',
#  '폴트버',
#  '냉면&',
#  '청년치킨',
#  '코브라 독습',
#  '우시장국',
#  '스시가',
#  '땅끝 수산',
#  'GTS',
#  '이끌림 마라탕',
#  '코브라독',
#  '탕화쿵푸',
#  '떡형',
#  '닭장수섭',
#  '더팔당매운오징어닭발김치찜',
#  '프레',
#  '백순대',
#  '나인 곱창',
#  '과일에반',
#  '본점장충왕족발보쌈',
#  '박가 부대',
#  '워커스커피로스터스',
#  '이토',
#  '봉명동내커피',
#  '탐나는피자',
#  '헬로팬닭갈비마약볶음밥',
#  '냉면숯불고기전문점줄벼락',
#  '자성당',
#  '도우라이',
#  '김포불',
#  '윤희',
#  '승도리네',
#  '맘스터치대덕테크노벨리점',
#  '쇼부덮밥',
#  '홍스족',
#  '두리',
#  '프레드 피자',
#  '이배달 ',
#  '텐텐마라',
#  '떡깨비',
#  '삽교 원조 두리 곱창',
#  '띵하',
#  '걸작떡',
#  '큰아들 백순대',
#  '시민 보쌈족발 감자탕',
#  '손수경의',
#  '킹프',
#  '백 소장',
#  '스시 리',
#  '플러스 82',
#  '모어댄버터',
#  '랜돌프뉴욕페페로니',
#  '이끌림마',
#  '띵하오차',
#  '빅스타',
#  '도야짬뽕',
#  '부대찌개',
#  '39도시',
#  '헬로팬닭',
#  '홍대개미',
#  '공주닭',
#  '팔도한마당순대',
#  '7번가피',
#  '더티베',
#  '나인곱',
#  '고씨네 카레',
#  '송파만다',
#  '무국적',
#  '더팔당',
#  '날제육',
#  '수상한삼겹살',
#  '텐텐마라탕',
#  '배달의 쌀국수',
#  '수제죽전문점',
#  '누보 닭갈비',
#  '나인곱창',
#  '킹프레소빅와플',
#  '조형 훈 족발보쌈',
#  '써브웨이',
#  '도우라이크피자',
#  '롱쓰부대찌개',
#  '봉명동내',
#  '폴트버거',
#  '띵하오차이',
#  '수비자',
#  '인생아구',
#  '대한 냉면',
#  '진지덮',
#  '닭 장수 섭 삼계탕 전기구이 통닭',
#  '마라하',
#  '승부 덮밥',
#  '구래 상회',
#  '상무 초밥',
#  '피자스웨그',
#  '야키토',
#  '당치땡',
#  '이토우',
#  '최가네한',
#  '토핑폭탄',
#  '부대찌개 자신 있는 집',
#  '김포불닭',
#  '놀부 부',
#  '킹 프레 소빅 와 플',
#  '고기 혁명',
#  '피자 보이 시나',
#  '박가부대',
#  '랜돌프뉴',
#  '보돌',
#  '인생아구찜',
#  '부산 오빠 1인 국밥',
#  '잭아저씨',
#  '플러스82',
#  '탕화쿵푸마라탕가오점',
#  '조형훈',
#  '인생 아귀찜',
#  '갈비민',
#  '라화',
#  '덮덮밥',
#  '짜글이가',
#  '모모타코야키카페',
#  '롱쓰',
#  '명작파스',
#  '보돌미',
#  '독습',
#  '고기혁',
#  '최가네 한 쌈',
#  '모어 덴버 터',
#  '이배달마약삼겹떡볶이상당구점',
#  '떡깨',
#  '밈이 피자',
#  '베지',
#  '울진 죽변항',
#  '청춘식당묵은지김치찜',
#  '김포 불 닭발',
#  '손이가시래기감자탕',
#  '올데',
#  '고기듬뿍미트박스',
#  '알촌',
#  '토핑폭탄김치찜김치찌개',
#  '놀부보',
#  '구래상회',
#  '뜸들이다',
#  '큰아들백',
#  '승도리네곱도리탕',
#  '카산도',
#  '워커스커',
#  '라화방마',
#  '당치 땡',
#  '삼파전',
#  '조형훈족발보쌈',
#  '살만',
#  '놀부 부대찌개',
#  '대한냉',
#  '인생 제육',
#  '밈피자',
#  '저팔계 중국 마라탕 덮밥 요리 전문점',
#  '콩샌전',
#  '땡초곱창막창',
#  '피자 이탈리',
#  '깨돌이김',
#  '미락 칼국수',
#  '직화삼겹',
#  '프레드피자',
#  '안녕 닭',
#  '할머니보쌈',
#  '춘리마라',
#  '누보닭갈비',
#  '신자매김치찜김치찌개',
#  '소빅',
#  '초밥 대통령',
#  '올데이파',
#  '랜돌프',
#  '빈자',
#  '봉명동 내 커피',
#  '올 데이 파스타',
#  '명작파스타',
#  '최고남제육명가',
#  '올데이파스타',
#  '도야짬',
#  '창타이',
#  '비오키',
#  '우리집반',
#  '짜 글이가 되었소',
#  '걸작떡볶',
#  '마라 쿡',
#  '초밥대',
#  '시나',
#  '행복한 찜닭',
#  '오키친',
#  '이태리면가게',
#  '안녕닭',
#  '1989마라탕',
#  '유쾌한꼬',
#  '수제 죽 전문점',
#  '팔도 한마당 순대',
#  '피자스웨',
#  '잭아저',
#  '홍스족발',
#  '여왕의브런치',
#  '이태리면 가게',
#  '초밥대통령',
#  '부성초',
#  '탐나는 피자',
#  '신자매',
#  '짜글',
#  '왕빈자',
#  '마라',
#  '오늘은 분식',
#  '병천토속순대',
#  '과일에반하다',
#  '원할머니',
#  '모모 다코야키 카페',
#  '배달의쌀국수',
#  '비 오키친',
#  '병천토',
#  '갈비 민족',
#  '떡 형',
#  '콩 샌 전북대점',
#  '킹프레소',
#  '순살만공',
#  '어시장',
#  '짱닭치',
#  '더팔당매',
#  '탕화 쿵후 마라탕 가오점',
#  '보돌미역',
#  '직화 삼겹 직구 삼',
#  '맘스터치 대덕테크노벨리점',
#  '혼밥 대왕',
#  '호랑이 초밥',
#  '잭아저씨족발보쌈',
#  '카페봄봄',
#  '전금례닭볶음탕',
#  '짱닭치킨',
#  '최가네',
#  '롱쓰부',
#  'GTS 버거',
#  '고 돼지',
#  '고씨네',
#  '국수나무',
#  '천년닭강정',
#  '오늘은분식',
#  '글이가',
#  '땅끝수산',
#  '승도리',
#  '한식 세 끼 1인 김치찜 김치찌개',
#  '밈피',
#  '꼬알라파',
#  '비오',
#  '카페 봄봄',
#  '죽변항',
#  '신 자매 김치찜 김치찌개',
#  '고기듬',
#  '고씨네카레',
#  '놀부보쌈족발',
#  '7번가',
#  '깨돌이',
#  '수피자',
#  '수피',
#  '대치 대파 생고기 김치찌개 정육 왕국 물 두루치기',
#  '홍수 족발',
#  '대한냉면',
#  '땡초 곱창 막창',
#  '빕스얌딜리버리',
#  '무국적식탁',
#  '대찌대파생고기김치찌개정육왕국물두루치기',
#  '피자프',
#  '7번가피자',
#  '혼밥대왕',
#  '닭강점',
#  '1988응답하라 추억의 옛날 도시락',
#  '도야짬뽕계림점',
#  '갈비민족',
#  '돈까스회관',
#  '창타',
#  '행복한찜',
#  '닭 강점',
#  '춘리마라탕',
#  '순살만공격',
#  '피자 스웨이',
#  '1988응답하라추억의옛날도시락',
#  '황궁쟁반',
#  '원할머니보쌈',
#  '팔당',
#  '소우',
#  '피자보이시나',
#  '빕스얌딜',
#  '안녕,닭',
#  '쇼부덮',
#  '뜸 들이다',
#  '우시장 국밥',
#  '모모타',
#  '춘리마',
#  '이화수 육개장',
#  '장닭 치킨',
#  '폴트 버거',
#  '병천토속',
#  '카산',
#  '후스 폭립',
#  '이화수육개장',
#  '후스',
#  '도우라',
#  '구래상',
#  '누보닭',
#  '조형',
#  '이화수',
#  '맘스터치',
#  '맘스',
#  '마라의 신 마라탕 마라샹궈',
#  '용문',
#  '킹프레',
#  '이 배달 마약 삼겹 떡볶이 상당구점',
#  '비오키친',
#  '미락칼',
#  '천년 닭강정',
#  '황궁쟁',
#  '마라의',
#  '여왕의 브런치',
#  '송파만다린',
#  '순살만',
#  '짬뽕관',
#  '뭇국적',
#  '피자이탈리',
#  '삼다수',
#  '본점 장충 왕족발보쌈',
#  '39도시락',
#  '부성 초밥',
#  '순 살만 공격',
#  '라이크',
#  '꼬알라파이',
#  '팔도한마',
#  '천년닭',
#  '걸작떡볶이',
#  '우시장',
#  '올데이케',
#  '육회연어',
#  '윤희횟',
#  '원할머',
#  '상무초밥',
#  '덴버',
#  '놀부보쌈',
#  '고기잔뜩짜글이찌개부대찌개',
#  '헬로 팬 닭갈비 마약 볶음밥',
#  '고기잔',
#  '삽교원조두리곱창',
#  '여왕의브',
#  '청춘식당',
#  '빽다',
#  '삽교원조',
#  '라화방마라탕',
#  '뭇국적 식탁',
#  '텐텐',
#  '청춘 식당 묵은 지 김치찜',
#  '1989마라',
#  '우리 집 반찬도시락',
#  '마라하오',
#  '짜글이가돼었소',
#  '플러스8',
#  '피제이피',
#  '후스폭',
#  '삽교',
#  '수제죽전',
#  '탐나는피',
#  '마라쿡',
#  '워커스 커피 로프터스',
#  '신자매김',
#  '랜돌',
#  '피자프라텔로',
#  '호랑',
#  '헬로팬',
#  '부대찌개자신있는집',
#  '피자이탈',
#  '1988응답',
#  '프레드피',
#  '창 타이 누들',
#  '돈까',
#  '수상한 삼겹살',
#  '잭 아저씨 족발보쌈',
#  '모모타코',
#  '탕화쿵',
#  '올데이케밥샐러드',
#  '이태리면',
#  '닭장수',
#  '울진죽변항',
#  '닭장수섭삼계탕전기구이통닭',
#  'GTS버거',
#  '도야',
#  '야키토리카마쿠라',
#  '부대찌',
#  '토핑 폭탄 김치찜 김치찌개',
#  '코알라 파이',
#  '울진죽변',
#  '땡초곱창',
#  '박가',
#  '짬뽕과',
#  '올 데이 케밥 샐러드',
#  '띵하오 차이',
#  '피제이 피자',
#  '깨돌이김밥',
#  '짚신 스시',
#  '고기 듬뿍 대왕 비빔밥',
#  '창타이누',
#  '짚신스',
#  '호랑이초밥',
#  '라화방',
#  '코브',
#  '스웨이',
#  '만다린',
#  '이화수육',
#  '더 팔당 매운 오징어 닭발 김치찜',
#  '텐텐 마라탕',
#  '피자보이',
#  '돈가스 회관',
#  '쿵후',
#  '고돼지',
#  '깨돌',
#  '이토우야',
#  '저팔계&',
#  '피자프라',
#  '써브웨',
#  '워커스',
#  '직화삼겹직구삼',
#  '글이',
#  '전금례닭',
#  '프레드',
#  '미친 피자',
#  '호랑이초',
#  '공주닭발',
#  '수락',
#  '피제이',
#  '감성 커피',
#  '인생제육',
#  '최가네한쌈',
#  'GTS버',
#  '피제이피자',
#  '고기 잔뜩 짜 글이 찌개 부대찌개',
#  '텔로',
#  '빅스타피자',
#  'OK반점',
#  '고기혁명',
#  '구구족',
#  '도야 짬뽕 계림점',
#  '깨비',
#  '미친피자',
#  '코브라독스',
#  '천년닭강',
#  '스시사',
#  '행복한찜닭',
#  '부성초밥',
#  '육회&연',
#  '당치',
#  '밈이',
#  '스시사소우',
#  '왕 빈자 삼파전',
#  '초밥대통',
#  '김포불닭발',
#  '미락',
#  '닭강',
#  '본점 장',
#  '짚신스시',
#  '우리집반찬도시락',
#  '고기 듬뿍 미트 박스',
#  '대찌 대',
#  '부성',
#  '맘스터',
#  '조형훈족',
#  '청년 치킨',
#  'OK반',
#  '손이 가시에 기 감자탕',
#  '빅스타피',
#  '보도로 미역',
#  '꼬알라',
#  '홍대 개미 ',
#  '진지덮밥',
#  '미락칼국수',
#  '손수경',
#  '걸작 떡볶이',
#  '전금례',
#  '빽다방',
#  '홍싸롱',
#  '백소정',
#  '콩샌전북대점',
#  '손수경의육회담은연어',
#  '깨돌이 김밥',
#  '폴트',
#  '누보',
#  '롱 쓰 부대찌개',
#  '과일에 반하다',
#  '냉면 숯불고기전문점줄벼락',
#  '최고남제',
#  '직화삼',
#  '떡 깨비',
#  '마라의신',
#  '큰아들백순대',
#  '더티베지',
#  '누보닭갈',
#  '윤희 횟집',
#  '왕빈자삼',
#  '땡초곱',
#  '손수경의 육회 담은 연어',
#  '유쾌한 꼬막 한 끼 끝판왕',
#  '이토야',
#  '송파 만다린',
#  '춘리',
#  '부산오빠1인국밥',
#  '원 할머니보쌈',
#  '명작 파스타',
#  '삽교원',
#  '왕빈자삼파전',
#  '진지 덮밥',
#  '청년치',
#  '춘리 마라탕',
#  '놀부부대찌개',
#  '7번가 피자',
#  '팔도한',
#  '감성커피',
#  '유쾌한꼬막한끼끝판왕',
#  '백소',
#  '육회 연어',
#  '한식세',
#  '콩샌전북',
#  '야키토리 가마쿠라',
#  '스시리',
#  '꼬알',
#  '윤희횟집',
#  '무국적식',
#  '마라의신마라탕마라샹궈',
#  '토핑폭',
#  '스시가 소우',
#  '피자 프라 텔로',
#  '후스폭립',
#  '탕화',
#  '저팔계중국마라탕덮밥요리전문점',
#  '보도로',
#  '롱쓰부대',
#  '미락칼국',
#  '코브라',
#  '덮덮',
#  '수상한삼',
#  '병천 토속 순대',
#  '인생제',
#  '이끌림마라탕',
#  '냉면&숯',
#  '피제',
#  '더티 베지',
#  '봄봄',
#  '빅스타 피자',
#  '시민보쌈',
#  'OK 반점',
#  '황궁쟁반짜장',
#  '프라',
#  '띵하오',
#  '시민보쌈족발감자탕',
#  '최고 날제육 명가',
#  '카페봄',
#  '도우 라이크 피자',
#  '1988응답하라',
#  '창타이누들',
#  '배달의쌀',
#  '텐텐마',
#  '공주 닭발',
#  '최고남',
#  '한식세끼1인김치찜김치찌개',
#  '랜돌프 뉴욕 페퍼로니',
#  '자 성당',
#  '고씨네카',
#  '우시장국밥',
#  '고기듬뿍대왕비빔밥',
#  '놀부']

# %% [markdown]
# - 빠진 음식점 이름 추가하기

# %%
store_add = ['당신은 지금 치킨이 땡긴다','당신은 지금 치킨이 당긴다','마라 하오','빕스 얌 딜리버리','한식 끼','헬로팬','라화방','미.친피자','밈 피자','부자집','안녕닭','토핑폭탄','카마쿠라','땡초곱창','이배달','프루타','시민족발보쌈','조형훈의족발보쌈도시락','잭아저씨 족발보쌈','프라 텔로','홍스','도우 라이크']

# %%
store_list.extend(store_add)

# %%
train_df['store'] = train_df['corrected_reply'].apply(lambda x: next((store for store in store_list if store in x), " "))

# %%
train_df.head()
# Out:
#                                                 고객리뷰  \
# 0                          맛있게 잘먹었습니다 묵사발도 시원하니 맛있네요
# 1                         기름 있는 부분이 생각보다 많아요! 참고하세요
# 2    양도 푸짐하고 맛있습니다! 청국장 냄새 많이 안나고 콩도 많이 들어있어서 좋았습니다!
# 3                                                .,.
# 4  냉면을 따로 시키고 미니냉면을 합친것인데 양이 좀 적어보이고. 김치정식도 양이 적어...
#
#                                      corrected_reply store
# 0  즐거운 순간을 저희와 함께해 주셔서 감사합니다 보람차게 일할 수 있게 해 주셔서 감...
# 1  소중한 의견 남겨 주셔서 감사합니다. 잘 새겨듣고 앞으로 더욱더 개선할 수 있도록 ...
# 2  늘 최고의 메뉴를 제공해 드리고 싶습니다! 맛있는 메뉴를 넉넉하게 먹을 수 있는 것...
# 3  저희 매장과 함께 편안한 시간 되셨을까요? 1. 고객을 생각하는 마음 2. 더 나은...
# 4  이번 주문을 통해 한걸음 더 가까워진 것 같아 기분이 좋아요! 고객님의 행복한 시간...

# %% [markdown]
# ##4_지점명 키워드 컬럼화

# %%
store_list = train['가게이름']
branch_arr = (store_list.str.split('-| ')).str.get(1).unique()
branch_arr
# Out:
# array(['방이점', '로스터스', '가락점', '헬리오시티점', '석촌점', '송파점', nan, '삼전점', '본점',
#        '미아본점', '성신여대역점', '대학로점', '성북점', '동대문구점', '북서울꿈의숲점', '김치찜',
#        '혜화막내딸지점', '대파생고기김치찌개&정육왕국물두루치기', '부천점', '부평점', '부천부평점', '본가진죽',
#        '분식', '신중동점', '부천시청점', '도촌점', '야탑점', '판교점', '수제돈까스&파스타', '정자본점',
#        '미금본점', '미금점', '분당정자점', '분당미금역점', '죽전점', '용인수지점', '카마쿠라', '서현본점',
#        '분당점', '', '용암점', '마약삼겹떡볶이', '대전4호점', '신탄진점', '신일점', '목동충촌점',
#        '대전동구점', '우송대점', '대전역점', '대흥문창점', '서대전점', '유성봉명점', '장충왕족발보쌈', '대전',
#        '대덕테크노벨리점', '대전전민점', '마라탕', '대전한남대점', '충남대점', '유성점', '광주백운점',
#        '계림점', '조대점', '광주본점', '광주광천점', '북구(전대)점', '광주직영점', '부대찌개', '전주평화점',
#        '객사점', '전주1호점', '전주금암점'], dtype=object)

# %%
branch_lst = [item for item in branch_arr if isinstance(item, str) and item.endswith('점')]
branch_lst
# Out:
# ['방이점',
#  '가락점',
#  '헬리오시티점',
#  '석촌점',
#  '송파점',
#  '삼전점',
#  '본점',
#  '미아본점',
#  '성신여대역점',
#  '대학로점',
#  '성북점',
#  '동대문구점',
#  '북서울꿈의숲점',
#  '혜화막내딸지점',
#  '부천점',
#  '부평점',
#  '부천부평점',
#  '신중동점',
#  '부천시청점',
#  '도촌점',
#  '야탑점',
#  '판교점',
#  '정자본점',
#  '미금본점',
#  '미금점',
#  '분당정자점',
#  '분당미금역점',
#  '죽전점',
#  '용인수지점',
#  '서현본점',
#  '분당점',
#  '용암점',
#  '대전4호점',
#  '신탄진점',
#  '신일점',
#  '목동충촌점',
#  '대전동구점',
#  '우송대점',
#  '대전역점',
#  '대흥문창점',
#  '서대전점',
#  '유성봉명점',
#  '대덕테크노벨리점',
#  '대전전민점',
#  '대전한남대점',
#  '충남대점',
#  '유성점',
#  '광주백운점',
#  '계림점',
#  '조대점',
#  '광주본점',
#  '광주광천점',
#  '북구(전대)점',
#  '광주직영점',
#  '전주평화점',
#  '객사점',
#  '전주1호점',
#  '전주금암점']

# %% [markdown]
# - 지점명에 띄어쓰기가 있을 경우

# %%
branch_space = []
for name in branch_lst:
    hanspell_sent = spell_checker.check(name)
    branch_space.append(hanspell_sent.checked)

branch_space
# Out:
# ['방이점',
#  '가락점',
#  '헬리오 시티점',
#  '석촌점',
#  '송파점',
#  '삼전점',
#  '본점',
#  '미아 본점',
#  '성신여대역점',
#  '대학로점',
#  '성북점',
#  '동대문구점',
#  '북서울꿈의 숲점',
#  '혜화 막내딸 지점',
#  '부천점',
#  '부평점',
#  '부천 부평점',
#  '신중동점',
#  '부천 시청점',
#  '도촌점',
#  '야탑점',
#  '판교점',
#  '정자본점',
#  '미금 본점',
#  '미금점',
#  '분당 정자점',
#  '분당 미금역점',
#  '죽전점',
#  '용인 수지점',
#  '서현 본점',
#  '분당점',
#  '용암점',
#  '대전 4호점',
#  '신탄진점',
#  '신일점',
#  '목동충촌점',
#  '대전 동구점',
#  '우송대점',
#  '대전역점',
#  '대흥 문창점',
#  '서대전점',
#  '유성 봉명점',
#  '대덕테크노벨리점',
#  '대전 전민점',
#  '대전 한남대점',
#  '충남대점',
#  '유성점',
#  '광주백운점',
#  '계림점',
#  '조대점',
#  '광주 본점',
#  '광주 광천점',
#  '북구(전대) 점',
#  '광주 직영점',
#  '전주 평화점',
#  '객사점',
#  '전주 1호점',
#  '전주 금암점']

# %% [markdown]
# - 띄어쓰기 적용한 가게명 중 '점' 찾기 (ex- 콩 샌 전북대점)

# %%
branch = []
for i in corrected_store:
    if i.endswith('점'):
        branch.append(i)
branch
# Out:
# ['저팔계 중국 마라탕 덮밥 요리 전문점',
#  '콩 샌 전북대점',
#  '맘스터치 대덕테크노벨리점',
#  'OK 반점',
#  '이 배달 마약 삼겹 떡볶이 상당구점',
#  '수제 죽 전문점',
#  '탕화 쿵후 마라탕 가오점',
#  '닭 강점',
#  '도야 짬뽕 계림점']

# %%
branch_list = branch_lst + branch_space

# %% [markdown]
# - 지점명 추가

# %%
branch_add = ['전북대점','관평점','부천대점']

# %%
branch_list.extend(branch_add)

# %%
branch_list = list(set(branch_list)) # 중복 제거
branch_list
# Out:
# ['대흥 문창점',
#  '광주 직영점',
#  '전주1호점',
#  '혜화막내딸지점',
#  '북구(전대) 점',
#  '삼전점',
#  '분당 미금역점',
#  '헬리오시티점',
#  '성신여대역점',
#  '석촌점',
#  '부평점',
#  '송파점',
#  '용암점',
#  '미금 본점',
#  '대흥문창점',
#  '대전한남대점',
#  '계림점',
#  '부천 시청점',
#  '미아본점',
#  '성북점',
#  '도촌점',
#  '판교점',
#  '전주금암점',
#  '대전4호점',
#  '서현 본점',
#  '전주 평화점',
#  '정자본점',
#  '분당 정자점',
#  '관평점',
#  '대학로점',
#  '신탄진점',
#  '헬리오 시티점',
#  '방이점',
#  '신중동점',
#  '부천점',
#  '우송대점',
#  '대전전민점',
#  '광주직영점',
#  '죽전점',
#  '전주평화점',
#  '유성 봉명점',
#  '북구(전대)점',
#  '유성봉명점',
#  '미아 본점',
#  '전북대점',
#  '광주백운점',
#  '대덕테크노벨리점',
#  '신일점',
#  '유성점',
#  '미금점',
#  '용인 수지점',
#  '목동충촌점',
#  '북서울꿈의숲점',
#  '객사점',
#  '부천 부평점',
#  '전주 1호점',
#  '대전 전민점',
#  '동대문구점',
#  '조대점',
#  '광주 본점',
#  '미금본점',
#  '대전동구점',
#  '분당미금역점',
#  '혜화 막내딸 지점',
#  '분당정자점',
#  '광주 광천점',
#  '광주본점',
#  '서현본점',
#  '대전 동구점',
#  '광주광천점',
#  '서대전점',
#  '부천시청점',
#  '대전역점',
#  '대전 한남대점',
#  '용인수지점',
#  '부천부평점',
#  '충남대점',
#  '가락점',
#  '분당점',
#  '부천대점',
#  '전주 금암점',
#  '대전 4호점',
#  '본점',
#  '야탑점',
#  '북서울꿈의 숲점']

# %%
train_df['branch'] = train_df['corrected_reply'].apply(lambda x: next((branch for branch in branch_list if branch in x), " "))
train_df['branch']
# Out:
# 0
# 1
# 2
# 3
# 4
#         ..
# 37135
# 37136
# 37137
# 37138
# 37139
# Name: branch, Length: 37140, dtype: object

# %%
train_df.head()
# Out:
#                                                 고객리뷰  \
# 0                          맛있게 잘먹었습니다 묵사발도 시원하니 맛있네요
# 1                         기름 있는 부분이 생각보다 많아요! 참고하세요
# 2    양도 푸짐하고 맛있습니다! 청국장 냄새 많이 안나고 콩도 많이 들어있어서 좋았습니다!
# 3                                                .,.
# 4  냉면을 따로 시키고 미니냉면을 합친것인데 양이 좀 적어보이고. 김치정식도 양이 적어...
#
#                                      corrected_reply store branch
# 0  즐거운 순간을 저희와 함께해 주셔서 감사합니다 보람차게 일할 수 있게 해 주셔서 감...
# 1  소중한 의견 남겨 주셔서 감사합니다. 잘 새겨듣고 앞으로 더욱더 개선할 수 있도록 ...
# 2  늘 최고의 메뉴를 제공해 드리고 싶습니다! 맛있는 메뉴를 넉넉하게 먹을 수 있는 것...
# 3  저희 매장과 함께 편안한 시간 되셨을까요? 1. 고객을 생각하는 마음 2. 더 나은...
# 4  이번 주문을 통해 한걸음 더 가까워진 것 같아 기분이 좋아요! 고객님의 행복한 시간...

# %% [markdown]
# ##5_음식 키워드 컬럼화

# %%
food_list = pd.read_csv(f"{DATA_PATH}food.csv").drop_duplicates(ignore_index = True)["대표식품명"]
food_list
# Out:
# 0          케이크
# 1          치즈빵
# 2         카스텔라
# 3          츄러스
# 4         치아바타
#         ...
# 753      햄채소볶음
# 754    무생채(무만)
# 755     참나물겉절이
# 756     치커리겉절이
# 757       짜장소스
# Name: 대표식품명, Length: 758, dtype: object

# %%
food_lst = []
for food in food_list:
    parts = re.split('/|-|\(', food)
    food_lst.append(parts[0])

# %%
food_lst
# Out:
# ['케이크',
#  '치즈빵',
#  '카스텔라',
#  '츄러스',
#  '치아바타',
#  '와플',
#  '찰떡빵',
#  '김밥',
#  '덮밥',
#  '보리밥',
#  '볶음밥',
#  '비빔밥',
#  '삼각김밥',
#  '수수밥',
#  '알밥',
#  '영양돌솥밥',
#  '오므라이스',
#  '자장밥',
#  '잡곡밥',
#  '잡채밥',
#  '주먹밥',
#  '짬뽕밥',
#  '차조밥',
#  '찰밥',
#  '초밥',
#  '카레라이스',
#  '콩나물밥',
#  '콩밥',
#  '하이라이스',
#  '현미밥',
#  '회덮밥',
#  '가래떡',
#  '경단',
#  '꿀떡',
#  '모듬찰떡',
#  '백설기',
#  '송편',
#  '시루떡',
#  '약식',
#  '인절미',
#  '절편',
#  '증편',
#  '찹쌀떡',
#  '도넛',
#  '마늘빵',
#  '머핀',
#  '모닝빵',
#  '모카빵',
#  '베이글',
#  '샌드위치',
#  '소보로빵',
#  '식빵',
#  '초코소라빵',
#  '크로와상',
#  '파이',
#  '페이스트리',
#  '피자',
#  '피자빵',
#  '햄버거',
#  '호떡',
#  '간자장',
#  '국수',
#  '냉면',
#  '떡국',
#  '떡만두국',
#  '라면',
#  '만두',
#  '만두국',
#  '메밀국수',
#  '수제비',
#  '스파게티',
#  '우동',
#  '우동볶음',
#  '월남쌈',
#  '자장면',
#  '짬뽕',
#  '쫄면',
#  '칼국수',
#  '콩국수',
#  '닭죽',
#  '스프',
#  '오리죽',
#  '전복죽',
#  '채소죽',
#  '팥죽',
#  '호박죽',
#  '흑임자죽',
#  '갈비탕',
#  '감자국',
#  '곰탕',
#  '굴국',
#  '김치국',
#  '내장탕',
#  '냉국',
#  '달걀국',
#  '달걀탕',
#  '닭곰탕',
#  '도가니탕',
#  '된장국',
#  '무국',
#  '묵국',
#  '미역국',
#  '배추국',
#  '북어국',
#  '사골국',
#  '삼계탕',
#  '새우탕',
#  '설렁탕',
#  '순대국',
#  '어묵국',
#  '오징어국',
#  '육개장',
#  '장어탕',
#  '재첩국',
#  '조개국',
#  '콩나물국',
#  '토란국',
#  '해장국',
#  '갈치찌개',
#  '감자탕',
#  '김치전골',
#  '김치찌개',
#  '꽃게탕',
#  '낙지전골',
#  '동태국',
#  '동태찌개',
#  '돼지고기찌개',
#  '된장찌개',
#  '두부찌개',
#  '매운탕',
#  '버섯전골',
#  '부대찌개',
#  '샤브샤브',
#  '소고기전골',
#  '순두부찌개',
#  '알탕',
#  '오리백숙',
#  '오리탕',
#  '오징어찌개',
#  '청국장찌개',
#  '마카롱',
#  '추어탕',
#  '콩비지찌개',
#  '호박찌개',
#  '고구마',
#  '가오리찜',
#  '갈비찜',
#  '감자',
#  '깻잎찜',
#  '꼬막찜',
#  '꽈리고추찜',
#  '달걀찜',
#  '닭찜',
#  '돼지갈비찜',
#  '사태찜',
#  '수육',
#  '순대',
#  '아귀찜',
#  '애호박찜',
#  '옥수수',
#  '족발',
#  '코다리찜',
#  '콩나물찜',
#  '풋고추찜',
#  '가자미구이',
#  '갈비구이',
#  '갈치구이',
#  '고등어구이',
#  '곱창구이',
#  '김구이',
#  '꼬치구이',
#  '닭구이',
#  '닭발구이',
#  '떡갈비',
#  '런천미트구이',
#  '뱅어포구이',
#  '버섯구이',
#  '버섯구이표고버섯',
#  '삼겹살구이',
#  '삼치구이',
#  '새우구이',
#  '소불고기',
#  '스테이크',
#  '오리고기구이',
#  '오리불고기',
#  '장어구이',
#  '조개구이',
#  '조기구이',
#  '참치구이',
#  '치킨데리야끼',
#  '함박스테이크',
#  '가지전',
#  '감자전',
#  '고구마전',
#  '김치전',
#  '달걀말이',
#  '달걀부침',
#  '두부부침',
#  '맛살전',
#  '메밀전',
#  '버섯전',
#  '부추전',
#  '산적',
#  '스크램블드에그',
#  '애호박전',
#  '완자전',
#  '채소전',
#  '파전',
#  '감자볶음',
#  '건새우볶음',
#  '곱창볶음',
#  '김치볶음',
#  '낙지볶음',
#  '번',
#  '닭발볶음',
#  '닭볶음',
#  '당근볶음',
#  '돼지고기볶음',
#  '돼지고기볶음',
#  '떡볶이',
#  '라볶이',
#  '마늘쫑볶음',
#  '마파두부',
#  '멸치볶음',
#  '문어볶음',
#  '미역줄기볶음',
#  '버섯볶음',
#  '브로콜리볶음',
#  '삼겹살볶음',
#  '새우볶음',
#  '소고기볶음',
#  '소시지볶음',
#  '애호박볶음',
#  '양파볶음',
#  '어묵볶음',
#  '오징어볶음',
#  '유산슬',
#  '잔멸치볶음',
#  '잡채',
#  '죽순볶음',
#  '팔보채',
#  '풋고추볶음',
#  '햄볶음',
#  '감자조림',
#  '고등어조림',
#  '꽁치조림',
#  '닭볶음탕',
#  '닭조림',
#  '두부조림',
#  '땅콩조림',
#  '멸치조림',
#  '무조림',
#  '미트볼조림',
#  '버섯조림',
#  '병어조림',
#  '삼치조림',
#  '양미리조림',
#  '어묵조림',
#  '연근조림',
#  '오징어조림',
#  '오징어채조림',
#  '우엉조림',
#  '장조림',
#  '쥐포조림',
#  '코다리조림',
#  '콩조림',
#  '감자튀김',
#  '김튀김',
#  '다시마튀각',
#  '닭다리튀김',
#  '닭튀김',
#  '떡강정',
#  '미역튀각',
#  '탕수육',
#  '가지나물',
#  '고구마줄기나물',
#  '고사리나물무침',
#  '고춧잎나물무침',
#  '깻잎나물',
#  '냉이나물',
#  '도라지나물무침',
#  '돌나물무침',
#  '머위대나물무침',
#  '무나물무침',
#  '방풍나물무침',
#  '배추나물',
#  '비름나물무침',
#  '숙주나물',
#  '시금치나물',
#  '시래기나물무침',
#  '씀바귀나물무침',
#  '열무나물',
#  '유채나물',
#  '참나물',
#  '취나물',
#  '콩나물무침',
#  '토란대나물무침',
#  '호박오가리나물무침',
#  '가죽나물무침',
#  '겉절이',
#  '골뱅이무침',
#  '굴무침',
#  '김무침',
#  '낙지무침',
#  '냉채',
#  '다시마무침',
#  '달래무침',
#  '도라지생채',
#  '두릅무침',
#  '마늘쫑무침',
#  '무말랭이무침',
#  '무생채',
#  '묵무침',
#  '물회',
#  '미나리무침',
#  '미역초무침',
#  '민들레잎무침',
#  '버섯무침',
#  '부추무침',
#  '북어채무침',
#  '샐러드',
#  '양장피',
#  '오이무침',
#  '오이생채',
#  '오이지무침',
#  '오징어무침',
#  '오징어채무침',
#  '톳나물무침',
#  '파래무침',
#  '파무침',
#  '풋고추된장무침',
#  '풋마늘무침',
#  '피조개무침',
#  '해초무침',
#  '회무침',
#  '고들빼기김치',
#  '깍두기',
#  '깻잎김치',
#  '나박김치',
#  '동치미',
#  '물김치',
#  '보쌈김치',
#  '부추김치',
#  '얼갈이배추김치',
#  '오이김치',
#  '가자미식해',
#  '갈치젓',
#  '멸치젓',
#  '새우젓',
#  '오징어젓',
#  '꽃게장',
#  '단무지',
#  '더덕장아찌',
#  '매실장아찌',
#  '무짠지',
#  '무초절임',
#  '오이장아찌',
#  '오이지',
#  '미숫가루',
#  '육회',
#  '리소토',
#  '감자빵',
#  '건포도빵',
#  '계란빵',
#  '기타빵',
#  '깨찰빵',
#  '또띠아',
#  '롤빵',
#  '바게트',
#  '버거',
#  '버터빵',
#  '소세지빵',
#  '스콘',
#  '앙금빵',
#  '야채빵',
#  '국밥',
#  '기장밥',
#  '커피',
#  '크로켓',
#  '크림빵',
#  '타르트',
#  '토스트',
#  '팥빵',
#  '프레즐',
#  '핫도그',
#  '허니브레드',
#  '호밀빵',
#  '효모빵',
#  '젤리',
#  '밤',
#  '비스킷',
#  '시리얼',
#  '웨이퍼',
#  '초콜릿',
#  '캔디',
#  '푸딩',
#  '소스',
#  '빙수',
#  '샤베트',
#  '아이스크림',
#  '요구르트',
#  '요구르트',
#  '우유',
#  '치즈',
#  '과ㆍ채주스',
#  '녹차',
#  '기타차',
#  '귤차',
#  '기타음료',
#  '꿀차',
#  '대추차',
#  '라떼',
#  '레몬차',
#  '레몬홍차',
#  '마테차',
#  '밀크티',
#  '스무디',
#  '유자차',
#  '뱅쇼',
#  '복숭아홍차',
#  '사과차',
#  '생강차',
#  '식혜',
#  '쌍화차',
#  '아이스티',
#  '에이드',
#  '오미자차',
#  '우롱차',
#  '자몽차',
#  '자몽홍차',
#  '코코아',
#  '콤부차',
#  '탄산음료',
#  '허브차',
#  '홍차',
#  '과일',
#  '견과',
#  '소시지',
#  '계란덮밥',
#  '곤드레나물밥',
#  '귀리밥',
#  '누룽지',
#  '리조또',
#  '묵밥',
#  '새우튀김롤',
#  '쌀밥',
#  '연어롤',
#  '연잎밥',
#  '오곡밥',
#  '잡탕밥',
#  '짜장밥',
#  '충무김밥',
#  '캘리포니아롤',
#  '개피떡',
#  '기피편',
#  '모싯잎송편',
#  '무지개떡',
#  '빙떡',
#  '수수경단',
#  '수수부꾸미',
#  '수수팥떡',
#  '쑥떡',
#  '찰시루떡',
#  '다식',
#  '다쿠아즈',
#  '버터크림빵',
#  '매작과',
#  '산자',
#  '약과',
#  '유과',
#  '기스면',
#  '라멘',
#  '막국수',
#  '메밀소바',
#  '밀면',
#  '볶음면',
#  '분짜',
#  '비빔국수',
#  '비빔면',
#  '쌀국수',
#  '올갱이국수',
#  '울면',
#  '탄탄면',
#  '팟타이',
#  '게살죽',
#  '깨죽',
#  '미음',
#  '백합죽',
#  '소고기버섯죽',
#  '쌀죽',
#  '어죽',
#  '율무죽',
#  '잣죽',
#  '참깨죽',
#  '참치죽',
#  '현미죽',
#  '게국지',
#  '곰치국',
#  '꼬리곰탕',
#  '낙지탕',
#  '매생이국',
#  '묵말이',
#  '미소된장국',
#  '선짓국',
#  '소탕',
#  '아구탕',
#  '어묵탕',
#  '어탕',
#  '연포탕',
#  '오이냉국',
#  '올갱이국',
#  '육탕',
#  '전복탕',
#  '지리탕',
#  '초당순두부',
#  '탕국',
#  '홍합탕',
#  '황태해장국',
#  '고등어찌개',
#  '곱창전골',
#  '꽁치찌개',
#  '나베',
#  '두부전골',
#  '마라탕',
#  '만두전골',
#  '밀푀유나베',
#  '버섯찌개',
#  '불고기전골',
#  '불낙전골',
#  '해물탕',
#  '해신탕',
#  '훠궈',
#  '김치찜',
#  '꼬막무침',
#  '대구찜',
#  '도미찜',
#  '동태찜',
#  '동파육',
#  '돼지고기',
#  '돼지등갈비찜',
#  '병어찜',
#  '북어찜',
#  '붕어찜',
#  '수란',
#  '숙회',
#  '오징어순대',
#  '전어찜',
#  '조기찜',
#  '해물찜',
#  '갈매기살구이',
#  '곰장어구이',
#  '꿩불고기',
#  '닭튀김',
#  '대창구이',
#  '더덕구이',
#  '도미구이',
#  '돼지갈비구이',
#  '돼지껍데기구이',
#  '돼지불고기',
#  '막창구이',
#  '연어구이',
#  '오겹살구이',
#  '임연수구이',
#  '차돌박이구이',
#  '콘치즈구이',
#  '황태구이',
#  '훈제오리',
#  '고추전',
#  '굴전',
#  '깻잎전',
#  '꼬치구치',
#  '녹두빈대떡',
#  '동태전',
#  '두부전',
#  '미나리전',
#  '배추전',
#  '새우전',
#  '생선전',
#  '느타리버섯볶음',
#  '소고기산적',
#  '소라산적',
#  '오징어산적',
#  '해물파전',
#  '햄부침',
#  '호박전',
#  '홍합산적',
#  '화양적',
#  '감바스',
#  '고추잡채',
#  '난자완스',
#  '닭모래집볶음',
#  '두부김치',
#  '머위나물볶음',
#  '순대볶음',
#  '오징어채볶음',
#  '주꾸미볶음',
#  '주꾸미삼겹살',
#  '해물볶음',
#  '가자미조림',
#  '고추조림',
#  '동태조림',
#  '북어조림',
#  '조기조림',
#  '고구마맛탕',
#  '고구마튀김',
#  '고추튀김',
#  '김말이튀김',
#  '깐풍기',
#  '깐풍새우',
#  '닭모래집튀김',
#  '돈가스',
#  '라조기',
#  '멘보샤',
#  '미꾸라지튀김',
#  '복어튀김',
#  '북어강정',
#  '생선까스',
#  '양파링튀김',
#  '쥐포튀김',
#  '채소튀김',
#  '치즈볼',
#  '치즈스틱',
#  '치킨가스',
#  '깻잎나물볶음',
#  '머위나물무침',
#  '미나리나물',
#  '세발나물무침',
#  '우거지나물무침',
#  '취나물무침',
#  '노각무침',
#  '단무지무침',
#  '더덕무침',
#  '배추겉절이',
#  '밴댕이무침',
#  '상추겉절이',
#  '쑥갓나물무침',
#  '탕평채',
#  '홍어무침',
#  '갓김치',
#  '배추김치',
#  '백김치',
#  '열무김치',
#  '열무물김치',
#  '열무얼갈이김치',
#  '오이소박이',
#  '유채김치',
#  '유채물김치',
#  '총각김치',
#  '파김치',
#  '게장',
#  '명란젓',
#  '조개젓',
#  '고추장아찌',
#  '들깻잎장아찌',
#  '마늘장아찌',
#  '마늘쫑장아찌',
#  '무장아찌',
#  '카레소스',
#  '밀크쉐이크',
#  '레몬청차',
#  '밀크티',
#  '액상커피',
#  '팝콘',
#  '달걀',
#  '대구포',
#  '북어포',
#  '넙치',
#  '돌솥비빔밥',
#  '우럭회덮밥',
#  '참치덮밥',
#  '참치회덮밥',
#  '콩나물국밥',
#  '비빔막국수',
#  '쟁반짜장',
#  '중식우동',
#  '해물칼국수',
#  '닭고기육개장',
#  '닭백숙',
#  '개고기전골',
#  '고추장찌개',
#  '내장전골',
#  '소고기샤브샤브',
#  '순대전골',
#  '아귀지리',
#  '가오리콩나물찜',
#  '꽃게콩나물찜',
#  '낙지찜',
#  '단호박찜',
#  '대구볼찜',
#  '복찜',
#  '소갈비찜',
#  '해물콩나물찜',
#  '홍어찜',
#  '황태콩나물찜',
#  '굴비구이',
#  '꽁치구이',
#  '소내장구이',
#  '오리고기로스',
#  '옥돔구이',
#  '옥수수구이',
#  '전어구이',
#  '새송이버섯전',
#  '어육소시지전',
#  '장떡',
#  '파래전',
#  '가지볶음',
#  '건표고버섯볶음',
#  '멸치볶음',
#  '새송이버섯볶음',
#  '오리볶음',
#  '중식잡채',
#  '쫄볶이',
#  '파래볶음',
#  '표고버섯볶음',
#  '호박볶음',
#  '갈치조림',
#  '달걀조림',
#  '닭도리탕',
#  '깐쇼새우',
#  '시래기나물',
#  '청경채나물',
#  '톳나물',
#  '간재미회무침',
#  '개고기무침',
#  '곤약무침',
#  '과일샐러드',
#  '돌나물',
#  '마늘장아찌무침',
#  '모자반무침',
#  '얼갈이겉절이',
#  '톳나물초무침',
#  '곤드레밥',
#  '율무밥',
#  '흑미밥',
#  '잔치국수',
#  '들깨국',
#  '소고기육개장',
#  '어묵국',
#  '감자구이',
#  '닭날개구이',
#  '닭다리구이',
#  '고추장볶음',
#  '동태까스',
#  '숙주미나리나물',
#  '갑오징어무침',
#  '느타리버섯무침',
#  '도토리묵무침',
#  '청포묵무침',
#  '돼지고기덮밥',
#  '유부국',
#  '돼지고기찜',
#  '햄전',
#  '미역냉국',
#  '햄채소볶음',
#  '무생채',
#  '참나물겉절이',
#  '치커리겉절이',
#  '짜장소스']

# %%
food_tmp = []
for name in food_lst:
    hanspell_sent = spell_checker.check(name)
    food_tmp.append(hanspell_sent.checked)

food_tmp
# Out:
# ['케이크',
#  '치즈빵',
#  '카스텔라',
#  '추로스',
#  '치아바타',
#  '와플',
#  '찰떡 빵',
#  '김밥',
#  '덮밥',
#  '보리밥',
#  '볶음밥',
#  '비빔밥',
#  '삼각김밥',
#  '수수밥',
#  '알밥',
#  '영양 돌솥밥',
#  '오므라이스',
#  '자장밥',
#  '잡곡밥',
#  '잡채밥',
#  '주먹밥',
#  '짬뽕밥',
#  '차조밥',
#  '찰밥',
#  '초밥',
#  '카레라이스',
#  '콩나물밥',
#  '콩밥',
#  '하이라이스',
#  '현미밥',
#  '회덮밥',
#  '가래떡',
#  '경단',
#  '꿀떡',
#  '모둠 찰떡',
#  '백설기',
#  '송편',
#  '시루떡',
#  '약식',
#  '인절미',
#  '절편',
#  '증편',
#  '찹쌀떡',
#  '도넛',
#  '마늘빵',
#  '머핀',
#  '모닝빵',
#  '모카빵',
#  '베이글',
#  '샌드위치',
#  '곰보빵',
#  '식빵',
#  '초코 소라고 빵',
#  '크루아상',
#  '파이',
#  '페이스트리',
#  '피자',
#  '피자빵',
#  '햄버거',
#  '호떡',
#  '간자장',
#  '국수',
#  '냉면',
#  '떡국',
#  '떡만둣국',
#  '라면',
#  '만두',
#  '만둣국',
#  '메밀국수',
#  '수제비',
#  '스파게티',
#  '가락국수',
#  '가락국수 볶음',
#  '월남쌈',
#  '자장면',
#  '짬뽕',
#  '쫄면',
#  '칼국수',
#  '콩국수',
#  '닭죽',
#  '수프',
#  '오리 죽',
#  '전복죽',
#  '채소 죽',
#  '팥죽',
#  '호박죽',
#  '흑임자죽',
#  '갈비탕',
#  '감잣국',
#  '곰탕',
#  '굴국',
#  '김칫국',
#  '내장탕',
#  '냉국',
#  '달 결국',
#  '달걀탕',
#  '닭곰탕',
#  '도가니탕',
#  '된장국',
#  '뭇국',
#  '묵국',
#  '미역국',
#  '배춧국',
#  '북엇국',
#  '사골국',
#  '삼계탕',
#  '새우탕',
#  '설렁탕',
#  '순댓국',
#  '어묵국',
#  '오징어 국',
#  '육개장',
#  '장어탕',
#  '재첩 국',
#  '조갯국',
#  '콩나물국',
#  '토란국',
#  '해장국',
#  '갈치 찌개',
#  '감자탕',
#  '김치전골',
#  '김치찌개',
#  '꽃게탕',
#  '낙지전골',
#  '동탯국',
#  '동태찌개',
#  '돼지고기 찌개',
#  '된장찌개',
#  '두부찌개',
#  '매운탕',
#  '버섯전골',
#  '부대찌개',
#  '샤부샤부',
#  '소고기 전골',
#  '순두부찌개',
#  '알탕',
#  '오리백숙',
#  '오리탕',
#  '오징어찌개',
#  '청국장찌개',
#  '마카롱',
#  '추어탕',
#  '콩비지찌개',
#  '호박 찌개',
#  '고구마',
#  '가오리 찜',
#  '갈비찜',
#  '감자',
#  '깻잎 찜',
#  '꼬막 찜',
#  '꽈리고추찜',
#  '달걀찜',
#  '닭찜',
#  '돼지갈비찜',
#  '사태 찜',
#  '수육',
#  '순대',
#  '아귀찜',
#  '애호박찜',
#  '옥수수',
#  '족발',
#  '코다리찜',
#  '콩나물찜',
#  '풋고추찜',
#  '가자미구이',
#  '갈비구이',
#  '갈치구이',
#  '고등어구이',
#  '곱창구이',
#  '김구이',
#  '꼬치구이',
#  '닭구이',
#  '닭발구이',
#  '떡갈비',
#  '런천미트 구이',
#  '뱅어포구이',
#  '버섯 구이',
#  '버섯 구이 표고버섯',
#  '삼겹살 구이',
#  '삼치구이',
#  '새우구이',
#  '소불고기',
#  '스테이크',
#  '오리고기구이',
#  '오리불고기',
#  '장어구이',
#  '조개구이',
#  '조기구이',
#  '참치구이',
#  '치킨 데리야키',
#  '햄버그스테이크',
#  '가지전',
#  '감자전',
#  '고구마 전',
#  '김치전',
#  '달걀말이',
#  '달걀부침',
#  '두부 부침',
#  '맛살 천',
#  '메밀전',
#  '버섯전',
#  '부추전',
#  '산적',
#  '스크램블드에그',
#  '애호박전',
#  '완자전',
#  '채소전',
#  '파전',
#  '감자볶음',
#  '건새우 볶음',
#  '곱창볶음',
#  '김치볶음',
#  '낙지볶음',
#  '번',
#  '닭발볶음',
#  '닭볶음',
#  '당근볶음',
#  '돼지고기볶음',
#  '돼지고기볶음',
#  '떡볶이',
#  '라볶이',
#  '마늘종 볶음',
#  '마파두부',
#  '멸치볶음',
#  '문어볶음',
#  '미역줄기볶음',
#  '버섯볶음',
#  '브로콜리 볶음',
#  '삼겹살볶음',
#  '새우볶음',
#  '소고기 볶음',
#  '소시지볶음',
#  '애호박볶음',
#  '양파 볶음',
#  '어묵볶음',
#  '오징어볶음',
#  '유산슬',
#  '잔멸치 볶음',
#  '잡채',
#  '죽순 볶음',
#  '팔보채',
#  '풋고추볶음',
#  '햄 볶음',
#  '감자조림',
#  '고등어조림',
#  '꽁치조림',
#  '닭볶음탕',
#  '닭조림',
#  '두부조림',
#  '땅콩조림',
#  '멸치조림',
#  '무 조림',
#  '미트볼 조림',
#  '버섯 조림',
#  '병어조림',
#  '삼치 조림',
#  '양미리 조림',
#  '어묵조림',
#  '연근조림',
#  '오징어 조림',
#  '오징어채 조림',
#  '우엉조림',
#  '장조림',
#  '쥐포 조림',
#  '코다리조림',
#  '콩 조림',
#  '감자튀김',
#  '김튀김',
#  '다시마튀각',
#  '닭 다리 튀김',
#  '닭튀김',
#  '떡 강정',
#  '미역튀각',
#  '탕수육',
#  '가지나물',
#  '고구마 줄기나 물',
#  '고사리나물 무침',
#  '고춧잎나물 무침',
#  '깻잎나물',
#  '냉이나물',
#  '도라지나물 무침',
#  '돌나물 무침',
#  '머위대 나물 무침',
#  '무나물 무침',
#  '방풍나물 무침',
#  '배추 나물',
#  '비름나물 무침',
#  '숙주나물',
#  '시금치나물',
#  '시래기나물 무침',
#  '씀바귀나물 무침',
#  '열무 나물',
#  '유채나물',
#  '참나물',
#  '취나물',
#  '콩나물무침',
#  '토란대나물 무침',
#  '호박오가리나물 무침',
#  '가죽나물 무침',
#  '겉절이',
#  '골뱅이무침',
#  '굴 무침',
#  '김 무침',
#  '낙지 무침',
#  '냉채',
#  '다시마 무침',
#  '달래무침',
#  '도라지생채',
#  '두릅무침',
#  '마늘종 무침',
#  '무말랭이무침',
#  '무생채',
#  '묵무침',
#  '물회',
#  '미나리 무침',
#  '미역초무침',
#  '민들레 잎무침',
#  '버섯무침',
#  '부추무침',
#  '북어채 무침',
#  '샐러드',
#  '양장피',
#  '오이무침',
#  '오이생채',
#  '오이지무침',
#  '오징어무침',
#  '오징어채 물침',
#  '톳 나물 무침',
#  '파래무침',
#  '파무침',
#  '풋고추 된장무침',
#  '풋마늘 무침',
#  '피조개 무침',
#  '해초무침',
#  '회 무침',
#  '고들빼기김치',
#  '깍두기',
#  '깻잎김치',
#  '나박김치',
#  '동치미',
#  '물김치',
#  '보쌈김치',
#  '부추김치',
#  '얼갈이배추김치',
#  '오이김치',
#  '가자미식해',
#  '갈치젓',
#  '멸치젓',
#  '새우젓',
#  '오징어젓',
#  '꽃게장',
#  '단무지',
#  '더덕장아찌',
#  '매실장아찌',
#  '무짠지',
#  '무 초절임',
#  '오이장아찌',
#  '오이지',
#  '미숫가루',
#  '육회',
#  '리소토',
#  '감자빵',
#  '건포도 빵',
#  '계란빵',
#  '기타 빵',
#  '깨찰빵',
#  '토르티야',
#  '롤빵',
#  '바게트',
#  '버거',
#  '버터빵',
#  '소시지 빵',
#  '스콘',
#  '앙금빵',
#  '야채빵',
#  '국밥',
#  '기장밥',
#  '커피',
#  '크로켓',
#  '크림빵',
#  '타르트',
#  '토스트',
#  '팥빵',
#  '프레즐',
#  '핫도그',
#  '허니브레드',
#  '호밀빵',
#  '효모빵',
#  '젤리',
#  '밤',
#  '비스킷',
#  '시리얼',
#  '웨이퍼',
#  '초콜릿',
#  '캔디',
#  '푸딩',
#  '소스',
#  '빙수',
#  '셔벗',
#  '아이스크림',
#  '요구르트',
#  '요구르트',
#  '우유',
#  '치즈',
#  '과ㆍ체 주스',
#  '녹차',
#  '기타 차',
#  '귤차',
#  '기타 음료',
#  '꿀차',
#  '대추차',
#  '라테',
#  '레몬차',
#  '레몬홍차',
#  '마테차',
#  '밀크티',
#  '스무디',
#  '유자차',
#  '뱅쇼',
#  '복숭아홍차',
#  '사과차',
#  '생강차',
#  '식혜',
#  '쌍화차',
#  '아이스티',
#  '에이드',
#  '오미자차',
#  '우롱차',
#  '자몽차',
#  '자몽 홍차',
#  '코코아',
#  '콤부차',
#  '탄산음료',
#  '허브차',
#  '홍차',
#  '과일',
#  '견과',
#  '소시지',
#  '계란덮밥',
#  '곤드레 나물밥',
#  '귀리밥',
#  '누룽지',
#  '리소토',
#  '묵밥',
#  '새우튀김 롤',
#  '쌀밥',
#  '연어롤',
#  '연잎밥',
#  '오곡밥',
#  '잡탕밥',
#  '짜장밥',
#  '충무김밥',
#  '캘리포니아롤',
#  '개피떡',
#  '기피 편',
#  '모싯잎송편',
#  '무지개떡',
#  '빙떡',
#  '수수경단',
#  '수수부꾸미',
#  '수수팥떡',
#  '쑥떡',
#  '찰시루떡',
#  '다식',
#  '다쿠아즈',
#  '버터크림빵',
#  '매작과',
#  '산자',
#  '약과',
#  '유과',
#  '기스면',
#  '라멘',
#  '막국수',
#  '메밀소바',
#  '밀면',
#  '볶음면',
#  '분짜',
#  '비빔국수',
#  '비빔면',
#  '쌀국수',
#  '다슬기 국 수',
#  '울면',
#  '탄탄면',
#  '팟타이',
#  '게살죽',
#  '깨죽',
#  '미음',
#  '백합죽',
#  '소고기 버섯죽',
#  '쌀죽',
#  '어죽',
#  '율무죽',
#  '잣죽',
#  '참깨죽',
#  '참치죽',
#  '현미죽',
#  '게국지',
#  '곰치 국',
#  '꼬리곰탕',
#  '낙지탕',
#  '매생이국',
#  '묵 말이',
#  '미소된장국',
#  '선짓국',
#  '소탕',
#  '아귀탕',
#  '어묵탕',
#  '어탕',
#  '연포탕',
#  '오이냉국',
#  '다슬기 국',
#  '육탕',
#  '전복탕',
#  '지리탕',
#  '초당순두부',
#  '탕국',
#  '홍합탕',
#  '황태 해장국',
#  '고등어찌개',
#  '곱창전골',
#  '꽁치찌개',
#  '나베',
#  '두부전골',
#  '마라탕',
#  '만두전골',
#  '밀푀유나베',
#  '버섯찌개',
#  '불고기 전골',
#  '불낙 전골',
#  '해물탕',
#  '해신탕',
#  '훠궈',
#  '김치찜',
#  '꼬막무침',
#  '대구 찜',
#  '도미찜',
#  '동태찜',
#  '동파육',
#  '돼지고기',
#  '돼지 등갈비찜',
#  '병어 찜',
#  '북어찜',
#  '붕어찜',
#  '수란',
#  '숙회',
#  '오징어순대',
#  '전어 찜',
#  '조기 찜',
#  '해물찜',
#  '갈매기살 구이',
#  '곰장어 구이',
#  '꿩 불고기',
#  '닭튀김',
#  '대창구이',
#  '더덕구이',
#  '도미구이',
#  '돼지갈비구이',
#  '돼지껍질 구이',
#  '돼지불고기',
#  '막창구이',
#  '연어구이',
#  '오겹살 구이',
#  '임연수 구이',
#  '차돌박이 귀이',
#  '콘치즈구이',
#  '황태구이',
#  '훈제오리',
#  '고추전',
#  '굴전',
#  '깻잎 전',
#  '꼬치 구치',
#  '녹두빈대떡',
#  '동태전',
#  '두부 전',
#  '미나리 전',
#  '배추전',
#  '새우전',
#  '생선전',
#  '느타리버섯볶음',
#  '소고기 산적',
#  '소라 산적',
#  '오징어 산적',
#  '해물파전',
#  '햄부침',
#  '호박전',
#  '홍합 산적',
#  '화양적',
#  '감바스',
#  '고추잡채',
#  '난젠완쯔',
#  '닭모래집 볶음',
#  '두부김치',
#  '머위나물볶음',
#  '순대볶음',
#  '오징어채볶음',
#  '주꾸미볶음',
#  '주꾸미 삼겹살',
#  '해물볶음',
#  '가자미조림',
#  '고추 조림',
#  '동태조림',
#  '북어조림',
#  '조기조림',
#  '고구마 맛탕',
#  '고구마튀김',
#  '고추튀김',
#  '김말이 튀김',
#  '깐풍기',
#  '깐풍 새우',
#  '닭모래집 튀김',
#  '돈가스',
#  '라조기',
#  '멘보샤',
#  '미꾸라지 튀김',
#  '복어 튀김',
#  '북어 강정',
#  '생선가스',
#  '양파링 튀김',
#  '쥐포 튀김',
#  '채소 튀김',
#  '치즈볼',
#  '치즈스틱',
#  '치킨가스',
#  '깻잎나물볶음',
#  '머위나물 무침',
#  '미나리나물',
#  '세 발 나물 무침',
#  '우거지 나물 무침',
#  '취나물무침',
#  '노각 무침',
#  '단무지무침',
#  '더덕무침',
#  '배추 겉절이',
#  '밴댕이 무침',
#  '상추겉절이',
#  '쑥갓나물 무침',
#  '탕평채',
#  '홍어무침',
#  '갓김치',
#  '배추김치',
#  '백김치',
#  '열무김치',
#  '열무물김치',
#  '열무 얼갈이김치',
#  '오이소박이',
#  '유채 김치',
#  '유채 물김치',
#  '총각김치',
#  '파김치',
#  '게장',
#  '명란젓',
#  '조개젓',
#  '고추장아찌',
#  '들깻잎 장아찌',
#  '마늘장아찌',
#  '마늘종 장아찌',
#  '무장아찌',
#  '카레소스',
#  '밀크셰이크',
#  '레몬 청자',
#  '밀크티',
#  '액상커피',
#  '팝콘',
#  '달걀',
#  '대구포',
#  '북어포',
#  '넙치',
#  '돌솥비빔밥',
#  '우럭 회덮밥',
#  '참치 덮밥',
#  '참치 회 덮밥',
#  '콩나물국밥',
#  '비빔막국수',
#  '쟁반짜장',
#  '중식 가락국수',
#  '해물칼국수',
#  '닭고기 육개장',
#  '닭백숙',
#  '개고기 전골',
#  '고추장찌개',
#  '내장 전골',
#  '소고기 샤부샤부',
#  '순대전골',
#  '아귀 지리',
#  '가오리 콩나물찜',
#  '꽃게 콩나물찜',
#  '낙지 찜',
#  '단호박찜',
#  '대구볼 찜',
#  '복찜',
#  '소갈비찜',
#  '해물 콩나물찜',
#  '홍어 찜',
#  '황태 콩나물찜',
#  '굴비구이',
#  '꽁치구이',
#  '소대장 구이',
#  '오리고기로 스',
#  '옥돔구이',
#  '옥수수 구이',
#  '전어구이',
#  '새송이버섯전',
#  '어육소시지 전',
#  '장떡',
#  '파래 전',
#  '가지볶음',
#  '건표고버섯볶음',
#  '멸치볶음',
#  '새송이버섯볶음',
#  '오리볶음',
#  '중식 잡채',
#  '쫄볶이',
#  '파래 볶음',
#  '표고버섯볶음',
#  '호박볶음',
#  '갈치조림',
#  '달걀조림',
#  '닭볶음탕',
#  '깐쇼새우',
#  '시래기나물',
#  '청경채 나물',
#  '톳 나물',
#  '간재미 회 무침',
#  '개고기 무침',
#  '곤약 무침',
#  '과일 샐러드',
#  '돌나물',
#  '마늘장아찌 무침',
#  '모자반 무침',
#  '얼갈이 겉절이',
#  '톳 나물 초무침',
#  '곤드레 밥',
#  '율무밥',
#  '흑미밥',
#  '잔치국수',
#  '들깨국',
#  '소고기육개장',
#  '어묵국',
#  '감자구이',
#  '닭 날개 구이',
#  '닭 다리 구이',
#  '고추장볶음',
#  '동태 가스',
#  '숙주 미나리나물',
#  '갑오징어무침',
#  '느타리버섯무침',
#  '도토리묵무침',
#  '청포묵무침',
#  '돼지고기 덮밥',
#  '유부국',
#  '돼지고기 찜',
#  '햄전',
#  '미역냉국',
#  '햄 채소볶음',
#  '무생채',
#  '참나물겉절이',
#  '치커리 겉절이',
#  '짜장 소스']

# %%
food_short = []
for food_space in food_tmp:
    tmp = food_space.split(' ')
    food_short.extend(tmp)

food_short = list(set(food_short)) # 중복 제거
food_short
# Out:
# ['새우탕',
#  '떡국',
#  '고추튀김',
#  '새우튀김',
#  '깻잎나물볶음',
#  '김',
#  '어탕',
#  '수프',
#  '갈치구이',
#  '전복탕',
#  '새우전',
#  '미꾸라지',
#  '도라지나물',
#  '호박죽',
#  '기피',
#  '밤',
#  '어묵조림',
#  '조개젓',
#  '갑오징어무침',
#  '북어포',
#  '닭발볶음',
#  '오리고기로',
#  '도넛',
#  '우럭',
#  '곤약',
#  '배춧국',
#  '에이드',
#  '순두부찌개',
#  '닭발구이',
#  '완자전',
#  '게살죽',
#  '굴비구이',
#  '양파링',
#  '꽁치찌개',
#  '돼지갈비찜',
#  '라면',
#  '북어조림',
#  '달걀',
#  '꽁치조림',
#  '애호박볶음',
#  '멸치젓',
#  '닭죽',
#  '오이무침',
#  '해신탕',
#  '화양적',
#  '삼각김밥',
#  '미역줄기볶음',
#  '미역튀각',
#  '꼬치구이',
#  '김치찌개',
#  '오므라이스',
#  '김칫국',
#  '콩나물국',
#  '낙지전골',
#  '오징어찌개',
#  '수수팥떡',
#  '과ㆍ체',
#  '스테이크',
#  '우유',
#  '소갈비찜',
#  '부대찌개',
#  '쥐포',
#  '파래무침',
#  '소탕',
#  '순대전골',
#  '지리',
#  '북어찜',
#  '조기조림',
#  '들깨국',
#  '고춧잎나물',
#  '호박오가리나물',
#  '가스',
#  '콩나물밥',
#  '인절미',
#  '피조개',
#  '뱅쇼',
#  '조기',
#  '카레라이스',
#  '런천미트',
#  '깐풍',
#  '프레즐',
#  '초콜릿',
#  '전',
#  '누룽지',
#  '샌드위치',
#  '깐쇼새우',
#  '참나물겉절이',
#  '쑥갓나물',
#  '베이글',
#  '순대볶음',
#  '게국지',
#  '아이스티',
#  '천',
#  '된장무침',
#  '밀면',
#  '참치',
#  '김치찜',
#  '수수밥',
#  '고추',
#  '달',
#  '유채나물',
#  '미음',
#  '얼갈이',
#  '다식',
#  '풋고추찜',
#  '약과',
#  '풋고추볶음',
#  '붕어찜',
#  '레몬홍차',
#  '발',
#  '육회',
#  '오이지무침',
#  '얼갈이배추김치',
#  '다쿠아즈',
#  '미트볼',
#  '연어구이',
#  '버섯찌개',
#  '칼국수',
#  '떡',
#  '호박전',
#  '전복죽',
#  '쑥떡',
#  '효모빵',
#  '깐풍기',
#  '낙지볶음',
#  '불고기',
#  '두부',
#  '약식',
#  '세',
#  '차조밥',
#  '오이지',
#  '콩국수',
#  '얼갈이김치',
#  '빙떡',
#  '만두전골',
#  '동치미',
#  '삼겹살볶음',
#  '팥빵',
#  '달걀찜',
#  '쌀밥',
#  '애호박전',
#  '돌솥밥',
#  '아이스크림',
#  '견과',
#  '물회',
#  '스콘',
#  '팟타이',
#  '병어',
#  '오징어볶음',
#  '차',
#  '총각김치',
#  '머위나물',
#  '우엉조림',
#  '파전',
#  '고추잡채',
#  '더덕장아찌',
#  '브로콜리',
#  '다시마',
#  '당근볶음',
#  '오리불고기',
#  '밀크티',
#  '주꾸미볶음',
#  '민들레',
#  '크림빵',
#  '돼지갈비구이',
#  '북어',
#  '셔벗',
#  '치즈스틱',
#  '연어롤',
#  '모카빵',
#  '소고기',
#  '오징어',
#  '조갯국',
#  '콤부차',
#  '기장밥',
#  '생강차',
#  '새우',
#  '다리',
#  '달걀탕',
#  '미나리나물',
#  '곰보빵',
#  '비빔국수',
#  '김치전골',
#  '돼지고기',
#  '수수경단',
#  '찰시루떡',
#  '황태',
#  '숙회',
#  '무나물',
#  '오이냉국',
#  '떡만둣국',
#  '꿀차',
#  '도미찜',
#  '주먹밥',
#  '유자차',
#  '탕수육',
#  '홍어무침',
#  '해물',
#  '마라탕',
#  '묵밥',
#  '씀바귀나물',
#  '꽃게탕',
#  '새송이버섯볶음',
#  '흑미밥',
#  '치즈빵',
#  '회',
#  '절편',
#  '피자빵',
#  '롤',
#  '곰탕',
#  '레몬차',
#  '복어',
#  '깍두기',
#  '볶음',
#  '마카롱',
#  '새우구이',
#  '연포탕',
#  '말이',
#  '달래무침',
#  '갈비탕',
#  '부추전',
#  '유과',
#  '꼬리곰탕',
#  '꿀떡',
#  '곱창볶음',
#  '볶음밥',
#  '스무디',
#  '어육소시지',
#  '장떡',
#  '소시지',
#  '삼겹살',
#  '우롱차',
#  '짬뽕밥',
#  '건새우',
#  '난젠완쯔',
#  '마테차',
#  '코코아',
#  '귤차',
#  '파무침',
#  '수제비',
#  '맛탕',
#  '감자조림',
#  '밥',
#  '감자구이',
#  '가자미조림',
#  '비스킷',
#  '어묵볶음',
#  '동탯국',
#  '구치',
#  '차돌박이',
#  '밀푀유나베',
#  '초밥',
#  '닭곰탕',
#  '무짠지',
#  '곰치',
#  '사골국',
#  '열무',
#  '갈치젓',
#  '오곡밥',
#  '생선전',
#  '대구볼',
#  '연잎밥',
#  '갓김치',
#  '잡탕밥',
#  '가지전',
#  '수',
#  '멸치볶음',
#  '머위대',
#  '마늘빵',
#  '지리탕',
#  '쫄볶이',
#  '짜장밥',
#  '찰떡',
#  '밴댕이',
#  '오겹살',
#  '소대장',
#  '고사리나물',
#  '홍어',
#  '콩',
#  '자몽차',
#  '잡채',
#  '콩나물찜',
#  '기타',
#  '꽃게장',
#  '양장피',
#  '귀이',
#  '돌솥비빔밥',
#  '갈비구이',
#  '회덮밥',
#  '호박볶음',
#  '월남쌈',
#  '풋고추',
#  '등갈비찜',
#  '해물파전',
#  '버터크림빵',
#  '대구',
#  '날개',
#  '꼬막무침',
#  '단무지',
#  '비빔막국수',
#  '미역냉국',
#  '앙금빵',
#  '경단',
#  '만두',
#  '명란젓',
#  '아귀찜',
#  '건포도',
#  '감자탕',
#  '버섯',
#  '찰밥',
#  '새우볶음',
#  '오이소박이',
#  '냉면',
#  '알밥',
#  '사태',
#  '동태찌개',
#  '내장탕',
#  '계란빵',
#  '요구르트',
#  '노각',
#  '복찜',
#  '동태전',
#  '번',
#  '묵국',
#  '영양',
#  '뱅어포구이',
#  '깨찰빵',
#  '새송이버섯전',
#  '닭볶음탕',
#  '아귀',
#  '모자반',
#  '고추장볶음',
#  '비빔밥',
#  '숙주',
#  '햄버거',
#  '깻잎',
#  '튀김',
#  '미소된장국',
#  '국',
#  '전골',
#  '만둣국',
#  '표고버섯',
#  '애호박찜',
#  '파김치',
#  '치커리',
#  '고추장찌개',
#  '가자미구이',
#  '율무죽',
#  '시래기나물',
#  '닭구이',
#  '맛살',
#  '고등어조림',
#  '샐러드',
#  '깨죽',
#  '호밀빵',
#  '어묵탕',
#  '마파두부',
#  '낙지탕',
#  '홍합',
#  '달걀조림',
#  '식빵',
#  '알탕',
#  '추로스',
#  '가래떡',
#  '사과차',
#  '수란',
#  '배추',
#  '열무김치',
#  '팝콘',
#  '햄전',
#  '도토리묵무침',
#  '라테',
#  '닭튀김',
#  '장어구이',
#  '스',
#  '백설기',
#  '상추겉절이',
#  '콩밥',
#  '순댓국',
#  '충무김밥',
#  '돈가스',
#  '감자',
#  '나박김치',
#  '꽃게',
#  '콩나물국밥',
#  '코다리찜',
#  '골뱅이무침',
#  '라볶이',
#  '고들빼기김치',
#  '버섯무침',
#  '볶음면',
#  '가락국수',
#  '멸치조림',
#  '물김치',
#  '쟁반짜장',
#  '국수',
#  '보쌈김치',
#  '젤리',
#  '분짜',
#  '치즈',
#  '표고버섯볶음',
#  '오징어젓',
#  '내장',
#  '잡곡밥',
#  '수육',
#  '간재미',
#  '삼치',
#  '잡채밥',
#  '돼지껍질',
#  '닭찜',
#  '굴전',
#  '깻잎김치',
#  '귀리밥',
#  '백김치',
#  '잔멸치',
#  '편',
#  '육탕',
#  '오리',
#  '크루아상',
#  '굴국',
#  '게장',
#  '결국',
#  '두부찌개',
#  '파이',
#  '불낙',
#  '무침',
#  '머위나물볶음',
#  '찌개',
#  '돼지',
#  '멘보샤',
#  '막창구이',
#  '개고기',
#  '오이생채',
#  '족발',
#  '햄',
#  '동태찜',
#  '새우젓',
#  '버터빵',
#  '곱창전골',
#  '울면',
#  '자장면',
#  '초절임',
#  '양파',
#  '허브차',
#  '메밀국수',
#  '시루떡',
#  '단무지무침',
#  '다슬기',
#  '백합죽',
#  '배추김치',
#  '코다리조림',
#  '머핀',
#  '토란국',
#  '캔디',
#  '옥수수',
#  '훈제오리',
#  '해장국',
#  '짬뽕',
#  '닭',
#  '간자장',
#  '순대',
#  '야채빵',
#  '고구마',
#  '냉국',
#  '국밥',
#  '닭볶음',
#  '감자볶음',
#  '중식',
#  '가지나물',
#  '버섯전골',
#  '녹차',
#  '홍합탕',
#  '오징어채볶음',
#  '다시마튀각',
#  '숙주나물',
#  '소불고기',
#  '탄산음료',
#  '더덕무침',
#  '김치',
#  '꼬치',
#  '묵',
#  '쌀국수',
#  '청포묵무침',
#  '오이김치',
#  '빵',
#  '우거지',
#  '버섯전',
#  '현미밥',
#  '동태조림',
#  '꽈리고추찜',
#  '떡갈비',
#  '감자빵',
#  '잣죽',
#  '스파게티',
#  '땅콩조림',
#  '버섯죽',
#  '대구포',
#  '비름나물',
#  '삼계탕',
#  '취나물',
#  '톳',
#  '닭고기',
#  '양미리',
#  '가자미식해',
#  '쌍화차',
#  '떡볶이',
#  '임연수',
#  '조기구이',
#  '메밀전',
#  '유산슬',
#  '찜',
#  '가오리',
#  '조림',
#  '갈비찜',
#  '산자',
#  '막국수',
#  '파래',
#  '두부조림',
#  '달걀말이',
#  '곤드레',
#  '미나리',
#  '꿩',
#  '와플',
#  '웨이퍼',
#  '데리야키',
#  '식혜',
#  '줄기나',
#  '동태',
#  '북엇국',
#  '생선가스',
#  '소라',
#  '매실장아찌',
#  '짜장',
#  '김말이',
#  '채소',
#  '느타리버섯무침',
#  '된장찌개',
#  '가지볶음',
#  '기스면',
#  '추어탕',
#  '토란대나물',
#  '청국장찌개',
#  '푸딩',
#  '모둠',
#  '풋마늘',
#  '아귀탕',
#  '갈치조림',
#  '홍차',
#  '해물탕',
#  '음료',
#  '선짓국',
#  '부추김치',
#  '느타리버섯볶음',
#  '물',
#  '냉이나물',
#  '소시지볶음',
#  '레몬',
#  '삼치구이',
#  '닭모래집',
#  '꼬막',
#  '캘리포니아롤',
#  '호박',
#  '율무밥',
#  '덮밥',
#  '모싯잎송편',
#  '장아찌',
#  '죽순',
#  '쫄면',
#  '채소전',
#  '방풍나물',
#  '김치볶음',
#  '밀크셰이크',
#  '빙수',
#  '돌나물',
#  '어죽',
#  '닭백숙',
#  '해초무침',
#  '라멘',
#  '미숫가루',
#  '감잣국',
#  '낙지',
#  '대추차',
#  '동파육',
#  '재첩',
#  '피자',
#  '고구마튀김',
#  '청경채',
#  '비빔면',
#  '배추전',
#  '시금치나물',
#  '설렁탕',
#  '치아바타',
#  '어묵국',
#  '자장밥',
#  '흑임자죽',
#  '매작과',
#  '콩비지찌개',
#  '김밥',
#  '고등어구이',
#  '두릅무침',
#  '과일',
#  '겉절이',
#  '토스트',
#  '청자',
#  '장조림',
#  '탄탄면',
#  '버섯볶음',
#  '콩나물무침',
#  '고추전',
#  '곱창구이',
#  '녹두빈대떡',
#  '계란덮밥',
#  '찹쌀떡',
#  '고추장아찌',
#  '꽁치구이',
#  '건표고버섯볶음',
#  '무말랭이무침',
#  '김튀김',
#  '핫도그',
#  '참치죽',
#  '치킨',
#  '들깻잎',
#  '뭇국',
#  '버거',
#  '참치구이',
#  '참나물',
#  '오징어무침',
#  '감자튀김',
#  '샤부샤부',
#  '부추무침',
#  '주꾸미',
#  '하이라이스',
#  '부침',
#  '오이장아찌',
#  '자몽',
#  '오징어순대',
#  '도미구이',
#  '유부국',
#  '산적',
#  '햄버그스테이크',
#  '강정',
#  '오미자차',
#  '묵무침',
#  '케이크',
#  '김구이',
#  '카레소스',
#  '나물',
#  '롤빵',
#  '구이',
#  '쌀죽',
#  '콘치즈구이',
#  '액상커피',
#  '열무물김치',
#  '전어구이',
#  '연근조림',
#  '토르티야',
#  '문어볶음',
#  '갈치',
#  '가죽나물',
#  '마늘종',
#  '참깨죽',
#  '오리고기구이',
#  '굴',
#  '카스텔라',
#  '소스',
#  '개피떡',
#  '오리볶음',
#  '잎무침',
#  '장어탕',
#  '주스',
#  '복숭아홍차',
#  '보리밥',
#  '전어',
#  '훠궈',
#  '무장아찌',
#  '무지개떡',
#  '페이스트리',
#  '탕평채',
#  '팥죽',
#  '닭조림',
#  '옥돔구이',
#  '더덕구이',
#  '된장국',
#  '오리탕',
#  '크로켓',
#  '시리얼',
#  '초당순두부',
#  '곰장어',
#  '감바스',
#  '김치전',
#  '잔치국수',
#  '황태구이',
#  '대창구이',
#  '오리백숙',
#  '달걀부침',
#  '넙치',
#  '수수부꾸미',
#  '바게트',
#  '냉채',
#  '유채',
#  '갈매기살',
#  '물침',
#  '무생채',
#  '팔보채',
#  '커피',
#  '해물찜',
#  '매생이국',
#  '돼지불고기',
#  '두부김치',
#  '소라고',
#  '증편',
#  '탕국',
#  '채소볶음',
#  '조개구이',
#  '호떡',
#  '햄부침',
#  '도가니탕',
#  '도라지생채',
#  '육개장',
#  '치킨가스',
#  '매운탕',
#  '마늘장아찌',
#  '타르트',
#  '소고기육개장',
#  '메밀소바',
#  '오징어채',
#  '나베',
#  '미역국',
#  '북어채',
#  '스크램블드에그',
#  '취나물무침',
#  '미역초무침',
#  '해물볶음',
#  '죽',
#  '치즈볼',
#  '해물칼국수',
#  '현미죽',
#  '초코',
#  '감자전',
#  '리소토',
#  '병어조림',
#  '단호박찜',
#  '모닝빵',
#  '고등어찌개',
#  '무',
#  '돼지고기볶음',
#  '송편',
#  '깻잎나물',
#  '허니브레드',
#  '라조기',
#  '두부전골',
#  '초무침',
#  '나물밥']

# %%
len(food_short)
# Out:
# 753

# %%
drop_name = ['대구','영양','소라고','모둠','조기','청자','결국','내장','다리','귀이','매작과']

# %%
food_short = [i for i in food_short if i not in drop_name]

# %%
len(food_short)
# Out:
# 742

# %%
food = food_lst + food_tmp + food_short

# %%
food_lst = list(set(food)) # 중복 제거
food_lst
# Out:
# ['새우탕',
#  '떡국',
#  '고추튀김',
#  '깻잎나물볶음',
#  '새우튀김',
#  '김',
#  '어탕',
#  '숙주미나리나물',
#  '두부 전',
#  '들깻잎 장아찌',
#  '수프',
#  '갈치구이',
#  '전복탕',
#  '새우전',
#  '미꾸라지',
#  '도라지나물',
#  '유채물김치',
#  '오겹살구이',
#  '소고기샤브샤브',
#  '호박죽',
#  '기피',
#  '불낙 전골',
#  '버섯조림',
#  '밤',
#  '어묵조림',
#  '조개젓',
#  '꼬막 찜',
#  '갑오징어무침',
#  '북어포',
#  '달걀국',
#  '닭발볶음',
#  '오리고기로',
#  '채소 튀김',
#  '중식 잡채',
#  '도넛',
#  '우럭',
#  '곤약',
#  '배춧국',
#  '에이드',
#  '순두부찌개',
#  '닭발구이',
#  '채소 죽',
#  '열무 얼갈이김치',
#  '완자전',
#  '소고기 산적',
#  '파래 전',
#  '게살죽',
#  '오리고기로스',
#  '다슬기 국 수',
#  '굴비구이',
#  '양파링',
#  '꽁치찌개',
#  '햄 채소볶음',
#  '미나리전',
#  '돼지갈비찜',
#  '소내장구이',
#  '라면',
#  '북어국',
#  '유채 물김치',
#  '치킨 데리야키',
#  '북어조림',
#  '우거지 나물 무침',
#  '달걀',
#  '기타 차',
#  '꽁치조림',
#  '애호박볶음',
#  '멸치젓',
#  '참치덮밥',
#  '옥수수 구이',
#  '닭죽',
#  '오이무침',
#  '깐풍 새우',
#  '해신탕',
#  '화양적',
#  '삼각김밥',
#  '미역줄기볶음',
#  '양파링튀김',
#  '미역튀각',
#  '소고기 볶음',
#  '꼬치구이',
#  '김치찌개',
#  '오므라이스',
#  '콩나물국',
#  '오징어찌개',
#  '낙지전골',
#  '김칫국',
#  '수수팥떡',
#  '초코 소라고 빵',
#  '과ㆍ체',
#  '마늘쫑무침',
#  '스테이크',
#  '우유',
#  '소갈비찜',
#  '부대찌개',
#  '오징어 국',
#  '배추 나물',
#  '파래무침',
#  '쥐포',
#  '소탕',
#  '순대전골',
#  '지리',
#  '북어찜',
#  '조기조림',
#  '톳 나물',
#  '소라산적',
#  '오징어 조림',
#  '호박오가리나물 무침',
#  '소고기 샤부샤부',
#  '꼬치구치',
#  '비름나물무침',
#  '배추겉절이',
#  '돼지고기찜',
#  '가오리콩나물찜',
#  '곤약무침',
#  '들깨국',
#  '고춧잎나물',
#  '호박오가리나물',
#  '가스',
#  '삼겹살 구이',
#  '콩나물밥',
#  '인절미',
#  '밴댕이 무침',
#  '피조개',
#  '뱅쇼',
#  '다슬기 국',
#  '찰떡 빵',
#  '카레라이스',
#  '런천미트',
#  '깐풍',
#  '프레즐',
#  '초콜릿',
#  '전',
#  '누룽지',
#  '샌드위치',
#  '깐쇼새우',
#  '밀크쉐이크',
#  '도라지나물무침',
#  '참나물겉절이',
#  '쑥갓나물',
#  '베이글',
#  '순대볶음',
#  '게국지',
#  '아이스티',
#  '씀바귀나물무침',
#  '천',
#  '고춧잎나물무침',
#  '된장무침',
#  '우동볶음',
#  '밀면',
#  '참치',
#  '난자완스',
#  '닭고기 육개장',
#  '김치찜',
#  '돼지고기 덮밥',
#  '수수밥',
#  '청경채 나물',
#  '불고기전골',
#  '고추',
#  '미음',
#  '유채나물',
#  '쑥갓나물 무침',
#  '우동',
#  '달',
#  '다식',
#  '풋고추찜',
#  '약과',
#  '얼갈이',
#  '콩 조림',
#  '풋고추볶음',
#  '붕어찜',
#  '생선까스',
#  '레몬홍차',
#  '발',
#  '치커리 겉절이',
#  '무나물무침',
#  '육회',
#  '오이지무침',
#  '치커리겉절이',
#  '건새우 볶음',
#  '갈치찌개',
#  '얼갈이배추김치',
#  '다쿠아즈',
#  '미트볼',
#  '연어구이',
#  '버섯찌개',
#  '칼국수',
#  '닭도리탕',
#  '떡',
#  '호박전',
#  '전복죽',
#  '갈매기살구이',
#  '쑥떡',
#  '효모빵',
#  '깐풍기',
#  '낙지볶음',
#  '들깻잎장아찌',
#  '불고기',
#  '두부',
#  '약식',
#  '세',
#  '쥐포튀김',
#  '차조밥',
#  '오이지',
#  '콩국수',
#  '아귀지리',
#  '얼갈이김치',
#  '빙떡',
#  '과일샐러드',
#  '구이',
#  '만두전골',
#  '감자국',
#  '동치미',
#  '삼겹살볶음',
#  '다시마무침',
#  '달걀찜',
#  '팥빵',
#  '애호박전',
#  '쌀밥',
#  '돌솥밥',
#  '아이스크림',
#  '닭다리구이',
#  '견과',
#  '물회',
#  '스콘',
#  '팟타이',
#  '마늘쫑장아찌',
#  '병어',
#  '오징어볶음',
#  '소세지빵',
#  '쑥갓나물무침',
#  '참치회덮밥',
#  '곰치국',
#  '차',
#  '기피편',
#  '총각김치',
#  '머위나물',
#  '고사리나물무침',
#  '우엉조림',
#  '돼지고기찌개',
#  '파전',
#  '고추잡채',
#  '더덕장아찌',
#  '브로콜리',
#  '다시마',
#  '닭날개구이',
#  '쥐포 조림',
#  '당근볶음',
#  '오리불고기',
#  '마늘쫑볶음',
#  '밀크티',
#  '열무 나물',
#  '주꾸미볶음',
#  '우럭회덮밥',
#  '민들레',
#  '김무침',
#  '크림빵',
#  '돼지갈비구이',
#  '버섯 구이',
#  '북어',
#  '두부 부침',
#  '셔벗',
#  '치즈스틱',
#  '연어롤',
#  '모카빵',
#  '새우튀김롤',
#  '과일 샐러드',
#  '소고기',
#  '오징어',
#  '가죽나물무침',
#  '모자반무침',
#  '라떼',
#  '기피 편',
#  '조갯국',
#  '콤부차',
#  '곤약 무침',
#  '기장밥',
#  '오징어국',
#  '생강차',
#  '시래기나물무침',
#  '새우',
#  '햄채소볶음',
#  '얼갈이겉절이',
#  '민들레 잎무침',
#  '달걀탕',
#  '오징어 산적',
#  '미나리나물',
#  '곰보빵',
#  '비빔국수',
#  '김치전골',
#  '양미리조림',
#  '돼지고기',
#  '수수경단',
#  '흑미밥',
#  '찰시루떡',
#  '황태',
#  '숙회',
#  '무나물',
#  '해물 콩나물찜',
#  '재첩국',
#  '오이냉국',
#  '떡만둣국',
#  '꿀차',
#  '북어 강정',
#  '만두국',
#  '미나리무침',
#  '도미찜',
#  '개고기 전골',
#  '무 조림',
#  '주먹밥',
#  '호박찌개',
#  '유자차',
#  '버섯구이',
#  '탕수육',
#  '홍어무침',
#  '마라탕',
#  '묵밥',
#  '오징어조림',
#  '꽃게탕',
#  '새송이버섯볶음',
#  '곰장어구이',
#  '꽃게 콩나물찜',
#  '해물',
#  '치즈빵',
#  '씀바귀나물',
#  '회',
#  '절편',
#  '피자빵',
#  '롤',
#  '과ㆍ체 주스',
#  '곰탕',
#  '레몬차',
#  '풋마늘무침',
#  '복어',
#  '깍두기',
#  '대구 찜',
#  '마카롱',
#  '볶음',
#  '새우구이',
#  '연포탕',
#  '시래기나물 무침',
#  '말이',
#  '달래무침',
#  '갈비탕',
#  '닭고기육개장',
#  '부추전',
#  '유과',
#  '꼬리곰탕',
#  '꿀떡',
#  '곱창볶음',
#  '사태찜',
#  '불낙전골',
#  '볶음밥',
#  '홍합산적',
#  '스무디',
#  '호박 찌개',
#  '톳 나물 무침',
#  '어육소시지',
#  '쥐포조림',
#  '장떡',
#  '소시지',
#  '내장전골',
#  '우롱차',
#  '소보로빵',
#  '짬뽕밥',
#  '가오리찜',
#  '곤드레밥',
#  '삼겹살',
#  '난젠완쯔',
#  '건새우',
#  '마테차',
#  '열무나물',
#  '돼지고기 찌개',
#  '오리고기로 스',
#  '떡만두국',
#  '귤차',
#  '파무침',
#  '수제비',
#  '코코아',
#  '스',
#  '꿩 불고기',
#  '맛탕',
#  '해물콩나물찜',
#  '감자조림',
#  '노각 무침',
#  '밥',
#  '감자구이',
#  '곤드레나물밥',
#  '톳나물',
#  '고추 조림',
#  '가자미조림',
#  '비스킷',
#  '어묵볶음',
#  '동탯국',
#  '구치',
#  '차돌박이',
#  '밀푀유나베',
#  '초밥',
#  '닭곰탕',
#  '풋고추 된장무침',
#  '무짠지',
#  '곰치',
#  '사골국',
#  '갈치젓',
#  '열무',
#  '북어강정',
#  '오곡밥',
#  '생선전',
#  '대구볼',
#  '연잎밥',
#  '맛살 천',
#  '홍어찜',
#  '갓김치',
#  '잡탕밥',
#  '가지전',
#  '돼지껍데기구이',
#  '수',
#  '멸치볶음',
#  '북어채무침',
#  '지리탕',
#  '마늘빵',
#  '머위대',
#  '쫄볶이',
#  '순대국',
#  '짜장밥',
#  '찰떡',
#  '밴댕이',
#  '톳나물초무침',
#  '오겹살',
#  '소대장',
#  '고사리나물',
#  '스프',
#  '홍어',
#  '콩',
#  '자몽차',
#  '잡채',
#  '콩나물찜',
#  '기타',
#  '꽃게장',
#  '양장피',
#  '돌솥비빔밥',
#  '가오리 찜',
#  '갈비구이',
#  '런천미트 구이',
#  '회덮밥',
#  '호박볶음',
#  '중식',
#  '월남쌈',
#  '해물파전',
#  '머위나물무침',
#  '죽순볶음',
#  '피조개무침',
#  '버터크림빵',
#  '김 무침',
#  '풋고추',
#  '등갈비찜',
#  '날개',
#  '꼬막무침',
#  '고구마전',
#  '단무지',
#  '미트볼 조림',
#  '비빔막국수',
#  '미역냉국',
#  '앙금빵',
#  '경단',
#  '만두',
#  '명란젓',
#  '아귀찜',
#  '고추조림',
#  '브로콜리볶음',
#  '소고기 버섯죽',
#  '얼갈이 겉절이',
#  '감자탕',
#  '꼬치 구치',
#  '건포도',
#  '버섯',
#  '찰밥',
#  '유채 김치',
#  '낙지찜',
#  '방풍나물무침',
#  '토란대나물무침',
#  '새우볶음',
#  '건포도빵',
#  '함박스테이크',
#  '톳 나물 초무침',
#  '오이소박이',
#  '냉면',
#  '알밥',
#  '사태',
#  '동태찌개',
#  '내장탕',
#  '계란빵',
#  '요구르트',
#  '마늘장아찌 무침',
#  '깻잎 찜',
#  '노각',
#  '복찜',
#  '잔멸치볶음',
#  '조기찜',
#  '조기 찜',
#  '동태전',
#  '번',
#  '깻잎 전',
#  '묵국',
#  '마늘종 볶음',
#  '파래전',
#  '가락국수 볶음',
#  '홍어 찜',
#  '뱅어포구이',
#  '깨찰빵',
#  '새송이버섯전',
#  '닭볶음탕',
#  '아귀',
#  '모자반',
#  '고추장볶음',
#  '대구볼찜',
#  '비빔밥',
#  '버섯 조림',
#  '햄버거',
#  '숙주',
#  '미소된장국',
#  '깻잎',
#  '튀김',
#  '황태해장국',
#  '국',
#  '만둣국',
#  '파김치',
#  '애호박찜',
#  '전골',
#  '표고버섯',
#  '고추장찌개',
#  '치커리',
#  '가자미구이',
#  '율무죽',
#  '무 초절임',
#  '시래기나물',
#  '닭구이',
#  '밴댕이무침',
#  '고등어조림',
#  '맛살',
#  '샐러드',
#  '짜장소스',
#  '깨죽',
#  '호밀빵',
#  '어묵탕',
#  '곰장어 구이',
#  '고구마 전',
#  '홍합 산적',
#  '깐풍새우',
#  '마파두부',
#  '낙지탕',
#  '마늘종 무침',
#  '달걀조림',
#  '청경채나물',
#  '모둠 찰떡',
#  '홍합',
#  '소고기산적',
#  '식빵',
#  '알탕',
#  '사과차',
#  '가래떡',
#  '수란',
#  '민들레잎무침',
#  '열무김치',
#  '팝콘',
#  '햄전',
#  '추로스',
#  '도토리묵무침',
#  '라테',
#  '닭튀김',
#  '모자반 무침',
#  '장어구이',
#  '고사리나물 무침',
#  '영양돌솥밥',
#  '백설기',
#  '콩밥',
#  '충무김밥',
#  '돈가스',
#  '상추겉절이',
#  '감자',
#  '김말이튀김',
#  '순댓국',
#  '나박김치',
#  '건포도 빵',
#  '꽃게',
#  '황태 콩나물찜',
#  '갈매기살 구이',
#  '콩나물국밥',
#  '코다리찜',
#  '골뱅이무침',
#  '라볶이',
#  '샤브샤브',
#  '런천미트구이',
#  '고들빼기김치',
#  '버섯무침',
#  '전어 찜',
#  '볶음면',
#  '맛살전',
#  '개고기무침',
#  '쟁반짜장',
#  '삼겹살구이',
#  '멸치조림',
#  '물김치',
#  '가락국수',
#  '국수',
#  '묵 말이',
#  '보쌈김치',
#  '젤리',
#  '소라 산적',
#  '어육소시지전',
#  '분짜',
#  '치즈',
#  '묵말이',
#  '표고버섯볶음',
#  '오징어젓',
#  '세 발 나물 무침',
#  '오징어채조림',
#  '잡곡밥',
#  '수육',
#  '가오리 콩나물찜',
#  '간재미',
#  '삼치',
#  '잡채밥',
#  '돼지껍질',
#  '닭모래집 튀김',
#  '닭찜',
#  '굴전',
#  '굴 무침',
#  '깻잎김치',
#  '귀리밥',
#  '백김치',
#  '레몬 청자',
#  '잔멸치',
#  '편',
#  '육탕',
#  '굴국',
#  '크루아상',
#  '오리',
#  '게장',
#  '두부찌개',
#  '파이',
#  '불낙',
#  '깻잎찜',
#  '삼치조림',
#  '무침',
#  '머위나물볶음',
#  '멘보샤',
#  '대구볼 찜',
#  '닭모래집볶음',
#  '막창구이',
#  '미꾸라지튀김',
#  '임연수 구이',
#  '찌개',
#  '오징어산적',
#  '돼지',
#  '개고기',
#  '참치 덮밥',
#  '오이생채',
#  '족발',
#  '햄',
#  '크로와상',
#  '동태찜',
#  '새우젓',
#  '북어채 무침',
#  '채소죽',
#  '버터빵',
#  '곱창전골',
#  '울면',
#  '자장면',
#  '방풍나물 무침',
#  '미나리 전',
#  '내장 전골',
#  '초절임',
#  '짜장 소스',
#  '허브차',
#  '양파',
#  '메밀국수',
#  '시루떡',
#  '오징어채무침',
#  '단무지무침',
#  '닭모래집 볶음',
#  '백합죽',
#  '다슬기',
#  '배추김치',
#  '달 결국',
#  '코다리조림',
#  '머핀',
#  '리조또',
#  '닭 다리 구이',
#  '토란국',
#  '캔디',
#  '옥수수',
#  '훈제오리',
#  '해장국',
#  '짬뽕',
#  '파래 볶음',
#  '닭',
#  '간자장',
#  '기타빵',
#  '곤드레 나물밥',
#  '순대',
#  '야채빵',
#  '고구마',
#  '콩조림',
#  '냉국',
#  '국밥',
#  '닭볶음',
#  '아구탕',
#  '차돌박이구이',
#  '머위나물 무침',
#  '닭 다리 튀김',
#  '감자볶음',
#  '황태콩나물찜',
#  '고춧잎나물 무침',
#  '가지나물',
#  '버섯전골',
#  '녹차',
#  '홍합탕',
#  '오징어채볶음',
#  '마늘장아찌무침',
#  '병어 찜',
#  '다시마튀각',
#  '숙주나물',
#  '소불고기',
#  '탄산음료',
#  '더덕무침',
#  '김치',
#  '꼬치',
#  '묵',
#  '쌀국수',
#  '청포묵무침',
#  '배추국',
#  '소고기전골',
#  '오이김치',
#  '빵',
#  '우거지',
#  '치킨데리야끼',
#  '버섯전',
#  '현미밥',
#  '동태조림',
#  '꽈리고추찜',
#  '떡갈비',
#  '버섯구이표고버섯',
#  '감자빵',
#  '잣죽',
#  '스파게티',
#  '땅콩조림',
#  '버섯죽',
#  '새우튀김 롤',
#  '채소튀김',
#  '미나리 무침',
#  '대구포',
#  '도라지나물 무침',
#  '취나물',
#  '삼계탕',
#  '양파 볶음',
#  '비름나물',
#  '톳',
#  '닭고기',
#  '양미리',
#  '가자미식해',
#  '쌍화차',
#  '떡볶이',
#  '잔멸치 볶음',
#  '다시마 무침',
#  '조기구이',
#  '메밀전',
#  '건새우볶음',
#  '유산슬',
#  '임연수',
#  '찜',
#  '가오리',
#  '조림',
#  '갈비찜',
#  '산자',
#  '과ㆍ채주스',
#  '초코소라빵',
#  '막국수',
#  '파래',
#  '두부조림',
#  '달걀말이',
#  '곤드레',
#  '미나리',
#  '꿩',
#  '와플',
#  '머위대나물무침',
#  '웨이퍼',
#  '소시지 빵',
#  '데리야키',
#  '햄 볶음',
#  '식혜',
#  '무나물 무침',
#  '주꾸미삼겹살',
#  '머위대 나물 무침',
#  '줄기나',
#  '북엇국',
#  '생선가스',
#  '동태',
#  '소라',
#  '매실장아찌',
#  '짜장',
#  '김말이',
#  '곰치 국',
#  '숙주 미나리나물',
#  '병어찜',
#  '채소',
#  '또띠아',
#  '느타리버섯무침',
#  '배추나물',
#  '된장찌개',
#  '대구찜',
#  '가지볶음',
#  '곰장어',
#  '개고기 무침',
#  '떡 강정',
#  '노각무침',
#  '기스면',
#  '파래볶음',
#  '양파볶음',
#  '추어탕',
#  '옥수수구이',
#  '토란대나물',
#  '청국장찌개',
#  '푸딩',
#  '버섯 구이 표고버섯',
#  '불고기 전골',
#  '아귀탕',
#  '풋마늘',
#  '갈치조림',
#  '홍차',
#  '오징어채 조림',
#  '회무침',
#  '해물탕',
#  '선짓국',
#  '부추김치',
#  '자몽홍차',
#  '느타리버섯볶음',
#  '냉이나물',
#  '소시지볶음',
#  '영양 돌솥밥',
#  '음료',
#  '물',
#  '레몬',
#  '삼치구이',
#  '어육소시지 전',
#  '풋고추된장무침',
#  '닭모래집',
#  '꼬막',
#  '캘리포니아롤',
#  '조개국',
#  '호박',
#  '레몬청차',
#  '율무밥',
#  '낙지 무침',
#  '덮밥',
#  '브로콜리 볶음',
#  '개고기전골',
#  '모싯잎송편',
#  '장아찌',
#  '죽순',
#  '쫄면',
#  '채소전',
#  '방풍나물',
#  '낙지 찜',
#  '김치볶음',
#  '차돌박이 귀이',
#  '밀크셰이크',
#  '빙수',
#  '어죽',
#  '닭백숙',
#  '돌나물',
#  '모듬찰떡',
#  '간재미회무침',
#  '해초무침',
#  '라멘',
#  '미숫가루',
#  '기타음료',
#  '전어찜',
#  '배추',
#  '감잣국',
#  '동파육',
#  '대추차',
#  '낙지',
#  '재첩',
#  '피자',
#  '고구마튀김',
#  '소고기볶음',
#  '청경채',
#  '비빔면',
#  '배추전',
#  '시금치나물',
#  '오리 죽',
#  '기타 음료',
#  '설렁탕',
#  '치아바타',
#  '어묵국',
#  '자장밥',
#  '고구마줄기나물',
#  '양파링 튀김',
#  '흑임자죽',
#  '마늘종 장아찌',
#  '매작과',
#  '콩비지찌개',
#  '임연수구이',
#  '김밥',
#  '고등어구이',
#  '두릅무침',
#  '과일',
#  '겉절이',
#  '굴무침',
#  '씀바귀나물 무침',
#  '닭다리튀김',
#  '토스트',
#  '동태국',
#  '재첩 국',
#  '장조림',
#  '탄탄면',
#  '버섯볶음',
#  '콩나물무침',
#  '호박오가리나물무침',
#  '곱창구이',
#  '꿩불고기',
#  '고추전',
#  '참치 회 덮밥',
#  '녹두빈대떡',
#  '계란덮밥',
#  '찹쌀떡',
#  '고추장아찌',
#  '떡강정',
#  '김말이 튀김',
#  '돌나물무침',
#  '소고기버섯죽',
#  '꽁치구이',
#  '간재미 회 무침',
#  '건표고버섯볶음',
#  '무말랭이무침',
#  '김튀김',
#  '핫도그',
#  '참치죽',
#  '치킨',
#  '들깻잎',
#  '뭇국',
#  '복어 튀김',
#  '버거',
#  '참치구이',
#  '참나물',
#  '오징어무침',
#  '감자튀김',
#  '샤부샤부',
#  '소고기 전골',
#  '부추무침',
#  '황태 해장국',
#  '무국',
#  '기타 빵',
#  '샤베트',
#  '하이라이스',
#  '오이장아찌',
#  '주꾸미',
#  '오징어순대',
#  '부침',
#  '자몽',
#  '도미구이',
#  '올갱이국수',
#  '동태까스',
#  '산적',
#  '유부국',
#  '돼지껍질 구이',
#  '햄버그스테이크',
#  '쥐포 튀김',
#  '강정',
#  '오미자차',
#  '묵무침',
#  '갈치 찌개',
#  '미꾸라지 튀김',
#  '케이크',
#  '김구이',
#  '카레소스',
#  '나물',
#  '롤빵',
#  '전어구이',
#  '쌀죽',
#  '콘치즈구이',
#  '액상커피',
#  '열무물김치',
#  '피조개 무침',
#  '연근조림',
#  '양미리 조림',
#  '토르티야',
#  '문어볶음',
#  '갈치',
#  '가죽나물',
#  '복어튀김',
#  '마늘종',
#  '참깨죽',
#  '올갱이국',
#  '돼지 등갈비찜',
#  '오리고기구이',
#  '굴',
#  '카스텔라',
#  '소스',
#  '개피떡',
#  ...]

# %%
all_food = [word for word in food_lst if len(word) > 1]

# %% [markdown]
# - 빠진 음식이름 추가

# %%
food_add = ['펩시콜라','똠얌꿍','닭','목살','얌꿍','꽈리고추','파스타']

# %%
all_food.extend(food_add)

# %%
all_food.remove('파이')

# %%
if '닭' in all_food:
    print("True")
else:
    print("False")
# Out:
# True

# %%
train_df['food'] = train_df['corrected_reply'].apply(lambda x: next((food for food in all_food if food in x), " "))

# %%
train_df.head()
# Out:
#                                                 고객리뷰  \
# 0                          맛있게 잘먹었습니다 묵사발도 시원하니 맛있네요
# 1                         기름 있는 부분이 생각보다 많아요! 참고하세요
# 2    양도 푸짐하고 맛있습니다! 청국장 냄새 많이 안나고 콩도 많이 들어있어서 좋았습니다!
# 3                                                .,.
# 4  냉면을 따로 시키고 미니냉면을 합친것인데 양이 좀 적어보이고. 김치정식도 양이 적어...
#
#                                      corrected_reply store branch food
# 0  즐거운 순간을 저희와 함께해 주셔서 감사합니다 보람차게 일할 수 있게 해 주셔서 감...
# 1  소중한 의견 남겨 주셔서 감사합니다. 잘 새겨듣고 앞으로 더욱더 개선할 수 있도록 ...
# 2  늘 최고의 메뉴를 제공해 드리고 싶습니다! 맛있는 메뉴를 넉넉하게 먹을 수 있는 것...
# 3  저희 매장과 함께 편안한 시간 되셨을까요? 1. 고객을 생각하는 마음 2. 더 나은...
# 4  이번 주문을 통해 한걸음 더 가까워진 것 같아 기분이 좋아요! 고객님의 행복한 시간...

# %% [markdown]
# ##6_긍/부정 라벨 컬럼화

# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.33.2-py3-none-any.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 72.1 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.2)
# Collecting huggingface-hub<1.0,>=0.15.1 (from transformers)
#   Downloading huggingface_hub-0.17.2-py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 16.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 88.7 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 73.6 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Installing collected packages: tokenizers, safetensors, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.17.2 safetensors-0.3.3 tokenizers-0.13.3 transformers-4.33.2

# %%
import pandas as pd
from transformers import pipeline

def analyze_reviews(reviews):
    # 모델 불러오기
    model_name = "MLOpsEngineer/review-rate-prediction"
    classifier = pipeline("sentiment-analysis", model=model_name)

    results = []
    for review_text in tqdm(reviews):
        # 모델 추론
        result = classifier(review_text)[0]

        # 결과 해석
        label = result['label']
        score = result['score']

        if label in ['LABEL_0', 'LABEL_1']:
            sentiment = 0 # '부정'
        else:
            sentiment = 1 # '긍정'

        results.append((review_text, sentiment, score))

    # 데이터프레임 생성
    tmp = pd.DataFrame(results, columns=['review', 'sentiment', 'score'])
    return tmp

# %%
sentiment_train = analyze_reviews(train['고객리뷰'])
sentiment_train
# Out:
#   0%|          | 0/37140 [00:00<?, ?it/s]
#                                                   review  sentiment     score
# 0                              맛있게 잘먹었습니다 묵사발도 시원하니 맛있네요          1  0.566494
# 1                             기름 있는 부분이 생각보다 많아요! 참고하세요           0  0.723872
# 2        양도 푸짐하고 맛있습니다! 청국장 냄새 많이 안나고 콩도 많이 들어있어서 좋았습니다!          1  0.608408
# 3                                                    .,.          0  0.499478
# 4      냉면을 따로 시키고 미니냉면을 합친것인데 양이 좀 적어보이고. 김치정식도 양이 적어...          1  0.381793
# ...                                                  ...        ...       ...
# 37135  맛있어요 저번에주문하고 맛있어서또주문핰건데 늦은시간에시켜서그렄지 국물이 엄청 걸쭉하...          1  0.424215
# 37136                                         맛있어요 또시킬게요          1  0.720691
# 37137                           정말 맛있게 잘먹었어요!자주 시켜 먹을께요!          1  0.833007
# 37138  와우. 여기뭐죠 주변에서 맛있다고 먹어보라해서 시켰는데 육수가 일단 시원칼칼하니 조...          1  0.900031
# 37139  제발 양파추가 선택란 하나 만들어주세요. 단무지대신 양파달라고 요청써놨지만 바쁠때 ...          1  0.431002
#
# [37140 rows x 3 columns]

# %% [markdown]
# - Sentiment(긍/부정 사전학습 결과) 비율

# %%
for i in range(0, 2):
    num_rating = sentiment_train[sentiment_train['sentiment'] == i].shape[0]
    print(f"별점 {i}점 개수: {num_rating}, {num_rating / sentiment_train.shape[0] * 100}%")
# Out:
# 별점 0점 개수: 1824, 4.911147011308562%
# 별점 1점 개수: 35316, 95.08885298869144%

# %% [markdown]
# - 저장해 놓은 긍/부정 결과 불러오기

# %%
sentiment_train = pd.read_csv(f"{DATA_PATH}train+sentiment_0913.csv")
sentiment_train
# Out:
#                                                     고객리뷰  \
# 0                              맛있게 잘먹었습니다 묵사발도 시원하니 맛있네요
# 1                             기름 있는 부분이 생각보다 많아요! 참고하세요
# 2        양도 푸짐하고 맛있습니다! 청국장 냄새 많이 안나고 콩도 많이 들어있어서 좋았습니다!
# 3                                                    .,.
# 4      냉면을 따로 시키고 미니냉면을 합친것인데 양이 좀 적어보이고. 김치정식도 양이 적어...
# ...                                                  ...
# 37135  맛있어요 저번에주문하고 맛있어서또주문핰건데 늦은시간에시켜서그렄지 국물이 엄청 걸쭉하...
# 37136                                         맛있어요 또시킬게요
# 37137                           정말 맛있게 잘먹었어요!자주 시켜 먹을께요!
# 37138  와우. 여기뭐죠 주변에서 맛있다고 먹어보라해서 시켰는데 육수가 일단 시원칼칼하니 조...
# 37139  제발 양파추가 선택란 하나 만들어주세요. 단무지대신 양파달라고 요청써놨지만 바쁠때 ...
#
#                                                     사장댓글 store branch food  \
# 0      즐거운 순간을 저희와 함께해주셔서 감사합니다 보람차게 일할 수 있게 해 주셔서 감사...
# 1      소중한 의견 남겨 주셔서 감사합니다. 잘 새겨 듣고 앞으로 더욱 더 개선 할 수 있...
# 2      늘 최고의 메뉴를 제공해드리고 싶습니다! 맛있는 메뉴를 넉넉하게 먹을 수 있는 것보...
# 3      저희 매장과 함께 편안한 시간 되셨을까요? 1. 고객을 생각하는 마음 2. 더 나은...
# 4      이번 주문을 통해 한걸음 더 가까워진 것 같아 기분이 좋아요! 고객님의 행복한 시간...
# ...                                                  ...   ...    ...  ...
# 37135  고객님 안녕하세요 짬뽕관입니다~ 소중한 리뷰 너무 감사합니다! 재주문해 주셨는데 국...   짬뽕관          짬뽕
# 37136  고객님 안녕하요 짬뽕관입니다! 소중한 리뷰 남겨주셔 서 정말 달감사합니다! 만족스러...   짬뽕관          짬뽕
# 37137  고객님 안녕하세요 짬뽕관입니다~ 맛있게 드셨다는 말씀에 힘이 나는거 같습니다 항상 ...   짬뽕관          짬뽕
# 37138  고객님 안녕하세요 짬뽕관입니다! 맛있게 드셔주시고 정성스러운 사진 리뷰까지 정말 감...   짬뽕관          짬뽕
# 37139  고객님 안녕하세요 우선 소중한 리뷰 감사합니다 배달이 몰리는 시간대여서 실수가 있었...
#
#        sentiment
# 0              1
# 1              0
# 2              1
# 3              0
# 4              1
# ...          ...
# 37135          1
# 37136          1
# 37137          1
# 37138          1
# 37139          1
#
# [37140 rows x 6 columns]

# %%
sentiment_train = sentiment_train[['사장댓글','sentiment']]

# %%
df = pd.concat([train_df, sentiment_train], axis=1)
df.head()
# Out:
#                                                 고객리뷰  \
# 0                          맛있게 잘먹었습니다 묵사발도 시원하니 맛있네요
# 1                         기름 있는 부분이 생각보다 많아요! 참고하세요
# 2    양도 푸짐하고 맛있습니다! 청국장 냄새 많이 안나고 콩도 많이 들어있어서 좋았습니다!
# 3                                                .,.
# 4  냉면을 따로 시키고 미니냉면을 합친것인데 양이 좀 적어보이고. 김치정식도 양이 적어...
#
#                                      corrected_reply store branch food  \
# 0  즐거운 순간을 저희와 함께해 주셔서 감사합니다 보람차게 일할 수 있게 해 주셔서 감...
# 1  소중한 의견 남겨 주셔서 감사합니다. 잘 새겨듣고 앞으로 더욱더 개선할 수 있도록 ...
# 2  늘 최고의 메뉴를 제공해 드리고 싶습니다! 맛있는 메뉴를 넉넉하게 먹을 수 있는 것...
# 3  저희 매장과 함께 편안한 시간 되셨을까요? 1. 고객을 생각하는 마음 2. 더 나은...
# 4  이번 주문을 통해 한걸음 더 가까워진 것 같아 기분이 좋아요! 고객님의 행복한 시간...
#
#                                                 사장댓글  sentiment
# 0  즐거운 순간을 저희와 함께해주셔서 감사합니다 보람차게 일할 수 있게 해 주셔서 감사...          1
# 1  소중한 의견 남겨 주셔서 감사합니다. 잘 새겨 듣고 앞으로 더욱 더 개선 할 수 있...          0
# 2  늘 최고의 메뉴를 제공해드리고 싶습니다! 맛있는 메뉴를 넉넉하게 먹을 수 있는 것보...          1
# 3  저희 매장과 함께 편안한 시간 되셨을까요? 1. 고객을 생각하는 마음 2. 더 나은...          0
# 4  이번 주문을 통해 한걸음 더 가까워진 것 같아 기분이 좋아요! 고객님의 행복한 시간...          1

# %%
df = df[['고객리뷰','corrected_reply','store','branch','food','sentiment']]
df
# Out:
#                                                     고객리뷰  \
# 0                              맛있게 잘먹었습니다 묵사발도 시원하니 맛있네요
# 1                             기름 있는 부분이 생각보다 많아요! 참고하세요
# 2        양도 푸짐하고 맛있습니다! 청국장 냄새 많이 안나고 콩도 많이 들어있어서 좋았습니다!
# 3                                                    .,.
# 4      냉면을 따로 시키고 미니냉면을 합친것인데 양이 좀 적어보이고. 김치정식도 양이 적어...
# ...                                                  ...
# 37135  맛있어요 저번에주문하고 맛있어서또주문핰건데 늦은시간에시켜서그렄지 국물이 엄청 걸쭉하...
# 37136                                         맛있어요 또시킬게요
# 37137                           정말 맛있게 잘먹었어요!자주 시켜 먹을께요!
# 37138  와우. 여기뭐죠 주변에서 맛있다고 먹어보라해서 시켰는데 육수가 일단 시원칼칼하니 조...
# 37139  제발 양파추가 선택란 하나 만들어주세요. 단무지대신 양파달라고 요청써놨지만 바쁠때 ...
#
#                                          corrected_reply store branch food  \
# 0      즐거운 순간을 저희와 함께해 주셔서 감사합니다 보람차게 일할 수 있게 해 주셔서 감...
# 1      소중한 의견 남겨 주셔서 감사합니다. 잘 새겨듣고 앞으로 더욱더 개선할 수 있도록 ...
# 2      늘 최고의 메뉴를 제공해 드리고 싶습니다! 맛있는 메뉴를 넉넉하게 먹을 수 있는 것...
# 3      저희 매장과 함께 편안한 시간 되셨을까요? 1. 고객을 생각하는 마음 2. 더 나은...
# 4      이번 주문을 통해 한걸음 더 가까워진 것 같아 기분이 좋아요! 고객님의 행복한 시간...
# ...                                                  ...   ...    ...  ...
# 37135  고객님 안녕하세요 짬뽕과입니다~ 소중한 리뷰 너무 감사합니다! 재주문해 주셨는데 국...   짬뽕과          짬뽕
# 37136  고객님 안녕하오 짬뽕과입니다! 소중한 리뷰 남겨주셔 서 정말 달 감사합니다! 만족스...   짬뽕과          짬뽕
# 37137  고객님 안녕하세요 짬뽕과입니다~ 맛있게 드셨다는 말씀에 힘이 나는 거 같습니다 항상...   짬뽕과          짬뽕
# 37138  고객님 안녕하세요 짬뽕과입니다! 맛있게 드셔주시고 정성스러운 사진 리뷰까지 정말 감...   짬뽕과          짬뽕
# 37139  고객님 안녕하세요 우선 소중한 리뷰 감사합니다 배달이 몰리는 시간대여서 실수가 있었...
#
#        sentiment
# 0              1
# 1              0
# 2              1
# 3              0
# 4              1
# ...          ...
# 37135          1
# 37136          1
# 37137          1
# 37138          1
# 37139          1
#
# [37140 rows x 6 columns]

# %%
df.columns = ['고객리뷰','사장댓글','store','branch','food','sentiment']
df.head()
# Out:
#                                                 고객리뷰  \
# 0                          맛있게 잘먹었습니다 묵사발도 시원하니 맛있네요
# 1                         기름 있는 부분이 생각보다 많아요! 참고하세요
# 2    양도 푸짐하고 맛있습니다! 청국장 냄새 많이 안나고 콩도 많이 들어있어서 좋았습니다!
# 3                                                .,.
# 4  냉면을 따로 시키고 미니냉면을 합친것인데 양이 좀 적어보이고. 김치정식도 양이 적어...
#
#                                                 사장댓글 store branch food  \
# 0  즐거운 순간을 저희와 함께해 주셔서 감사합니다 보람차게 일할 수 있게 해 주셔서 감...
# 1  소중한 의견 남겨 주셔서 감사합니다. 잘 새겨듣고 앞으로 더욱더 개선할 수 있도록 ...
# 2  늘 최고의 메뉴를 제공해 드리고 싶습니다! 맛있는 메뉴를 넉넉하게 먹을 수 있는 것...
# 3  저희 매장과 함께 편안한 시간 되셨을까요? 1. 고객을 생각하는 마음 2. 더 나은...
# 4  이번 주문을 통해 한걸음 더 가까워진 것 같아 기분이 좋아요! 고객님의 행복한 시간...
#
#    sentiment
# 0          1
# 1          0
# 2          1
# 3          0
# 4          1

# %% [markdown]
# # GPT 데이터셋 불러오기

# %%
gpt = pd.read_csv(f"{DATA_PATH}gpt_neg_9300.csv")
gpt
# Out:
#                                         original_review  \
# 0               맛도 양도 모두 만족합니다 배달도 정확히 보내 주시고 아주 만족합니다.
# 1                                       너무 맛있게 잘 먹었습니다!
# 2                              너무 배고파서 먹다가 찍었어요. 너무맛있어요
# 3     두번째시켜요~ 이번엔 아이들이 잡채가 먹고싶대서 주문해봤는데 고기도 많이 들어가있고...
# 4                                         푸짐하고 너무 맛있어용~
# ...                                                 ...
# 9318                                       늘믿고먹어요 싱싱맛나요
# 9319                              초밥은 늘 여기만 주문해요. 늘 맛나요
# 9320          해장하려구 시켰는데 진짜 맛있네용 . 다음에 또 시켜먹을게요 감사합니다 !
# 9321                   늘 맛있어요~ 사진이 없어요~ 또 시킬께요~예쁜사진과 함께
# 9322                           멘보샤 정말맛있고 새우많이들었어요 크기도커요
#
#                                          original_reply  rating  \
# 0     안녕하세요! 주문해 주셔서 진심으로 감사드려요! 이렇게 좋은 리뷰 써 주시니, 메뉴...       5
# 1     즐거운 순간을 저희와 함께해주셔서 감사합니다 보람차게 일할 수 있게 해 주셔서 감사...       5
# 2     행복한 하루를 만들어 주셔서 감사합니다 직접 드시는 건데 맛은 당연히 좋아야 된다고...       5
# 3     다시 주문해 주셔서 감사합니다 저희 메뉴 맛있죠? 이제 점점 저희 메뉴만 생각 나실...       5
# 4     이렇게 저희를 선택해 주셔서 감사합니다~ ~ 맛있게 먹다가 양이 부족하다.? 저는 ...       5
# ...                                                 ...     ...
# 9318  안녕하세요~ 상무초밥 유성점입니다~! 저희 매장을 이용해주셔서 정말 감사드립니다! ...       5
# 9319  안녕하세요~ 상무초밥 유성점입니다~! 저희 매장을 이용해주셔서 정말 감사드립니다! ...       5
# 9320  안 녕 하세요 해장은 잘 하셨어요? 속풀이에도 좋고 한잔 할때도 좋고 다 어울리지요...       5
# 9321  감사합니다 다음에는 예쁜 사진 기대할게요. 오늘도 좋은 하루 되세요. 또 맛있게 뵙...       5
# 9322  저희 도야짬뽕 계림점을 찾아 주셔서 감사합니다! 소중한 사진과 함께 리뷰까지 남겨주...       5
#
#                                              gpt_review  \
# 0          김치찌개는 별로였어요. 약간 김치국 느낌이 나서 실망했어요. 고기도 별로였고.
# 1                       양이 너무 많아서 배터질뻔했어요. 서비스도 별로였어요.
# 2          음식이 너무 싱겁고 부족해서 맛이 없었어요. 배달도 늦게 왔고 실망스러웠어요.
# 3                 잡채는 짜다고 하지도 않았는데 맛이 진짜 짜요. 먹기 어려웠어요.
# 4                  가격에 비해 음식의 양도 적고 맛도 별로였어요. 실망이었습니다.
# ...                                                 ...
# 9318  맛이 별로였어요, 음식이 촉촉하지 않고 식어서 먹기가 좀 그랬네요. 다음에는 안시킬...
# 9319                          맛도 없고, 배달도 늦어서 너무 실망했습니다
# 9320                       진짜 최악이었어요. 맛도 없고 배달도 오래걸렸어요
# 9321                    완전 별로였어요. 음식이 시큼해서 입에 맞지가 않았어요
# 9322                   다른 음식점 주문해서 먹을걸 그랬어요. 정말 실망했습니다
#
#                                               gpt_reply  sentiment     score
# 0     안녕하세요. 김치찌개와 고기에 대한 실망을 드려 죄송합니다. 지속적인 품질 개선을 ...          0  0.908812
# 1     배터질뻔하셨다니 정말 안타깝습니다. 양에 대한 조정을 더 신경써야겠습니다. 불편을 ...          0  0.820514
# 2     음식 맛과 배달 시간에 대한 실망을 드려 죄송합니다. 앞으로 더 신속하고 맛있는 음...          0  0.941290
# 3     잡채가 짜다는 피드백을 반영하지 못해 죄송합니다. 더 맛있고 조리하기 쉽도록 개선하...          0  0.910234
# 4     가격과 맛에 대한 실망을 드려 죄송합니다. 더 다양한 메뉴와 향상된 품질로 보답하겠...          0  0.928585
# ...                                                 ...        ...       ...
# 9318  안녕하세요, 고객님. 말씀해주신 점 먼저 진심으로 사과드립니다. 맛과 촉감에 실망하...          0  0.942769
# 9319  고객님께 실망을 드려 죄송합니다. 저희 음식이 맛있지 않아서 큰 실망을 받으셨군요....          0  0.912723
# 9320  맛이 없고 배달이 늦어서 정말 죄송합니다. 저희는 항상 맛과 배달 시간을 최우선으로...          0  0.894588
# 9321  고객님께 실망을 드려 정말 죄송합니다. 음식에 대한 맛과 냄새에 대한 불만을 제기해...          0  0.933854
# 9322  진심으로 죄송합니다. 맛과 배달 속도에 대한 실망을 드린 점 정말 죄송합니다. 저희...          0  0.910645
#
# [9323 rows x 7 columns]

# %%
# 긍정 데이터 확인
gpt[gpt['sentiment'] == 1]
# Out:
# Empty DataFrame
# Columns: [original_review, original_reply, rating, gpt_review, gpt_reply, sentiment, score]
# Index: []

# %%
# 결측치 확인
gpt.isnull().sum()
# Out:
# original_review    0
# original_reply     0
# rating             0
# gpt_review         0
# gpt_reply          0
# sentiment          0
# score              0
# dtype: int64

# %%
gpt = gpt[['gpt_review','gpt_reply','sentiment']]
# gpt['sentiment'] = 0 # 부정 -> 0
gpt.head()
# Out:
#                                      gpt_review  \
# 0  김치찌개는 별로였어요. 약간 김치국 느낌이 나서 실망했어요. 고기도 별로였고.
# 1               양이 너무 많아서 배터질뻔했어요. 서비스도 별로였어요.
# 2  음식이 너무 싱겁고 부족해서 맛이 없었어요. 배달도 늦게 왔고 실망스러웠어요.
# 3         잡채는 짜다고 하지도 않았는데 맛이 진짜 짜요. 먹기 어려웠어요.
# 4          가격에 비해 음식의 양도 적고 맛도 별로였어요. 실망이었습니다.
#
#                                            gpt_reply  sentiment
# 0  안녕하세요. 김치찌개와 고기에 대한 실망을 드려 죄송합니다. 지속적인 품질 개선을 ...          0
# 1  배터질뻔하셨다니 정말 안타깝습니다. 양에 대한 조정을 더 신경써야겠습니다. 불편을 ...          0
# 2  음식 맛과 배달 시간에 대한 실망을 드려 죄송합니다. 앞으로 더 신속하고 맛있는 음...          0
# 3  잡채가 짜다는 피드백을 반영하지 못해 죄송합니다. 더 맛있고 조리하기 쉽도록 개선하...          0
# 4  가격과 맛에 대한 실망을 드려 죄송합니다. 더 다양한 메뉴와 향상된 품질로 보답하겠...          0

# %% [markdown]
# ## 특이 패턴(','), '사장님의 답변이 없습니다 ,' 제거

# %%
gpt[gpt['gpt_reply'].str.contains("사장님의 답변이 없습니다 ,")]
# Out:
# Empty DataFrame
# Columns: [gpt_review, gpt_reply, sentiment]
# Index: []

# %%
reply_list = []
for reply in gpt['gpt_reply']:
    if isinstance(reply, str):
        pat = r'^\s*,\s*'
        result = re.sub(pat, '', reply)
        reply_list.append(result)
    else:
        reply_list.append("")

gpt['gpt_reply'] = reply_list
gpt.head()

# %%
gpt = gpt[~gpt['gpt_reply'].str.contains("사장님의 답변이 없습니다 ,")]
gpt

# %% [markdown]
# ## 공백으로 시작하는 텍스트 제거

# %%
reply_list = []
for reply in gpt['gpt_reply']:
    if isinstance(reply, str):
        pat = r'^\s*'
        result = re.sub(pat, '', reply)
        reply_list.append(result)
    else:
        reply_list.append("")

gpt['gpt_reply'] = reply_list
gpt.head()
# Out:
# <ipython-input-12-be1eec3393e8>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gpt['gpt_reply'] = reply_list
#                                      gpt_review  \
# 0  김치찌개는 별로였어요. 약간 김치국 느낌이 나서 실망했어요. 고기도 별로였고.
# 1               양이 너무 많아서 배터질뻔했어요. 서비스도 별로였어요.
# 2  음식이 너무 싱겁고 부족해서 맛이 없었어요. 배달도 늦게 왔고 실망스러웠어요.
# 3         잡채는 짜다고 하지도 않았는데 맛이 진짜 짜요. 먹기 어려웠어요.
# 4          가격에 비해 음식의 양도 적고 맛도 별로였어요. 실망이었습니다.
#
#                                            gpt_reply  sentiment
# 0  안녕하세요. 김치찌개와 고기에 대한 실망을 드려 죄송합니다. 지속적인 품질 개선을 ...          0
# 1  배터질뻔하셨다니 정말 안타깝습니다. 양에 대한 조정을 더 신경써야겠습니다. 불편을 ...          0
# 2  음식 맛과 배달 시간에 대한 실망을 드려 죄송합니다. 앞으로 더 신속하고 맛있는 음...          0
# 3  잡채가 짜다는 피드백을 반영하지 못해 죄송합니다. 더 맛있고 조리하기 쉽도록 개선하...          0
# 4  가격과 맛에 대한 실망을 드려 죄송합니다. 더 다양한 메뉴와 향상된 품질로 보답하겠...          0

# %%
review_list = []
for review in gpt['gpt_review']:
    if isinstance(review, str):
        pat = r'^\s*'
        result = re.sub(pat, '', review)
        review_list.append(result)
    else:
        review_list.append("")
gpt['gpt_review'] = review_list
gpt.head()
# Out:
# <ipython-input-13-82fa37e5f8af>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gpt['gpt_review'] = review_list
#                                      gpt_review  \
# 0  김치찌개는 별로였어요. 약간 김치국 느낌이 나서 실망했어요. 고기도 별로였고.
# 1               양이 너무 많아서 배터질뻔했어요. 서비스도 별로였어요.
# 2  음식이 너무 싱겁고 부족해서 맛이 없었어요. 배달도 늦게 왔고 실망스러웠어요.
# 3         잡채는 짜다고 하지도 않았는데 맛이 진짜 짜요. 먹기 어려웠어요.
# 4          가격에 비해 음식의 양도 적고 맛도 별로였어요. 실망이었습니다.
#
#                                            gpt_reply  sentiment
# 0  안녕하세요. 김치찌개와 고기에 대한 실망을 드려 죄송합니다. 지속적인 품질 개선을 ...          0
# 1  배터질뻔하셨다니 정말 안타깝습니다. 양에 대한 조정을 더 신경써야겠습니다. 불편을 ...          0
# 2  음식 맛과 배달 시간에 대한 실망을 드려 죄송합니다. 앞으로 더 신속하고 맛있는 음...          0
# 3  잡채가 짜다는 피드백을 반영하지 못해 죄송합니다. 더 맛있고 조리하기 쉽도록 개선하...          0
# 4  가격과 맛에 대한 실망을 드려 죄송합니다. 더 다양한 메뉴와 향상된 품질로 보답하겠...          0

# %% [markdown]
# ## 영어 답변 제거

# %%
gpt[gpt['gpt_reply'].str.match('^[a-zA-Z]')]
# Out:
# Empty DataFrame
# Columns: [gpt_review, gpt_reply, sentiment]
# Index: []

# %%
gpt = gpt[~gpt['gpt_reply'].str.match('^[a-zA-Z]')]
gpt

# %%
gpt['food'] = gpt['gpt_reply'].apply(lambda x: next((food for food in all_food if food in x), " "))
# Out:
# <ipython-input-65-38c5204b18c2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gpt['food'] = gpt['gpt_reply'].apply(lambda x: next((food for food in all_food if food in x), " "))

# %%
gpt.head()
# Out:
#                                      gpt_review  \
# 0  김치찌개는 별로였어요. 약간 김치국 느낌이 나서 실망했어요. 고기도 별로였고.
# 1               양이 너무 많아서 배터질뻔했어요. 서비스도 별로였어요.
# 2  음식이 너무 싱겁고 부족해서 맛이 없었어요. 배달도 늦게 왔고 실망스러웠어요.
# 3         잡채는 짜다고 하지도 않았는데 맛이 진짜 짜요. 먹기 어려웠어요.
# 4          가격에 비해 음식의 양도 적고 맛도 별로였어요. 실망이었습니다.
#
#                                            gpt_reply  sentiment food
# 0  안녕하세요. 김치찌개와 고기에 대한 실망을 드려 죄송합니다. 지속적인 품질 개선을 ...          0   김치
# 1  배터질뻔하셨다니 정말 안타깝습니다. 양에 대한 조정을 더 신경써야겠습니다. 불편을 ...          0
# 2  음식 맛과 배달 시간에 대한 실망을 드려 죄송합니다. 앞으로 더 신속하고 맛있는 음...          0
# 3  잡채가 짜다는 피드백을 반영하지 못해 죄송합니다. 더 맛있고 조리하기 쉽도록 개선하...          0   잡채
# 4  가격과 맛에 대한 실망을 드려 죄송합니다. 더 다양한 메뉴와 향상된 품질로 보답하겠...          0

# %%
gpt['store'] = ''
gpt['branch'] = ''
gpt.head()
# Out:
# <ipython-input-67-6c7f168ddb52>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gpt['store'] = ''
# <ipython-input-67-6c7f168ddb52>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gpt['branch'] = ''
#                                      gpt_review  \
# 0  김치찌개는 별로였어요. 약간 김치국 느낌이 나서 실망했어요. 고기도 별로였고.
# 1               양이 너무 많아서 배터질뻔했어요. 서비스도 별로였어요.
# 2  음식이 너무 싱겁고 부족해서 맛이 없었어요. 배달도 늦게 왔고 실망스러웠어요.
# 3         잡채는 짜다고 하지도 않았는데 맛이 진짜 짜요. 먹기 어려웠어요.
# 4          가격에 비해 음식의 양도 적고 맛도 별로였어요. 실망이었습니다.
#
#                                            gpt_reply  sentiment food store  \
# 0  안녕하세요. 김치찌개와 고기에 대한 실망을 드려 죄송합니다. 지속적인 품질 개선을 ...          0   김치
# 1  배터질뻔하셨다니 정말 안타깝습니다. 양에 대한 조정을 더 신경써야겠습니다. 불편을 ...          0
# 2  음식 맛과 배달 시간에 대한 실망을 드려 죄송합니다. 앞으로 더 신속하고 맛있는 음...          0
# 3  잡채가 짜다는 피드백을 반영하지 못해 죄송합니다. 더 맛있고 조리하기 쉽도록 개선하...          0   잡채
# 4  가격과 맛에 대한 실망을 드려 죄송합니다. 더 다양한 메뉴와 향상된 품질로 보답하겠...          0
#
#   branch
# 0
# 1
# 2
# 3
# 4

# %%
gpt.columns = ['고객리뷰','사장댓글','sentiment','food','store','branch']

# %%
gpt
# Out:
#                                                    고객리뷰  \
# 0          김치찌개는 별로였어요. 약간 김치국 느낌이 나서 실망했어요. 고기도 별로였고.
# 1                       양이 너무 많아서 배터질뻔했어요. 서비스도 별로였어요.
# 2          음식이 너무 싱겁고 부족해서 맛이 없었어요. 배달도 늦게 왔고 실망스러웠어요.
# 3                 잡채는 짜다고 하지도 않았는데 맛이 진짜 짜요. 먹기 어려웠어요.
# 4                  가격에 비해 음식의 양도 적고 맛도 별로였어요. 실망이었습니다.
# ...                                                 ...
# 9318  맛이 별로였어요, 음식이 촉촉하지 않고 식어서 먹기가 좀 그랬네요. 다음에는 안시킬...
# 9319                          맛도 없고, 배달도 늦어서 너무 실망했습니다
# 9320                       진짜 최악이었어요. 맛도 없고 배달도 오래걸렸어요
# 9321                    완전 별로였어요. 음식이 시큼해서 입에 맞지가 않았어요
# 9322                   다른 음식점 주문해서 먹을걸 그랬어요. 정말 실망했습니다
#
#                                                    사장댓글  sentiment food store  \
# 0     안녕하세요. 김치찌개와 고기에 대한 실망을 드려 죄송합니다. 지속적인 품질 개선을 ...          0   김치
# 1     배터질뻔하셨다니 정말 안타깝습니다. 양에 대한 조정을 더 신경써야겠습니다. 불편을 ...          0
# 2     음식 맛과 배달 시간에 대한 실망을 드려 죄송합니다. 앞으로 더 신속하고 맛있는 음...          0
# 3     잡채가 짜다는 피드백을 반영하지 못해 죄송합니다. 더 맛있고 조리하기 쉽도록 개선하...          0   잡채
# 4     가격과 맛에 대한 실망을 드려 죄송합니다. 더 다양한 메뉴와 향상된 품질로 보답하겠...          0
# ...                                                 ...        ...  ...   ...
# 9318  안녕하세요, 고객님. 말씀해주신 점 먼저 진심으로 사과드립니다. 맛과 촉감에 실망하...          0
# 9319  고객님께 실망을 드려 죄송합니다. 저희 음식이 맛있지 않아서 큰 실망을 받으셨군요....          0
# 9320  맛이 없고 배달이 늦어서 정말 죄송합니다. 저희는 항상 맛과 배달 시간을 최우선으로...          0
# 9321  고객님께 실망을 드려 정말 죄송합니다. 음식에 대한 맛과 냄새에 대한 불만을 제기해...          0
# 9322  진심으로 죄송합니다. 맛과 배달 속도에 대한 실망을 드린 점 정말 죄송합니다. 저희...          0
#
#      branch
# 0
# 1
# 2
# 3
# 4
# ...     ...
# 9318
# 9319
# 9320
# 9321
# 9322
#
# [9323 rows x 6 columns]

# %%
gpt.to_csv(f'{DATA_PATH}gpt_9300.csv', index=False, encoding = "utf-8-sig")

# %% [markdown]
# # 데이터셋 합치기

# %% [markdown]
# - 긍부정 비율 조정

# %%
df = df.loc[df.sentiment == 1]
df = df.sample(frac=1, random_state=SEED)

# %%
df = df[:9323]

# %%
yogiyo_train = pd.concat([gpt,df], axis=0)
yogiyo_train
# Out:
#                                                고객리뷰  \
# 0      김치찌개는 별로였어요. 약간 김치국 느낌이 나서 실망했어요. 고기도 별로였고.
# 1                   양이 너무 많아서 배터질뻔했어요. 서비스도 별로였어요.
# 2      음식이 너무 싱겁고 부족해서 맛이 없었어요. 배달도 늦게 왔고 실망스러웠어요.
# 3             잡채는 짜다고 하지도 않았는데 맛이 진짜 짜요. 먹기 어려웠어요.
# 4              가격에 비해 음식의 양도 적고 맛도 별로였어요. 실망이었습니다.
# ...                                             ...
# 13448              맛있어요 배달도 빠르고 국물도 안새고 안전배달 잘먹었습니다
# 33950                주말되면 생각나서 찾게되는 너무맛있어요 잘먹었습니다~
# 19298                              맛있게 잘먹었네요. 배부르네요
# 20050                                   맛있게 잘 먹었습니다
# 36495         여긴 두말하면 입아프쥬~ 시킬때마다 맛있쥬~ 오늘도 역시나 최고쥬
#
#                                                     사장댓글  sentiment food  \
# 0      안녕하세요. 김치찌개와 고기에 대한 실망을 드려 죄송합니다. 지속적인 품질 개선을 ...          0   김치
# 1      배터질뻔하셨다니 정말 안타깝습니다. 양에 대한 조정을 더 신경써야겠습니다. 불편을 ...          0
# 2      음식 맛과 배달 시간에 대한 실망을 드려 죄송합니다. 앞으로 더 신속하고 맛있는 음...          0
# 3      잡채가 짜다는 피드백을 반영하지 못해 죄송합니다. 더 맛있고 조리하기 쉽도록 개선하...          0   잡채
# 4      가격과 맛에 대한 실망을 드려 죄송합니다. 더 다양한 메뉴와 향상된 품질로 보답하겠...          0
# ...                                                  ...        ...  ...
# 13448                           감사드립니다 리뷰님. 찬바람 건강 유의하세요          1
# 33950  저희 인생 아귀찜은 신선한 재료와 넉넉한 양으로 고객님께 맛있는 식사를 대접해 드리...          1   아귀
# 19298                                   맛있게 드셔주셔서 감사합니다           1
# 20050  맛있게 잘 드셨다니 감사합니다~ 다음에 드실 때도 변함없이 맛있게 드실 수 있도록 ...          1    닭
# 36495   칭찬해 주셔서 감사합니다 기분 좋은 식사가 되실 수 있게 더욱 노력하는 평화점이 ...          1
#
#         store branch
# 0
# 1
# 2
# 3
# 4
# ...       ...    ...
# 13448
# 33950  인생 아귀찜
# 19298
# 20050
# 36495
#
# [18646 rows x 6 columns]

# %%
for i in range(0, 2):
    num_rating = yogiyo_train[yogiyo_train['sentiment'] == i].shape[0]
    print(f"긍/부정 {i}점 개수: {num_rating}, {num_rating / yogiyo_train.shape[0] * 100}%")
# Out:
# 긍/부정 0점 개수: 9323, 50.0%
# 긍/부정 1점 개수: 9323, 50.0%

# %%
yogiyo_train.to_csv(f'{DATA_PATH}train_0920.csv', index=False, encoding = "utf-8-sig")

# %%
tt = pd.read_csv(f"{DATA_PATH}train_0920.csv")
tt.head()
# Out:
#                                            고객리뷰  \
# 0  김치찌개는 별로였어요. 약간 김치국 느낌이 나서 실망했어요. 고기도 별로였고.
# 1               양이 너무 많아서 배터질뻔했어요. 서비스도 별로였어요.
# 2  음식이 너무 싱겁고 부족해서 맛이 없었어요. 배달도 늦게 왔고 실망스러웠어요.
# 3         잡채는 짜다고 하지도 않았는데 맛이 진짜 짜요. 먹기 어려웠어요.
# 4          가격에 비해 음식의 양도 적고 맛도 별로였어요. 실망이었습니다.
#
#                                                 사장댓글  sentiment food store  \
# 0  안녕하세요. 김치찌개와 고기에 대한 실망을 드려 죄송합니다. 지속적인 품질 개선을 ...          0   김치   NaN
# 1  배터질뻔하셨다니 정말 안타깝습니다. 양에 대한 조정을 더 신경써야겠습니다. 불편을 ...          0        NaN
# 2  음식 맛과 배달 시간에 대한 실망을 드려 죄송합니다. 앞으로 더 신속하고 맛있는 음...          0        NaN
# 3  잡채가 짜다는 피드백을 반영하지 못해 죄송합니다. 더 맛있고 조리하기 쉽도록 개선하...          0   잡채   NaN
# 4  가격과 맛에 대한 실망을 드려 죄송합니다. 더 다양한 메뉴와 향상된 품질로 보답하겠...          0        NaN
#
#   branch
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %%
tt['store'] = tt['store'].fillna("")
tt['branch'] = tt['branch'].fillna("")

# %%
tt['고객리뷰'] = tt['고객리뷰'].astype(str)
tt['사장댓글'] = tt['사장댓글'].astype(str)

# %%
tt['food'] = tt['사장댓글'].apply(lambda x: next((food for food in all_food if food in x), " "))

# %%
tt['store'] = tt['사장댓글'].apply(lambda x: next((store for store in store_list if store in x), " "))

# %%
tt
# Out:
#                                                고객리뷰  \
# 0      김치찌개는 별로였어요. 약간 김치국 느낌이 나서 실망했어요. 고기도 별로였고.
# 1                   양이 너무 많아서 배터질뻔했어요. 서비스도 별로였어요.
# 2      음식이 너무 싱겁고 부족해서 맛이 없었어요. 배달도 늦게 왔고 실망스러웠어요.
# 3             잡채는 짜다고 하지도 않았는데 맛이 진짜 짜요. 먹기 어려웠어요.
# 4              가격에 비해 음식의 양도 적고 맛도 별로였어요. 실망이었습니다.
# ...                                             ...
# 18641              맛있어요 배달도 빠르고 국물도 안새고 안전배달 잘먹었습니다
# 18642                주말되면 생각나서 찾게되는 너무맛있어요 잘먹었습니다~
# 18643                              맛있게 잘먹었네요. 배부르네요
# 18644                                   맛있게 잘 먹었습니다
# 18645         여긴 두말하면 입아프쥬~ 시킬때마다 맛있쥬~ 오늘도 역시나 최고쥬
#
#                                                     사장댓글  sentiment  food  \
# 0      안녕하세요. 김치찌개와 고기에 대한 실망을 드려 죄송합니다. 지속적인 품질 개선을 ...          0  김치찌개
# 1      배터질뻔하셨다니 정말 안타깝습니다. 양에 대한 조정을 더 신경써야겠습니다. 불편을 ...          0
# 2      음식 맛과 배달 시간에 대한 실망을 드려 죄송합니다. 앞으로 더 신속하고 맛있는 음...          0
# 3      잡채가 짜다는 피드백을 반영하지 못해 죄송합니다. 더 맛있고 조리하기 쉽도록 개선하...          0    잡채
# 4      가격과 맛에 대한 실망을 드려 죄송합니다. 더 다양한 메뉴와 향상된 품질로 보답하겠...          0
# ...                                                  ...        ...   ...
# 18641                           감사드립니다 리뷰님. 찬바람 건강 유의하세요          1
# 18642  저희 인생 아귀찜은 신선한 재료와 넉넉한 양으로 고객님께 맛있는 식사를 대접해 드리...          1   아귀찜
# 18643                                   맛있게 드셔주셔서 감사합니다           1
# 18644  맛있게 잘 드셨다니 감사합니다~ 다음에 드실 때도 변함없이 맛있게 드실 수 있도록 ...          1     닭
# 18645   칭찬해 주셔서 감사합니다 기분 좋은 식사가 되실 수 있게 더욱 노력하는 평화점이 ...          1
#
#         store branch
# 0
# 1
# 2
# 3
# 4
# ...       ...    ...
# 18641
# 18642  인생 아귀찜
# 18643
# 18644
# 18645
#
# [18646 rows x 6 columns]

# %%
tt.to_csv(f'{DATA_PATH}train_0920.csv', index=False, encoding = "utf-8-sig")
