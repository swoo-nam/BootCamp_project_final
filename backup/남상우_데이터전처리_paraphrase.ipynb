# %% [markdown]
# <a href="https://colab.research.google.com/github/swoo-nam/project_final_team1/blob/main/%EB%82%A8%EC%83%81%EC%9A%B0_%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%A0%84%EC%B2%98%EB%A6%AC_paraphrase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kiwipiepy

# %%
# !pip install konlpy

# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.32.1-py3-none-any.whl (7.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 59.1 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.2)
# Collecting huggingface-hub<1.0,>=0.15.1 (from transformers)
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 34.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 108.9 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 98.8 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Installing collected packages: tokenizers, safetensors, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.16.4 safetensors-0.3.3 tokenizers-0.13.3 transformers-4.32.1

# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-3.3.0-py3-none-any.whl (404 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.2/404.2 kB 7.0 MB/s eta 0:00:00
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.12.0-py3-none-any.whl (226 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.0/226.0 kB 14.7 MB/s eta 0:00:00
# Collecting cmaes>=0.10.0 (from optuna)
#   Downloading cmaes-0.10.0-py3-none-any.whl (29 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (23.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.20)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.1)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 9.9 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.7.1)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (2.0.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.3)
# Installing collected packages: Mako, colorlog, cmaes, alembic, optuna
# Successfully installed Mako-1.2.4 alembic-1.12.0 cmaes-0.10.0 colorlog-6.7.0 optuna-3.3.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
from torch.utils.data.dataset import Dataset

from sklearn.utils import resample

# %%
import warnings
# %config InlineBackend.figure_format = 'retina'
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import re
from tqdm.auto import tqdm
import random
import os

def reset_seeds(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

DATA_PATH = "/content/drive/MyDrive/project_final/data/"
# DATA_PATH = "C:\python-code\project_final\data/"
SEED = 42

device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cpu'

# %% [markdown]
# # 데이터 불러오기

# %% [markdown]
# ### 전체 데이터셋

# %%
yo_review = pd.read_csv(f"{DATA_PATH}yogiyo_reviews_jsi.csv")['고객리뷰']
yo_reply = pd.read_csv(f"{DATA_PATH}yogiyo_reviews_jsi.csv")['사장댓글']
yo_star = pd.read_csv(f"{DATA_PATH}yogiyo_reviews_jsi.csv")['별점']

train = pd.concat([yo_review, yo_reply, yo_star], axis=1)
rename_cols = ['review', 'reply', 'star']
train.columns = rename_cols
train['star'].value_counts().sort_index() # 별점 분포 확인

# shuffled_df = train.sample(frac=1, random_state=2)  # frac=1은 모든 행을 선택, random_state는 재현 가능한 랜덤 설정
# train = shuffled_df.iloc[:1000].reset_index(drop=True)
# Out:
# 1       92
# 2       64
# 3      179
# 4      560
# 5    17791
# Name: star, dtype: int64

# %%
# 중복된 답변을 한 경우 행 전체 삭제
train.drop_duplicates(subset='reply', keep=False, inplace=True)

# %% [markdown]
# ## 데이터 정제

# %% [markdown]
# - 불필요한 문자 삭제

# %%
review_list = []
for review in train['review']:
    if isinstance(review, str):
        pat = re.compile("[^a-zA-Z가-힣0-9]")
        # pat = re.compile("[^a-zA-Z가-힣0-9.,~?!]")
        result = pat.sub(" ", review)

        # result = re.sub(r'\.{2,}', '.', result)
        # result = re.sub(r'\,{2,}', ',', result)
        # result = re.sub(r'\~{2,}', '~', result)
        # result = re.sub(r'\!{2,}', '!', result)
        # result = re.sub(r'\?{2,}', '?', result)
        result = re.sub(" +", " ", result)
        review_list.append(result)
    else:
        review_list.append("")

train['review'] = review_list
train.head()
# Out:
#                               review  \
# 1       리뷰가 늦었네요 맛있게 잘 먹었습니다 또 시킬게요
# 2  잘 먹었습니다 다만 주문에 있던 펩시콜라는 받지 못했습니다
# 3                 굿 말이 필요 없는 메뉴 였습니다
# 4                        맛있어요 양도많구좋음
# 5                          양많고 맛있었어요
#
#                                                reply  star
# 1  좋은 리뷰 덕분에 기분이 행복해지는 것 같아요😇\n\n고객님께서 맛있다고 말씀 주시...     5
# 2  소중한 식사 시간에 저희 매장을 찾아 주셔서 감사드립니다. \n\n저희를 찾아 주신...     5
# 3  수 많은 매장들을 헤치고 와주셔서 감사합니다!!\n\n저희 매장의 메뉴를 제대로 즐...     5
# 4  수 많은 매장들을 헤치고 와주셔서 감사합니다😂\n\n메뉴 그 자체로 행복을 드리고 ...     5
# 5  저희 매장 찾아주신 것도 감사한데 리뷰까지..감동입니다ㅠㅠ😭\n\n고객님들의 배고픔...     5

# %%
reply_list = []
for reply in train['reply']:
    if isinstance(reply, str):
        pat = re.compile("[^a-zA-Z가-힣0-9]")
        # pat = re.compile("[^a-zA-Z가-힣0-9.,~?!]")
        result = pat.sub(" ", reply)

        # result = re.sub(r'\.{2,}', '.', result)
        # result = re.sub(r'\,{2,}', ',', result)
        # result = re.sub(r'\~{2,}', '~', result)
        # result = re.sub(r'\!{2,}', '!', result)
        # result = re.sub(r'\?{2,}', '?', result)
        result = re.sub(" +", " ", result)
        reply_list.append(result)
    else:
        reply_list.append("")

train['reply'] = reply_list
train.head()
# Out:
#                               review  \
# 1       리뷰가 늦었네요 맛있게 잘 먹었습니다 또 시킬게요
# 2  잘 먹었습니다 다만 주문에 있던 펩시콜라는 받지 못했습니다
# 3                 굿 말이 필요 없는 메뉴 였습니다
# 4                        맛있어요 양도많구좋음
# 5                          양많고 맛있었어요
#
#                                                reply  star
# 1  좋은 리뷰 덕분에 기분이 행복해지는 것 같아요 고객님께서 맛있다고 말씀 주시니 피로...     5
# 2  소중한 식사 시간에 저희 매장을 찾아 주셔서 감사드립니다 저희를 찾아 주신 만큼 1...     5
# 3  수 많은 매장들을 헤치고 와주셔서 감사합니다 저희 매장의 메뉴를 제대로 즐기신 거 ...     5
# 4  수 많은 매장들을 헤치고 와주셔서 감사합니다 메뉴 그 자체로 행복을 드리고 싶었는데...     5
# 5  저희 매장 찾아주신 것도 감사한데 리뷰까지 감동입니다 고객님들의 배고픔을 저희는 지...     5

# %% [markdown]
# ### "~~님" → "고객님"으로 변환

# %%
train['reply'] = train['reply'].str.replace(r'\w+\s*님', '고객님', regex=True)

# %% [markdown]
# # 텍스트 Paraphrase
# ```
# https://huggingface.co/lcw99/t5-base-korean-paraphrase
# ```

# %%
train['star'].value_counts().sort_index() # 별점 분포 확인
# Out:
# 1      90
# 2      61
# 3     153
# 4     422
# 5    9776
# Name: star, dtype: int64

# %%
train[train['star'] == 1].index
# Out:
# Int64Index([   96,   144,   252,   363,   401,   658,  1552,  1835,  1951,
#              1988,  2002,  2049,  2171,  2228,  2229,  2509,  2653,  2780,
#              2858,  3636,  3731,  3861,  4390,  4857,  4922,  4990,  5120,
#              5662,  6005,  6984,  7367,  7427,  7450,  7508,  7653,  7693,
#              7849,  8068,  8238,  8294,  8477,  8555,  8605,  8652,  8790,
#              9233,  9449,  9594,  9799,  9881, 10398, 10811, 10938, 11612,
#             11670, 12519, 12526, 12583, 12646, 12755, 13079, 13135, 13173,
#             13209, 13347, 13714, 13980, 14404, 14410, 14413, 14425, 14515,
#             14599, 14616, 14853, 15130, 15299, 15599, 15798, 15800, 15811,
#             15911, 16088, 16113, 16265, 16302, 16401, 17313, 17679, 18188],
#            dtype='int64')

# %%
from transformers import pipeline
pipe = pipeline("text2text-generation", model="lcw99/t5-base-korean-paraphrase")
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/790 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/1.10G [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/2.40k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/2.92M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]

# %%
train['review'][96]
# Out:
# '리뷰 이벤트 한다지만 너무 아닌 거 같아서 적습니다 배달이 20분 넘게 안오길래 전화해서 배달이 안온다 했더니 여자분께서 한숨 푹 쉬시면서 하아 비가 와서 배달 기사 안 잡힌다 하시는데 제가 뭐 그런거에 이해 못하는 사람도 아니고 그냥 안와서 물어보는건데 한숨음 왜 크게 쉬시나요 아니 돈을 내고 배달 시간도 20분이나 지나서 물어보는게 잘못된건가요 배달기사한테 도착하면 문자 달라고 하니까 문자도 안주셔서 밥은 식은 상태로 먹고 진짜 배달 시켜 먹어본곳 중에 제일 최악이네요 여긴'

# %%
prompt = train['review'][96]
generated_text = pipe(prompt, max_length=128, num_beams=3, num_return_sequences=1, no_repeat_ngram_size=3, top_k=50, top_p=0.95, early_stopping=True)
# print("리뷰: ", prompt)
print("paraphrase: ", generated_text[0]['generated_text'])
# Out:
# paraphrase:  아니 그런데 배달이 20분 넘게 안와서 전화해서 물어보니 배달 기사님이 비가 와서 못 간다고 하시는데 제가 그 말을 이해할 수 없습니다.

# %%
train['reply'][96]
# Out:
# '안녕하세요 1988응답하라추억의옛날도시락 입니다 주신 리뷰 잘 읽었습니다 뒤돌아 보니 저희 응대에 미흡했던 점이 있던 것 같네요 응대 메뉴얼을 재점검 하도록 하겠습니다 이미 느끼신 불편함을 주워 담을 순 없지만 다음에 오실 때 요청 사항에 이 내용 남겨 주시면 저희가 더 신경 쓸 수 있도록 하겠습니다 그땐 온전한 만족감을 드릴 수 있도록 최선을 다하겠습니다 감사합니다 '

# %%
prompt = train['reply'][96]
generated_text = pipe(prompt, max_length=128, num_beams=4, num_return_sequences=1, no_repeat_ngram_size=4, top_k=50, top_p=0.95, early_stopping=True)
print(generated_text[0]['generated_text'])
# Out:
# 저희가 미처 생각하지 못한 부분이 있기 때문에 다시 한번 감사의 마음을 전하고 싶습니다.

# %%
train['review'][144]
# Out:
# '진짜리뷰안쓰는데 양이 2만원씩내고 먹을양은 절대아닙니다 장난하는것도아니고'

# %%
prompt = train['review'][144]
generated_text = pipe(prompt, max_length=128, num_beams=5, num_return_sequences=5, no_repeat_ngram_size=3, top_k=50, top_p=0.95, early_stopping=True)
# print("리뷰: ", prompt)
print("paraphrase: ", generated_text[0]['generated_text'])
# Out:
# paraphrase:  진짜 2만원씩 내고 두번먹을 양이면 충분한데 제가 장난으로 글을 쓴것도 아니고 진짜 양이 너무 많아서 남길 생각도 없습니다.

# %%
train['reply'][144]
# Out:
# '솔직한 리뷰 남겨 주셔서 감사합니다 저희 1988응답하라추억의옛날도시락은 언제나 약속 드린 정량을 드리기 위해 노력하고 있습니다 드렸을 때 준비 과정을 다시 살펴 보고 혹시 미흡했던 점은 없었는지 확인하겠습니다 아울러 본사 측에도 이 의견 전달 해서 더 개선 될 수 있는 부분은 없는지 검토해 보겠습니다 다음에 오실 때 요청 사항에 이 내용 남겨 주시면 저희가 더 신경 쓸 수 있도록 하겠습니다 감사합니다 '

# %%
prompt = train['reply'][144]
generated_text = pipe(prompt, max_length=128, num_beams=4, num_return_sequences=1, no_repeat_ngram_size=4, top_k=50, top_p=0.95, early_stopping=True)
print(generated_text[0]['generated_text'])
# Out:
# 저희 1988응답하라추억의옛날도시락은 언제나 약속 드린 정량을 지키기 위해 노력하고 있습니다 전달 시 준비 과정을 다시 살펴 보고 혹시 부족한 점은 없는지 검토해 보겠습니다.

# %%
prompt = "저희 1988응답하라추억의옛날도시락은 언제나 약속 드린 정량을 지키기 위해 노력하고 있습니다 전달 시 준비 과정을 다시 살펴 보고 혹시 부족한 점은 없는지 검토해 보겠습니다."
generated_text = pipe(prompt, max_length=128, num_beams=4, num_return_sequences=1, no_repeat_ngram_size=4, top_k=50, top_p=0.95, early_stopping=True)
print(generated_text[0]['generated_text'])
# Out:
# 저희 1988응답하라추억의옛날도시락은 언제나 약속 드린 정량을 지키기 위해 노력하고 있습니다 전달 시 준비 과정을 살펴 보고 혹시 부족한 점은 없는지 검토해 보겠습니다.

# %%
star_1 = train[train['star'] == 1]
star_2 = train[train['star'] == 2]
star_3 = train[train['star'] == 3]
star_4 = train[train['star'] == 4]

train_star = pd.concat([star_1, star_2, star_3, star_4], ignore_index=True)
train_star
# Out:
#                                                 review  \
# 0    리뷰 이벤트 한다지만 너무 아닌 거 같아서 적습니다 배달이 20분 넘게 안오길래 전...
# 1             진짜리뷰안쓰는데 양이 2만원씩내고 먹을양은 절대아닙니다 장난하는것도아니고
# 2                  만들어 놓은지 한참 된 커피 배달 예정 시간 25분이 지났어요
# 3    밥이 쉬었어요 단무지 때문도 아니고 김이 많아서 그런것도 아니고 쉬어서 냄새가 나서...
# 4    잠실점에 처음 시켜먹었던게 맛있어서 주문했더니 돈 은 나갔는데 다시 앱을 들어와보니...
# ..                                                 ...
# 721                                        맛있게 잘 먹었습니다
# 722                 국은 시원하게 맛있었어요 국물양이 더 많았으면 더 좋았겠습니다
# 723  배송 맛 반찬등 구성도 좋고 맛도 괜찮고 가격도 넘좋아요 양이 좀만더 많음 좋겠어용...
# 724                                  잘먹었숩당 양은 증말로 많아요
# 725          요청사항을 항상 잘 들어주셨는데 오늘은 못 모셨나봐요 그래도 잘 먹었습니다
#
#                                                  reply  star
# 0    안녕하세요 1988응답하라추억의옛날도시락 입니다 주신 리뷰 잘 읽었습니다 뒤돌아 보...     1
# 1    솔직한 리뷰 남겨 주셔서 감사합니다 저희 1988응답하라추억의옛날도시락은 언제나 약...     1
# 2    안녕하세요 배달이 늦어져 죄송합니다 한파로 길이 얼어서 고객님들이 상황이 여유치가 ...     1
# 3    밥이 쉬다뇨 말도 안되는 소리좀 하지마세요 진짜 먼 정신이 이상한 사람인가 하루에 ...     1
# 4    요기요가 주문어플에 렉이 자주 있어서 여러가지로 혼돈이 있어 정말 죄송하게 되었습니...     1
# ..                                                 ...   ...
# 721                맛있게 드셔주셔서 감사드립니다 더 노력하는 보둘미역이 되겠습니다     4
# 722  맛있게 드셨다니 감사드립니다 매장과 같이 최대한 드리고있습니다 배달용기에 국물을 더...     4
# 723  양이 좀 적어셨나봐요 보통 1인분에 두명도 드실수있는 양인데 그래도 맛있게 드셨다니...     4
# 724                  맛있게 드셔주셔서 감사합니다 별 5개 받도록 노력하겠습니다      4
# 725                                 죄송합니다 다음에도 애용해주세용      4
#
# [726 rows x 3 columns]

# %% [markdown]
# ## 하이퍼파라미터 튜닝

# %% [markdown]
# - BLEU 계산 함수

# %%
from nltk.translate.bleu_score import sentence_bleu

def calculate_bleu(text, generated_text):
    y = [text]  # 실제 데이터 y
    X = generated_text  # 생성된 텍스트 X

    # BLEU 점수 계산
    bleu_score = sentence_bleu(y, X)
    return bleu_score

# %% [markdown]
# ### review

# %%
# import optuna
# from transformers import pipeline

# def objective(trial):
#     hp = {
#         "num_beams" : trial.suggest_int("num_beams", 1, 10),
#         "num_return_sequences" : trial.suggest_int("num_return_sequences", 1, 5),
#         "no_repeat_ngram_size" : trial.suggest_int("no_repeat_ngram_size", 1, 5),
#         "top_k" : trial.suggest_int("top_k", 10, 100),
#         "top_p" : trial.suggest_float("top_p", 0.8, 1.0)
#     }
#     # num_return_sequences가 num_beams보다 작거나 같아야 하기 때문에 조건문 추가
#     if hp["num_return_sequences"] > hp["num_beams"]:
#         hp["num_return_sequences"] = hp["num_beams"]

#     pipe = pipeline(
#         "text2text-generation",
#         model="lcw99/t5-base-korean-paraphrase",
#         device = 'cuda' if torch.cuda.is_available() else 'cpu'
#     )

#     bleu_scores = []
#     for prompt in tqdm(train_star["review"]): # star1~4까지
#         generated_text = pipe(prompt, max_length=128, **hp, early_stopping=True)

#         bleu_score = calculate_bleu(prompt, generated_text[0]['generated_text'])
#         bleu_scores.append(bleu_score)

#     # 모든 입력 텍스트에 대한 BLEU 점수 평균 계산 및 반환
#     bleu_score_avg = sum(bleu_scores) / len(bleu_scores)
#     return bleu_score_avg

# %%
# # 하이퍼파라미터 최적화
# sampler = optuna.samplers.TPESampler(seed=SEED)
# study = optuna.create_study(sampler=sampler, direction="maximize")
# study.optimize(objective, n_trials=12)

# # 최적 값 출력
# best_bleu_score = study.best_value
# best_params = study.best_params
# print("best_bleu_score:", best_bleu_score)
# print("best_params:", best_params)
# Out:
# [I 2023-09-04 18:21:25,156] A new study created in memory with name: no-name-88447d6d-9e54-42fa-ad15-c88fcd87f12d
#   0%|          | 0/726 [00:00<?, ?it/s]
# [I 2023-09-04 18:57:51,133] Trial 0 finished with value: 0.285731536841964 and parameters: {'num_beams': 4, 'num_return_sequences': 5, 'no_repeat_ngram_size': 4, 'top_k': 64, 'top_p': 0.8312037280884873}. Best is trial 0 with value: 0.285731536841964.
#   0%|          | 0/726 [00:00<?, ?it/s]
# [I 2023-09-04 19:25:28,423] Trial 1 finished with value: 0.28140373147755066 and parameters: {'num_beams': 2, 'num_return_sequences': 1, 'no_repeat_ngram_size': 5, 'top_k': 64, 'top_p': 0.941614515559209}. Best is trial 0 with value: 0.285731536841964.
#   0%|          | 0/726 [00:00<?, ?it/s]
# [I 2023-09-04 19:44:18,818] Trial 2 finished with value: 0.2599486749168758 and parameters: {'num_beams': 1, 'num_return_sequences': 5, 'no_repeat_ngram_size': 5, 'top_k': 29, 'top_p': 0.8363649934414201}. Best is trial 0 with value: 0.285731536841964.
#   0%|          | 0/726 [00:00<?, ?it/s]
# [I 2023-09-04 20:11:13,109] Trial 3 finished with value: 0.28033029449808605 and parameters: {'num_beams': 2, 'num_return_sequences': 2, 'no_repeat_ngram_size': 3, 'top_k': 49, 'top_p': 0.8582458280396084}. Best is trial 0 with value: 0.285731536841964.
#   0%|          | 0/726 [00:00<?, ?it/s]
# [I 2023-09-04 20:48:14,059] Trial 4 finished with value: 0.2694733191553665 and parameters: {'num_beams': 7, 'num_return_sequences': 1, 'no_repeat_ngram_size': 2, 'top_k': 43, 'top_p': 0.8912139968434072}. Best is trial 0 with value: 0.285731536841964.
#   0%|          | 0/726 [00:00<?, ?it/s]
# [I 2023-09-04 21:29:24,568] Trial 5 finished with value: 0.2850724303388997 and parameters: {'num_beams': 8, 'num_return_sequences': 1, 'no_repeat_ngram_size': 3, 'top_k': 63, 'top_p': 0.8092900825439996}. Best is trial 0 with value: 0.285731536841964.
#   0%|          | 0/726 [00:00<?, ?it/s]
# [I 2023-09-04 21:53:44,957] Trial 6 finished with value: 0.1070840014655058 and parameters: {'num_beams': 7, 'num_return_sequences': 1, 'no_repeat_ngram_size': 1, 'top_k': 96, 'top_p': 0.9931264066149119}. Best is trial 0 with value: 0.285731536841964.
#   0%|          | 0/726 [00:00<?, ?it/s]
# [I 2023-09-04 22:22:23,977] Trial 7 finished with value: 0.10654797208747599 and parameters: {'num_beams': 9, 'num_return_sequences': 2, 'no_repeat_ngram_size': 1, 'top_k': 72, 'top_p': 0.8880304987479203}. Best is trial 0 with value: 0.285731536841964.
#   0%|          | 0/726 [00:00<?, ?it/s]
# [I 2023-09-04 22:38:33,125] Trial 8 finished with value: 0.11919134029393139 and parameters: {'num_beams': 2, 'num_return_sequences': 3, 'no_repeat_ngram_size': 1, 'top_k': 92, 'top_p': 0.8517559963200034}. Best is trial 0 with value: 0.285731536841964.
#   0%|          | 0/726 [00:00<?, ?it/s]
# [I 2023-09-04 23:18:10,413] Trial 9 finished with value: 0.2843770295826129 and parameters: {'num_beams': 7, 'num_return_sequences': 2, 'no_repeat_ngram_size': 3, 'top_k': 59, 'top_p': 0.8369708911051055}. Best is trial 0 with value: 0.285731536841964.
#   0%|          | 0/726 [00:00<?, ?it/s]
# [I 2023-09-04 23:49:39,909] Trial 10 finished with value: 0.285731536841964 and parameters: {'num_beams': 4, 'num_return_sequences': 5, 'no_repeat_ngram_size': 4, 'top_k': 11, 'top_p': 0.8030735474656209}. Best is trial 0 with value: 0.285731536841964.
#   0%|          | 0/726 [00:00<?, ?it/s]
# [I 2023-09-05 00:20:59,956] Trial 11 finished with value: 0.285731536841964 and parameters: {'num_beams': 4, 'num_return_sequences': 5, 'no_repeat_ngram_size': 4, 'top_k': 17, 'top_p': 0.8007473955626367}. Best is trial 0 with value: 0.285731536841964.
# best_bleu_score: 0.285731536841964
# best_params: {'num_beams': 4, 'num_return_sequences': 5, 'no_repeat_ngram_size': 4, 'top_k': 64, 'top_p': 0.8312037280884873}

# %% [markdown]
# ### reply

# %%
import optuna
from transformers import pipeline

def objective(trial):
    hp = {
        "num_beams" : trial.suggest_int("num_beams", 1, 10),
        "num_return_sequences" : trial.suggest_int("num_return_sequences", 1, 5),
        "no_repeat_ngram_size" : trial.suggest_int("no_repeat_ngram_size", 1, 5),
        "top_k" : trial.suggest_int("top_k", 10, 100),
        "top_p" : trial.suggest_float("top_p", 0.8, 1.0)
    }
    # num_return_sequences가 num_beams보다 작거나 같아야 하기 때문에 조건문 추가
    if hp["num_return_sequences"] > hp["num_beams"]:
        hp["num_return_sequences"] = hp["num_beams"]

    pipe = pipeline(
        "text2text-generation",
        model="lcw99/t5-base-korean-paraphrase",
        device = 'cuda' if torch.cuda.is_available() else 'cpu'
    )

    bleu_scores = []
    for prompt in tqdm(train_star["reply"]): # star1~4까지
        generated_text = pipe(prompt, max_length=128, **hp, early_stopping=True)

        bleu_score = calculate_bleu(prompt, generated_text[0]['generated_text'])
        bleu_scores.append(bleu_score)

    # 모든 입력 텍스트에 대한 BLEU 점수 평균 계산 및 반환
    bleu_score_avg = sum(bleu_scores) / len(bleu_scores)
    return bleu_score_avg

# %%
# 하이퍼파라미터 최적화
sampler = optuna.samplers.TPESampler(seed=SEED)
study = optuna.create_study(sampler=sampler, direction="maximize")
study.optimize(objective, n_trials=12)

# 최적 값 출력
best_bleu_score = study.best_value
best_params = study.best_params
print("best_bleu_score:", best_bleu_score)
print("best_params:", best_params)
# Out:
# [I 2023-09-05 09:06:47,480] A new study created in memory with name: no-name-d76cd6a4-4637-44d8-9c4e-b723d6953cec
#   0%|          | 0/726 [00:00<?, ?it/s]

# %% [markdown]
# # 오버샘플링

# %% [markdown]
# - review

# %%
# review_best_params = {'num_beams': 5, 'num_return_sequences': 5, 'no_repeat_ngram_size': 4, 'top_k': 64, 'top_p': 0.8312037280884873}

# over_review = []
# for prompt in tqdm(train_star['review']):
#     generated_text = pipe(prompt, max_length=128, **review_best_params, early_stopping=True)
#     generated_text = generated_text[0]['generated_text']
#     over_review.append(generated_text)

# over_review
# Out:
#   0%|          | 0/726 [00:00<?, ?it/s]
# ['아니 그런데 배달이 20분 넘게 안 와서 전화해서 물었더니 배달 기사님이 비가 와서 안 된다고 하시는데 제가 그 말을 이해할 수 없습니다.',
#  '양이 2만원씩이나하는데 장난으로하는것도 아니고 진짜 이거 2만원주고 사서 먹을 정도도 아닙니다 저는 진짜 양이 너무 많아서 남기는 남길 수 없어요.',
#  '커피가 배달되기를 기다린 지 25분이 지나자 커피 배달 예정 시간은 이미 커피를 만들어 놓은 지 한참이 되었어요',
#  '김이 많아서 그런것도 있고 단무짠지 김이 많이 없어서 그런지도 모르겠지만 밥이 쉬었어요 나머지는 잘 먹었어요',
#  '처음 먹었을 때 너무 맛있게 먹었던 기억에 다시 찾아 주문하려고 잠실점에 갔는데 역시나 문 연 지 한 시간 만에 만석, 남은 음식은 포장해 놓은 채로 남았고 그 자리에서 바로 처리해 주는 서비스에 감동했다.',
#  '이 지역 사람이 아니라 현재위치로 설정해 놓은 상세 주소에 의하면 다른 배달 음식점은 20분도 채 안 걸려 도착했는데 여기만 유독 오래 걸리는 거예요.',
#  '한 점 올렸다고 글 지우고 진상짓 하는 거 아닙니다 그냥 더 묻지 말아 주세요 양이 적기도 하고 맛도 적어요',
#  '양이 많은 것은 장점으로 작용하지만 배달 속도가 너무 느렸고 배달 완료된 후에도 계속 문자가 오는 등 관리가 소홀했던 것이 단점으로 작용했다.',
#  '닭고기는 냄새가 엄청 나고 상추는 아삭아삭하고 고기는 부들부들한데 식감이 전혀 부드럽지 않아요 47000원짜리 치고 이렇게 질기진 않아요',
#  '도보로 10분 거리에 위치한 익스프래스에서 12시 47분에 주문한 물건은 12시가 되기 7분 전에 도착했고 음식도 모두 식어 있었습니다.',
#  '딴 사람들은 다 모이만큼 먹는데 나만 안 그런가 봄 내가 시킨 음식은 다 내 입맛에 맞는 것인데 말이지',
#  '쌀국수 양은 많은데 고기가 너무 질겨서 한 입 먹고 안 먹을 것 같아요 사장님 죄송해요',
#  '배가 고팠기 때문에 억지로 음식을 먹었지만 면을 씹으면 쓴 맛이 나고 안 익은 밀가루 면 같은 텁텁한 느낌이 나서 다 못 먹었어요',
#  '보통은 새우라도 있는데 정말 아무것도 안 들어 있고 밥이랑 야채만 있으면 괜찮은데 팟타이에는 밥과 야채가 조금 들어 있어요',
#  '국수와 숙주 비율을 1 : 1로 해도 모자를 정도로 맛이 없을 수 밖에 없는 쌀국수는 지금까지 먹어본 쌀국수 중에 최악의 맛이었다.',
#  '이 가격에 이 맛에 밑반찬도 돈을 받는다니까요 심지어 한솥 밥도 만원도 안 하는데 누가 그걸 사 먹을 수 있겠어요 사장님 상식적으로 생각해보면',
#  '와 진짜 김치 없었으면 어쩔뻔 했어요 침 질질 흘리면서 먹을 수 밖에 없었을 것 같아요 침',
#  '반죽이며 빵은 온데간데 없고 계란만 잔뜩 올려진 이상한 식당에서 밥을 시켰는데 무슨 메뉴를 시켰는지 알 수 없을 정도로 맛이 없어요 비싸요',
#  '두 번 시켜 먹고 두 번은 안 시켜 먹을 거야 벌써 세 번 시켰는데 말이야 전화해서 늦어도 괜찮겠나요 했더니',
#  '더운 날씨에 밖에 있는 음식이 얼마나 많은데 다음엔 배달되면 연락 좀 주세요 그 외에 또 먹고 싶은 게 있으면 말해 주세요',
#  '저번 누룽지 사건 이후로 사장님 심기가 불편하셨는지 예전에 보내주셨던 양파는 거의 다 보내주셨는데 이제는 안 보내주셔도 됩니다 내일 또 맛있는 요리로 찾아 뵐게요',
#  '갈비는 정말 맛있게 먹었지만 냉면은 별로였어요 냉면 맛은 괜찮은데 갈비가 좀 아쉬웠어요',
#  '기분나빠서 버렸어요 버려버린 건 버릴 생각도 했지만 이렇게 온 게 너무 마음에 들었거든요',
#  '저녁 식사를 위해 선물해 주신 분께 감사의 뜻을 전하고 싶지만 초밥을 맛있게 해 드실 수 있도록 해 드릴 자신이 없었습니다.',
#  '회도 비려서 먹기 힘들고 손질도 제대로 안 된 회는 별로 비추입니다',
#  '마라 소스가 너무 많이 들어가서 맛이 없을 뿐 아니라 어묵이랑 김치도 너무 많아서 한 입 먹고 안 먹을 수도 있대요 저는 근데 이런 재료로 만든 음식은 처음이에요',
#  '꿔바로우(꿔바로우)는 고기를 먹기 힘든 찹쌀 튀김이라고 하던데 저는 그 옆에 있는 찹쌀 탕수육을 먹었어요',
#  '가격이 좀 더 저렴해도 맛은 보장되니 자주 사 먹었지만 초심을 못 따라간 것 같은 곳에서는 맛이 더 좋아지기도 했고 실망도 했다.',
#  '저는 이런거 첨가하지 않는데 억지로 고추장에 찍어 먹고 퉤퉤 했어요 불필요한 거 같아요',
#  '고객이 남긴 후기를 지키지 않으면 장사가 안 되는 것도 아니고 그냥 뻔한 맛에 먹을 수밖에 없는 식당에서 점심 먹었어요.',
#  '일단 혐오감을 느끼게 하는 건 일단 닭발이 혐오스러워 보이고 양념이 맛이 없을뿐더러 뜯는 것도 힘들어 보인다.',
#  '자주 시켜 먹는 단골집인데 이번에는 실패해서 아쉬워요 저번에는 국물 닭발이랑 같이 시켰는데 그땐 정말 맛있게 먹었어요',
#  '예전에 먹던 그맛은 어디로 가고 맛은 그대로인가요 ?',
#  '양도 푸짐하고 맛도 있어 지난번에 이어 또 주문했는데 한 번 먹을 때마다 머리카락이 약간 나오는 건 위생에 문제가 있어요.',
#  '기본 구성품도 부실한 가게에서 음식을 먹으면 기분이 상하기 마련인데 기본적으로 밥은 안 나오고 참기름날티알 덮밥이라고 해서 밥이 안 나왔는데 이것은 뭐지?',
#  '맛이 없다는 느낌이 전혀 없고 짜지 않다는 느낌을 딱 한마디로 표현할 수 있을 정도로 맛이 없다.',
#  '평이 좋아서 처음 시켜봤는데 역시나 맛있네요 랩을 벗기자 마자 곱창 위에 있는 벌레를 봤어요 맛은 어떨지 모르겠지만요',
#  '느끼하다는 느낌이 좀 많이 나요 약간.',
#  '제가 예민한 건가 봐요 주문하고 바로 취소 신청했는데 3분 뒤에 갑자기 취소 불가 문자가 오는 거예요.',
#  '돈가스세트 이름을 바꿔야 할 것 같아요. 돈가스세트',
#  '왜 이런거죠 차갑고 찔기고 이런 닭발은 안 먹고 싶은데 말이죠',
#  '원래는 서비스로 주는 계란찜이 있었는데 그건 이미 조리중에 버렸고 새로 산 계란찜도 한 이틀 전에 다 먹어서 이번엔 그냥 안 시킬래',
#  '한시간 반 정도 있다가 왔는데 어디서 뭘 시킬 수 있나요 여기서 뭐 시킬 수도 없고',
#  '장사가 엄청 잘되는 거 같아 다음에도 다른 피자 시켜먹을 거야 59분 지나면 배달 된다고 해서 기다리는데 10분이 지나도 안 오면 나는 이미 늦었다고 생각해',
#  '저번에 먹고 이번에 또 먹을 건데 그땐 정말 기대도 안 했던 행동을 한 거예요.',
#  '콜라도 맛이 이상하고 유통기한도 지나서 환불도 안되고 해서 고객센터에 다시 전화했을 때는 아예 받지를 않으시더라고요',
#  '한시간 전에 시켰는데 아직도 안오고 영업하지 않는다는 말은 뭐죠?',
#  '고기는 여기서 거의 다 먹고 다른 데 가서 먹을 땐 국물이 거의 없을 정도로 바싹 익히던데 여기는 그렇지가 않아요.',
#  '부대찌개 맛은 괜찮은데 배달 온 게 너무 늦어서 밥은 못 먹고 반찬만 남은 밥을 먹었어요',
#  '매장에서 안내받은 시간은 50분이었고 제가 계산대에 있을 때는 11시 46분이었는데 미처 준비하지 못한 것은 미처 몰랐습니다.',
#  '지금까지 먹어온 피자 중에 제일 최악이에요 치즈맛도 없고 도우만 씬이고 모든 재료가 다 씬인 피자가.',
#  '비린맛이난게,맛이난것이,죽에서비린맛이났어요.그런데맛이맛이난거예요.맛이비린맛이나는게',
#  '이 씨 부부의 경우 임신 8개월째로 배 속 아기가 근심되어 허리를 약간 굽히고 한 손으로 배를 가린 채 전동차에 올랐다.',
#  '하 정말 말을 할 수가 없습니다 경쟁업체 신중동칠리마라 치킨마라 먹어보신 분들은 아시겠지만 정말 맛이 없을 수 없습니다 사장님.',
#  '조금만 더 신경써주면 감사할텐데 미안하다 못해 미안할 것 같아요 흑흑 국물맛은 괜찮은데 약간 작은 벌레 같은 게 자꾸 나와서 아쉬웠어요 흑흑',
#  '비오는 날 배달해서 배달이 늦은 건 이해할 수 있어도 비닐에 싸져서 온 버팔로봉 때문에 기분이 나빴고 내일 준다고 한 뚱캔도 내일 안 와서 내일 못 먹을 거 같아 버렸어요.',
#  '고객을 상대로 한 서비스가 이렇게 허술할 수 있는지 처음 알았어요 저도 이런 서비스 받고 싶지 않았거든요 고객과 대화를 나누려면 전화번호랑 홈페이지 주소만 입력창에 써넣',
#  '제가 받은 것만 그런 건지 원래 있던 것인지 모르겠지만 아무튼 햄버거 세 개가 너무 물러서 하나도 못 먹고 버렸어요.',
#  '별점 한 개를 줘도 안 아까울 정도로 별점이 없어요.',
#  '핫소스 많이 넣어주시고 고추씨도 넣어주세요 근데 핫소스가 원래 이렇게 나오나요',
#  '편의점에서 파는 닭다리살이랑 비교해보니 양은 훨씬 많은데 가격은 더 적고 맛도 그냥 평범해요.',
#  '가격에 비해 약간 아쉬움이 있음 약간 싼티가 좀 나는 편임',
#  '아 이건 좀 아니지 않나요 이렇게 안 익은 돈가스를 처음 봤어요',
#  '돈가스가 전혀 익지않았습니다 요즘은 돼지고기도 소고기처럼 레어로 먹는게 유행인가요 생고기에 튀김만 익혀서 배달이 왔습니다',
#  '제가 2만 원 짜리 우동을 사 먹고 싶어서 시켰는데 오천 원도 안 되는 돈을 먹고 우동은 겉이 바삭하지도 않고 속이 비쳐서 왔어요',
#  '집에서 해 먹는 게 더 맛있는 것도 있지만 건강에 좋은 음식도 있죠.',
#  '회만 나온거치고는 돈이 너무 아까웠는데 회집 사진에는 스끼다시도 괜찮던데 원래 횟집에서 나오는 스끼다시가 이렇게 짜지는 않나요',
#  '이런 초밥집은 처음이에요 냉모밀면이 익지도 않았는데 나오는 거 있죠?',
#  '편의점에서 판매하는 것은 이런 맛이 날까 싶을 정도로 얇팍한 밥에 와사비가 하나도 없어서 식감이 전혀 부드럽지 않고 자칫 김밥처럼 느껴질 수도 있다.',
#  '별로 에요 별로 요 별로 에요',
#  '냉소바는 맛있게 먹었지만 연어 회는 좀 별로였어요 싼 가격의 초밥만 잔뜩 먹고 온 게 원인이었어요',
#  '소비자 문의에 대한 제대로 된 답변도 없고 배달 시작한 지 2시간 반이 지나도 배달이 되지 않는 등 배달에서 심각한 문제가 발생하고 있다.',
#  '배달 예정 시간인 30분보다 65분이 더 빨리 왔는데 아직도 안 와서 이걸 뭐라고 표현해야 할지 모르겠네요.',
#  '하 그냥 먹던 집 갈걸 후회가 되는 게 집에서 해 먹는 게 훨씬 편하고 좋거든요.',
#  '집에 있는 상추를 사용해서 비벼 봤는데 맛은 괜찮은데 약간 특유의 향이 있어요 약간 닭갈비 집에서 나는 냄새가 나요',
#  '위생에 더욱 신경 써 주셨으면 합니다 김치에서 파리가 발견된 건 매우 불쾌한 일인데 이런 식으로 관리를 하시니까요.',
#  '저는 밥도 짓고 계란도 풀고 그랬는데 다 됐어요 밥 짓는 것도 근데 잘 안 되고.',
#  '치킨은 무난하게 맛있고 가격이 저렴한 편이라 여기서 시켰는데 치킨은 그냥 그런데 떡이 너무 달아서 밥은 못 먹을 것 같고 왔어요',
#  '저희가 단체로 점심시간에 시켰는데 1시간도 채 안 남아서 못 간다고 전화했을 때 그제서야 배달 완료됐다고 하시고 너무 성의가 없으셨죠.',
#  '설탕이 너무 많이 들어가서 단맛 조절이 어려운 맛이 나서 설탕 넣은 게 후회가 된다.',
#  '음식은 다 식어 차갑고 스파게티면은 탄게 들어있고 카레소스는 짜고 돈가스는 튀겨놓고 나중에 다시 튀긴듯이 엄청 딱딱했어요',
#  '영수증에 주소까지 써있는데 전화하셔서 주소가 잘못되었다고 사과하고 음식을 받았는데 기분나쁜 식사만아니었으면 더 좋았을 것 같네요.',
#  '배달의 민족은 원래 이런 건가요 배달 시키면 제일 짜증나는 메뉴가 뭔지 모르겠어요',
#  '저번에 친구 계정으로 여러 번 시켜먹었던 기억이 있는데 그때는 배달 올 때 문자로 주소 불러주고 잠깐 기다리라고 했는데 지금은 배달이 안 되네요?',
#  '악플이라 생각하지 마시고 개선을 좀 해 주셨으면 합니다.',
#  '여기 원래 세트메뉴에 탕수육 소스 안나오나요 저번에 한번 시켜먹고 한동안 안시켰는데 세트메뉴가 없어져서 아쉬웠어요',
#  '콜라는 보자마자 바로 입에 넣는데 왜 이렇게 빨리 먹는지 모르겠어요 봉지를 째고 넣는 순간 면이 쪼개져서 먹을 수가 없어요',
#  '저는 개인적으로 멍게 비빔밥이 너무 먹고 싶었는데 못 먹었어요.',
#  '음료 맛도 별로고 샌드위치도 마감 전이라 못 판다고 하고 1L 짜리 시켰는데 얼음도 하나도 안 주고 해서 그냥 버렸다.',
#  '쌀국수 국물이 넘쳐 흘러 넘쳐서 정리하는데 30분 소요됨',
#  '음식의 양은 많지 않았지만 맛은 있었고 다만 배달 기사분이 늦게 와서 제가 전화를 했더니 그제서야 배달 완료 메시지를 띄우는 등 대처가 아쉬웠어요.',
#  '일단 배가 고프긴 한데 맛은 없을 수밖에 없을 것 같고 무엇보다 제일 아쉬운 건 배달이 너무 늦어서 밥을 못 먹었다는 것.',
#  '전화해서 늦어도 괜찮겠나요 했더니 그래도 된다는 거예요 하는 거예요',
#  '문 열고 닫는 것도 5분 넘게 걸리고 세 번이나 통화했는데 안 받으시더라고요 배달원 분은 배달 안 하시는 거 같던데 배달',
#  '맛은 있는데 좀 더 시간을 넉넉히 주지 그런 식으로 하면 안 될 것 같아요 너무 오래 기다렸거든요',
#  '재료는 좋은거 쓰시는거 같고 맛도 전반적으로 다 좋은데 아주 부족한 느낌입니다.',
#  '양념이 많이 묻혀있어 소스가 많이 짭니다 양념이 너무 많이 묻은 탓이죠',
#  '첫주문 토요일 아침에 주문했는데 국물은 진하나 이미 간이 되어있고 고기는 질긴데 밥은 겉이 말라있고 쌀은 안좋은건지 밥',
#  '국물은 너무 시원하지도 않고 국물 떠 먹는 재미도 없어 그냥 뜨거운 물에 쌀국수 면을 삶아 넣은 건지 고기가 들어간 건지 알 수 없을 정도였어요',
#  '콜라를 2개 주문했는데 1개만 온 거야 뭐 어쩔 수 없죠 뭐 그냥 맛있게 먹고 내일 또 먹을게요 뭐',
#  '배달은 거의 1시간 걸려 배달비는 53분정도 나왔고 맛은 쏘쏘한 편이었고 양념은 약간 싱거울 수 있어 보였어요',
#  '빵이 모자람 없이 빵이 만들어지는 것은 빵의 스크램블 양이 많은데 빵이',
#  '베이컨에서 돼지누린내가 나는 것과 계란 비린내, 그리고 베이컨에서 나는 그 외의 모든 냄새는 먹었어요.',
#  '맛이 너무 없어서 몇 번 못 먹고 버렸어요 다른 사람 주려고 산 것도 아니고 나 혼자 먹으려고 산 건데',
#  '10분 걸린다는 시간이 10분 정도 걸린다더니 30분이 지나도 안 오시네요?',
#  '영업 시간 이전이라 재료가 준비되지 않은 건지 1/3도 안 되는 찌개 양을 보내주신 건 너무 심했다.',
#  '바쁜건 당연하고 그런 응대가 마음에 안드네요 다들 수고하세요',
#  '이번 피자에 특별한 재료가 들어간 것 같네요 사장님 이번 피자는 정말 특별합니다.',
#  '피자는 소금을 너무 많이 넣으셔서 짠맛이 많이 나고 스파게티는 소스가 너무 짜 맛이 없었어요',
#  '피자집 많은데 굳이 여기서 시킬거같진 않아요 배달하는 분이 사장님인지 알바인지 모르겠지만 아무튼 엄청 무뚝뚝하고 계산도 미리 다 해놔요',
#  '치츠 마늘빵 맛있어요 피자도 맛있고 치츠 피자는 정말 최악이에요 피자 너무 맛있어요',
#  '맛은 쏘쏘하나 배달비 4천원에 밑반찬 4장이랑 배달 온 거 보니 2만 원도 안 되는 돈을 내고 먹을 건 못 된다.',
#  '잘 먹고 잘 포장해서 보내주신 것 같아요.',
#  '서비스로 초밥을 주셨는데 초밥은 안 주시고 서비스로 주신 것은 우동이었어요',
#  '치킨을 좋아하는 아이들과 부모님을 생각하며 주문했는데 아이들이 치킨을 너무 잘 먹어서 주문할 때 마다 제가 다 먹기도 했어요.',
#  '새우젓 한개 숟가락 두개만 넣고 순대국 3개 술국 1개 이렇게만 넣어서 새우젓 맛이 어우러지게 해주시면 좋을 것 같아요',
#  '새우젓 1개랑 다대기 1개였는데 새우젓이 너무 작긴 작구나 뭐야 사무실에서 먹는 새우젓은 이렇게 작은 거야',
#  '집앞에 놓고 가신 후 문자를 주셔도 되는데 제가 번거롭게 한 것 같습니다.',
#  '냄새 안 나고 맛있는 고기로 잘 골라서 보내주셨는데 상추는 왜 이렇게 작은지 모르겠어요 된장찌개 고기는 괜찮은데 고기는.',
#  '맛은 그냥 그래 많이 짠고 그리고 김치찌개에서 머리카락도 엄청 나오고 배달은 생각보다 빨리도착 했어요.',
#  '양파 꼭 빼달라 부탁드렸는데 양파가 안들어간 음식이 없네요 음식에 배달도 오래걸려 새로 받기도 힘든데 양파 안',
#  '진짜 너무 배고팠어서 그런지 몰라도 샐러드 드레싱이 너무 짜서 한 점 먹고는 안 먹을 정도였어요 목살 스테이크랑 콜라비 먹었는데 둘 다 너무 비',
#  '6900원인데 진짜 양이 너무 한 것 같아 보이는 게 690원에 파는 어니언링도 너무 맛있고요.',
#  '식어서 그런건지 매장에서 먹던 그 맛이 안 나네요 식어서',
#  '치킨버거랑 치킨 사이에 있는 거기서 머리카락 나왔는데 그거 머리카락이에요',
#  '맛은 그냥 그런데 포장이 너무 성의가 없어서 받는 사람도 기분 나쁠 것 같고 무엇보다 고객이 주문한 게 맞는지 확인할 수 없음',
#  '와이프와 제가 모두 별로 안 좋아하는 피자였습니다 기름기 많은 담백하고 고소한 피자를 원했지만 와이프는 전혀 안 좋아했습니다.',
#  '이렇게 피자가 눌어붙어서 온 게 반은 먹고 남은 건 식어서 버리고 안에 든 파마산 치즈는 반만 남기고 다 먹었어요.',
#  '배달의 속도가 너무 느렸고 돈가스는 아주 느끼해서 먹을 수가 없었습니다.',
#  '평범한 맛 배달비가 비싼 편이나 맛은 평범하다. 보통의 가격에 무난한 맛을 낸다.',
#  '저는 도로명주소를 사용한 적이 없는데 저한테 배달기사님이 건물명이랑 호수를 제대로 알려줬다면 이런 일이 일어나지 않았을 것 같아요.',
#  '다음엔 소스 따로 또 주세요 다음엔 그 때 소스도 따로 주세요',
#  '양은 많은데 가격이 좀 비싼 편이고 아직 따뜻한 음식을 못 먹어서 냉동시켰는데 맛은 어떨지 모르겠네요',
#  '저번에 시켰던 카레가 너무 맛있어 이번에도 시켰는데 역시나 맛있네요 이번엔 세 개만 시켰는데 내일 한 개는 먹을 거라고 하셨어요',
#  '밥이 찰밥인지 뭔지 모를 정도로 고기만 잔뜩 들어있는 그런 비주얼의 삼계탕을 먹을 수 있어요.',
#  '좀 써요 그래서 고추장이랑 쌈장 맛이 별로 안 나고 고추기름도 엄청 많이 나왔어요',
#  '사장님이 보내신거는 아니실듯하고 배달이 너무 오래걸려서 이렇게 된듯한데 먹을수가 없네요 한시간 20분 정도 있다가 배달',
#  '늦게 온 탓에 다 못먹고 남은 건 못 먹고 온 게 아쉬웠어요.',
#  '방어회를 시켰는데 그 횟집 된장 조금하고 그냥 재래식된장 조금에 백김치 참기름 이런거 하나도 안주고 스끼다시도 너무 성의가 없어서 돈이 너무 아까움',
#  '익스프렉스 면 안내가 오긴 했지만 다시 구매할지는 모르겠네요. 가격이 저렴하고 배송이 빠르다고 해서 샀는데 별로 안 빠르네요.',
#  '쌀 콩 대두가 없어서 부리또 맛이 안 나는데요 부리또에는 쌀 콩비지가 들어 있는데요',
#  '맛은 그냥 그런데 양도 적고 무엇보다 배달이 너무 늦어서 배 터지는 줄 알았',
#  '두줄도 채 안 되는 두꺼운 대패삼겹살을 받고 싶어서 비싼 돈 주고 산 삼겹살을 한시간 걸려 수령했는데 정말 실망입니다.',
#  '처음 전화했을 때는 40분이 넘게 대기하고 있었고 음식 나오는 시간은 이미 정해져 있었기 때문에 음식을 빨리 먹고 싶었는데 30분이 지나도 안 남아서 결국 못 먹고 남은 음식은 포장해둔 채 포장되어 있었습니다.',
#  '배달은 아주 빠르게 왔는데 이미 한 봉지를 다 먹었을 정도로 다 상해버린 짜장면을 보니 마치 마감시간에 나온 짜장면인 것 같습니다.',
#  '잘 먹었습니다 수고하세요 맛있게 잘 먹었습니다',
#  '콘 음료가 상한 것 같네요 딸내미가 마시고 나서 배가 아프다며 잠을 못 잘 정도로 재료를 신선하게 사용하세요.',
#  '두 사람은 서로 무뚝뚝하기는 해도 자주 만나고 포장도 자주 해주기 때문에 자주 포장해주거나 포장해주던 단골인데 이번에 배달 문제로 연락이 와서 불편을 겪었다.',
#  '참 이런 식으로 얼음을 가득 채운 채로 판매하시는 건 정말 식품 안전에 심각한 문제가 아닌가요?',
#  '전화도 안받고 짜증나서 코코낫 음료도 못먹고 맵싸한 맛이 나는 것은 입에 넣지도 못',
#  '조개하고 소고기하고 혼합된 것이 소고기인데 조개와 섞여 있네요.',
#  '맛이나 양은 괜찮은데 배달이 예정보다 너무 늦게 배달되면 기다리는 일이 너무 많아 짜증이 나기도 했다.',
#  '묵 어묵 김치 나물 무 무침 등 이날 메인 메뉴가 다 나갔는지 반찬이 하나도 안 나왔어요 그래서 인지 몰라도 밥을 씹는 맛이 시원찮았어요',
#  '음식도 다 식어가고 식어서 도착하기로 예정된 시간인 30분을 훨씬 초과해 도착한 것이었어요.',
#  '추가로 반찬 더 준 것도 아니고 그냥 사진에 있는 반찬만 준 거면 제가 돈 주고 산 거 아닌가요?',
#  '배송이 너무 느렸고 배송완료 문자도 안 보내서 짜증이 났으며 아이스 카페라떼를 주문했는데 한 조각 먹고 다 비었어요.',
#  '오늘 알았어요 퍼포먼스 원두가 500원이나 저렴하고 배달료도 무료 라는걸 그런데 커피가 맛있어요 배',
#  '항상 먹던 것만 먹고 다른 건 안 먹을 거니까 걱정하지 않아도 돼요',
#  '메뉴를 고를 때 주의를 기울여야 하는 부분은 단맛이 첨가된 메뉴이기 때문입니다.',
#  '배X에서 판매하는 모든 제품이 무료배송인 것은 너무 기쁜데 맛은 말할 것도 없고 오로지 레몬그라스 향만 나는 커피를 마시고 싶을 때는 오후 11시 이전에 주문하면 다음날 받을 수 있는 것이 단점입니다.',
#  '한번 먹으면 중독성 있어서 멈출 생각을 안 하고 계속 시켜 먹는 게 한번 먹고 난 다음의 맛이에요.',
#  '맛은 있는데 배달이 조금 늦어서 담에 또 주문할 기회가 생기면 또 사러 올게요',
#  '맛도 변한거 같고 1인분 떡볶이 양이 너무 적은데 1인분이면 얼마 안 되는 것 같아요',
#  '떡볶이도 맛있고 튀김도 바삭하고 무엇보다 튀김이 아주 그냥 다 맛있어요.',
#  '문 앞에 갖다 놓고 가는 것도 모자라 그냥 바닥에 놓고 가버리고 가는 게 배달 온 시간보다 더 늦었는데 말이죠.',
#  '양이 많고 배달도 빠르며 가격도 저렴한 데다가 양도 많고 맛도 좋은 편이다.',
#  '항상 맛있게 먹고 있는 곳이지만 시간이 너무 늦어서 중국당면을 기본으로 빼 먹으셔서 아쉬웠어요.',
#  '배달도 빠르고 맛있어요 특히 배달이 빠르고 음식이 빨리 나왔으면 더 좋았을 것 같아요',
#  '탕수육 냄새가 많이 나요 군만두는 들익은거 처럼 밀가루맛이 나요 짬뽕국물은 맛있어요',
#  '음식이 전반적으로 다 짜져서 전체적으로 사장님이 바뀌셨어요.',
#  '국물은 진하고 숙주양이 많아서 국물이 시원할 것 같았지만 맛은 밍밍하고 면은 불어서 먹을 수가 없어요',
#  '쌀국수에 들어있는 고기 두 점과 소고기 한 점 이건 무슨 일이 있어도 먹을 수 있는 음식이죠 이건',
#  '먹을만은 한데 양이 좀 적은 편인 것 같아요 족발은 먹을만 해요',
#  '예전에 맛있게 먹었던 기억이 나서 시켰는데 맛이 변한 것도 있고 안에 든 부추전이랑 콜라만 엄청 먹고 다른 건 안 먹을 거야',
#  '혼자 먹기 충분한 양이고 배달 예정 시간보다 20분 정도 더 걸렸어요 혼자 먹기엔 양이 너무 적은 것 같아요',
#  '그냥 보족세트 시킬걸 그랬어여 1인이 먹기엔 양이 너무 적고 그냥 간장 세트로 시킬걸',
#  '면에서 냄새가 나는 것은 당연하고 소스도 약간 물탄 것처럼 너무 묽어서 마치 밀가루 반죽처럼 되었어요',
#  '특히 김치가 안 들어 있어서 다시 전화해서 다행히 김치를 받아 먹었지만 색깔이 좀 이상해서 다시 연락했더니 그때는 괜찮다고 하셨지만 색이 너무 안 예쁘게 나왔어요.',
#  '적당한 양과 적당한 가격에 적당한 양까지 만족스러운 제품입니다.',
#  '빵 세 개를 사서 반으로 자른 후 각각 6개를 포장해 달라고 요청했는데 흔쾌히 수락해주시고 3개 포장을 해 주셨습니다.',
#  '좋아하는 메뉴가 대체적으로 다양하게 팔아서 좋고, 또한 여러 가지로 팔아서 좋습니다.',
#  '배달 포장을 너무 대충 해서 오는 거 같아요 배달 포장이',
#  '여기 친절한거는 마음에 들어요.',
#  '렌틸틸과 해바라기씨는 전부 밑으로 내려와야 하는데 그래야 해바라기씨가 나오기 때문입니다',
#  '이번에 받은 고기는 부위도 정확하지 않고 비계도 너무 많아서 무슨 고기인지 알 수가 없었어요.',
#  '맛있게 잘 먹었습니다 감사합니다',
#  '양도 많고 맛도 있는데 아쉬운 점은 보통 때보다 날치알이 좀 적게 들어있다는 것이었어요',
#  '아주 맛있게 잘 비벼서 잘 먹었습니다.',
#  '배달 음식은 대체로 별 5개 주는데 처음으로 별3개 해봐요 배달 음식 대부분이 별5개인데 너무 질겨서 고기반 야채반 도착 시간도 늦',
#  '진짜 말이 필요없는 초밥왕중에 왕입니다 아이가 먹는 회에서 와사비를 빼달라고 하는데도 잘 받아주셔서 너무 잘 먹었어요',
#  '숙주 빼달라고 했는데 안 빼줘서 고기는 그냥 그런데 맛은 그냥 평범해요 숙주 맛이 궁금했는데 그냥 보통이에요',
#  '크림소스 가루가 뭉쳐지지도 않고 뭉치고 소스도 너무 적고 면에 소스 묻혀먹는 느낌 오늘 맛이 별로네요 크림',
#  '맛이 너무 시고 자극적이어서 주변에 있는 제육집에서 같은 맛을 내긴 하는데 저는 별로 안 좋아하는 것 같아요',
#  '특히 왼쪽의 고기는 1인분에 1000원으로 일반 식당에서 파는 고기보다 훨씬 비싼데 맛도 없고 영양도 덜 주는 것이 문제가 되고 말았다.',
#  '배달이 늦은 탓인지 배달 완료된 후 육회가 거의 차갑지 않게 식어 있었습니다.',
#  '저번에도 이랬는데 이번에도 이러면 이번엔 그릇에 반이 차지 않을 정도로 많이 줄어들 것 같아요.',
#  '솔직히 돈아까워요 당면불어터지고왓고 음식이상햇는지 설사하고 배탈이나서 혼낫네요 솔직히',
#  '단골로 자주 가던 곳이 맛이 없어져서 여기로 오게 됐는데 뜻밖에 너무 맛있어요.',
#  '식당과 관련 없는 내용이지만 양해 바랍니다. 양념과 소스는 맛있어 보였지만 양이 적거나 적은 건 양념이 별로 없어서였습니다.',
#  '잘 먹었고 다 먹고 나서 사진 찍는 것 빼고는 다 괜찮았네요 맛있게 잘 먹었습니다',
#  '전분이 들어있는 것 같은 그런 끈적거리는 느낌의 닭발이에요.',
#  '근데 매운맛 시켰는데 약간 더 맵았으면 좋겠고 마감시간 10분 전에 시켰는데 취소 안 되고 잘 배달돼서 좋았어요.',
#  '맛있게 잘 먹었습니다.',
#  '치즈스틱은 먹지 마세요 그리고 50분 예정이었던 배달 시간이 15분이 지연되었고 배달 완료된 시간은 50분이었는데 기다린 사람은 저뿐이었습니다.',
#  '맛은 있는데 배달 예정 시간보다 너무 늦게 왔어요 맛은 있어요',
#  '맛은 있었지만 머리카락이 들어있는 채로 배달된 건 처음이었어요 꿔바로우 안에 든 머리카락은 정말 궁금했던 꿔바로우였어요',
#  '맛있어요 조아요 굿 맛있어요 조요 굿굿 좋아요 맛있어',
#  '매번 주문하던 닭발인데 맛은 좋은데 평소보다 살이 많이 없어서 아쉬워요 추가로 주먹밥에 넣는 김가루 안주셨어요',
#  '적당하게 맛있게 잘 먹었습니다.',
#  '다 좋은 것 같은데 배달료 5500원이 너무 많은 것 아닌가 그런데 다 좋은데 배달료를 5500원으로 한 건 좀 심한 것 같다.',
#  '제가 제일 싫어 하는 게 비린내 인데 어제 먹은게 닭비린내 인지 아님 곱창인지 비릿한 냄새가 조금 나더라구요 그래서 내일은 비릿한',
#  '일반 김밥과 비교했을 때 김밥의 고소한 맛이 덜하고 식감도 보통 김밥보다 못한 편인 것은 저의 개인적인 견해입니다.',
#  '개인적 입맛에 따라 다르게 평가한 것은 개인적으로 김밥과 쫄면, 튀김은 맛이 괜찮았지만 쫄면과 김밥은 별개인 것입니다.',
#  '처음부터 끝까지 다 익혀 먹는 거예요 너무 익히면 누린내가 나서 못 먹을 수도 있으니까요.',
#  '요즘 몇 달 전만 해도 안 이랬는데 요즘 곱창 양이 정말 적어졌어요 저도 이번에 먹어 보고 싶었는데 아쉬워요',
#  '오늘 아침부터 와이프와 저는 배가 고팠기 때문에 화장실을 갔는데 사장님이 아주 작은 손으로 음식을 데워드셨더라고요',
#  '소스가 조금만 더 많았으면 반찬대용으로 먹기 좋고 가격이 좀 더 저렴했다면 더 많은 반찬을 만들어 먹었을 것 같습니다 .',
#  '제가 원래 이런 사진 잘 안 올리는데 이번엔 좀 제대로 올려주세요.',
#  '양이 엄청 많은데 배달은 엄청 느렸고 맛도 약간 싱거울 수 있다고 해야 하나 암튼 닭은 아주 맛있게 먹었어요',
#  '평이 좋아서 샀는데 제 입맛에는 별로였어요 식감은 부드럽긴 한데 너무 기름져서 마치 기름을 바른 듯한 느낌이었어요',
#  '음식은 다 맛있다고 해서 기대하고 갔는데 제 입맛에는 별로였어요 냄새도 나고 음식은 따뜻했는데 저랑 남편은 별로 안 좋아하는 것 같',
#  '아 그리고 치즈크러스트 추가하면 피자가 더 작아져요 저번에 제가 김포점에서 시켰을 때는 치즈가 많이 들어갔는데 여기는 전혀 아니에요',
#  '급하게 오시느라고 피자가 거의 안 잘라진 상태로 배달됐고 주문한 것도 제대로 안 와서 한시간 반이나 늦게 배달받았네요.',
#  '다른 데서 먹어보고 여기서 먹어봤는데 거긴 더 맛있는 것 같아요 여기는',
#  '평소에 아주 매운 음식을 선호하지는 않지만 집에서 만든 음식 중에 좋아하는 음식이 있을 정도는 아닌데 오늘 받은 마라탕은 너무 짜서 한 입 먹고 못 먹을 정도였어요.',
#  '감자가 두꺼운데 다른건 다 얇은 정도인데 감자가 너무 두꺼워요',
#  '당면도 부서져서 오고 옥수수면도 추가했는데 당면도 덜 왔어요 그래서 조금 아쉬웠어요',
#  '배달 온 게 늦어서 8시 44분에 문자로 알림 온 뒤 9시 10분에 문 앞에 도착했는데 안 와서 당황했어요 그래도 맛은 있으니까 괜찮아요',
#  '처음부터 끝까지 다 맛있는 꿔바로우를 먹기 위해 3단계까지 먹었지만 그래도 좀 아쉬웠던 건 제가 너무 기대를 많이 한 탓일까요?',
#  '육회 비빔밥 모두 정갈하고 정갈하게 잘 왔는데 비빔장 맛이 너무 평범해요 비빔장을 따로 좀 연구해 주시면 좋겠어요',
#  '최근에 여러 번 시켜도 처음 예상시간이 30분인데 기본적으로 1시간만 지나도 도착하면 너무 짜증나거든요 사장님이.',
#  '원래 순대는 3개만 들어가는데 특 순대국에는 순대가 4개만 나오기 때문에 그렇습니다.',
#  '태우지 않은 음식은 못 먹는 것이 당연한 것처럼 음식 쓰레기를 버리면서도 버리지 못 하는 이유는 음식을 태우면 나는 냄새 때문입니다.',
#  '맛있게 잘 먹고 있다가 머리카락 발견 근데 또 맛있는 음식은 머리카락도 맛있는 것이었어',
#  '맛은 있는데 좀 아쉬운 점이 있다면 떡에 머리카락이 붙어 있다는 점이었어요 그리고 무엇보다 양이 좀 적은 편이라는 점입니다.',
#  '여기서 고기 자주 시켜 먹었는데 다른 데 가서 먹을 때는 안 그런데 여기만 유독 냄새가 안 나고 고기가 신선하다 싶으면 바로 여기로 가 먹어요',
#  '김치찜은 좀 짜긴 해도 먹을만 한데 밑반찬 가격이 좀 나가긴 하네요 기본반찬 가격도 좀 나가고',
#  '조금 아쉬웠어요 그 부분은 제가 좀 아쉬웠어요',
#  '감사합니다 너무 맛있는 요리 만들어 주셔서 정말 감사합니다.',
#  '음식이 식어가고 20분 뒤에 배달 출발 알림톡이 왔을 때 너무 아쉬웠던 점은 순두부찌개에 들어간 기름이 너무 많이 나와 맛이 약간 싱거울 수 있다는 점이었습니다.',
#  '양은 많고 배달도 빠른데 맛은 좀 짜요 전반적으로 맛이 좋지않은데 짜니까 많이 먹기 힘들었어요',
#  '안먹는 꽃빵을 대신해 줄 수 있냐고 물었지만 답변이 없으시네요 심지어 새우는 입에도 안대고 있는데 어떻게 말린 새우를 튀겨야 하나요?',
#  "부천에서 자주 먹는 음식 중 하나인 '샤또'(샤또딜라이트)는 저번에 제가 친구 따라 간 곳에서 맛이 너무 괜찮아서 이번에 또 시켜먹었어요.",
#  '마라샹궈는 제 입맛에 좀 싱거울 수밖에 없고 궈빠로느는 새콤달콤 맛있네요.',
#  '그냥 그냥 그럼 그냥 그저 그럼 그저 그러면 그냥 그렇게 그럼',
#  '양은 2인분인데 2인분 정도 되는 양이라고 생각하기에는 부족한 느낌이었습니다.',
#  '두번째 주문인데 두번째는 저번보다 살이 덜쪄서 더 끊여서 먹어야할것 같아요 그리고 추가한 메추리알은 맛이 이상해요',
#  '원래 다른곳에서 주문해서 먹던 닭발이 있는데 거기가 문을 닫았어서 여기로 바꿨더니 맛은 더 좋아졌지만 좀 비려서 아쉬웠어요.',
#  '매운맛 조절도 어렵고 무엇보다 기름이 너무 많이 나와 옆에서 마늘을 볶던가 해야 할 판이에요 다른 분들도 이런 분들은 참고 견디시기 바랍니다.',
#  '맛은 괜찮은데 배달이 너무 늦어서 치킨무 곽에 다 흘러서 오고 콜라병에도 소스가 한가득 흘러서 불편했습니다.',
#  '자주 주문하던 맛집인데 한 번도 맛이 없었던 적이 없었는데 이번엔 소스가 너무 묽어서 파스타가 아니라 국물 요리 국수 같아요',
#  '맛은 나쁘지 않은데 포장이 잘못된건지 배달이 잘못된건지는 모르겠지만 리조또에 파스타가 섞여있고 도대체 뭔지 알 수 없는 요리에 온통 기름범벅으로 왔어요',
#  '항상 먹는 커피와 빵은 물론 맛있고 든든한 한 끼 식사가 될 수 있어 자주 애용하지만 여름엔 유난히 더 자주 먹게 되는 것 같아요.',
#  '치킨버거는 바삭한 맛이 좋았지만 폴트버거는 느끼함이 너무 강해서 느끼함을 잡아주지 못해서 아쉬웠어요.',
#  '버거는 괜찮은데 감튀는 양이 너무 적고 버거는 너무 식어 있어서 약간 아쉬웠어요',
#  '아들이 너무 좋아하는곳이고 아들이 좋아하는곳이라 시켰는데 도우가 씬 정도면 소스를 조절을 해주셔야하는데 너무 짜요 소스가',
#  '이름만 뉴욕 피자 집인 줄 알고 진짜 뉴욕 가서 피자 먹어 보고 싶다.',
#  '국물떡볶이의 맛도 괜찮고 양도 적당한 것이 국물떡볶이에 야채가 빠지면 섭섭하지 않을까 생각합니다',
#  '튀김이 바삭하지도 않고 밀가루만 잔뜩 묻은 채로 바닥에 놓여 있는 실정이고 면의 퍼짐도 심해서 먹을 기회가 거의 없는 것이 아쉬움으로 남는다.',
#  '근데 제가 생각한 이상으로 맛있게 잘 먹었던 음식은 명란 토란 덮밥입니다.',
#  '메모에 우동면에 넣을 파와 김을 빼달라고 했는데 안 빼주시고 그냥 우동면만 가져오셨습니다.',
#  '양이 많이 모자랐고 배달 시간이 예상보다 많이 늦어져서 근무 점심 시간에 많이 불편을 겪었다.',
#  '잘 먹긴 했는데 좀 느끼하긴 했어요 소금이랑 같이 넣어서 그런가 봐요',
#  '원래 이렇게 얇게 나오나요 다른 제품들은 다 잘 잘라져서 왔는데 유독 여기만 그러네요',
#  '중심이 좀 덜 익은 것 때문에 두 조각 중 한 조각은 별 차이가 없이 먹었지만요.',
#  '좋은 후기를 남기기 위해 노력하는 것도 중요하지만 그보다 중요한 것은 변하지 않는 음식 재료와 정성스러운 포장에 감동했다는 것입니다.',
#  '잘 먹었고 맛있게 잘 먹었어요',
#  '맛있게 먹었지만 왠지 모르게 허전한 느낌 맛있는 건 잘 먹었는데 뭔가 허전한 것 같아',
#  '이번에 받은 닭고기는 원래 있던 것보다 훨씬 부드러웠어요 The chicken was very sickle to me at the first day.',
#  '김밥 1줄 비용 3000원 환불을 해 주셨으면 합니다. 문을 시끄럽게 두드려서 가족들이 다 깼습니다.',
#  '근데 역시 맛있는 죽변항 근데 공기밥 추가 했는데 공기밥은 안 왔어요',
#  '맛은 있었지만 두 줄이 아닌 한 줄에 불과한 회를 먹으면서 3천원도 안 되는 배달비를 지불하고 나니 이 정도 양이면 거의 6만 원이라는 가격은 납득하기 어려웠습니다.',
#  '제가 급하게 친구의 부탁으로 주문한 것이었고 시간이 늦었다고 미안하다고 사과는 드렸지만 햄버거 프라이 윙을 하나 먹었는데 하나도 안 남아서 너무 슬펐습니다.',
#  '음 음 야채가 쉬웠어요 음 채소가 쉬웠',
#  '회덮밥을 시켰는데 초장은 왜 안 주셨을까요? 배달은 예상보다 빨리 왔지만 회무침은 초장이 없어서 아쉬웠어요.',
#  '회종류가 많지 않아 아쉬웠어요 맛있게 잘먹었고 회종류가',
#  '그냥 저냥 그래요 특별한 건 없어요 그냥 저냥',
#  '연어 색이 왜 이런거죠 저렴한 가격에 이런 연어를 먹을 수 있다니 정말 만족스러운 식사였습니다.',
#  '배달은 빨랐고 맛은 마트에서 파는 초밥이랑 비슷했어요 배달은',
#  '그냥 한끼 식사로 괜찮고 회가 전부 무슨 맛인지는 몰라도 많이 줘서 배부르다.',
#  '진짜 이건 너무하다 싶을 정도로 어이가 없어서 말도 못 내놓겠습니다.',
#  '저는 개인적으로 양념게장살 초밥이 좀 짜긴 해도 먹을만 했어요 근데 기사님이 너무 빨리 오셔서 제가 다 먹긴 했어요',
#  '간장 없는 초밥은 처음 먹어보는데 맛있게 잘 먹었어요 근데 원래 이렇게 초밥에 간장을 안 넣으시나요?',
#  '용기는 아주 그냥 그런데 랩을 한 번 두르던지 아니면 뚜껑을 열고 내용물을 막던지 방법을 좀 바꾸던가 해야할 것 같아요.',
#  '괜찮네요 종종 시켜 먹을게요 괜찮네요 괜찮네요',
#  '오전 10시에 주문해서 1시간 넘어서 도착할 줄 알고 있었는데 한시간 더 늦게 도착하는 건 무슨 경우입니까?',
#  '전에 시켰던 고구마가 3~4개가 이번에 시킨 고구마는 4개였는데 이건 너무 심한것 같네요',
#  '너무 짜서 거의 다 먹고 남긴 건 소금만 빼고 나머지는 다 남겼어요 너무 짜서',
#  '다좋은데 오래된 족족을 주시나요 너무 딱딱해서 턱빠질뻔 했어요 다좋은데',
#  '일반적으로 배달 음식을 많이 먹는 편인데 이번에는 좀 덜했으면 좋겠어요 맛은 기본적으로 알던 맛이고 얇게 썰어서 그런가 봐요',
#  '일부러 여기서 구매한건데 제가 생각한 샤베트는 식감이 아삭거리는 샤베트가 아니라 약간 거친 샤베트였어요.',
#  '배달하는 시간이 너무 오래 걸리고 배달은 중간 정도로 중간쯤 됩니다.',
#  '마요네즈가 너무 많이 많아서 마요네즈가 엄청 많았어요',
#  '콩나물은 약간 탄 맛이 좀 났지만 원래 편식쟁이라 상관없고 된장하고 계란볶밥은 조금 심심하지만 반찬들이 먹을만해서 먹을만 했어요',
#  '콘 같은 반찬 말고 단무지가 더 필요한 것이 맛 시그니처 메뉴라 기대했는데 너무 달아서 내 입맛에는 그저 그랬다 배달 빠르고 포장용기 세련되고 깔끔',
#  '매운탕 끓이던 중에 이런 게 나왔는데 하마터면 매운탕 다 먹을 뻔했다니까요 매운탕 맛은 깔끔했지만 말이죠.',
#  '아무리 바빠도 그렇지 저번처럼 야채 더 주는 것도 아니었어요 사장님 이번에는 꼭 드실 분만 넣어주세요',
#  '서비스도 좋고 양도 푸짐하고 무엇보다 푸짐한 양의 족발이 맛있어요 그런데 서비스로 주신 족발은 좀 별로예요.',
#  '다른 것은 인정 신속 배달은 좋은데 배달에 콜라가 안 나오고 다른 건 괜찮아요.',
#  '음식을 배달해 주는 곳이 다른 곳에 비해 빨리 도착했고 배달 완료된 음식을 보니 더 맛있을 수밖에 없었다.',
#  '제가 별도로 포장해 달라고 요청하지도 않았는데 그냥 보내주신 이유가 무엇이죠? 다른 집에도 나눠 줘야 하는데 번거롭게 해드려 죄송합니다.',
#  '진하지는 않지만 먹을만 합니다 배달비가 너무 비싼 것만 빼면요',
#  '질겨요 질겨서 고기가 질겨요',
#  '특히 연어는 밥보다 연어 회를 먹는 게 훨씬 이익이에요',
#  '저번달에 맛있게 먹어서 또 시켰는데 고기 양이 엄청 줄었더라고요 된장찌개도 엄청 짜고 고기 양도 엄청 적어요',
#  '맛있게잘먹었습니다맛있어맛있어맛있어맛있네요맛있어맛있어맛있어맛있어맛있게잘먹었습니다맛있게잘먹을수맛있게맛있게잘먹었어요맛있어맛있어맛있네맛있어맛있어맛있네맛있네맛있어맛있네맛있어맛있네맛있게잘먹었습니다맛있네맛있어맛있네맛있네맛있네맛있어맛있어맛있게맛있어맛있어맛있네맛있게맛있어맛있어맛있어잘먹었습니다맛있어맛있네맛있네맛있게잘먹을맛있게맛있네맛있네맛있네맛있게맛있네맛있네맛있어맛있게잘먹을먹었습니다맛있어맛있네맛있게맛있네맛있어맛있네요리맛있게잘먹을먹었어요맛있게맛있게잘먹을감사맛있게맛있게잘먹었습니다아주맛있게맛있게잘맛있네맛있게잘먹었어맛있네맛있어맛있네요맛있네맛있어맛있어잘먹을수맛있어맛있어맛있게맛있네맛있어맛있게맛있게잘잘먹을수요리맛있게맛있게잘',
#  '이 씨 부부의 경우 임신 8개월째로 배 속 아기가 근심되어 허리를 약간 굽히고 한 손으로 배를 가린 채 전동차에 올랐다.',
#  '맛있어요 잘먹었고 잘먹었습니다 맛있어요',
#  '맛있게 잘먹었고 아주 만족스러운 요리였습니다.',
#  '맛은 만족 근데 좀 더 조심해서 비벼야 할 것 같은 맛이 나서 숟가락으로 퍼 먹는 건 좀 힘들운 듯 해요.',
#  '한끼 식사로 아주 든든하게 잘 먹었습니다.',
#  '밥이랑 계란 말고 그냥 계란만 주시면 되는데 제가 그냥 달라고 한 것은 밥이고 후라이는 그냥 주시면 됩니다.',
#  '저렴한 가격으로 한끼 식사를 할 수 있어 좋지만 예전과 좀 차이가 있는 것 같은 외관도 한 몫을 하는 듯합니다.',
#  '커피를 내려도 설탕 넣은 물 말고 우유를 타야 하는데 그게 없으면 블랙 커피가 될 것 같고 아니면 설탕 넣지 않은 차를 마셔요',
#  '디저트로 아주 잘 어울리는 디저트네요 맛있게 잘 먹었어요',
#  '많이 기대했는데 정말 맛있어요 기대만큼 많이 기대하지 않았는데 기대 이상으로 맛있어요',
#  '커피와 와플, 그리고 맛있는 카페와 와플까지 맛있게 먹었습니다.',
#  '식어서 조금 남긴 했지만 잘 먹었어요 식어서',
#  '부모님이 엄청 좋아하셨어요 그런데 조금 더 달았으면 더 맛있을 것 같다고 하셨어요',
#  '오후 11시에 아들이 떡볶이가 먹고 싶다해서 주문했는데 배달이 60분 걸린다는 알림을 받았지만 그정도로 밀리신건 모르겠는데 차라리 주문취소해주시면 감사하겠습니다.',
#  '양이 엄청 많아서 행복했어요 위에 고구마무스케이크는 매운맛으로 했는데 약간 더 달았어요 배송도 빠르고 위에',
#  '배송이 너무 오래 걸린 것만 빼고는 다 맛있어요 고구마 무스 안 한 게 더 맛있네요',
#  '순한맛 순한맛 두 개 시켰는데 둘이 먹기엔 약간 단 느낌이 있어서 조금 더 달게 해달라고 했어요',
#  '저 원래 다른 지점에서 엄청 맛있게 먹었어요 매운맛 순한맛 두 종류 시켰는데 전부 잘 먹었어요',
#  '양은 타브랜드에 비해 적긴 하지만 진짜 맛있어요 특히 이 소스가 다른 곳에서는 찾아볼 수 없는 맛이에요',
#  '치즈가 이렇게 많이 들어있는 줄 처음 알았어요 집에서 먹는 치즈처럼 이런 치즈는 처음이에요 맛은 평범한데 치즈가 엄청 많아서 놀랐어요',
#  '별점을 하나도 안 준 이유는 별로 안 좋은 후기가 많은 이유가 저도 이해가 안 가기 때문입니다.',
#  '당치땡 양념에 비해서 맛이 떨어지는 것 같아요.',
#  '다회용으로 구매했는데 국그릇만 남고 나머지는 모두 플라스틱 용기에 담겨 있어 아쉬웠어요.',
#  '감사합니다 맛있게 잘 먹었습니다 감사합니다',
#  '너무 맛있게 잘먹었고 배달비도 무료라서 너무 좋아요',
#  '국물이 조금 더 진했다면 더 맛있게 먹었을 것 같아요 순대도 부들부들하고 국물도 진하고 또 먹고 싶네요',
#  '맛있게 잘 먹었습니다 다음에 또 주문할게요 감사합니다',
#  '맛있게 잘 먹었습니다 다음에 또 주문할게요 수고하세요 감사합니다',
#  "일반 플라스틱용기에 뜨거운 국물을 담아 주실때는 '내가 먹지 않으면 환경에 유해해' '환경을 오염시키는 일은 하지 않을 거야' 등의 강한 어조로 말씀하시지만 드시는 동안 계속 그런 생각이 드실 거예요.",
#  '꿔바로우가 기본적으로 양이 적은 데다가 맛도 없어서 두 번 구매는 안 할 것 같아요.',
#  '생각보다 맛이 진하지는 않고 예전에 먹던 것보다 덜 짜진 것 같아요',
#  '저번에 시킨거는 매운맛 시켰는데 이번에는 마라맛이 좀 적어서 아쉬웠어요 다음엔 매운맛이랑 마라맛 두 종류 다 시켜먹어 볼 것 같아요',
#  '제가 두부피시볼을 토핑으로 추가했는데 제가 빠뜨린 게 있는 건가요 ? 맛은 괜찮은데 두부가 원래 있던 토핑에서 빠진 건가요',
#  '처음 주문할 때 제가 단무지 좀 넣어 달라고 요청했는데 안 넣어주시고 그냥 오신 분이 더 많았죠.',
#  '첫 주문이 큰 기대를 받지 못했는데 기대 이상으로 좋은 제품이 많아 덕분에 좋은 시간 보냈습니다 또 맛있는 요리로 찾아 뵐게요.',
#  '근데 삼겹살에서 이상한 털들이 나왔어요 너무 맛있게 잘 먹고 있는데 감사합니다',
#  '김치 볶음밥은 조금 덜 볶은 김치로 흰밥 부위가 좀 남아 있었고 나머지는 모두 만족했습니다.',
#  '밤이 맛있는 집은 맛이 덜해서 슬퍼 이집은 낮에 먹어야 하는 날은 잘 먹지 않는 거야',
#  '시킬때마다 다른 맛을 내는 건 주문할 때마다 같아요.',
#  '짜장면은 맛있게 먹었지만 사이드 만두가 적고 짜장면은 짜장면보다 덜 달았어요',
#  '저번에 먹었던 잡채밥이 너무 질겨서 이번엔 밥을 좀 적게 넣은 것 같아요.',
#  '음식 자체는 맛있어요 다만 아쉬운 점은 배달 온 지 한 시간 만에 면을 하나 더 주셨다는 거예요 그게 좀 아쉬웠어요',
#  '양 많고 국물은 약간 심심하게 먹을 수 있게 해줘서 오랜 시간 만에 다시 찾은 만다린인데 맛은 그저 그랬어요 맛',
#  '잘 먹었습니다 배달 시간이 지났는데도 짜장면이 녹지 않고 배달된 건 정말 감사합니다.',
#  '여느 짬뽕집과 차이가 없을 정도로 깔끔한 맛이었지만 마파두부는 역시 맛있습니다.',
#  '양이 엄청 많은데 배달이 약간 늦었는데 사장님이 너무 친절하셔서 그랬고요 양도 많고 정말 친절하셨어요.',
#  '숙주랑 같이 먹을 수 있어서 좋고 숙주 양이 적지 않아서 좋았어요',
#  '숙주 상태가 안좋아서 숙주는 못먹었고 쌀국수도 맛있는 편이지만 숙주를 넣어서 만든 밥과 김치 모두 별로였어요.',
#  '면이 별도로 있으면 더 시원할 것 같은데 면이 따로 있으면 국물 맛은 더 좋을 것 같습니다',
#  '사장님이 너무 친절하셔서 감사했어요 팟타이볶음밥도 너무 맛있어요 양도 푸짐하고 헤자인데도 엄청 많아요',
#  '양이나 맛은 그냥 그런데 배송은 빨랐고 배달 해주시는 분이 엄청 친절했어요.',
#  '잘 먹었지만 소스가 달콤 소스라 그런지 좀 짰어요. 잘 먹긴 했는데.',
#  '기름맛 고추장 맛이 많이 나고 기름과 맛 있는 고추장 양념이 많았어요',
#  '이 씨 부부의 경우 임신 8개월째로 배 속 아기가 근심되어 허리를 약간 굽히고 한 손으로 배를 가린 채 전동차에 올랐다.',
#  '요즘 2, 3차례 시켜 봤는데 두 곳 다 너무 맛이 없어서 실망했어요 .',
#  '쌈이 없으면 그냥 먹을 정도로 맛이 좀 약하네요 상추를 싸 먹는 것도 좋을 것 같아요',
#  '맛은 항상 좋은 것 같아요 근데 배달이 한시간 십몇분 만에 와서 아쉬웠어요',
#  '늦은 시간에도 맛있게 잘 먹었고 덕분에 잘 먹었다고 인사드립니다.',
#  '혼자 먹는 것은 혼자 먹을 정도로 먹을만 했습니다.',
#  '저번에도 그러더니 이번에도 그러네요 상추랑 깻잎만 보내주시고 나머지 음식은 그냥 줘요 저도 먹을 거지만 말이죠',
#  '맛있어요 배송도 빨랐고 무엇보다 음식이 빨리 나와서 만족했습니다.',
#  '일단 제일 좋아하는 된장이 너무 짜서 배달 음식 중에서 제일 별로인 것도 감점 요인이고 제일 중요한 채소 신선도를 생각한다면 총점 4점을 줘도 괜찮',
#  '잘먹을게요 맛있어요 잘먹을게요',
#  '저렴한 가격에 잘 먹었습니다 둘이 먹기에 양이 좀 적다 싶은 정도였는데 막상 먹고 나니 배부르더라고요 양',
#  '양이 정말 많아서 둘이 먹다가 하나는 죽어도 못 먹을 정도예요.',
#  '개인적으로 아쉬운 점을 꼽자면 매운맛 조절이 가능했다면 더 맛있게 먹었을 것 같은데 아쉬웠어요.',
#  '맛있게 잘 먹었어요 맛있게 잘',
#  '자주 시켜 먹는 편인데 전반적으로 괜찮은 편이었으나 이번엔 실패 고기가 저번만큼 좋지 않았음 이건 고기의 문제인지 아니면 삶는 사람의 컨디션 때문인지 다음에 한번더 시켜 보는걸로 판단유예',
#  '바쁜건 알지만 항상 놓치는 게 있는 것 같아요 저번에도 그랬던 것 같은데 말이죠',
#  '다 좋은데 샐러드만 별로에요 다른 건 다 좋아요',
#  '전체적으로 빵 맛이 전반적으로 다 괜찮습니다.',
#  '서비스도 주시고 감사합니다 다음에 또 구매할게요 너무 맛있어요 서비스로 주신 것도 감사합니다',
#  '종류도 다양하고 맛있는 빵도 많지만 비싼 가격을 감수해야 하는 빵은 바나나푸딩과 시나몬 페스츄리가 있어요.',
#  '가격이 좀 나가지만 버터가 맛있고 특히 스콘도 맛있어요 크로아상도 소금빵도 모두 맛있어요',
#  '맛있어요 특히 바삭한 크렘블이랑 파삭한 브라우니는 제 입맛에 딱이었는데 여기도 역시나 질겨서 아쉬웠어요',
#  '맛도 엄청 좋고 포장도 깔끔하고 무엇보다 배달이 엄청 빨라 놀랐어요.',
#  '전부터 먹어보고 싶었던 곳이라 고민 없이 주문했는데 역시나 맛있네요 :) 다만 아쉬운 점은 샌드위치 겉면이 종이로 된 부분이 붙어 있어서 그게 좀 아쉬웠어요.',
#  '이번엔 꼭 와플만 있는 메뉴를 판매해주셨음 좋겠어요 아니면 그냥 케이크도 괜찮았을 것 같아요',
#  '여전히 맛있고 양도 많은데 가격이 좀 더 저렴해도 될 것 같아요.',
#  '메뉴는 괜찮은데 가격이 좀 더 저렴해도 될 것 같아요 보이는 부분 말고 나머지는 모두 양상추라 좀 아쉬웠어요',
#  '아쉬워도 다시 맛있는 요리로 찾아오리라 기대하며 쓴 후기입니다.',
#  '식어서 그런지 몰라도 엄청 딱딱해서 하나만 먹고 못 먹은 게 아쉬웠어요 기사님 잘못으로 인해 배송이 엄청 지연됐는데 그 때문이었어요',
#  '잘 먹었습니다 호박씨를 많이 주셔서 감사합니다 잘 먹었습니다',
#  '제가 진짜 좋아하는 샐러드인데 오늘은 고기가 너무 질겨서 못 먹고 남겼어요 그리고 오리엔탈소스 체크하고 로제소스 추가했는데 로제소스만 왔어요',
#  '언제나 맛있게 잘 먹었습니다.',
#  '자주 주문하는 데 자주 주문하는데 항상 맛있고 깔끔하네요.',
#  '양도 많고 맛도 좋아서 다음에도 또 구매할 예정이에요.',
#  '여러날 나눠서 먹고있는데 아직 싱싱해서 좋고 양이 엄청 많아요 맛도 있고요',
#  '맛있게 잘 먹었어요 맛있게',
#  '아이들도 잘 먹고 저도 밥 한 그릇 먹었는데 배가 부른지 얼마 안 돼 또 먹고 싶다고 하네요 ᄒᄒ',
#  '전반적으로 맛있게 잘 먹었지만 배추가 비싼 만큼 배춧대가 비싸 그런지 배추보다는 무가 더 많은 김치였습니다.',
#  '남김없이 남김없이 아주 잘 먹었습니다 남김없이 깨끗하게',
#  '그 면 소스가 좀 달달해서 맛있고 면 먹는 맛이 더 나요.',
#  '골고루 남김없이 먹을수 있는 넉넉한 양으로 온 가족이 함께 즐길수 있도록 구성된 세트입니다.',
#  '많은 사람들이 추천해서 한번 시켜 봤는데 써 본 사람들 말 믿고 싶지는 않아서 먹어 보지는 않았어요',
#  '양이 조금 적은 것 빼곤 대체로 맛있어요 배달만 좀 빨랐으면 좋겠어요 맛은 좀 덜 짜긴 했지만요',
#  '접시 크기도 작고 내용물도 적게 담겨 있어서 3세트 시키면 한 번에 다 먹지 못할 수도 있대요.',
#  '냉면 치고 가격이 좀 나가는 편이지만 맛은 보장할 거니까요.',
#  '다른 날 보다 유난히 고기 양이 적었던 날은 단골 추가 100g 까지 했는데 이날은 특별히 고기가 덜 느껴졌던 날이었습니다.',
#  '아주 맛있게 잘 먹었습니다.',
#  '양 많고 맛도 괜찮은데 배달 기사님이 왜 저한테 2900원을 더 부과한 건지 이해가 안 갑니다.',
#  '매운 냉면하고 같이 주문했는데 냉면에 들어있는 고기가 정말 맛있네요 특히 냉면 먹을 때 없으면 못 배길 정도로 맛있네요',
#  '고기도 잡내 안 나고 육수가 정말 맛있어요 비빔냉면도 맛있고 고기 들어간 냉면도 맛있어요',
#  '맛도 있고 양도 푸짐하고 무엇보다 다른 배달 음식보다 짜지 않아서 좋아요',
#  '그런데 다른 날보다 냉면 사리가 더 적게 들어 있어서 아쉬웠어요 그래도 맛있게 잘 먹었습니다',
#  '특별히 새송이 버섯이 다른 날보다 더 많았고 고기는 보통보다 약간 작았지만 대체로 잘 먹었습니다.',
#  '김치전이 조금 짜긴 했지만 전반적으로 맛있게 잘 먹었고 특히 김치전에 양파간장이 없어서 아쉬웠어요',
#  '맥주를 같이 시켰는데 생맥주를 여기에다 다 쓰지는 못하겠어요 조금 더 주더라도 관리를 좀 더 해주면 좋을거같아요',
#  '배달도 빠르고 음식도 맛있어 남김없이 잘 먹었습니다.',
#  '막걸리가 먹고싶어서 주문했어요 고추전을 좋아하는데 품절이라 아쉬웠어요 다음에 또 주문할땐 고추전 말고 다른 전종류도 넣어주세요',
#  '일찍 주문해서 1시간 반 이상 소요되는 배달 때문에 집 나가기 전에 다 먹고 나와야 했는데 아쉬웠어요 맛은 있었지만 배달 과정이 너무 늦어서 아쉬웠어요',
#  '맛있는 음식과 더불어 정성스러운 손편지까지 감사드립니다. 맛있게 잘 먹을게요.',
#  '배달이 너무 늦어서 모밀면이 다 식었어요 속상하고 속상하고 그래요',
#  '배달도 빠르고 물건도 이상없이 잘 왔어요',
#  '냉소바는 면이 너무 삶아져서 물이 많이 나왔고 새우튀김이랑 냉국수는 정말 맛있어 보였는데 모두 실패했습니다.',
#  '배달해 주는 시간은 예상외로 빨랐고 맛은 배달 치고 괜찮습니다.',
#  '약간 느끼하게 매운 맛을 좋아하시면 드셔도 괜찮고요 저는 개인적으로 이게 너무 먹고 싶었거든요',
#  '사진에 보이는 것처럼 새우도 한마리 없고 국물도 시원하지가 않아요 해산물파스타에 새우랑 홍합은 없는데 말이죠.',
#  '배달 예상 시간 보고 점심시간 맞춰서 주문했는데 너무 빨리 와서 놀랐어요 파스타 소스는 맛이 괜찮은데 면이랑 좀 겉도는 느낌이었어요 미트볼은',
#  '음식은 정말 맛있어요 그런데 배달 상태가 주문 누락에 배달 완료까지 돼서 오늘은 좀 많이 아쉬웠어요',
#  '양이 적지 않고 맛도 괜찮은데 무엇보다 오일과 크림의 중간 느낌? 배달 출발 1시간 전에 문자가 와서 좀 기다렸더니 도착했어요.',
#  '맛있게 잘 먹었습니다.',
#  '옛날에 종종 시켜먹었던 기억이 있는데 그때는 공기밥 안 주는데 제육만 팔아서 밥은 따로 안 시켰어요.',
#  '그리고 오늘 배달을 주문한지 1시간 30분이나 되어서 받았더니 배달이 예정시간이 지나도 안와서 가게에 전화했더니 그제서야 콜을 부르시겠다고 하셨고 그 후로 40분이나 지나서 받았어요',
#  '기름이 상당히 많지만 맛은 있어요. 아주 기름지지 않고 맛있어요.',
#  '하 정말 맛있게 잘먹었고 하 아주 잘하 먹',
#  '시간이 조금 늦게 도착했고 항정살이 너무 커서 먹기 힘들었어요 크기가 조금만 작았으면 좋았을 것 같아요',
#  '솔직히 저는 고기가 좀 질겨서 못 먹을 정도였어요 솔직히',
#  '처음에 양이 좀 적은 거 아닌가 했는데 집에 있던 쌈채소랑 같이 먹어보니 먹을만하더라고요 집에서 고기 구워 먹는 거 별로 안 좋아하는 편인데 말이죠',
#  '저번에 시켰던 게 더 맛있는 거라서 이번에도 시켜 봤는데 역시나 맛있네요.',
#  '제가 멸치 육수를 안 좋아 해서 잘 모르는데 된장찌개는 진하고 찌개는 약간 짠 느낌? 혼자 먹기 좋은 양이긴 한데 식구들이 다 먹을 정도는 아니에요',
#  '된장찌개는 삼겹살보다 항정살이 훨씬 부드러웠고 소스, 계란 야채 등 여러 가지 구성이 좋았지만 된장찌개가 약간 아쉬웠어요',
#  '고기만 먹기엔 집에 있는 다른 종류의 쌈이 먹고 싶을 정도로 양이 많았어요 집에서 싸 온 상추랑 비교했을 때 말이죠',
#  '맛은 있었지만 서비스로 준 고기랑 김치가 너무 좋아서 또 먹고 싶네요 사장님 너무 감사했는데 사모님이 주신 반찬이랑 고기만 먹었어요',
#  '조금 비싼 배달비 말고는 아주 만족스러운 데가 없었는데, 배달비가 조금 비쌌기 때문입니다.',
#  '어우 진짜 너무 셔요 정말 너무너무 셔',
#  '양이 너무 적게 느껴져서 조금 실망했어요 맛은 그냥 보통이고 양이 적어서 좀 아쉬웠어요',
#  '질겨서 못 먹을 정도로 식감이 안 좋아요',
#  '양파의 맛이 아주 좋습니다 양파는 너무 많이 먹으면 좋습니다',
#  '납당말고 일반당면으로 하면 더 맛있을 것 같은데 납당보다는 일반당면이 더 맛있는 것 같아요.',
#  '야채곱창과 직화곱창은 각각 야채곱창, 직화곱창이라고 칭합니다.',
#  '야채곱창 말고 다른 종류의 곱창을 먹어봤는데 그건 너무 질기더라고요 다음엔 야채곱창 도전해볼게요',
#  '시간이 좀 걸리는 게 흠이긴 한데 맛은 있어요 거리가 좀 있어서 그게 좀 걸린 것 빼고는.',
#  '양 많고 배달 빨리 왔어요 그런데 원래 이렇게 곱창 표면이 평평하지 않은 거 아시죠?',
#  '이 씨 부부의 경우 임신 8개월째로 배 속 아기가 근심되어 허리를 약간 굽히고 한 손으로 배를 가린 채 전동차에 올랐다.',
#  '배달이 한시간 반 정도 늦게 왔지만 맛은 보장되니 이틀 연속으로 두 그릇 먹었어요',
#  '꼬막이 좀 달긴 했지만 제 기준에선 꼬막이 제 입맛엔 좀 달았어요.',
#  '오늘따라 고기가 부드러웠어요 맛있게 잘 먹었습니다 오늘따라',
#  '사진에는 없지만 주먹밥은 정말 짜구요 날치알이 들어간 건지 뭔지 아무튼 그 외의 음식들은 그냥 그랬어요 가격에 비해 정말 별로인 듯 해요',
#  '양이 많은 느낌은 아니고 맛도 궁금했는데 생각보다 양이 많았어요.',
#  '통오징어 중에 통오징어가 있는데 쫄깃한 식감과 부드러운 맛을 느낄 수 있어요.',
#  '자극적이지 않은 제육볶음이 맛있네요 양도 많고 맛있게 잘 먹었습니다.',
#  '큰멸치로 주문했는데 국물용 멸치로도 손색이 없을 정도로 간이 딱 맞고 맛도 좋았답니다.',
#  '맛있어요 맛있어요 반찬이 모두 맛있어요',
#  '또 배달이 옆집으로 해서 다 제 입맛에 맞쳐 더 맛있게 먹었어요 특히 다 맛있어요',
#  '처음 먹어보는데 한 입 크기로 먹을 수 있는 양으로 나와서 좋고 맛도 기존 먹던 것보다 나은 것 같아요.',
#  '맛있어요 배송도 엄청 빠르고 다만 아쉬운 점은 저번에 이어 이번에도 주문했는데 오돌뼈는 처음 주문해봤어요 근데 고추장맛이 너무 강하네요',
#  '오랜만에 먹으니 맛있네요 김포불닭발 오랜만에 먹',
#  '잘먹었어요 근데 좀 짜긴 짜네요 그래도 잘 먹었어요',
#  '똥집이랑 오돌뼈 세트로 주문해서 맥주 안주로도 좋고 적당히 매운 맛의 주먹밥을 먹고 싶어서 급 주문한 것이 처음이었어요.',
#  '담엔 잘 챙겨 주세요 담엔 더 잘 해 주세요',
#  '저번에 너무 맛있게 먹어서 이번에도 맛있게 매운맛으로 주문했는데 오늘은 너무 맵다못해 입주변까지 아프네요 저번에 맛있게 먹었던 매운맛도 똑같이 주문했는데',
#  '잘 먹지는 못하지만 매운거 좋아하는 편이라 자주 시키는데 많이 안맵더라고요 담에 더 매운 맛 도전해보려고요',
#  '국물 닭발은 괜찮은데 좀 잘 안 익은 것 같은 느낌? 이집 닭발 여러 종류 시켜 봤는데 국물 맛은 제일 별로였어요',
#  '배달 빨리 해주시고 기사님 친절하셨어요 계란찜 추가했는데 맛있어요 순한맛으로 주문해서 전혀 매울 것 같았지만 심하지 않았어요',
#  '처음 시켜보는데 맛있어요 처음 시켰는데 원래도 맛있는 곳이에요',
#  '매운 맛 나는 닭발 주문했는데 아주 맛있어요.',
#  '담엔 세트말고 하나만 시켜야겠어요 닭발 좋아하는 저는 근데 하나로는 부족해요',
#  '매운맛 주문했는데 전에 먹던 것보다 덜 맵네요 닭발이랑 오돌뼈는 진짜 빨리 익는데 이것만 아직 안 남아서 못 먹고 있어요',
#  '불이 붙어서 더 맛있게 느껴지는 게 불 맛이 더 강한 것 같아요.',
#  '잘받았습니다 감사합니다 잘받았습니다 잘받았어요 감사합니다',
#  '이번엔 무뼈닭발 도전해보고 내일은 무뼈 말고 다른 걸로 먹어볼게요 항상 주문하는 곳이에요 이번에도',
#  '전체적으로 다 괜찮은데 막국수면이 너무 퍼져서 별하나 뺐어요.',
#  '닭갈비 맛있어요 다른 것도 먹어보고 싶은데 가격이 좀 나가네요 많이 파시고 수고하세요',
#  '깔끔하면서도 맛도 깔끔한 게 아주 맛있어요.',
#  '한끼식사로 충분했습니다 다만 아쉬운점은 닭이 좀 질겨서 야채를 좀 넉넉히 넣어주셨으연 좋았을거같아요',
#  '그리고 배달하시는 분이 업소명을 잘못입력해서 안나가갓다가 혹시나 하는 맘에 나갓는데 역시나 잇엇음 배달하는 분은 뭐라표현',
#  '진짜 집밥 느낌 나게 맛있게 먹었어요 다만 아쉬운 점은 떡볶이 국물이 조금 짜다는 것과 집에서 먹는 느낌이 나게 해 달라는 것이었어요',
#  '다 먹고 나서 찍은 사진이지만 맛있어요 굳 다먹고 난 뒤에 찍은거지만 맛있어요',
#  '맛있어요 배송도 빠르고 가격도 착하고 무엇보다 맛이 있어요',
#  '깔끔하고 무엇보다 담백하고 맛이 있어요 그렇게 깔끔하고 맛있어요',
#  '완조리도 가능하다고 해서 메모 남겼었는데 그냥 와서 조금 당황했지만 맛있게 잘 먹었습니다.',
#  '음식이 아주 깔끔하고 정갈하고 맛도 있어 아주 만족스러운 식사를 했습니다.',
#  '제가 실수로 잘못된 주문 내역을 입력해서 제가 잘못 보낸 것도 있고 또 주문할 때도 똑바로 기재해 주시기를 바랍니다.',
#  '전형적인 배달 음식 맛 오징어는 질기고 고기도 질겨서 별로 안 맛있어요',
#  '고기 추가 했는데도 김치가 모자랐어요 맛은 있는데 고기 양을 더 늘려도 모자를 것 같았어요',
#  '편지까지 써주시고 정성이 많이 느껴져서 감동했어요 맛은 정말 있는데 양이 좀 적은 감이 있어요 하지만 정말 맛있어요',
#  '맛은 전체적으로 다 좋은데 부추랑 간장소스를 더 넣어 주시면 더 맛있을 것 같아요 저는 또 시킬 거니까요',
#  '양은 생각보다 작았지만 맛은 있어요 애들이 보통 먹는 양보다 적게 들었긴 했지만 배달 온 거 보니까 또 먹고 싶다고 해서 조만간 또 주문할 것 같네요',
#  '또 주문할것 같습니다 너무 맛있어요 다음에 또',
#  '회는 두껍고 맛났는데 회가 약간 아쉬웠던 건 다 먹고 나서 사장님이 좀 바빴다는 점이었어요',
#  '좀 더 차갑게 해서 먹으면 더 맛있을 것 같아요.',
#  '예전부터 종종 가던 곳인데 회가 싸고 맛도 좋아서 배달료가 좀 붙긴 해도 오래 됐어요.',
#  '안에 내용물이 다 비쳐서 겉에 기름이 약간 묻어 있어요 그래서 기름을 좀 두르시고요',
#  '오징어랑 어묵무침이 충무김밥에 비해 별로인 게 오징어하고 어묵무침도 마찬가지예요.',
#  '맛있어요 돈가스는 여기서만 사요 다른 데서는 못 먹어요',
#  '밥이랑 국이랑 다 나오는 줄 알고 등심돈까스 세트 시켰는데 단독 세트네요 당황스럽게 그래서 사진을 수정했어요.',
#  '배송이 너무 느렸고 두시간 넘게 기다렸고 회무침이랑 우동은 터져가지고 밥은 못 먹고 남겼지만 그 외의 음식들은 괜찮으니까 괜찮아요.',
#  '새우초밥이 좀 이상한 냄새가 나고 맛도 좀 싱거울 정도였어요',
#  '맛도 괜찮고 양도 많은데 가격이 좀 더 합리적으로 내려가도 될 것 같아요.',
#  '포장해서 진공해서 먹고 남은 것은 포장해서 먹었는데 맛이 고소하고 부드럽습니다.',
#  '양이 생각보다 많고 식감도 부드러운 게 계란찜도 같이 주셔서 감사했습니다.',
#  '정말 맛있어 보이는 막창과 달리 닭발은 조금 아쉬웠어요 그리고 양이 너무 적은 닭꼬치.',
#  '치킨 피자 정말 맛있어요 도우도 바삭하고 특히 우리나라에서 나는 닭고기는 껍질이 잘 벗겨지던데 얘는 껍질도 잘 안 까져서 아이가 잘 먹어요.',
#  '맛도 있구 배달도 빠르고 무엇보다 가격이 싸니까 자주 애용하게 되는 것 같아요.',
#  '조금 맵싸한 맛이 나고 간은 좀 세게 돼요',
#  '피자는 느끼하지 않고 담백하고 진짜 맛있어요 근데 갈릭소스 추가했는데 하얀 요거트소스가 두 개 왔어요 그건 갈릭소스',
#  '피자가 이렇게 눌려서 왔어요.',
#  '잘먹었고요 맛있게 잘 먹었습니다.',
#  '딸기 수박 서비스로 나온 눈꽃 빙수가 양도 많고 맛도 최고였어요 사장님 많이 파시고 번창하세요',
#  '맛있는육회비빔밥과배달음식은배달음식으로잘나오는게맛있고배달도잘배달되고우유배달도좋고낙지비빔밥도배달음식으로맛있는게잘나오는게배달음식으로는맛있는게배달되고감자배달도맛있는게맛있고육회비빔밥',
#  '간제미 무침(간장제미)은 조금 맛이 덜했다 느낌이 좀 덜했다',
#  '음식은 정말 맛있고 좋은데 배달 실수로 주류를 시켰는데 그것도 안 오고 해서 그냥 제가 별도로 연락을 드린 것뿐이었습니다.',
#  '응 그래 쏘쏘한 거는 그냥 쏘',
#  '우족탕은 처음 먹어보는데 설렁탕 같은 맛이 나고 육회비빔밥이랑 우족탕도 맛있다고 하던데 저는 아직 먹어 보지는 못했어요.',
#  '육회비빔밥 진짜 맛있어요 특히 아주 맛있는 육회비빔밥 완성했어요',
#  '맛있게 잘 먹었어요 다음에 또 시켜먹을게요 감사합니다',
#  '처음 주문해본 곳인데 배달도 빠르고 무엇보다 양이 너무 많아서 놀랐어요 앞으로 자주 주문할 것 같네요.',
#  '잘먹었고 잘받았습니다 감사합니다 잘먹었습니다 감사합니다',
#  '신랑은 여기 순대국을 제일 좋아했고 저는 그냥 평범해서 자주 먹는 편이에요.',
#  '담부턴 한번 더 확인해서 보내주세요 근데 공기밥이 안왔어요 덕분에 맛있게 잘 먹고 있는데 다음부턴 그러지 말아요',
#  '매운거 좋아하는 사람으로 다대기 줄때 청양고추썰은 것 좀 주시면 아주 좋을것 같네요 배달음식치고는 먹을만 해요 냉장고 냄새가 조금 나기는 하지만',
#  '잘받았습니다 감사합니다 잘먹었습니다 감사합니다',
#  '잘먹었고 배달 과정에서 약간 문제가 있어 다시 보내주신 것도 잘 받았습니다.',
#  '양도 푸짐하고 맛도 있어 아주 맛있게 잘 먹었습니다.',
#  '양도 많고 맛도 있는데 양도 푸짐하고 정말 맛있어요',
#  '나쁘지는 않지만 또 시켜먹기엔 제 입맛에 맞지 않았어요.',
#  '맛이나 양이나 언제나처럼 괜찮은데 배달 오신분이 얼마나 흔들린건지 도착한 콜라 뜯자마자 다 튀어서 부엌은 엉망에 옷도 다 젖',
#  '굿굿굿굿굿굿굿굿굿굿굿굿좋아굿굿굿굿굿굿굿굿좋아좋아굿굿굿굿굿굿굿굿좋아굿굿굿굿굿굿굿좋아굿굿굿굿굿굿굿굿굿굿굿굿좋아좋아좋아굿굿굿배리굿굿굿좋아굿굿굿굿굿좋아굿굿굿굿배리굿굿굿굿굿너무좋아좋아좋아요굿굿굿굿굿배리굿좋아굿굿좋아좋아굿굿좋아굿굿배리굿굿굿굿굿배리굿굿좋아좋아좋아좋아굿굿굿굿배리배리굿굿굿굿너무좋아굿굿굿좋아배리굿굿굿굿굿굿배리굿굿굿굿굿배리굿굿굿굿좋아굿좋아굿굿배리배리굿굿굿굿좋아굿굿굿좋아좋아굿좋아좋아굿굿굿굿',
#  '파닭 소스가 1/5 이상 쏟아진 건 5연속 트리플악셀 15바퀴를 주행한 탓인지 몰라도 맛있게 먹었습니다.',
#  '저는 개인적으로 이게 더 마음에 들었습니다.',
#  '양이 많지 않고 맛도 별로 없는 편인 순대는 너무 달아서 못 먹을 정도였어요',
#  '목살이 약간 딱딱해서 고기 잡내가 좀 나고 고기에서 나는 냄새가 약간 비려요',
#  '맛있는야식타임으로 주문한 메뉴 잘 도착했고 제육볶음맛을 좀 더 맛있게 해주셨음 더 좋았을 것이라는 아쉬움이 있어요.',
#  '밑반찬은 사진이랑 차이가 좀 있지만 그 외에는 다 괜찮았다고 생각해요.',
#  '맛있게 잘먹었고 아주 만족스러운 요리였습니다.',
#  '그 외의 사람들은 이름만 들어보면 알 수 없는 맛 때문에 안 좋아하는 사람들도 여럿 있었고 특히 내가 좋아하는 스타일의 음식은 없었다.',
#  '여행 갔다 온 뒤 집에서 삼겹살 편하게 먹는 게 2, 5인분 정도 되는 것 같아요.',
#  '양이 아주 많아 두부가 정말 많아오.',
#  '맛있게 잘 먹었습니다 감사합니다',
#  '맛은 있었지만 배달 온 지 이틀 뒤에 두 번이나 전화를 한 배달 기사 때문에 별 하나 뺐어요 다시는 이런 기사 쓰지 말아 주세요',
#  '식어서 온 피자는 무슨 맛인지 모르겠지만 피자가 너무 짜서 무슨 피자인지 모르겠어요',
#  '불고기 맛 좋고 간편히 한 끼 식사 하기 좋아요 파채도 좀 많이 넣고 불고기도 좀 넣어 주세요',
#  '맛은 정말 좋은데 호박죽에 팥 빼달라고 요청했더니 그냥 해주시고 게다가 추가요금 내고 주문한 동치미는 배달되지도 않았어요',
#  '맛은 있었지만 자세히 써 달라는 댓글은 안 써 있어서 아쉬웠어요 후기이벤트도 안 해서 아쉬웠어요',
#  '근데 7찬 반찬에 명태 회 무침이 있다해서 시켰는데 맛있으시다면서 다 드셨다네요 감사합니다.',
#  '맛있게 잘 먹었습니다.',
#  '몸이 너무 아파서 밥 먹을 기운이 없는데 좋은 한끼 입니다 먹느라 사진은 없네요 몸이',
#  '저는 알레르기성 접촉 피부염을 앓는 편이라 안 먹어 본 지가 엄청 오래됐네요',
#  '양도 많고 맛도 있어서 몸에 좋은 음식이라고 해서 시켜봤는데 생각보다 훨씬 괜찮네요.',
#  '달걀찜 주신거 잘 먹을게요 내일 또 맛있는 요리로 만나뵐게요',
#  '조금 매웠지만 맛은 있었고 조금 조금 더 매웠음 좋았을 것 같은 게 조금 아쉬웠어요 그래도 맛있어요',
#  '평소 35점을 받던 김밥의 맛이 싱거울 때가 있는데 이 날은 김밥이 약간 덜 짜긴 했어도 재료의 신선함보단 맛의 신선도에 승부를 걸었다.',
#  '김밥도 두꺼운 편이고 어묵도 쫄깃한 것이 신선하게 바로 부쳐낸 것처럼 아주 잘 먹었어요.',
#  '김밥은 양이 푸짐하고 좋은데 김밥 겉부분이 약간 질겨서 아쉬웠어요 김밥은 맛있게 먹었고 대체로 다 괜찮아요',
#  '다좋았는데 매우 느린 배달 속도 그리고 배달이 되게 느리게 된 것 같아요.',
#  '뭔가 이상해서 사진은 찍지 못했지만 메뉴를 자세히 보니까 마라탕을 마라샹궈로 해서 오고 마라샹구를 마라탕으로 해서 왔어요.',
#  '제입맛에는 맞지 않았던 것 같아요 제입맛에는',
#  '오리지널 중국 마라토너랑 가장 흡사한 맛을 내기 위해 요청한 소스가 좀 더 진했으면 더 맛있을 것 같아요.',
#  '너무맛있게 잘먹었고 덕분에 아주 맛있게 잘먹었습니다',
#  '전부 좋았는데 유부가 안 보여서 아쉬웠어요 다 좋았는데',
#  '양이 엄청 많아서 좋고 맛도 있어요 저는 특히 꿔바로우가 너무 먹고 싶었는데 품절이라 못 먹었어요 흑흑',
#  '서비스도 주시고 포장도 식지않게 잘 해주셨는데 감사합니다 또 사러 올게요 수고하세요',
#  '다들 좋다고 난리인데 저는 안 좋은 거 썼거든요? 근데 왜 안 주었나 했더니 이번 달에 하는 글 이벤트에 참여할 수 없어서요.',
#  '기본 찬이 최소 단무지 정도는 나와야 되지 않나요 맛은 있는데 구성이 너무 대충 만든 느낌이라 맛이 없다고 할 수 있네요',
#  '우삽겹과 우삽겹을 추가해서 그런지 누린내가 확 나기 시작했지만 그 외에는 괜찮습니다.',
#  '추가로 주문한 계란찜은 부드러웠는데 얇은김2개와 밥2개로 밥은 좀 질겼고 김치찌개는 좀 짰어요',
#  '찜이라 좀만 더 끓였음 좋겠으나 배달도 빠르고 양도 맘에 들어요',
#  '맛있게 잘 먹었습니다.',
#  '삼겹살은 아삭아삭 씹히는 맛이 좋고 푸짐한 한상차림으로 다시 찾을 의향이 있지만 김치찜은 질겨서 다시 못 먹을 것 같아요.',
#  '새로운 브랜드 치킨이 치킨 업계의 최강자로 떠오른 가운데 출시된 것은 짱닭치킨입니다.',
#  '맛은 있어요 한마리 먹으면 보통 한마리를 다 먹어서 금방 없어지는데 이건 양이 적은 것 같아요 맛은 있는데 한',
#  '이전에 비해 양념이 너무 적게 들어있어 이전보다 맛이 훨씬 덜 짜진 느낌이었습니다.',
#  '문앞에 갖다 놓고 문자 달라고 했는데 안 와서 별 하나 뺐고, 면이 다 불게 돼서 별 2개 뺀 건 연락이 안 돼서였다.',
#  '추천합니다 친구랑 같이 먹어서 더 맛있게 먹었어요',
#  '한끼 식사 간단하게 맛있게 잘 먹었어요 간단하게',
#  '조금 짰지만 맛있게 먹었고 배달도 엄청 늦게 왔어요 조금 짰어도 맛있게 먹었어요',
#  '팰트버거랑 감자튀김이 더욱더 맛있어졌던 이유는 더 맛있게 된 감자튀김 때문이에요.',
#  '맛은 있는데 다른 수제버거 집에 비해 특별한 맛은 없는데 가격이 너무 비싸요.',
#  '설명에 있는 것보단 덜 바삭한 식감의 치킨과 소고기 육즙이 느껴지네요.',
#  '맛있어요 역시 버팔로 윙보다 맛있네요',
#  '조금 늦게 온 데다 식어서 와서 별 하나 뺀 건 배달이 좀 늦게 돼서였는데, 맛은 괜찮습니다.',
#  '치킨은 돈이 너무 많이 들고 버거는 맛있고 치킨은 진짜 별로예요.',
#  '음식이 조금 식어서 온 것 빼고는 배송 시간은 빨랐어요.',
#  '맛있는 건 바이젠이라는 과자인데 달달해서 맛있어요.',
#  '잘먹었고 다만 좀 덜 먹음직스러워 보이는 사진과 비주얼은 차이가 있을 수 있지만 맛있게 잘 먹었습니다.',
#  '소개받고 나서 주문해봤는데 추천할 만한 게 있네요. 굿 초이스입니다.',
#  '맛있게 잘 먹었습니다.',
#  '개인적으로 콘 들어간 피자 파스타를 안좋아하는데 이번에 세트로 시킨건 고구마무스 피자에 들어간 토핑이 너무 달아서 피자 본연의 맛이 하나도 안 느껴지네요.',
#  '잘 먹었습니다 그런데 페페로니가 좀 적게 들어가서 아쉬웠어요 잘 먹었습니다',
#  '맛은 이미 네 번째 주문한거라 말할 필요도 없고여 다만 좀 아쉬웠던 건 치즈가 좀 굳어서 온 것 빼곤 맛있게 잘 먹었다는 것입니다.',
#  '조각을 조금 나눠 주셔도 맛있어요 큰 조각으로 계속 먹을 수 있으니까요.',
#  '피자는 보통 다 맛있고 특히 요 감바스랑 피자가 너무 괜찮아서 배달만 시키면 되는데 혹시 배달 가능한 가격에 맞춰서 피자만 시켜도 되나요',
#  '오늘은 전체적으로 탄 느낌을 받았습니다 그래서 좀 딱딱해서 아쉬웠어요 그래서 페페로니가 조금 아쉬웠어요',
#  '조금 식어서 온 피자는 피자가 조금 식은 것이었는데 그래도 맛있게 잘 먹었습니다.',
#  '좋아요 좋아요 굳이에요 좋아요',
#  '맛은 있는데 좀 짜요 근데 저는 단 걸 별로 안 좋아하기 때문에 조금 짜도 맛있게 먹을 수 있어요',
#  '양은 좀 적을 수 있으니 두판 세트를 시키는 걸 추천드려요.',
#  '제가 이전에 몇 번 가서 먹어 봤던 곳이긴 한데 여기도 지점이 하나 있어서 거긴 줄 서서 먹었어요.',
#  '안매운맛으로 주문했는데 아이가 잘 먹지 않아서 아쉬웠어요.',
#  '잘 먹었습니다 감사합니다 잘 먹었습니다',
#  '매장에서 먹으면 맛이 없을 수도 있는데 저는 맛있게 먹었습니다.',
#  '식어서 온 음식물이 찬 공기와 함께 있네요.',
#  '양이 정말 많았어요 고기도 엄청 부드러웠고 그런데 두꺼운 고기 때문인지 속 일부가 덜 익었어요 고기는 정말 부드러웠어요',
#  '좀 더 따뜻했으면 좋겠어요 대창덮밥이랑 카츠산도가 더 맛있을 것 같아요 맛있게 먹었습니다',
#  '카레 맛집으로 유명한 곳 중 하나인 여기에서 제일 맛있는 메뉴는 가라아게 정식인데 저번에 내가 먹었던 건 토했기 때문에 오늘은 못 먹었지만 맛은 보장',
#  '잘 먹었어요 맛있게 잘 먹었습니다 많이 파세요',
#  '너무 빠른 시간 안에 따뜻한 음식이 빠르게 배달되어 맛있게 잘 먹었습니다.',
#  '맛은있는데 75분걸린다고해서 밖에서 다른볼일보고 배달완료뜨면 들어갈려고 했는데 한참안떠서 집에가니 문앞에 닭이 식어있었어요 그래도 맛은있어요',
#  '전기구이 통닭 맛있게 잘 먹었다고 엄지척 해 줄게요.',
#  '근데 혹시 들깨삼계탕에 소금 안 뿌셔도 되는데요 소금이 들어가면 약간 짠 맛이 날 수도 있거든요',
#  '굿굿굿굿굿굿굿굿굿굿굿굿좋아굿굿굿굿굿굿굿굿좋아좋아굿굿굿굿굿굿굿굿좋아굿굿굿굿굿굿굿좋아굿굿굿굿굿굿굿굿굿굿굿굿좋아좋아좋아굿굿굿배리굿굿굿좋아굿굿굿굿굿좋아굿굿굿굿배리굿굿굿굿굿너무좋아좋아좋아요굿굿굿굿굿배리굿좋아굿굿좋아좋아굿굿좋아굿굿배리굿굿굿굿굿배리굿굿좋아좋아좋아좋아굿굿굿굿배리배리굿굿굿굿너무좋아굿굿굿좋아배리굿굿굿굿굿굿배리굿굿굿굿굿배리굿굿굿굿좋아굿좋아굿굿배리배리굿굿굿굿좋아굿굿굿좋아좋아굿좋아좋아굿굿굿굿',
#  '잘먹었습니다잘먹었어요잘먹었습니다잘먹었습니다잘받았습니다잘먹었습니다잘감사감사잘먹었어요많이잘먹었습니다맛있네요잘먹었습니다감사잘먹었습니다잘먹기잘먹었어요아주잘먹었습니다맛있어맛있네요잘먹었어요맛있어잘먹었어요맛있게잘먹었습니다맛있네잘먹었어요맛있네잘먹었습니다잘구매했어요잘먹었습니다맛있네맛있네요잘먹기잘먹었습니다감사감사많이잘먹었어요너무잘먹었어요감사잘감사많이맛있네맛있네요맛있어잘먹었습니다잘먹을수구매했어요맛있어맛있네요감사잘먹었습니다많이감사감사감사합니다잘먹었습니다아주잘먹었습니다감사많이잘먹었습니다맛있어요잘먹었습니다많이잘먹었습니다감사맛있네요잘',
#  '그냥 보통이에요 그냥 평범해요',
#  '순대는 냄새가 좀 나고 김밥도 맛있고 떡볶이도 맛있어요',
#  '김밥은 김밥맛이 났고 만두는 김밥이 별로 안 나왔어요 배달 온 지 33분 만에 다른 집에서 밥을 먹었는데 밥 냄새가 엄청 났어요',
#  '잘받아서 잘 사용해서 먹었습니다.',
#  '해물찜 같은 거 생각하고 시켰는데 해물찜처럼 국물이 진하고 맛있어요 사장님 사진 수정하시면 될 것 같아요',
#  '손님 왔을 때 쓰려고 했는데 제가 보기엔 그냥 그럴 건데 이렇게 와사비에 고춧가루처럼 파란 부분이 있는 건 왜죠?',
#  '또 좋은 가게 생겨서 회 떠먹고 싶을 때 시켜먹을게요 대방어 소개글 보고 시켰는데 대방어가 예전만큼 맛있지는 않았어요',
#  '맛은 보통이고 두께는 3.5밀리미터 정도로 두께가 얇은 편입니다.',
#  '회로 아주 맛있게 먹고 회도 아주 많이 먹었어요 석화회 정말 신선하고 맛있어요',
#  '맛도 괜찮고 무엇보다 생각보다 배달이 빨랐어요 생각보다',
#  '집에서 멀지 않은 데 있어서 자주 갔었는데 회무침이나 전 이런 거 할 일이 종종 생기곤 했어요.',
#  '큰 기대를 하지 않은 탓인지 몰라도 회 두께와 양에서 처음 주문한 두 곳 모두 실망을 안겨 주고 말았다.',
#  '회로 환장하는 사람이라 회로 환장하는데 이번에는 좀 다를까 싶을 정도로 맛이 좀 약했지만 1인 가구가 먹기엔 너무 많은 양이라 그냥 회로 대신했습니다.',
#  '배달은 엄청나게 빨리 왔어요 가서 먹으면 좀 다를 수도 있을 것 같은데 회나 밥은 대체로 다 괜찮았을 것 같아요',
#  '여러가지 부위 골고루 담아주셨는데 아무래도 양이 좀 적은 것 같아요 약속한 시간에 정확히 도착했네요',
#  '맛있게 잘 먹었습니다.',
#  '맛있게 잘 먹었습니다 맛있게',
#  '가격이 조금 비싸긴 하지만 맛은 있어요 근데 좀 비싼 감이 없지 않아 있어요',
#  '배달의 민족 앱을 보고 너무 먹고 싶어서 시켰지만 막상 먹어보니 기대 이하의 맛이었습니다 매장에서 먹어 볼 걸 그랬어요',
#  '먹기에는 좀 불편했지만 맛은 평범했던 핫도그 배달비 4500원 별도 공지가 없어서 기분은 나빴지만 핫도그는 잘 먹었어요',
#  '콜라 제로 시켰는데 그냥 오리지날이 왔어요 감자튀김이랑 핫도그는 맛있을 것 같은데 옵션 확인을 제대로 안 한 것 같아요',
#  '얼얼한 맛을 좋아하시면 3단계 하셔도 괜찮으실 것 같은데 저는 고기 없이 이것만 그냥 먹었어요',
#  '유부 알러지가 있는데 유부 들어간 음식은 거부했어요 기본적으로 알고 있는 것들만 적어주세요',
#  '치킨너겟이랑 꿔바로우가 치킨너겟 속에 들어있는 것 같았어요.',
#  '겨울엔 방어 냠냠 겨울엔 제철 방어 냠냠냠 겨울엔',
#  '다른점은 만점을 주고 싶은 부분이 있는데 그 중 하나가 광어도 괜찮고 방어는 약간 기름진 맛이 조금 부족했어요 그',
#  '회는 아주 신선하고 맛있는데 회가 좀 적게 나왔어요.',
#  '회무침도 맛있고 회 뜬 것도 괜찮았지만 매운탕에 있던 매운탕 맛도 시원찮았습니다.',
#  '맛있게 잘 먹었습니다.',
#  '서비스로 나온 알탕은 괜찮았지만 회는 좀 부실했고 알은 그냥 그랬어요',
#  '연어 회 방어 방어 등 여러 종류의 회를 맛볼 수 있었고 특히 연어 회와 연어 방어는 정말 맛있었답니다.',
#  '다만 생선 초밥의 종류나 개수가 좀 더 많았으면 하는 건 아쉬움이 좀 있는데 가격 대비 만족합니다',
#  '정말 맛있게 먹었던 게 타코야키랑 우동이었어요.',
#  '맛있게잘먹었습니다 잘먹었습니다 맛있게잘먹었습니다',
#  '종류도 다양하고 맛도 괜찮은데 배달비가 너무너무 비싼 초밥집이 집 근처에 있어서 그것만 먹기로 했어요.',
#  '마트에서 파는 초밥보다 가격은 좀 더 나가지만 구성은 훨씬 좋고 생선회 초밥도 가끔 나와요',
#  '전체적으로 맛이 좀 짜요 국물도 좀 진하고 국물 전체적으로',
#  '종류를 많이 늘려서 맛있는 음식 많이 먹게 해 주면 좋겠어요.',
#  '알러지 때문에 소라 초밥은 타마고로 변경해주시고 배달 늦어질 때 미리 전화 주셔서 감사했습니다.',
#  '아이가 고기 초밥을 너무 잘 먹어서 두 개는 시켜 줘야 할 것 같아요 가격도 착하고 아이가 좋아하는 맛이라 더 사 놔야 겠어요',
#  '연어 추천 새우 추천 참치는 잘 모르겠습니다만 가격이 싸고 품질이 좋은 것으로 보입니다.',
#  '가격대비 괜찮아요 배달도 빨랐고 가격도 싸고 근데 두번은 안시킬 것 같아요',
#  '자주 시켜먹는데 오늘은 배달도 늦었고 안에 든 기름도 적게 나왔는데 왜 이렇게 늦게 나왔는지 모르겠네요.',
#  '우선 맛은 보장되니 별 5개를 줬지만 포장을 뜯는 순간 기분이 나쁠 수 밖에 없었습니다.',
#  '항상 맛있게 먹고 있는데 이전처럼 계란양이 줄어서 김밥 두께가 많이 줄어든것 같아요 예전처럼 달걀양을 많이 넣어주시길 부탁드립니다',
#  '맛있어요 근데 한끼에 두줄이상 먹으면 질려서 밥은 한공기만 먹고 나가요',
#  '배달이 빨라요 맛있게 잘 먹었습니다.',
#  '다이어트 하는 데 도움이 되는 게 먹기 편하고 다이어트 할 때 먹으면 좋아요.',
#  '맛있게 잘 먹었습니다 많이 파시고 수고하세요',
#  '맛있게 잘 먹었고 아주 잘 먹었습니다.',
#  '예상보다 더 오래 걸렷지만 맛은 있었어요 생각보다 시간이 더 걸렸지만요',
#  '항상 따뜻한 배달로 항상 보내 주셔서 너무 감사합니다.',
#  '양도 많고 맛도 좋고 가격도 싸고 아주 잘 먹었습니다.',
#  '생각지도 못한 음료수 서비스 감사합니다 맛은 예상하지 못한 맛이지만 고기가 얇긴 하지만 부드럽네요 서비스로 주신 과자도 맛있어요',
#  '국이좀식어서 맛이좀 덜하긴했지만 국이 좀 식어서 아쉬웠어요 맛은 있었지만 국이',
#  '원래 먹던 곳에서 한 사람당 4개 주던 반찬이 여기서는 1인 1반찬으로 바뀌니 얼마나 편한지 다른 사람들도 저 글을 본다면 기분이 좋을 것 같다.',
#  '잘 먹었고 배달도 무척 빨랐어요 맛있게 잘 먹었습니다.',
#  '비싼 냉동피자 말고 좀 덜 비싼 그런 피자를 판매하는 곳이 여기밖에 없는데 오늘 실망시키지 않을 거라고 장담합니다.',
#  '맛은 있는데 아직 안 와서 글을 썼는데 안 왔어요?',
#  '햄 중에 동그랗게 생긴 건 고기냄새가 너무 많이 나서 다 빼고 먹었어요 그 햄만 빼고는 다 맛있어요',
#  '매달 시켜먹는 양과 맛 모두 만족스러워서 두 달마다 시키는 것 말고는 딱히 다른 이유가 없는 것 같아요.',
#  '배추김치가 맛이 괜찮은데 이것이 쟁반국수양념과 같은 양념을 사용한 것처럼 배추김치맛이 난다.',
#  '카페인이 너무 많이 들어 있어서 미숫가루 같은 고소한 맛은 전혀 없고 핫도그처럼 단맛이 강한 건 없어요',
#  '잘 먹었습니다 다음에 또 주문할게요 감사합니다 잘 먹었습니다',
#  '사이다의 행방은 실종되었습니다.',
#  '어묵은 별로 맛이 없지만 떡볶이 맛은 평범하고 치킨도 특이소스가 안 발라져서 일반 양념맛 나는 양념만 있음',
#  '좀 짜다는 느낌이 있어서 제 입맛엔 좀 안 맞는 것 같아요.',
#  '답변해주신것에 감사드립니다. 질문에 다시 한번 더 답해주시면 감사하겠습니다.',
#  '튀김은 바삭하고 떡은 부드럽지만 좀 딱딱해요 떡볶이 양념이 좀 약하네요',
#  '조금 탄맛이 나는 것 같았지만 맛있게 먹었습니다. 조금 탄 맛이 난 것 빼고는.',
#  '말이필요없습니다 그냥 말이필요없어요 그냥 말입니다.',
#  '양도 푸짐하고 맛도 괜찮을 것 같네요',
#  '진짜 맛있어요 특히 간장 양념이 너무 달지 않고 새콤해서 더 맛있게 느껴져요',
#  '치킨마요는 마요네즈가 너무 많이 들어 느끼했고 김치볶음밥은 약간 심심했는데 돈가스는 정말 맛있어요.',
#  '양은 적지는 않고 길지는 않아요 약간 매콤한 맛이 나는데 저는 매운걸 잘 못먹어서 집에 있는 고추가루를 넣어 먹었어요',
#  '배달의 민족은 새해 복 많이 받으시려면 설날 전에는 안 드시는 게 좋아요.',
#  '문 앞에서 한숨 푹 쉬고 문자를 반말로 보내고 나서 배달원 분이 나이가 얼마나 많은데 할아버지 할머니 하면서 계속 문자 오는 거예요.',
#  '맛도 괜찮고 양도많고 배송도 빨라 좋았는데 오늘은 간짜장면 품질이 일반 짜장면 수준이네요 드시는 분이 보통 짜장면 맛이 아니라고 하네요',
#  '다른곳보다 가격이 저렴한 편인 이유는 가쓰오부시 양이 줄어든 것 외에는 별다른 차이가 없는 것처럼 보이지만 가격은 28알에 2천원 올랐기 때문입니다.',
#  '크림치즈 크러스트 피자가 먹고싶어서 시켰는데 크림치즈가 아닌 볼이 온 거 빼고는 다 좋아요.',
#  '하지만 포장을 개봉하기 전 내용물이 너무 많아 밥은 못 먹고 김 용기 포장은 세척해서 재사용하고 포장 및 배달은 신경 써 주세요.',
#  '회뜬 광어도 맛있게 잘 먹었습니다.',
#  '회덮밥 추천해요 회덮밥 맛있게 먹었어요',
#  '저녁이라 그런가 봐 좀 덜 미끌미끌한 회를 맛볼 수 있었만 저녁이라 그런지 몰라도 꽤 많은 수의 횟집에서 매운탕을 남겼다.',
#  '이 씨 부부의 경우 임신 8개월째로 배 속 아기가 근심되어 허리를 약간 굽히고 한 손으로 배를 가린 채 전동차에 올랐다.',
#  '매운탕은 잘먹었고 회는 별로 안싱싱해서 매운탕은 못먹었어요',
#  '맛있게 잘 먹었습니다 감사합니다 맛있는 음식 많이 만들어 주세요',
#  '아주 맛있게 잘 먹었고 음식도 아주 정갈하네요.',
#  '또 시킬 의향이 있어요 근데 배달이 조금 늦게 왔지만 맛은 있었어요 다음에 또 시킬게요',
#  '양념 갈비찜은 뼈를 잘 발라 먹지 않으면 잘 안 빠져요 그래서 2명이서 먹기엔 양이 좀 적은 듯하고요',
#  '맛 있게 맛있게 잘 먹었습니다.',
#  '잘 먹었고요, 다만 빵이 직접 만드는 게 아니라 아쉬웠어요.',
#  '메뉴를 선택할 때 Hot이랑 Ice 중 하나를 선택해야 하는데 기본 메뉴가 hot 으로 되어 있는 걸 모르고 먹었다가 화를 면키겠어요.',
#  '아이스 커피가 먹고 싶었는데 마침 배송도 빠르고 아이스 커피도 잘 먹었습니다.',
#  '여름엔 아무래도 좀 바삭한 맛이 있어야 하는 것 같아요 카페에서 파는 와플이 그렇게 당기긴 하던데요',
#  '붕어빵은 냉동이 아닌 생것으로 먹는걸 선호해서 자주 사 먹는데 오늘은 유난히 부친 붕어빵이 덜 구워져서 아쉬웠어요.',
#  '딸기잼이 들어간 양이 너무 많은 것 같지만 맛은 있었어요.',
#  '저는 항상 푸짐한 음식을 선호하는 저는 배달의 민족으로서 늘 밥상에 대한 정보를 적고 있죠.',
#  '메인이랑 사이드 아주 많이 나오는 게 메인이랑 서브네요 아주 잘먹었어요',
#  '우리나라에서 나는 어묵처럼 생긴 것을 어묵이라고 생각하면 거부감이 들 수도 있을 것 같아요.',
#  '맛은 정말 괜찮은데 기본으로 주는 쌀국수가 양이 너무 적어요 곱배기에 계란 추가한건데도 그렇게 배부르진 않았어요',
#  '고기도 부드럽고 맛도 있어요 정말 맛있어요',
#  '맛있게 잘 먹었습니다.',
#  '시원한 국물이 더 많았으면 국물 맛은 더 시원했을 것 같아요 시원한 국을 시원하게 먹었으니 말이죠.',
#  '맛있어요 포장도 꼼꼼하고 무엇보다 반찬이 짜지 않고 맛있어요 구성이 여러 가지라 더 만족스러워요',
#  '양이 진짜 많아요 진짜 많이 많이 덕분에 맛있게 먹었어요',
#  '항상 잘 들어주시고 잘 챙겨주셨는데 오늘은 못 드려서 아쉬웠어요 그래도 맛있게 잘 먹었습니다.']

# %% [markdown]
# - reply

# %%
# reply_best_params = {'num_beams': 5, 'num_return_sequences': 5, 'no_repeat_ngram_size': 4, 'top_k': 64, 'top_p': 0.8312037280884873}

# over_reply = []
# for prompt in tqdm(train_star['reply']):
#     generated_text = pipe(prompt, max_length=128, **reply_best_params, early_stopping=True)
#     generated_text = generated_text[0]['generated_text']
#     over_reply.append(generated_text)

# over_reply
# Out:
#   0%|          | 0/726 [00:00<?, ?it/s]
# ['저희가 미처 생각하지 못한 부분이 있기 때문에 다시 한번 감사의 마음을 전하고 싶습니다.',
#  '저희 1988응답하라추억의옛날도시락은 언제나 약속 드린 정량을 지키기 위해 노력하고 있습니다 전달 시 준비 과정을 다시 살펴 보고 혹시 부족한 점은 없는지 검토해 보겠습니다.',
#  '한파로 길이 꽁꽁 얼어 고객님들이 불편을 드려 죄송했는데 주문해 주셔서 감사합니다.',
#  '이런 댓글은 본인 가족이나 지인에게 하는데 본인이 아니더라도 주변 사람이 해야 할 말이라고 생각합니다.',
#  '잠실점에서 기분이 상하셨었는데 저희가 다시 실수를 한 것 같은데 다시 한번 연락드리겠습니다.',
#  '본인이 직접 말하지 않는 이상 누가 시켜서 하는 일은 없을 겁니다 본인이 알고 있는 사실에 대해 솔직히 말씀해 주세요',
#  '항상 고객님들이 기분 좋게 식사하실 수 있도록 노력하고 있는데 아쉬운 부분이 많았던 것 같습니다 다음에는 더 좋은 요리로 찾아 뵙겠습니다.',
#  '고객님 죄송합니다 음식 받아보시고 매장으로 바로 연락주시면 좋을 것 같은데 그러지 못해 대단히 죄송합니다 다음 주문때는 꼭 그렇게 해드릴게요',
#  '저희 매장을 찾아와 주신 분들께 감사의 말씀을 전하며 더 좋은 서비스와 좋은 제품으로 보답하겠습니다.',
#  '제가 직접 하지는 않고 저희가 주문 후 받는 그런 시스템이거든요 혹 다음에 이런 일이 발생하면 본사나 협력사에 얘기해서 해결하겠습니다.',
#  '구정 연휴에 날씨도 너무 추웠지만 배달이 좀 많이 밀려 있었습니다 죄송합니다 그럼 빠른 배달 해 드리도록 하겠습니다.',
#  '배달의 민족 송파점은 고객님의 성원에 항상 감사의 마음을 전하며 최선을 다해 서비스를 해 드릴 것을 약속하겠습니다.',
#  '죄송합니다 고객님 덕분에 맛있는 요리 만들어 드릴 수 있었는데 다음 날 바로 매장에서 재교육 하겠습니다 감사합니다',
#  '고객님 죄송합니다 오늘은 저희가 좋은 요리로 보답할 수 있도록 요리 더욱 열심히 하겠습니다요.',
#  '오늘 직원들과의 미팅에서 고객님이 하신 말씀에 대해 현장 교육을 충분히 진행했고 고객님께 다시 한 번 감사의 뜻을 전하고 싶어서 이렇게 댓글을 작성했습니다.',
#  '저희 매장을 방문해 주신 고객님들께 항상 감사드립니다. 부족한 점이 있더라도 최선을 다해 노력하겠습니다.',
#  '추운 날씨에 배송 시간이 지연되어 맛이 없을 수 있다는 고객님의 말씀에 깊은 공감을 느끼며 다시 한번 고객님께 감사의 마음을 전합니다.',
#  '항상 행복하고 기쁜 마음으로 고객님의 소중한 의견을 감사드립니다 앞으로도 더욱 좋은 요리와 유익한 정보로 찾아 뵐게요.',
#  '고객님께 드리는 사죄의 의미로 다시 한번 죄송합니다만 제가 매장을 처음 방문했을 때 직원이 다른 고객님이 주문한 물건을 받는 과정에서 떨어뜨린 스티커를 미처 발견하지 못한 것 같습니다.',
#  '저희 매장을 방문해 주신 고객님께 감사의 뜻을 전하고 더 좋은 서비스를 위해서 더 많은 노력을 경주하겠습니다.',
#  '이용해 주셔서 감사합니다 말씀 못 드려서 죄송합니다 저희 매장을 방문해 주신 고객님께 다시 한 번 사과 드립니다.',
#  '항상 고객님들께 감사의 마음을 전하며 맛있는 음식을 만들어 드리는 갈비민족이 되기를 기원합니다.',
#  '고객님 믿고 주문해주셨는데 불편을 드려서 죄송합니다 항상 기본적으로 신경쓰고 있는 부분인데 이런 일이 생겨 정말 죄송합니다 다음 주문시에 말씀해주시면 더 신경써서 보내드리겠습니다',
#  '우선 오래된 재료를 쓰지 않고 또 매일 바로바로 잘 나가고 있기에 분명 그렇지 않은 재료들인데 배달과정에서 신선도가 떨어지는 환경이 있었는지 등 많은 생각이 들게 해드려 정말 죄송합니다.',
#  '항상 좋은 재료와 좋은 맛으로 여러분께 다가서 항상 최선을 다해 노력하는 회사가 되도록 노력하겠습니다.',
#  '저팔계 중국 마라탕 덮밥 요리가 더 발전하는 것을 응원하며 오늘도 최선을 다하겠습니다.',
#  '저팔계 중국 마라탕 덮밥 요리가 더 발전하고 발전해서 더 많은 분들이 만족할 수 있는 요리로 만들어 지도록 노력하겠습니다.',
#  '고객님 안녕하세요 소중한 식사 시간에 불편을 드려 대단히 죄송합니다 더욱 더 노력하는 대한냉면이 되도록 하겠습니다 감사합니다.',
#  '무더운 날씨에 건강 유의하시기 바랍니다. 감사합니다.',
#  '손님이 너무 많아서 기본 떡볶이랑 어묵이 모자랄 거 같아서 주문할 때 미리 전화 드렸는데 전화 안 받으신 분은 없다고 하셔서 제가 대신 드려요.',
#  '김포불닭발을 더욱 발전된 김포불닭발로 보답하기 위해 더 좋은 요리와 서비스로 찾아 뵙겠습니다.',
#  '너무 미안합니다 다음에 또 기회가 된다면 꼭 요청에 남겨주세요 그 자리에서 바로 전화드릴 테니 그땐 정말 죄송합니다',
#  '죄송합니다 더 노력 하겠습니다 전화 주셨으면 더 감사했을텐데 그러지 못 했네요.',
#  '혹시라도 이런 일이 반복되면 바로 신고해주시고 불편을 드려 사과드립니다 다음에 또 기회가 되면 그땐 꼭 전화 드리겠습니다 감사합니다',
#  '죄송해요 여러분 너무 늦어서 죄송합니다 제가 밥을 하나 못 챙겨 드렸네요 다음에 또 맛있는 요리 부탁드립니다',
#  '항상 일정한 맛을 유지하려고 노력하는 정육왕을 믿고 맡겨 주셔서 감사합니다.',
#  '이런 일이 전에도 있었던 적이 있다니 저로서는 정말 황당할 뿐이고 고객님도 마찬가지이시겠지만 저희가 드린 이런 말씀 양해 바랍니다.',
#  '고객님 죄송해요 그런데 식어서 못 드시는 거면 진작에 내놓으시던가 아니면 제가 그냥 드린 거라도 좀 챙겨 주세요',
#  '저희가 설 선물세트를 미리 준비했는데 고객님이 너무 늦게 도착하신다고 해서 저희가 그냥 드렸는데 고객님께 죄송하다면서 4시 1분에 다시 전화를 드려서 죄송합니다.',
#  '항상 최선을 다해 준비한다고 하지만 제가 놓친 부분이 너무 많아서 다시 한번 감사의 마음을 전하고 싶습니다.',
#  '주문 감사합니다 다음에는 차가운 야채는 따로 빼서 보내 주세요 닭발위에 차가운 양념이 올려져 포장된 것 같습니다 죄송합니다',
#  '고객님의 불편을 드려 대단히 죄송합니다 고객님 알림내용을 삭제한 것은 양해를 부탁드립니다 다음부터는 꼭 삭제하지 않을게요',
#  '12시12분24초에 배달 시작해서 13시28분에 배달을 완료했는데 배달이 11분이나 지연돼서 대단히 죄송합니다.',
#  '죄송합니다 고객님들 덕분에 피자가 잘 팔려 기분이 좋았는데 또 이런 일이 생겨 다시 한 번 사과드립니다.',
#  '여러 종류의 버섯을 선택하라고 하셔서 두 가지 버섯만 빼주시고 나머지는 그냥 주셨는데 제가 보기엔 그게 더 맛있었을 것 같거든요.',
#  '더 맛있는 치킨을 위해 더 많은 노력을 기울이겠습니다. 감사합니다.',
#  '축구 보면서 맛있게 드실 수 있게 해드리려고 했는데 너무 급하게 주문 넣으셔서 죄송합니다 다음에는 꼭 그렇게 하지 말아 주세요.',
#  '고객님 소중한 후기 잘 보았습니다 제가 너무 기대를 많이 한 것 같습니다 죄송합니다 다시 한번 더 최선을 다해 보내 드리겠습니다 감사합니다',
#  '저희 음식이 고객님께 만족을 드릴 수 있도록 더욱 노력하겠습니다. 감사합니다.',
#  '처음부터 끝까지 배달 예정 시간보다 더 빨리 먹을 수 있게 해 주시면 더욱 감사하겠습니다.',
#  '고객님들께 불편을 드려 대단히 죄송합니다 앞으로 더욱 조심하겠습니다 주문해 주셔서 감사합니다',
#  '제가 개업한 지 6개월이 되었는데 아직도 입맛이 전하시거나 몸이 안 좋아서 못 드시는 분들을 위해 제가 전복 특유의 냄새를 맡게 해 드리고 있습니다.',
#  '배달이 많이 지연돼서 정말 죄송합니다.',
#  '고객님 입맛에 안 맞으시면 제가 너무 송구스럽기도 합니다 사람마다 입맛이 다르듯이 마라탕 가게마다 맛이 다 다르니까요 너그럽게 이해해 주시면 감사하겠습니다',
#  '고객님 저희가 항상 생각하는 부분이라 생각하는데도 이런 일이 발생하다니 너무 황송합니다 고객님의 소중한 의견에 힘입어 더 열심히 노력하겠습니다.',
#  '잘못 기재한 내용에 대해 다시 한번 사과 드리고 앞으로 더 좋은 서비스로 찾아 뵙겠습니다.',
#  '고객님께 불편을 드려 대단히 죄송합니다 010 사칠삼오 삼삼구이 로 문자나 전화 주시면 최선을 다해 도와 드리겠습니다.',
#  '항상 고객님께 감사한 마음으로 준비하는 저희 폴트버거 에서는 재료부터 포장까지 직접 준비하여 정성을 듬뿍 담은 음식을 만들겠습니다.',
#  '매장으로 바로 전화 주시면 내가 가진 피자가 빨리 나올 수 있도록 최선을 다해 도와 드리겠습니다.',
#  '고객만족을 위해 최선을 다하지만 실수로 인해 핫소스가 안 들어간 것 때문에 다시 주문할 일은 없도록 하겠습니다 다음에 또 좋은 제품으로 찾아 뵐게요',
#  '매장에서 인기가 많은 닭다리랑 봉구비어 닭다리 사진 못 찍게 해서 죄송해요 죄송해요',
#  '제일 인기가 많은 메뉴인 돈코츠 요리를 많이 소개해 주셨는데 제가 좀 부족한 것 같습니다 죄송합니다.',
#  '저희가 가게 공지사항에 고기가 빨갛게 표시된 부분을 기재해 놓았지만 고객님께 불편을 드려 사과드립니다.',
#  '특 등심카츠는 일반 등심과 다르게 지방과 살코기를 조화시킨 게 특징이고 저희 매장에서 직접 먹는 손님들도 많이 계십니다.',
#  '고객님의 소중한 후기를 잘 써 주셔서 감사합니다. 감사의 뜻으로 맛있는 음식을 만들어 보겠습니다.',
#  '닭장수가 부족한 점을 헤아려 더 나은 서비스를 제공해 드리도록 노력하겠습니다.',
#  '고객님께 다시 한 번 사과 드립니다 매장에서 드시는 것보다 가짓수는 적더라도 생선구이랑 미역이랑 달래랑 같은 밑반찬은 더 정갈하고 맛있어요.',
#  '적극적으로 개선해서 다시는 이런 불편을 없도록 하겠습니다 더 좋은 제품으로 찾아 뵙겠습니다.',
#  '저희는 개인적으로 원하시는 부위를 말씀해주시면 거기에 맞춰서 적절히 올려 먹는 것을 도와드리고 있습니다.',
#  '저희는 저렴한 가격의 초밥으로 최고의 만족도를 자랑하는 초밥집으로 찾아주신 여러분께 감사드립니다.',
#  '매일 아침 손질하는건 기본이고요 그라브락스 연어를 사용해서 붉은색인 것은 본사에서 바로오는 회입니다 가격은 싸지만 절대 음식으로 장난치지 않습니다',
#  '최근에 배달의 민족들이 기상이 나빠져 배달 업무가 모두 차질이 생겼기 때문에 고객님들이 1시간에서 2시간 넘게 대기 중이면 저희가 참을 수밖에 없었습니다.',
#  '조치는 빨리 되는데 저희가 이용하고 있는 배달대행업체의 문제로 피크타임 배송이 늦어지는 경우가 생겨 저희도 너무 속상하고 정말 죄송합니다 계속해서 배송대행업체와 얘기하고 있습니다.',
#  '제가 분당에서 몇 년 동안 살았는데 배달 식당 중에 김치 깍두기 파는 데가 몇 군데 있는데 거기서 한 달 정도 있다가 김치가 다 떨어져서 여기로 옮겼거든요.',
#  '고객님 즐거운 식사시간에 불편을 드려 죄송했습니다 닭갈비 알밥은 본사에서 직접 공급하는 음식인데도 불구하고 맛이 좀 싱거울 수 있어서 저희가 최선을 다해 요리하겠습니다.',
#  '죄송합니다 앞으로는 이런 일이 발생하지 않도록 더욱 더 주의를 기울이겠습니다 여러분께 심려끼쳐 드려 진심으로 사과드립니다.',
#  '항상 맛있고 건강한 한 끼를 위해 찾아주시는 여러분께 감사의 마음을 전하며, 더 좋은 요리와 맛있는 요리로 찾아 뵐게요.',
#  '저희 매장은 하루 전날 주문을 받아서 당일 발송을 원칙으로 하고 있기 때문에 신선한 재료를 사용하기 위해 냉동 창고에서 며칠 동안 숙성시키고 있습니다.',
#  '제가 급하게 일정을 짜서 30분 정도 걸리는 곳을 지정해 놨었는데 시간이 잘못 가서 죄송합니다 내일 다시 좋은 내용으로 인사드리도록 하겠습니다.',
#  '조금 더 신경써서 준비해 드릴 테니 맛있게 만들어 주세요 30분 예약이라 빨리 나올 수 없어서 죄송해요',
#  '저희가 들어오는 순서대로 하는데 시간이 너무 빨리 지나쳐서 죄송합니다 이렇게 늦은 시간까지 주문이 밀려있으면 제가 바로 전화드릴 테니 양해 부탁드립니다.',
#  '고객님 오늘 제가 잘못된 대처를 한 것 같은데 죄송합니다 내일은 또 좋은 일이 생길 것 같습니다 감사합니다',
#  '저희가 맛없다는 소리는 안들었는데 짜장면이 이렇게 맛이 없을 수가 있나요 여러분?',
#  '전달하는부분에 더 신경써서 보내드리겠습니다 죄송합니다 문 앞에 배달원이 노크하는 소리가 났는데도 못 들은 것 같습니다 죄송합니다',
#  '저희가 그래도 10년넘게 장사하면서 맛없다는 소리를 안들어봤는데 실수가 있었나봐요 죄송해요 여러분 10년',
#  '비네리는 주말이다보니 배달이많이밀려 죄송합니다 다음에 또 주문하실때는 댓글 남겨주시면 서비스로 보내드리겠습니다 그럼 오늘도 수고하셨구요',
#  '우선 죄송합니다 오늘 비가 많이 와서 배달이 평소보다 늦었는데 고객님들이 다시 한번 양해해주시면 감사하겠습니다 죄송합니다 내일은 또 어떤 좋은 소식이 있을지 기대할게요',
#  '저희 윤희횟집을 방문해주신 고객님께 감사의 뜻을 전하고 부족한 내용이 있더라도 이해해 주시기 바랍니다.',
#  '고객님께 다시 한번 사과 드립니다 고객님께서 주문해 주신 샌드위치는 원래 냉동 제품으로 차게 드시면 맛있는 제품인데 제가 살짝 늦게 넣은 탓에 맛이 덜 했습니다 죄송합니다',
#  '좀 더 주의를 기울이도록 하겠습니다 여러분께 심려를 끼쳐 드려 정말 죄송합니다.',
#  '잘 봐 주신 것에 대해 다시 한 번 감사의 말씀을 드립니다. 앞으로는 더 좋은 제품으로 찾아 뵙겠습니다.',
#  '저희 매장은 배달 전문 업체로 고객님의 요청이 있을 경우 신속한 처리를 위해 대기 시간을 30분에서 1시간 정도로 줄이고 있습니다.',
#  '저희 1988응답하라추억의옛날도시락을 사랑해 주셔서 감사합니다.',
#  '우선 불편을 끼쳐 드려 머리 숙여 사과 드립니다 제가 드린 말씀은 양해해 주시기를 부탁드립니다.',
#  '제가 시간을 좀 더 빨리 알려 줬으면 좋았을 텐데 그렇게 늦은 건 아니었어요 죄송해요 여러분 지금 보니까 주문도 많이 밀려 있던데요',
#  '맛이 아주 부족하다는 말씀은 저희가 조리에 실수가 있었을수도 있고 배송이 늦어서 일수도 있지만 사진상으로는 모든 고객님의 입맞을 만족시킬수 없다 정도로만 받아주세요',
#  '지금 치킨이 너무 먹고 싶다면 헬리오시티에 있는 굽네치킨으로 와주세요 너무 맛있어요 여러분! 다음에 또 맛있는 요리로 찾아 뵐게요.',
#  '제가 괜한 짓을 했네 라고 생각하실 수도 있지만 제 얘기가 잘못된 것을 지적해 주신 것 같습니다.',
#  '고객님 죄송합니다 해당 부분은 매장에 명백한 실수였습니다 앞으로 더 많은 실수를 매장에서 할 수 있도록 하겠습니다 감사합니다',
#  '우선 저희 직원이 신입이라 실수를 했는데 다음 주문시 요청사항에 내용 적어주시면 감사하겠습니다. 추운 날씨 감기 조심하세요.',
#  '배달은 근거리 배달로 25 35분 사이 배달이 가능합니다 하지만 오늘 갑작스레 비가 와서 그런지 배달은 조금 지연되었습니다 다음 주문시 더 좋은 서비스로 보답하겠습니다',
#  '언제나 행복하고 건강한 밥상을 위해 노력하겠습니다. 감사합니다.',
#  '항상 행복하고 또 기쁜 일만 가득하길 바라는 마음으로 최선을 다해 준비하는 여왕의 브런치가 되도록 노력하겠습니다.',
#  '맛있는 해물 파전 드시고 오늘 하루도 행복하셨지요? 다음에 또 맛있는 요리로 찾아 뵙겠습니다.',
#  '눈길에 배달을 30분 동안 하려면 힘든 일이 한두 가지가 아닌데 30분을 꼬박 서서 해야 한다니 여간 힘이 들지 않습니다.',
#  '항상 먹던 양을 기준으로 하는데 조리과정에서 잘못된 부분이 발견된 것은 물론이고 앞으로는 이런 일이 생기지 않도록 더욱 철저히 하겠습니다.',
#  '죄송해요 늦게 답글을 달아서 죄송합니다 상황이 기억이 잘 안 나는데 답글 작성할 시간도 안 나고 그랬어요',
#  '제가 지금 확인해보니 주문하신 피자로 잘 만들어 졌네요 고객님께서 드시던 피자와 다른 피자를 주문하셔서 제가 착각한 것 같은데 주문서 다시 확인해 주세요',
#  '죄송합니다 소금은 넣지 말아 주세요 제가 싱겁게 먹는 편인데 좀 더 싱겁게 해도 괜찮으니까요',
#  '정말 죄송합니다 다음에도 또 이런 실수를 하시면 안 되는데 너무 죄송해요 다음에 또 좋은 모습으로 보여주세요 감사합니다',
#  '고객님 입맛에 딱 맞는 맛있는 피자 만들어 드릴 수 있음 얼마나 좋을까요 정말 궁금한데 도와 주실 수 있을까요',
#  '저희쪽에서도 최대한 많은 비용을 부담하고 있지만 장거리의 경우 조금은 부담이 될실거라 생각합니다 계란 후라이와 깻잎찌가 기본 구성으로 되어있습니다',
#  '개선하도록하겠습니다 개선하지 않으면 실망과 실망을 안겨드릴 수 있으니 그점 양해바랍니다.',
#  '서비스 초밥은 24피스(총 26피스)로 구성되어 있으며 초밥 2팩에 들어있는 2개의 비닐 봉투에 담긴 양이 다른 제품에 비해 월등히 많습니다',
#  '고객님께 불편을 드려 정말 죄송합니다 제가 직접 하지는 못하고 친구 고객님 알림에 메뉴 등록이나 안내를 하는 바람에 이렇게 된 것인데 양해 부탁드립니다.',
#  '신경써서 하겠습니다 죄송합니다 신경쓰지 못해 드려서 정말 죄송합니다.',
#  '죄송합니다 다음부턴 꼭 기억하겠습니다 그러지 못해 정말 죄송합니다',
#  '치킨은 매장에서 바로 먹는 것이 가장 맛있기로 유명한데 고객님들이 주문을 늦게 넣거나 평소보다 늦게 배달을 하면 고객님들은 그만큼 실망을 하시게 됩니다.',
#  '고객님 즐거운 식사 시간에 제가 야채를 제대로 확인하지 못한 것 때문에 죄송합니다 다음 주문시에는 더 좋은 요리로 준비해 드리겠습니다다시한번 사과 드립니다',
#  '현재 990원 사이드메뉴 이벤트와 함께 진행하고 있는 수삼 은 고객님들의 만족도를 위해 최선을 다해 노력하는 수상한삼겹살이 되도록 노력하겠습니다.',
#  '양파를 빼달라고 하셔서 이미 준비가 된 재료라서 양파만 골라내도 들어간 것 같습니다 양해 부탁드리려고 전화 드렸는데 전화 안받으시더라고요 죄송합니다',
#  '고객님이 주말저녁 맛있게 드실 수 있게 더 노력해 보겠습니다. 내일 또 맛있는 요리로 찾아 뵙겠습니다.',
#  '폴트버거는 고객님의 소중한 의견을 반영해 항상 노력하는 매장이 될 것을 약속합니다.',
#  '항상 따뜻한 밥상을 위해 노력하겠습니다. 감사의 뜻으로 맛있는 요리 만들어 보겠습니다.',
#  '고객님의 소중한 후기에 힘을 얻고 더 좋은 요리를 만들어 보답하겠습니다. 감사합니다.',
#  '정말 죄송합니다 이런 일이 생기면 바로 매장으로 연락 주시면 바로 조치를 취해 드리겠습니다.',
#  '저희 피자가 자극적이지 않고 담백해서 맥주 안주로도 괜찮았지만 다른 피자들도 괜찮으니까 다음에 또 맛있는 피자 만들어 주세요',
#  '고객님들이 소중한 한끼를 드실 수 있도록 최선을 다해 돕겠습니다 배달 대행업체 랜돌프뉴욕페페로니를 이용해 주셔서 감사드립니다',
#  '죄송합니다 빠른 시일 내에 문제가 된 부분을 바로 잡으며 이런 일이 또 일어나지 않도록 조치할 것입니다 .',
#  '아쉬워요 아쉬워요 아쉬운 부분이 많이 아쉬웠어요',
#  '저도 찍히는 곳으로 배달을 시켰지만 고객님께 욕을 듣고 기분이 나쁘네요 배달업체를 바꾸던가 해야할 것 같습니다.',
#  '고객님 소중한 후기 감사합니다 고객님 소스 따로따로 요청사항에 적어주시면 제가 따로 소스를 만들겠습니다.',
#  '저희도 직접 배달하지 않고 대행업체를 통해 배달을 하기 때문에 이런 일이 생길 수 있는데 고객님께 불편을 드려 사과 드립니다.',
#  '음식은 맛있게 먹었지만 배탈이 나셨다니 사진상으로는 익은 것으로 보이나 그래도 너무 속상하고 안타깝습니다.',
#  '저희 매장에도 시간과 내용물이 뜨꺼워 마늘양파고추가 쉽게 상해져서 포장해 드렸지만 고객님께 더 감사의 마음을 전하고 싶지 않았습니다.',
#  '메인메뉴인 회 맛이 훌륭했다면 더 좋은 맛을 내기 위해 더 많은 노력을 했을 건데 아쉬웠어요 고객님 감사의 말씀에 다시 한번 감사드립니다.',
#  '날씨가 좋지 않은 날의 배달은 특별히 신경을 쓰고 있음에도 불구하고 불편을 드렸습니다 다시 한 번 사과 말씀 드립니다 앞으로 더 노력하겠습니다',
#  '모든 음식은 주문 즉시 조리하고 배달의 경우 배차시간 등을 꼼꼼히 따져 조리하는데 코브라독스 분당미금역점의 주인장 올림니다.',
#  '저희가 항상 최선을 다한다는 것을 보여드리고 있는데 항상 부족한 점이 조금 있더라도 이해해 주시기 바랍니다.',
#  '더 발전된 초밥대통령이 되겠습니다 감사합니다 요기요 입점을 처음으로 해서 시스템에 적응하고 있는 초밥대통령입니다',
#  '맛있는 한 끼 식사를 위해 노력하는 올데이 케밥이 되도록 노력하겠습니다.',
#  '최대한 빨리 갔는데도 여기서 옥산이 차로 20분이 넘게 걸리네요 다음에는 더 빨리 가서 맛있는 음식으로 보답하겠습니다.',
#  '제가 나름대로 노력을 많이 했는데도 불구하고 이렇게 좋은 식사시간이 만들어 지지 못해 정말 죄송합니다 여기서 저희가 옥산까지 가는 데 17000~18000원 정도 나옵니다',
#  '제가 혼자서 근무하다보니 시간이 많이 부족해요 그래서 고객님께 빨리 식사 하시라고 90분에 정시 퇴근하도록 하겠습니다.',
#  '음식이 상하거나 배달이 잘못된 경우가 종종 있었는데 그때마다 불편을 드려 사과를 했는데 다음부터는 그러지 않도록 하겠습니다.',
#  '저희 윤희횟집을 방문해주신 고객님께 감사의 뜻을 전하고 앞으로 더 좋은 요리와 다양한 서비스로 찾아 뵙겠습니다.',
#  '우선 고객님께 죄송합니다 모든재료는 신선하게 위생 또한 철저하게 시행하고 있는데 옥수수콘은 완제품을 쓰고 있는데 저희도 본사에 의뢰하여 제조 업체측에 문의 드려 보겠습니다.',
#  '그동안 저희에게 많은 사랑을 주셨던 단골 고객님이시겠지만 고객님과 매장 사이의 소통이 원활하지 않아 불편을 드려 사과 드립니다.',
#  '저희 가게 빙수는 250g 이상 되는 팥을 사용하며 타 업체 대비 두 배 이상의 설탕을 넣어요.',
#  '저희 똠얌꿍이 약간 매콤한 맛인데 아주 매웠어요 그래서 점심 때 전화가 폭주해서 다시 전화했을 때는 너무 늦어서 못 먹었다고 했어요',
#  '조개가 들어간 미역국은 진하고 깊은 맛을 내기 위해 모든 국의 국물이 조개로 만들어졌다고 정보란에 나와 있는데 못 보신 분이 있을 것 같네요.',
#  '저희 매장은 배달 전문 업체로 고객님의 요청이 있을 경우 최대한 빠른 처리를 위해 노력하고 있으며 특히 메뉴 안내가 끝난 후에도 고객님들이 매장을 찾지 못할 경우 신속하게 처리해 드리고 있습니다.',
#  '저희 매장을 방문해 주신 분들께 우선 감사의 말씀을 드립니다. 열심히 하는 모습은 너무 보기 좋지만 그래도 조금 더 신경 써 주셨으면 합니다.',
#  '저희 매장은 배달 전문 업체로 고객님의 요청이 있을 경우 최대한 신속하게 처리해 드리고 있으나 배달이 늦어질 경우 고객님께 불편을 드려 죄송합니다.',
#  '저희를 찾아와 주셔서 정말 감사드립니다.',
#  '고객님 어렵게 주문해주셨는데 저희가 그 서비스를 만족시키지 못한 것 같아서 정말 죄송합니다 다음부터는 우리가 고객님들에게 여러 번 말씀드리겠습니다',
#  '커피를 산미 있는 것을 좋아하시면 여기나 쿠 등 기타 할인행사들 통해서 많이 사주시는 것 같은데 배달료는 거리와 주문금액 등 배 1과 다른 사이트들은 수 료 때문에 어쩔 수 없이 가격이 상이합니다.',
#  '항상 주문해주시는 고객님들을 위해 감사의 마음을 전하고 있는 만큼 잘 부탁드립니다.',
#  '신중한 메뉴 선택은 언제나 중요하죠 고객님의 소중한 후기를 위해 최선을 다해 노력하겠습니다.',
#  '자주 찾아주시는 분들께 감사의 마음을 전하며 손수 제작한 글레이즈드로 손수 만든 브라우니를 선물로 드리고 있습니다.',
#  '감사합니다 덕분에 잘 사용하겠습니다.',
#  '혹시라도 고객님들이 종종 이런 후기를 남겨주시면 저희가 확인해서 더 좋은 서비스로 찾아 뵐 수 있도록 하겠습니다.',
#  '1분인데 얼마나 더 드려야 할까요 맛도 1인분이 아닙니다 1인분입니다',
#  '고객님 소중한 시간 동안 불편을 드려 정말 죄송합니다 다음에 또 이런 실수를 하지 않도록 또 노력하겠습니다.',
#  '지금 치킨이 먹고 싶다면 헬리오시티 지점으로 오십시오 고객님의 성원에 힘입어 더 맛있는 요리를 만들어 보겠습니다.',
#  '만족하지 못했지만 다시 주문할 때는 꼭 만족시켜 드리려고 다시 노력하겠습니다. 고객님들이 다시 한번 주문해 주시면 더 열심히 하겠습니다.',
#  '춘리마라탕은 항상 좋은 맛과 좋은 서비스로 보답하는 곳이니 앞으로도 많은 사랑 부탁드립니다.',
#  '저희 만다린을 믿고 찾아와 주셔서 감사합니다 소중한 시간 동안 저희 매장을 방문해 주셔서 정말 감사드립니다.',
#  '체크 하겠습니다 감사합니다 잘 보겠습니다 감사합니다',
#  '배달의쌀국수 송파점은 고객님의 요청이 있을 시 언제나 최선을 다해 응대해 드릴 것이며 특히 우리 가족이 먹는 음식인 만큼 더 각별한 맛과 서비스를 제공',
#  '고객님 안녕하세요 고객님 지난 3년간 매장을 운영하면서 많은 주문을 해주셨는데 항상 부족한 점이 많지만 이해해 주시기 바랍니다.',
#  '고객님 감사합니다 지난 3년간 매장을 운영하면서 많은 주문을 해주셨는데 항상 부족한 점이 많았습니다 하지만 항상 고객님께 감사의 마음을 전하며 맛있는 음식을 만들겠습니다 감사합니다',
#  '메뉴 선택시 보신 것처럼 2인 식사 양으로 구성되어 있으며 항상 양이 부족하시면 추가 메뉴을 이용하시면 더욱 든든하게 드실 수 있습니다.',
#  '죄송합니다 매일 들어오는 재료의 차이로 인해 재료나 소스가 달라질 수 있으므로 조심스럽게 다루도록 하겠습니다 고기나 소스는 매일 바뀝니다',
#  '혼자서 드시기엔 양이 많이 모자라며 배달이 급하게 필요한 상황이라면 1인 메뉴 세트를 이용하셔도 괜찮으며 배달 시간이 길다면 포장해가시는 분에게 양해를 구하실 수 있습니다.',
#  '저희를 믿고 주문해 주셔서 감사합니다. 두 분이 드시기엔 양이 너무 많은데 혼자 먹기엔 너무 많은 양이라 두 세트를 시켰습니다.',
#  '고객님의 요청이 있을 시 신속한 답변과 책임감 있는 대처를 위해 노력하겠습니다.',
#  '제가 약간 어렵게 말씀드릴 게 있는데 우선 제가 포장할 때 기본적으로 제공되는 밑반찬에서 김치가 빠지면 섭섭하잖아요.',
#  '조금 더 노력해서 올스타5가 될 수 있도록 하겠습니다 다음에도 믿고 구매해 주세요 감사합니다.',
#  '죄송합니다 고객님 추후 주문시 요청사항에 고객님이라고 써 주세요 감사합니다 다음에 또 부탁 드리겠습니다 감사합니다',
#  '잠실역과 석촌역 사이에 있는 매장에 방문하시면 편안하게 티타임을 즐길 수 있고 맛있는 빵과 커피를 만나볼 수 있는 것이 더 많은 메뉴와 커피가 있기를 바랍니다.',
#  '잠실역과 석촌역 사이에 있는 매장에 방문하시면 편안하게 티타임을 즐길 수 있으며 맛있는 빵과 커피를 드실 수 있습니다.',
#  '저희 플러스82의 메뉴를 주문해 주신 여러분께 감사의 뜻을 전하고 싶고 부족한 부분은 언제든 보충해 드릴 테니 많은 이용 바랍니다.',
#  '음식물 쓰레기가 너무 많이 나와서 치우는 데 시간이 많이 걸리나 봐요. 죄송합니다.',
#  '고객님께 불편을 드려 대단히 죄송합니다 말씀해주신 대로 먼저 고기를 익히고 그 다음에 살코기와 지방을 충분히 넣어 잘 조리해 보겠습니다.',
#  '고객님의 소중한 의견을 최대한 반영해 항상 노력하는 매장이 될 수 있도록 노력하겠습니다.',
#  '이용해 주셔서 감사합니다 식사 시간에 불편을 드려 대단히 죄송합니다 다음에 또 맛있는 요리로 찾아 뵙겠습니다.',
#  '항상 고객님들께 감사의 마음을 전하며 맛있는 음식을 만들어 드리는 갈비민족이 되기를 기원합니다.',
#  '항상 고객님들께 감사의 마음을 전하며 더욱 노력하는 갈비민족이 되도록 노력하겠습니다.',
#  '맛있는 요리와 함께 별 세 개 주신 것에 대해 감사의 뜻을 전하고 싶은데 제가 별 욕심이 과했나요?',
#  '더 발전하는 저팔계 중국 마라탕 덮밥 요리 가 될수 있도록 오늘도 최선을 다해 노력하겠습니다 감사합니다.',
#  '올데이파스타 동대문구점은 고객님을 위해 최선을 다해 요리하겠습니다. 앞서 저희가 바쁜 관계로 조리 과정에서 잘못된 부분이 있으면 바로잡을 수 있도록 하겠습니다.',
#  '죄송합니다 죄를 지워서 더 좋은 일을 할 수 있게 해 주세요',
#  '너무 감사한 일이지만 감사의 뜻을 전하고 다시 한 번 더 사죄드립니다.',
#  '더운 날씨에 건강에 유의하시고 항상 행복하시기를 기원합니다.',
#  '항상 똑같은 사진으로 자주 주문주셔서 어떤 주문으로 주문주시는 분인지 알고 있어요 그런데 얼마전에 고객님이 부탁사항에 고기는 적게 주시고 김치는 많이 부탁드려요',
#  '저희는 배달 전문점이 아닌 홀매장 운영을 하기 때문에 항상 당일 납품 재료를 소진하고 있지만 혹시라도 모를 사고를 미연에 방지하기 위해 매장으로 전화를 주시는 고객님들이 계십니다.',
#  '항상 맛있는 요리를 위해 노력하는 삽교원조두리곱창이 되도록 노력하겠습니다.',
#  '고객님 말씀처럼 저희는 돼지 막창이 들어가는 지방식 곱창전골입니다 소곱창 전골로 잘못 아시고 주문하시면 됩니다 감사합니다.',
#  '북서울꿈의숲점 이 최고 국내산 햅쌀만 사용합니다 영수증 체크를 항상 해 주시고 부족한 점이 있으면 언제라도 댓글로 알려주세요.',
#  '죄송해요 고객님 다음에는 더 좋은 요리와 요리로 찾아 뵐게요 감사합니다',
#  '우선 고객님이 주문해주신날 비가 너무 많이 와서 대행사 고객님들이 2시에 마감인데 미리 퇴근하셔서 죄송합니다 다음에는 국물닭발이 많이 나가는 메뉴인데 더 맛있게 해',
#  '더위에 지치지 않게 항상 건강에 유의하시기 바라며 더 맛있는 요리와 다양한 요리로 찾아 뵐게요.',
#  '주문해 주신 피자는 빨리 도착했지만 주문 폭주가 너무 늦어 제가 다시 한 번 사과 드립니다.',
#  '항상 건강하고 행복한 하루를 보내도록 노력하겠습니다. 항상 감사의 마음으로 맛있는 음식을 만들어 보겠습니다.',
#  '저희는 항상 위생에 신경을 쓰고 있지만 혹시라도 모를 사고를 미연에 방지하기 위해 항상 준비하고 있습니다.',
#  '맛있는 요리와 건강한 밥상을 위해 더 열심히 노력하겠습니다. 별 3개를 주셨는데 3개가 무슨 의미지?',
#  '김포불닭발을 더욱 발전된 김포불닭발로 만들어 고객님의 소중한 식사 시간을 대신해 드리겠습니다.',
#  '고객님의 소중한 시간 동안 저희 정육왕을 찾아주시고 만족스러운 식사를 해주신 것에 대해 깊은 감사의 마음을 전하며 5점 만점을 위해 더욱 노력하겠습니다.',
#  '손님들의 만족도를 높이기 위해 더욱 노력하는 원조 곱도리탕 승도리네김포풍무점이 되도록 하겠습니다.',
#  '저희 승도리네 김포풍무점은 하루도 거르지 않고 귀한 손님을 맞이하여 항상 최선을 다하는 식당으로 만들겠습니다.',
#  '고객님 저희 음식이 좀 느끼하셨나봐요 그래도 이렇게 솔직하게 후기 써주셔서 감사합니다.',
#  'Si 주문해주시고 감사하게도 모두 좋은 의견 주셔서 고맙습니다.',
#  '저희가 잘못한 게 맞다면 고객님이 주문해주시면 감사하겠습니다 저희가 더 잘 살펴보고 다음에 또 맛있는 요리로 찾아 뵐게요.',
#  '고객님 덕분에 힘이 납니다 주문실수로 인해 번거롭게 해드려 죄송했어요 다음에는 실수 없이 확인하겠습니다 감사합니다',
#  '더 노력하는 매장이 되기 위해 더 많은 노력을 하겠습니다.',
#  '돈가스가 생각날 때 마다 돈가스회관 김포장기점을 방문해 주시면 감사하겠습니다.',
#  '저희가 판매하는 생선까스랑 치즈돈가스가 인기가 많은데 고객님께는 조금 아쉬운 감이 있어서 별도로 감사의 뜻을 전하고 싶지 않네요.',
#  '고객님들이 너무 급하게 굽지 마시고 예전처럼 바싹 굽게 해 주시면 오히려 탄맛이 나므로 양해 부탁드립니다.',
#  '저희 준전골 곱창볶음을 예약해 주시면 새해 복 많이 받으시라고 전화 드리겠습니다.',
#  '항상 건강하시고 행복한 주말 되세요 더 맛있는 요리와 요리로 찾아 뵐게요 감사합니다',
#  "제주시 고촌읍 소재 제일모직 영안빌딩 2층에 자리하고 있는 '래미안 리버젠' 오피스텔은 3.3m2당 분양가가 200만∼500만 원으로 책정되어 있는데 입",
#  '고객님께 불편을 드려 대단히 죄송합니다 제가 요즘 정신을 못차리고 있어서 그런 것 같은데 다시 한번 사과드립니다.',
#  '우선 댓글이 늦어서 죄송합니다 오픈하고 많은 부분에서 부족한 점 고쳐나가면서 열심히 하고 있으니 우리 고객님 다음 주문시 불편하셨던 부분을 요청사항에 적어주시고 전화 주시면 꼼꼼하게 체크해서 개선할 수 있도록 노력하겠습니다',
#  '항상 맛있게 잘 먹는 것만 보여 드리는 탠탠 마라탕 매장은 김포공항 근처에 있어 언제든지 방문해 주시면 감사하겠습니다.',
#  '지금까지 이런 맛은 어디서 못 찾을 것 같아요 여러분도 한번 도전해 보시면 어떨까요?',
#  '항상 맛있는 음식을 위해 노력하는 구리시 갈매지구 TGICA 옆에 있는 탠탠 마라탕 매장이 곧 문을 열었으니 많은 방문 바랍니다.',
#  '고객님께 감사의 마음을 전하며 더 좋은 요리와 서비스를 제공해 드리도록 노력하겠습니다.',
#  '우선 2단계로 주문주셨는데 3단계로 오해하셔서 죄송합니다 앞으로 고객님의 소중한 식사를 책임질 수 있도록 더욱 노력하겠습니다 감사합니다.',
#  '저희가 매장에서도 인기가 많은 메뉴인데 비빔장 얘기는 처음 듣는 것 같아요 주문해주시면 감사하겠습니다.',
#  '죄송합니다 다음부턴 배달대행을 하다보니 이런 경우가 발생할 수 있는데 다음부터는 꼭 그렇게 하지 않도록 하겠습니다 다들 즐거운 주말 되세요',
#  '예 기본적으로 3개만 기본으로 넣고 추가적으로 더 넣어드립니다 양해부탁드립니다 여러가지 요청이 있어서요',
#  '죄송합니다 다음부터 꼭 신경써 주시기 바랍니다 너무 늦어 미안합니다',
#  '고객님 저희가 머리망도 쓰고 항상 조리할때 신경을 쓰려고 노력 하고 있는데 다음에 이런일 없도록 더 청결에 유의하겠습니다.',
#  '양이 좀 적다 싶으면 고기를 더 넣어 드셔도 괜찮고요 시간 내서 제가 요리해 보겠습니다.',
#  '이런 문제에 대해서는 고객님께 다시 한번 사과 드립니다. 고객님 죄송합니다.',
#  '고객님께 드리고 싶은 말씀이 많은데 다 할 수 있는 말은 하지 못하는 게 죄송스럽기는 하네요 사장님은 제가 주문할 때 이미 반찬 종류를 몇 가지 주문했는데 다음 날 또 주문하겠습니다.',
#  '부족한 점이 많지만 다시 한번 감사하게 생각하고 앞으로 더 열심히 하겠습니다 감사합니다.',
#  '고객님은 별점에 크게 관심 없으셨으니 망정이지 이런 식이면 별점 3개짜리 업체는 별 볼 일 없습니다.',
#  '즐거워야 할 식사 시간을 망친 것 같아 정말 죄송합니다 맛있게 잘 먹었다고 내일 보내 드리려고 했는데 말이죠.',
#  '입맛에 맞지 않으면 정말 죄송합니다 제가 드린 말씀에 정말 노여워하셨군요',
#  '항상 고객님들의 만족도를 높이기 위해 노력하는 저희이지만 항상 부족한 점이 많은 요리를 만들어 낼 수 있도록 노력하겠습니다.',
#  '소중한 식사 시간에 만족스러운 한 끼를 제공해드리지 못해 정말 속상하고 죄송합니다 다시 한번 주문 주셔서 감사합니다 오늘도 맛있는거 많이 드시고 행복한 하루 되세요',
#  '우선 주문 감사드립니다 마라샹궈는 제 입맛에 맞지 않았군요 꿔보러우 역시 맛있게 먹었다니 다행이네요 고객님 소중한 의견 감사드립니다',
#  '고객만족도를 위해 최선을 다해 노력하겠습니다. 불편을 드렸거나 궁금하신 부분이 있으시면 언제든지 연락주십시오.',
#  '항상 더 많이 담으려고 노력하는 만큼 양이 부족한 부분이 있더라도 양해 부탁드립니다 고객님 소중한 주문 감사합니다',
#  '소중한 주말 저녁 식사시간에 불편을 드려 정말 죄송합니다 재료 하나하나 꼼꼼하게 체크하고 있는데 더 신경써서 만들겠습니다 감사합니다',
#  '항상 맛있는 요리와 청결한 식단으로 보답하겠습니다.',
#  '만족한 식사 대접에 더 힘을 쏟겠습니다 더 좋은 요리로 찾아 뵐게요 감사합니다',
#  '죄송합니다 고객님 덕분에 좋은 제품 만들어 낼 수 있었는데 다음에는 실수하지 않도록 더 많이 노력하겠습니다 감사합니다',
#  '맛있는 요리 보여드리려고 노력하는 면가게 야탑점이 되도록 하겠습니다.',
#  '손님 불편 드려 사과 말씀 드립니다. 앞으로 음식 관리에 더욱 유념하겠습니다.',
#  '고객님이 보내주신 음료는 잘 받았으나 다른 음료들도 많이 나왔으면 하는 바람입니다.',
#  '즐겁고 행복한 식사시간에 만족감을 못 드려서 죄송합니다 더욱 열심히 노력해서 맛의 즐거움을 고객님께 찾아 드릴 수 있도록 노력하겠습니다.',
#  '최대한 시간 맞춰 준비해도 항상 식는 것 같아서 더 열심히 준비하겠습니다.',
#  '좋은 평과 감사의 뜻을 모아 다시 한번 더 맛있는 요리로 찾아 뵙겠습니다.',
#  '저희 피자를 드시고 뉴욕 피자의 맛을 못 느끼셨다면 죄송했을 따름입니다 고객님의 만족도를 높여드릴 수 있도록 최선을 다해 노력하겠습니다.',
#  '더열심히노력하는홍싸롱이가되도록 더노력하는홍싸이롱이가',
#  '좀더 빠른 배달로 좀더 신속한 배달을 해주셨으면 합니다.',
#  '죄송해요 여러분 정말 죄송해요 혹시 마요네즈가 안들어있거나 해서 명란마요네즈를 사용하지 않았나요?',
#  '아 정말요 죄송해요 제가 실수를 좀 많이 했네요 정말요',
#  '더욱 발전하는 카산도가 되기 위해 더 노력하는 것이 무엇보다 중요한데 날씨가 너무 더워서 배달의 어려움이 많아졌기 때문입니다.',
#  "일본 식당에서 흔히 쓰는 '단짠 단짠'의 줄임말인 '단짠단짠'은 단짠 맛에 중점을 맞춘 음식인 반면, 이 음식은 단맛과 신맛의 조화가 조화되어 조화를 이루고 있습니다.",
#  '우천시에는 주문도 많고 고객님들도 안전운전을 위해 운전을 하다 보니 음식이 식는 경우가 많습니다 안심을 자르거나 사이즈 규격에 따라 그대로 넣는 경우가',
#  '저희 카산도 정자는 맛있는 돈가스 카레 산도를 위해 늘 긴장하고 있습니다니다.',
#  '죄송합니다 고객님 덕분에 맛있는 식사를 할 수 있었는데 대신 더 좋은 서비스를 해 드릴 수 있게 된 것 같습니다 감사합니다 :)',
#  '항상 만족하실수 있는 시간이 되도록 최선을 다해 노력하는 부성초밥 미금본점이 되기를 진심을 바랍니다.',
#  '즐겁고 행복한 여름 휴가철에 잘 맞는 그런 요리를 소개해 드리고 싶은데요.',
#  "I don't care for a chicken day to a hour day Bees on the morning day.",
#  '번거롭게 해드려 정말 죄송합니다 매장으로 방문해 주시면 확인 후 환불해 드리겠습니다 번거롭게 해드려서 죄송합니다',
#  '매장으로 전화주시면 환불조치와 별도로 사과말씀 드리겠습니다. 주말 잘 보내셨는지요?',
#  '최대한 많은 양을 지금보다 적게 그리고 최대한 적게 하려고 노력하는데 그렇게 하니까 그렇게 된 것 같아요.',
#  '비오는 날 특히 배달이 잘 안되는 주말이라 신경을 쓰고 있는데도 불편을 드렸네요 앞으로 더욱 더 노력하겠습니다 지적해주신 내용 모두 새겨듣겠습니다비',
#  '저희 매장은 새벽마다 신선한 채소가 들어오는데 그날은 저희가 새벽 서너 시에 채소를 들여오거든요.',
#  '제일 중요한 초장을 누락시키다니 정말 죄송합니다 앞으로는 꼼꼼히 더 챙겨보겠습니다 혹시 다음에 주문주신다면 연락 부탁드려요 서비스 챙겨드릴게요',
#  '회 종류가 많아지면 가격이 오를거라 조금 아쉬운 부분이 있지만 가게 운영하면서 제가 할 수 있는 부분은 최선을 다해 반영해 드리겠습니다.',
#  '주문해 주신 것에 대해 감사의 뜻을 전하고 싶은 마음은 매장으로 전화를 걸어 주시면 감사하겠습니다.',
#  '그라브락스 연어는 연어수급 문제가 해결되어 내일부터는 연어를 곤즈부메 연어로 다시 초밥을 만들 예정이구요 주문해주신 분들께 감사드립니다.',
#  '저희는 저렴한 가격에 훌륭한 맛까지 내는 초밥대통령을 찾아주시면 항상 최선을 다해 노력하겠습니다.',
#  '초밥대통령이 더 좋은 맛과 더 만족스러운 요리를 위해 노력하겠습니다.',
#  '여러모로 아쉬운점이 많았던 것 같습니다 만족시켜 드리지 못해 죄송스럽고요 더 세심하게 살피도록 하겠습니다 감사합니다',
#  '네 더 맛있는 초밥을 위해 더 노력하는 초밥대통령이 될게요 감사합니다.',
#  '확인을 제대로 안 한 것 같습니다 다시 확인해 보고 그래도 없으면 다시 연락드리겠습니다감사합니다',
#  '저희 라쿤핏 바베큐 주문해주신 고객님께 우선 감사의 말씀 드립니다. 앞으로 더 좋은 제품으로 찾아 뵐게요.',
#  '혹시 음식이 드시기에 불편한 점이 있다면 주저하지 말고 바로 가게로 전화하셔서 불편을 해결해 드리겠습니다.',
#  '처음부터 주문이 밀려 늦게 배송된 점 양해 부탁드립니다 다음 번 주문시에는 휴일과 연휴 사이에 주문 받겠습니다.',
#  '양이 적다고 느껴지시면 다음 주문 때 요청사항에 적어주시면 제일 큰 고구마로 서비스로 보내드리겠습니다.',
#  '죄송해요 제가 실수를 한 것 같은데 다시 한번 말씀해 주시면 감사하겠습니다.',
#  '죄송합니다 오늘 다시 한번 상황을 자세히 말씀해주시면 감사하겠습니다 감사합니다',
#  '항상 맛있고 든든한 한 끼 식사를 위해 노력하는 저희 식당에 항상 응원과 격려가 필요합니다.',
#  "항상 좋은 제품을 찾아 고객 만족도를 높여 나가는 일등 커피 전문점 '더 착한 커피'가 되기 위해 노력하겠습니다.",
#  '소중한 후기 덕분에 더 좋은 식사 시간이 될 것 같은데요 오늘도 행복한 하루 되세요.',
#  '앗 고객님께 뭐라도 더 많이 알려 드리고 싶은 마음에 좀 과하게 했나봐요 담에는 더 맛있는 맛으로 찾아 뵐게요',
#  '더 좋은 요리 만들어 낼 수 있도록 최선을 다해 노력하겠습니다. 오늘도 좋은 하루 되세요.',
#  '담에는 경양식 돈가스 드시는 것을 추천드려요 특히 단무지 같은 반찬은 입맛에 따라 달라질 수 있어요.',
#  '자연산 고기에서 낙시바늘을 저희가 못보고 매운탕에 넣은거같습니다 다시한번 죄송합니다 앞으로는 한번더 확인해서 이런일이 없도록 신경쓰겠습니다',
#  '시민들의 성원에 힘입어 맛있는 감자탕과 시원한 국물이 기다리고 있는 여름밤을 지새우겠습니다.',
#  '혹시나 다음에 또 주문하실 때는 메모 남겨주세요 사진에 불족 고기가 너무 적게 들어 있으면 제가 바로 잡아주겠습니다.',
#  '시민 족발 보쌈 감자탕은 매일 삶아 먹는 재료만으로 정성을 다해 요리하고 있습니다 더 맛있는 요리로 보답하겠습니다요.',
#  '우선 제가 직접 와이프에게 전화로 주문 확인 후 바로 취소 전화를 드렸구요 그런데 얼마 지나지 않아 또 한 분이 다른 동으로 배달이 됐고 그래서 그 음식을 그 근처에 사는 친구에게 다시 전달해 드렸구요.',
#  '맛있게 드셨다는데 포장을 하나만 해 주셔서 제가 다시 한번 감사드립니다. 다음에 또 맛있는 요리로 찾아오겠습니다.',
#  '이용해 주셔서 대단히 감사합니다.',
#  '음식하시는 데 불편을 드려 대단히 죄송합니다 음식 드시기가 불편하시면 주방에 전달토록 하겠습니다.',
#  '두툼하게 썰려서 아마도 다음에도 많이 이용해 주실 것 같습니다 다음으로도 이용해주시면 만족시켜드리겠습니다',
#  '저희 1988응답하라추억의옛날식대는 항상 양을 줄이시고 부족한 점은 채워 넣어 가면서 만들겠습니다.',
#  '맛있는 음식으로 항상 고객을 감동시키는 1988년 응답하라 추억의 옛날 간식을 소개합니다.',
#  '가족에게 든든한 한 끼 식사를 선물하고 싶다면 1988응답하라추억의옛날도시락을 찾아주세요.',
#  '이렇게 좋은 자리를 마련해 주신 여러분께 감사의 마음을 전하며 더 좋은 요리와 서비스로 찾아 뵙겠습니다.',
#  '저희 1988응답하라추억의옛날도시락은 맛있게 드실 수 있도록 재료와 조리 과정을 정성스럽게 준비했습니다.',
#  '항상 손님들이 저희 가게를 찾아와 주셔서 감사합니다 덕분에 더 좋은 자리를 마련할 수 있었어요 감사합니다',
#  '저희 1988응답하라추억의옛날도시락은 맛이 없는 음식은 안 드리려고 노력하고 있어요 맛있게 드실 수 있게 최선을 다해 노력하겠습니다.',
#  '저희를 발전하게 해주신 많은 분들께 감사의 말씀 드립니다.',
#  '저희 1988응답하라추억의옛날도시락이 다음에도 고객만족도를 위해 최선을 다해 노력하겠습니다.',
#  '저희는 식품 안전을 위해 제조 과정에서 소금을 사용하지 않습니다 고객님 감사합니다 연세우유 생우유를 사용합니다 프리미엄 제조법으로 우유에 설탕을 넣지 않습니다',
#  '저희 워커스를 맛있게 먹어 주셔서 감사합니다 추운 겨울 감기 조심하세요',
#  '맛있는 요리 만들어 주셔서 감사합니다. 기대만큼 좋지 않은 평가에도 불구하고 맛있게 먹어 주셔서 고맙습니다.',
#  '저희 음료와 디저트로 행복한 시간 보내셨길 바라며 항상 건강에 유의하시기 바랍니다.',
#  '조금 식어서 왔어요 안녕하세요 잠시만 식고 가는 일이 있어서 대단히 죄송합니다.',
#  '고객님 입맛에 맞으면 정말 저도 기분 좋고 행복한데 특히 저희 엄마가 맛없다는 말을 많이 하시는데 맛있는 하루 되세요.',
#  '제 의지로 일부러 늦게 가는것도 아니고 빨리 가는 것도 아닌데 왜 이렇게 오래 걸리나 하면 단건배달 이용해 주세요.',
#  '저는 개인적으로 좋아하지 않아서 메뉴에 추가할지 말지를 고민 많이 했는데 후회하게 만들 정도로 고구마무스를 좋아 하시는 분들이 많이 계십니다',
#  '요즘 배달의 민족이 증가함에 따라 제 나름대로 최선을 다해 배달하고 있음에도 불구하고 배달 만족도가 예전만 못 미치니 배달부들이 매우 불만스러워했다.',
#  '순한맛 순한맛 두 종류 샀는데 매운거 못드시는 분들도 중간맛 하나만 드셔도 괜찮을 것 같아요.',
#  '중간 맛으로 잘못 넣은 소스가 아마도 지점에서 판매하는 소스를 사용한 것 같습니다 죄송합니다 맛을 아시는 분은 아시겠지만요',
#  '어묵 크기도 크고 어묵도 부드러워서 어른 아이 할 것 없이 좋아할 만하지만 가격이 좀 더 나가요.',
#  '맛점수는 3점을 주셨는데 또 주문하신다고 하니 또 먹겠다는 연락은 받았지만 감사의 뜻으로 생각하겠습니다.',
#  '지금 치킨이 먹고 싶다면 헬리오시티점에 방문해 주세요 여러분의 성원에 힘입어 더욱 맛있는 요리로 찾아 뵙겠습니다.',
#  '지금 치킨이 먹고 싶다면 헬리오시티에 있는 뉴욕레드크림치즈를 방문해 주세요 :) 매운 양념과 담백한 치즈의 조합이 너무 잘 어우러지는 이곳의 맛을 느껴보세요.',
#  '이번에 서울시에서 환경을 생각한다는 취지로 실시한 제로 웨이스트 캠페인에 참여해 주신 분들께 감사의 말씀을 드립니다.',
#  '저희 우시장 국밥은 항상 좋은 맛과 좋은 서비스를 위해 노력하는 곳이니 만큼 앞으로도 잘 부탁드립니다.',
#  '저희 우시장 국밥을 많이 사랑해 주시면 감사하겠습니다. 감사합니다.',
#  '저희 우시장 국밥은 고객님이 주문해 주시면 그 자리에서 바로 끓여서 내 보내드리고 있어요 항상 최선을 다해 준비하는 모습 보여드릴게요.',
#  '저희 우시장 국밥은 믿고 먹을 수 있는 만큼 최선을 다해 노력하는 만큼 앞으로도 좋은 맛과 좋은 서비스로 찾아 뵙겠습니다.',
#  '저희 우시장 국밥은 항상 한결같은 맛과 좋은 서비스를 위해 노력하는 곳이니 만큼 맛있게 먹어 주시면 감사하겠습니다.',
#  '저희는 항상 최선을 다해 요리할 것을 약속드립니다.',
#  '많은 고객님께 만족감을 드리려고 연구하고 노력하고 있는데 아직 많이 부족한 것 같습니다 시간내시어 남겨주신 말씀은 모두 유의하고 더욱더 신경을 드리겠습니다.',
#  '항상 좋은 말씀 감사드립니다. 앞으로도 좋은 요리 만들어 보겠습니다.',
#  '항상 최선을 다해 요리해 드리고 있으니 혹 음식이 남긴 것이 있으면 언제든 문의해 주세요.',
#  '춘리마라탕은 항상 좋은 맛으로 보답하는 곳이니 앞으로도 많은 사랑 부탁드립니다.',
#  '춘리 마라탕은 항상 좋은 맛을 내 가족의 입맛을 사로잡는 훌륭한 음식으로 기억될 것입니다 감사합니다.',
#  '가족식사 준비하는 마음으로 항상 신선한 재료로 정성을 다해 요리하겠습니다 믿고 먹는 김천재 앞으로도 많이 사랑해주세요 감사합니다',
#  '항상 위생에 철저한 관리를 위해 노력하고 있는 만큼 더 좋은 요리로 찾아 뵙겠습니다.',
#  '고객님들이 저희 매장을 자주 방문해 주시면 더 좋은 요리를 만들어 드릴 수 있는 것처럼 최선을 다해 노력하겠습니다.',
#  '이용해 주셔서 감사드립니다 다음에도 또 이용해 주세요 :) 항상 좋은 제품으로 보답하는 무국적식탁이 되도록 노력하겠습니다.',
#  '저희 매장을 방문해 주신 고객님께 감사의 뜻을 전하고 앞으로 더 좋은 요리와 서비스로 찾아 뵙겠습니다.',
#  '이렇게 맛있는 만다린을 제공해 주셔서 감사합니다 맛있게 드실 수 있도록 더 노력하겠습니다 다음에도 좋은 요리로 찾아 뵐게요.',
#  '저희 만다린에 주문해 주셔서 감사합니다 다음에 또 주문할 때는 꼭 5점 만점에 5점을 드리고 싶네요.',
#  '저희는 자체적으로 배달을 하지 않기 때문에 배달 기사님들이 가끔 배달 문제가 생기면 저희가 대신 해결합니다 말씀 감사합니다',
#  '네 잘 알아 보겠습니다 감사합니다 잘 보겠습니다 잘 봤습니다 감사합니다',
#  '안녕하세요 감사합니다 건강하세요 정말 감사합니다',
#  '더맛있는 요리로 찾아 뵐게요 감사합니다.',
#  '항상 든든한 한끼를 찾고 계신 분이라면 배달의 민족 송파점을 방문해 주시면 좋겠습니다.',
#  '항상 푸짐한 양과 좋은 맛으로 보답하는 배달의 민족 배달의민족 송파점이 더 맛있게 먹고 건강해질 수 있게 더 노력하겠습니다.',
#  '언제나 맛있고 든든한 한끼 식사를 제공하고 계신 배달의 민족 송파점이 응원합니다.',
#  '항상 맛있는 음식과 신속한 배달로 항상 고객님들의 마음을 사로잡는 배달의 민족 송파점이 되기를 바랍니다.',
#  '매장을 지난 3년간 운영하면서 느낀 점은 항상 고객님께 감사드리는 마음뿐이라는 것이었습니다.',
#  '저희 닭강점을 방문해 주셔서 감사합니다 이렇게 좋은 후기를 써 주셔서 정말 감사합니다.',
#  '저희 닭강점을 방문해 주신 여러분께 감사의 인사를 드립니다.',
#  '맛있는 요리로 또 찾아 뵐게요 감사합니다.',
#  '더욱 사랑받는 음식이 되도록 더욱 노력하겠습니다 많은 관심과 주문 부탁드립니다.',
#  '매일 손수 삶고 있으며 생물이다 보니 약간 품질의 차이가 있을 수 있지만 최대한 검수하고 조리에 최선을 다하겠습니다.',
#  '저희 가게 계절 메뉴로 굴이 준비되어 있으니 주문하시면 별도로 초장을 준비해 드리겠습니다.',
#  '항상 성원해주시는 고객님을 위해 배달 장소까지 거리가 멀면 25~35분 정도 배달이 가능하도록 하겠습니다.',
#  '고객님의 후기와 사진은 저희에게 힘이 될 것이고 더 좋은 요리와 서비스를 위해 항상 노력하겠습니다.',
#  '혼자 드시기엔 1인분이 조금 넘는 양이지만 배달은 멀지 않은 곳에 위치해 있으니 배달 후 식기가 끝나기 전에 드시면 좋고요.',
#  '고객님의 요청이 있을 시 저희가 항상 준비해서 보내 드리고 있는데 시간이 조금만 늦더라도 양해를 부탁드립니다.',
#  '음식은 주문이 들어오는 즉시 조리하여 나가기 때문에 더욱 맛있습니다 배달은 근거리 배달로 25 35분 사이에 가능합니다 다음 주문시 더욱 좋은 서비스로 보답하겠습니다.',
#  '채소는 가락시장에서 직접 검수 후 세척 포장하여 더욱 신선하고 종류도 다양합니다 고객님이 남긴 후기를 저희가 다시 확인해 보겠습니다 감사합니다',
#  '고객님이 남긴 후기와 사진은 저희에게 힘이 될 뿐 아니라 다음에 또 맛있는 요리로 찾아 뵙겠습니다.',
#  '담 번에도 더 좋은 서비스로 찾아 뵙겠습니다.',
#  '배달은 근거리 배달로 25~35분 사이에 가능합니다 맛을 위해 하나하나의 정성을 다하는 족발보쌈전문입니다 다음 주문시 더욱더 좋은 서비스로 보답하겠습니다 감사합니다',
#  '항상 성원해주시는 만큼 더 좋은 요리와 서비스로 보답하겠습니다.',
#  "최고의 맛을 위해 매일 2시간 이상의 고온에서 삶은 후 껍질을 제거하고 마지막으로 달인 간장을 넣어 만든 '간장 비빔밥'을 여러분께 소개해 드리고 있습니다.",
#  '자주 주문해 주시는 것 같아 감사한데 이번에 또 이런 일이 생겨서 상품을 매일 점검하고 판매하는데 차질이 생겼다면 죄송합니다 다음에도 또 좋은 제품으로 찾아 뵙겠습니다',
#  '항상 감사드립니다 오늘도 행복한 하루 되세요 지금까지 2번이나 누락을 당하셨었어요 매장으로 전화주시면 빠른 처리가 가능합니다.',
#  '저희는 항상 신선한 재료를 사용해서 요리를 하기 때문에 샐러드가 항상 부족하거나 부족하면 고객님께 바로 전화드릴 수 있어 좋습니다.',
#  '오늘 하루도 행복하고 행복한 일이 가득하시길 기원하면서 다음에 또 맛있는 요리로 찾아 뵐게요.',
#  '잠실역과 석촌역 사이에 있는 매장에 방문하시면 넓은 매장에서 편안하게 티타임을 즐길 수 있고 맛있는 빵과 커피를 만나볼 수 있는 것은 바로 이런 이유 때문입니다.',
#  '소중한 주문 감사드립니다 잠실역과 석촌역 사이에 있는 매장에 오심 넓은 매장에서 편안하게 티타임 즐기실수 있으세요 다음에도 맛있는 빵과 커피로 보답하겠습니다',
#  '소중한 주문 감사드립니다 잠실역과 석촌역 사이에 있는 매장에 방문하시면 넓은 매장에서 편안하게 티타임을 즐길 수 있으며 가격의 압박 역시 받으시길 바랍니다.',
#  '소금빵을 살짝 데치시면 천국의 문이 열릴 것 같은데요 고객님 잠실역과 석촌역 사이에 있는 매장에 오심 넓은 매장에서 편안하게 티타임을 즐길 수 있습니다니다.',
#  '고객님 잠실역과 석촌역 사이에 있는 매장에 오심 넓은 매장에서 편안하게 티타임 즐기실수 있으세요 다음에도 맛있는 빵과 커피로 보답하겠습니다.',
#  '고객님께 최선을 다해 커피와 빵을 만들어 드리도록 하겠습니다. 잠실역과 석촌역 사이에 있는 매장에서 편안하게 커피를 마시는 것도 좋을 것 같습니다.',
#  '저희 플러스82가 더 나은 서비스를 제공하기 위해서 더 많은 노력을 기울이고 또 노력하겠습니다.',
#  '식사 중 불편을 드려 대단히 죄송합니다 소스가 혹시 스파이시 마요르로 잘못 전달드린것같습니다 다음에 이런일이있으시면 매장으로 연락주시면 바로 조치해드리겠습니다',
#  '양이 부족하셨나 봅니다 다음에는 요청사항에 양좀 많이라고 남겨주시면 더욱더 많이 전달드리도록 하겠습니다 감사합니다',
#  '여름철 음식 관리에 더욱 주의를 기울여야 할 것이 사실인데 그러지 못해 미안합니다 맛있는 샐러드 만들어서 여름동안 잘 먹었습니다.',
#  '우선 식사 중 불편을 드려 대단히 죄송합니다 다음엔 배달사고 없이 전달해 드리도록 하겠습니다 감사합니다.',
#  '마침 호박씨를 너무 많이 넣으셔서 이렇게 된 것 같은데 양을 조절 잘 하시면 맛있는 샐러드로 만들어 드실 수 있습니다.',
#  '전달하는 과정에서 실수가 있었나 봅니다 고기랑 소스까지 너무 죄송합니다 다음에는 고기 뿐만 아니라 누락없이 전달 드리도록 하겠습니다 감사합니다',
#  '맛있는 샐러드 전달해 주셔서 감사합니다 앞으로도 자주 이용할게요 :)',
#  '다음에도 좋은 요리 만들어 더 많이 만들어 주세요 맛있는 샐러드 더 맛있게 만들어 보겠습니다.',
#  '다음에도 맛있는 샐러드 제공해주시면 항상 감사하겠습니다.',
#  '항상 신선한 재료를 사용하여 최선을 다해 노력하는 회사가 되기를 진심으로 바랍니다 맛있게 먹어 주셔서 감사합니다',
#  '많은 가게들 중에 저희 매장을 찾아와 주셔서 감사합니다 손님의 선택에 최선을 다하겠습니다 고객님 좋은 하루 되세요 상단에 찜을 눌러주시면 감사하겠습니다',
#  '고객님 소중한 주문과 후기 너무 감사드립니다 항상 최선을 다해 노력하겠습니다 저희 매장을 이용해 주셔서 고맙습니다',
#  '손님이 많고 많은 가게 중 저희를 선택해 주셔서 정말 감사합니다 감사한 마음 잊지 않고 항상 맛있고 좋은 음식으로 보답하겠습니다.',
#  '저희 매장을 방문해 주신 고객님께 감사의 마음을 전하며 더 좋은 요리와 서비스로 보답하겠습니다.',
#  '항상 고객만족을 위해 노력하는 잭아저씨 족발보쌈을 많이 사랑해 주세요.',
#  '항상 건강하고 행복한 나날들이 되시길 기원합니다. 잭아저씨 족발보쌈을 찾아주신 여러분께 감사드립니다.',
#  '맛있는 요리와 푸짐한 양으로 항상 행복한 밥상을 준비하는 홈플러스가 되도록 최선을 다해 노력하겠습니다.',
#  '항상 맛있게 먹어주시는 고객님을 위해 최선을 다해 요리하겠습니다 내일도 맛있는 요리로 찾아 뵙겠습니다.',
#  '추가적으로 궁금하신 사항은 매장으로 전화 주시면 안내해 드리겠습니다.',
#  '항상 고객님들께 감사의 마음을 전하며 맛있는 음식을 만들어 드리는 갈비민족이 되기를 기원합니다.',
#  '항상 고객님들께 감사의 마음을 전하며 맛있는 음식을 만들어 드리는 갈비민족이 되기를 기원합니다.',
#  '항상 고객님들 주문 하나하나에 정성을 다해 요리하겠습니다 믿고 드실 수 있는 갈비민족 많이 사랑해 주세요',
#  '항상 맛있는 갈비민족을 기억해주시고 궁금하신 점이 있으면 전화 혹은 홈페이지(blutouch.kangnam.ac.kr)로 문의하시면 됩니다.',
#  '항상 고객님들께 감사의 마음을 전하며 맛있는 음식을 만들어 드리는 갈비민족이 되기를 기원합니다.',
#  '항상 고객님들께 감사의 마음을 전하며 맛있는 음식을 만들어 드리는 갈비민족이 되기를 기원합니다.',
#  '항상 고객님들께 감사의 마음을 전하며 맛있는 음식을 만들어 드리는 갈비민족이 되기를 기원합니다.',
#  '항상 고객님들께 감사의 마음을 전하며 맛있는 음식을 만들어 드리는 갈비민족이 되기를 기원합니다.',
#  '항상 고객님들께 감사의 마음을 전하며 맛있는 음식을 만들어 드리는 갈비민족이 되기를 기원합니다.',
#  '왕빈자 삼파전을 찾아주신 우리 고객님 감사합니다. 다음에도 더 좋은 요리로 찾아 뵐게요.',
#  '고객님 믿고 주문해주셨는데 불편을 드려 대단히 죄송합니다 앞으로도 더욱 발전하는 왕빈자 삼파전이 되도록 노력하겠습니다 감사합니다',
#  '맛있는 왕빈자 삼파전을 드시기 위해 방문해 주신 우리 고객님께 감사의 뜻을 전하고 더욱 좋은 요리로 찾아 뵐게요.',
#  '왕빈자 삼파전을 맛있게 먹어 주신 고객님께 감사의 뜻을 전하고 더 좋은 서비스를 위해 노력하겠습니다.',
#  '신속하고 안전한 배달을 위해 최선을 다해 노력하는 한편 시간이 부족할 경우 대처를 더 빨리 할 것을 바랍니다.',
#  '좋은 느낌이 들게 해주신 것 같아 작은 마음 작은 글씨로 감사의 마음을 전하고 있습니다 다시 만나 뵙게 되면 좋겠습니다.',
#  '좋은 맛과 안전한 배달을 위해 최선을 다해 노력하는데 배달 사고가 발생해 저희도 마음이 매우 아프네요 더 많은 분들을 위해 노력하겠습니다.',
#  '더 좋은 맛과 좋은 서비스로 더 많은 분들께 찾아 뵙도록 노력하겠습니다.',
#  '최선을 다해 요리하는데 그 과정에서 그런 심려를 끼쳐 드려 사과 드립니다.',
#  '항상 좋은 맛과 서비스를 위해 노력하겠습니다.',
#  '맛있는 파스타를 위해 오늘도 최선을 다하겠습니다. 감사합니다.',
#  '우선 맛을 기대하신 분들에게 실망을 드려 사과 말씀 드립니다 해물믹스를 사용하는데 모두 골고루 넣지 않은 것 같습니다 그럼 오늘도 맛있는 요리로 찾아 뵙도록 하겠습니다.',
#  '맛있는 파스타를 위해 직원들이 더욱 열심히 일하고 더 좋은 요리로 함께 만들어 보도록 하겠습니다.',
#  '우선 고객님의 식사에 불편을 드려 대단히 죄송합니다 다음에도 더 좋은 요리로 찾아 뵐게요 감사합니다.',
#  '오늘 하루도 감사했던 분들과 더 맛있는 요리를 만들어 보겠습니다.',
#  '맛있는 요리 소개해주신 분들께 감사의 마음을 전하며 더 좋은 요리와 서비스로 찾아 뵙겠습니다.',
#  '창업한 지 7년 만에 제육볶음을 너무 맛있게 먹어서 다시 한번 고객님께 감사의 마음을 전하고 싶어서 생강의 모든 반찬에 정성을 다해 요리하겠습니다.',
#  '우선 고기와 밥, 국 등의 가격이 오른 것은 사실이지만 저희가 공급하는 곳이 대기업이 아닌 만큼 공급사측이 책임을 지는 방식으로 원가를 관리하고 있습니다.',
#  '저희 항정살 맛있게 잘 먹었다고 내일 인사해야지 얼마나 더 먹고 싶었으면 그러겠어요',
#  '저희 삼겹살이 이렇게 맛있게 잘 먹었다고 이렇게 좋은 평가를 해 주시면 감사하겠습니다.',
#  '저희 삼겹살이 좀 작긴 했지만 맛있게 잘 먹었다고 내일 인사드립니다.',
#  '저희가 좀 더 주의를 기울이고 있을 때 더 잘 챙겨 드릴 수 있기를 바라마지 않습니다 저희가 약간 더 조심스럽게 다뤘거든요.',
#  '항상 최선을 다하려고 노력하는 만큼 더 좋은 요리를 만들어 보답하겠습니다. 더위에 지친 몸과 마음을 쉬게 해 드리고 더 노력하겠습니다.',
#  '특히 항정살은 기름기가 많은 음식이라 쌈 싸 드실 때 꼭 필수한 음식인데 제가 빠뜨렸군요 다음에 또 주문할 땐 꼭 빼 주세요',
#  '부쩍 더워진 날씨에 건강 유의하시고 즐겁고 행복한 주말 되시기 바랍니다.',
#  '환절기에 건강 잘 지키시고 오늘도 행복한 하루 되세요 저희 항정살 맛있게 잘 먹었다고 이렇게 상세한 후기와 더불어 저희에게 큰 힘이 되는 좋은 평가도 해 주시면 감사하겠습니다.',
#  '이렇게 좋은 글 써 주셔서 감사합니다 추운 날씨에 건강 잘 지키시고 저희 삼겹살과 항정살 맛있게 잘 먹었습니다.',
#  '저희 메뉴 중 고기만 있는 것은 가격대비 고기로 충실히 드릴려고 하는 것이니 오해하시면 안 되며 기본 간은 소금이나 씨간장으로 맞추시고 입맛에 맞게 소스를 추가하셔도 됩니다',
#  '잘 먹어야 청춘이다 o o 청 춘 식 당 항상 한결같은 맛으로 최선을 다합니다 언제든지 김치찜 생각나시면 또 들려주세요 깔끔하고 맛있게 드셨다',
#  '잘 먹어야 청춘이다 o o 청 춘 식 당 자 이제 잘 먹었다고 별 5개 평가 받을 수 있도록 더 열심히 노력하겠습니다.',
#  '저희 매장은 홀 형태의 가게로 돼지고기를 전문적으로 판매하는 곳인데 손님이 방문하시면 저희가 직접 요리해 드리고 있습니다.',
#  '저희 막창은 지방에서 나는 신선한 재료를 사용해 만들어 더욱 담백하고 쫄깃한 맛을 자랑하는데 고객님들이 자주 찾아주시는 덕분에 더 맛있게 드실 수 있어요.',
#  '저희 음식이 입맛에 맞았다니 정말 다행이고 감사합니다 삽교원조두리곱창은 항상 당일 납품받는 재료로 최고의 신선도를 유지해 고객의 요청이 있을 때 최선을 다해 돕겠습니다.',
#  '항상 당일 납품받는 재료로 최고의 신선도를 유지하여 맛있는 요리를 제공하는 삽교원조두리곱창을 찾아주셔서 감사합니다.',
#  '저희 음식이 입맛에 맞으셨다니 정말 다행이고 감사합니다 항상 당일 납품받는 재료로 최고의 신선도를 유지하여 맛있는 음식을 대접하겠습니다.',
#  '삽교원조두리곱창은 언제나 손님들에게 좋은 밥상을 제공하기 위해 노력하고 있는 곳으로 맛도 영양도 최고인 맛있는 요리를 제공하고 있습니다.',
#  '항상 고객님께 감사의 마음을 전하고 있는 삽교원조두리곱창은 바쁜 일상 속에서도 맛있는 요리로 위로를 드리고 있습니다.',
#  '저희 삽교원조두리곱창은 항상 그날 납품받는 재료로 최고의 신선도를 유지하며 고객님의 요청이 있을 때 최선을 다해 돕겠습니다.',
#  '항상 당일 납품받는 재료로 최고의 신선도를 유지하며 고객님의 입맛에 맞는 맛있는 요리를 만들어 드리는 삽교원조두리곱창에 감사드립니다.',
#  '삽교원조두리곱창은 고객님의 성원에 힘입어 항상 새로운 요리를 선보이면서도 항상 웃는 모습을 보여드리고 있어요.',
#  '북서울꿈의숲점 이 최고 영암군에서 재배한 국산 쌀만을 사용하여 최고의 밥맛을 자랑하며 고객님께 항상 감사의 마음을 전하는 곳으로 거듭나기 위해 노력하겠습니다.',
#  '북서울꿈의숲점 이 최고 영암군에서 난 좋은 품질의 국산 쌀을 사용하여 정직한 가격으로 판매하고 있으며 고객의 요청이 있을 경우 즉각 대응하여 철저한 고객 서비스를 제공하고 있다.',
#  '양의 관련된 부분은 저희가 정한 정량을 지켜서 다음에는 오징어 한번 먹어보겠습니다 양이 정말 많은데 다 못 드시고 가신 건 아니시죠?',
#  '저희가 가지고 있는 무뼈닭발을 전국 각지에서 소비자들에게 돌려 드리고 있는데 배달 업체가 파업을 하는 바람에 남은 양이 상대적으로 적은 것으로 느껴지셨다는 분들도 계십니다.',
#  '항상 맛있는음식 빠르게 전달해드릴수있도록 노력하겠습니다 주말 잘보내셨어요?',
#  '맛있는 요리와 건강한 재료로 항상 행복한 밥상을 차려 드리고 계신 고객님께 감사의 뜻을 전하며 더욱 건강하고 맛있는 요리로 보답하겠습니다.',
#  '추운 날씨에 감기 조심하시고 파이팅 하세요 주문 감사합니다 빠른 시일안에 사진작업을 완료하도록 하겠습니다 감사합니다',
#  '추운 날씨에 몸 조심하시고요 이번 한 주도 열심히 만들어 보겠습니다 주문해 주신 분들 감사합니다 앞으로도 좋은 요리 부탁드립니다.',
#  '항상 찾아 주셔서 감사합니다 오늘은 고객님이 너무 많이 찾았는데 시간이 부족했네요 다음에는 꼭 시간을 같이 해 주실거죠?',
#  '항상 고객님의 기대와 믿음에 부응하는 매장이 되기 위해 더욱 노력하고 노력하겠습니다.',
#  '저희 오돌뼈가 조금 아쉬웠어요 다음에는 더 맛있는 요리로 찾아 뵐게요 감사합니다.',
#  '항상 최선을 다하는 김포불닭발이 되도록 노력하겠습니다.',
#  '김포불닭발을 더욱 맛있게 만들기 위해 더 많은 노력을 기울이겠습니다.',
#  '더 노력하는 김포불 닭발이 되도록 노력하겠습니다. 맛있게 먹어 주셔서 감사합니다.',
#  '통에 넣는 야채를 빼라고 하신 건가요 아니면 바로 전화 드려서 준비해 드린 것인데 번거롭게 해드려 죄송합니다.',
#  '죄송해요 여러분 덕분에 맛있게 잘 먹었습니다 다음에도 또 부탁드릴게요 감기 조심하시구요',
#  '맛있는 요리 만들어 주셔서 감사합니다. 맛있게 먹어 줘서 또 고맙습니다.',
#  '무더운 여름 건강 유의 하시고 더 맛있게 드실 수 있게 더 노력 하겠습니다.',
#  '순한맛으로 해 달라고 하셔서 더 열심히 해 볼게요 감사합니다.',
#  '더 노력하는 김포불 닭이 되도록 더욱 노력하겠습니다 소중한 후기 써 주셔서 감사합니다.',
#  '더 노력해서 소중한 평가를 받아 드릴 수 있도록 최선을 다해 노력하겠습니다.',
#  '맛있게 먹어 주셔서 감사합니다 더 좋은 요리 만들어 보겠습니다 감사합니다',
#  '다시 주문할 때는 꼭 요청란에 남길게요 맛있는 요리 만들어 주셔서 감사합니다.',
#  '맛있는 요리 많이 만들어 주셔서 감사합니다 새해 복 많이 받으시려면 더 좋은 요리 만들어 주세요',
#  '다시 주문할 때는 조금 더 신경 써 주세요 소중한 후기 잘 써 볼게요.',
#  '더 열심히 노력 하겠습니다 소중한 글 써 주셔서 감사합니다 더 좋은 결과로 보답 드리겠습니다 감사합니다',
#  '전체적으로 다 괜찮았지만 조금 더 주의를 기울이고 계신 것은 배달이 좀 더 빨리 됐으면 좋겠어서입니다.',
#  '저희가 약간 매운 편인데 많이 맵지는 않아요 그래도 맛있게 잘 먹었다고 내일 인사해야지',
#  '푸짐한 한상차림의 커플세트 너무 잘 먹었어요 내일 또 만나요 여러분~',
#  '아 맛있어 보이는 닭고기 요리를 위해 더 노력하겠습니다 감사합니다.',
#  '고객님의 소중한 시간 동안 맛있는 식사 만들어 주셔서 감사합니다 항상 더 좋은 요리와 요리로 찾아 뵙겠습니다.',
#  '짠맛 나는 재료가 몇 가지 들어가는데 맛이 변할까봐 손을 못 대고 있습니다 소스 양을 줄여야 할까요 감사합니다',
#  '잘 먹었습니다 감사합니다 마저 먹지 않고 남긴 것을 어찌 사진으로 대신하겠습니까 맛있게 잘 먹었습니다',
#  '저희는 최선을 다해 고객님들께 맛있는 요리를 해 드릴 것을 약속하고 7월 한 달 동안 행복한 일만 가득하길 기원합니다.',
#  '항상 초심을 잃지 않고 재료에 대한 정직함으로 최선을 다하는 승도리네 곱도리탕 김포풍무점이 되기를 진심으로 바랍니다.',
#  '조금만 더 생각을 자세히 해 주시면 고객님이 불편함이 없도록 요리해 드릴 수 있을 것 같습니다.',
#  '항상 최선을 다해 요리하겠습니다 고객님 주문 너무 감사드립니다 감사합니다',
#  '저희 매장을 사랑해주시고 찾아주시는 고객님께 감사의 마음을 전하며 더 좋은 요리와 서비스로 보답하겠습니다.',
#  '더 좋은 맛을 내기 위해 노력하는 만큼 단골손님의 소중한 의견을 반영하겠습니다.',
#  '저런 김치가 저 안에 하나도 안 들어 있어서 아쉬움이 많이 남으셨네요 다음에 요청할 때 이런 내용을 좀 넣어 주세요 감사합니다.',
#  '잘 먹었다고 내일 인사해야지 음식 양을 좀 줄이던가 좀 더 신경써 주세요 새해 복 많이 받으시고요',
#  '저희가 더 연구하고 노력해서 다 같이 행복할 수 있는 사회가 되면 좋겠습니다.',
#  '나의 인생곱창 나인곱창입니다 고객님의 행복한 시간에 함께 할 수 있어서 감사드립니다 양이 적게 느껴지셨어도 정량이나 조금더 드리는 것이 감사하겠습니다.',
#  '가족이 먹는 음식인 만큼 정성을 다해 요리하고 가족 모두가 만족할 수 있는 요리를 만들어 보겠습니다 내일 또 찾아 뵐게요 감사합니다',
#  '다음 주문시에는 전부 만족하고 드실수 있도록 더욱더 신경써서 배달 잘해 드리겠습니다 다음',
#  '요즘 날씨가 더 추워졌기 때문에 밖에 나갈 일이 없어졌는데 이럴 때는 집에 있는 냉동실에 있던 핫팩으로 대체하고 있습니다.',
#  '더 맛있게 만들어 주시면 더 감사하겠습니다 다음에 또 맛있는 요리로 찾아 뵐게요.',
#  '고객님 먼저 감사의 말씀을 드립니다 다음 번에도 이런 실수를 반복하지 않도록 더 노력하겠습니다.',
#  '이런 충무김밥과 오징어 어묵무침이 맛이 없을 수도 있는데 고객님께 양해를 구할 수 없어 죄송합니다 다음에는 더 맛있게 해 드릴 것을 약속하겠습니다.',
#  '맛있는 돈가스를 위해 항상 노력하는 돈가스회관(김포장기점)이 될 수 있도록 하겠습니다.',
#  '저희가 급하게 메뉴를 수정해서 올려드리는 바람에 다른 메뉴는 못 보시고 등심돈가스 세트 메뉴만 보게 돼서 죄송합니다.',
#  '이용에 불편을 드려 대단히 죄송합니다 다음부터는 이런일이 없도록 배달 업체와 의견소통 하도록 하겠습니다 만일 배달 물품중 파손되거나 잘못된 제품이 있으면 연락 주시면 다시 보내드리도록 하겠습니다',
#  '제료를 준비하는 데 더욱 힘을 쏟겠습니다 이용에 불편을 드려 사과 드립니다.',
#  '이용해 주셔서 감사합니다 고객님 의견 감사드립니다 가격이 저렴한 제주도산 3kg이상 대광어만을 사용합니다 좋은 재료와 좋은 요리로 만나 뵐 수 있는 기회였습니다',
#  '호랑이초밥을 이용해 주셔서 감사합니다 별점 평가 부탁드립니다.',
#  '항상 행복하고 건강한 밥상을 위해 노력하겠습니다. 더 좋은 요리와 맛있는 요리 만들어 보겠습니다.',
#  '아쉬움에도 불구하고 맛있게 먹어 주셔서 감사합니다. 부족한 부분은 더 열심히 만들어 보겠습니다.',
#  '우리 고객님 가족분들 모두 건강하시고 늘 행복하시기를 기원합니다.',
#  '고객님 소중한 시간 내어 맛있는 재료와 건강한 맛으로 보답하는 피자이탈리 운양점이 되도록 노력하겠습니다.',
#  '죄송합니다 고객님 죄송합니다 다음 번 주문시에는 메뉴안내를 하기가 어려워서 할라피뇨가 들어가는 매콤한 피자표시를 하지 못했습니다 죄송합니다',
#  '매장으로 전화주시면 소스건은 바로 처리해 드릴 것이며 고객님이 맛있게 먹어 주셔서 정말 감사드립니다.',
#  '고객님 죄송합니다 제가 댓글 확인을 늦게 해서 죄송합니다 다음에 또 기회가 있으면 부탁드릴게요 031 구구팔 일이오육',
#  '맛있게 잘 먹었다고 내일 저녁 인사드리는 건 어때요 여러분?',
#  '항상 신선한 과일과 디저트를 제공해 드리고 항상 노력하는 쇼핑몰이 되도록 노력하겠습니다.',
#  '많이 많이 사랑해주시고 감사합니다 덕분에 좋은 평가 감사합니다.',
#  '고객님들의 입맛이 다 달라서 너무 어려운 메뉴인 가오리무침 다음에 주문하실땐 요청사항에 새콤하게 혹은 달달하게 이렇게 요청하시면 간을 맞춰 보내드릴게요.',
#  '주류는 저희가 잘못한 부분이 맞지만 고객님으로 기억하고 추후에 더 잘 챙겨 드릴 테니 걱정 붙들어 매세요.',
#  '만족도가 어느 정도인지 말씀해 주시면 감사하겠습니다. 다음에는 더 좋은 제품으로 찾아 뵙겠습니다.',
#  '우족탕은 직접 끓여서 먹기도 하지만 도가니탕은 손수 끓이는 거니까 더 많이 만들어 주세요 감사합니다.',
#  '잘 먹었다고 내일 인사해야지 저도 이제 맛있는 요리 해 줄게요 그럼 내일 또 만나요',
#  '다음에도 또 주문할게요 다들 감기 조심하시구요 감사합니다.',
#  '주소가 특이해서 다음에 또 주문할게요 다음에도 많이 이용할게요 감사합니다',
#  '좋은하루되세요 오늘 고마웠습니다 고맙습니다 좋은',
#  '늦은밤 행복한 시간 되세요 감사합니다 이렇게 좋은 제품 만들어 주셔서 고맙습니다',
#  '네 감사합니다 확인 잘 하겠습니다 감사합니다',
#  '네 그리하겠습니다 오늘 하루도 즐겁고 행복한 일만 가득하시길 기원하겠습니다.',
#  '고맙습니다 좋은하루 되세요 오늘도 좋은 일만 가득하길 바랍니다',
#  '죄송합니다 좋은밤 되세요 그럼 이만 실례하겠습니다 좋은 밤 되세요',
#  '고객님 오늘 좋은시간 되세요 감사합니다.',
#  '고객님 방문해 주셔서 대단히 고맙습니다.',
#  '항상 고객님들께 최선을 다하는 최고남이 되기 위해 노력하는 최고남제육쌈밥 구래점이 되겠습니다 다음에도 좋은 음식으로 찾아 뵙겠습니다 감사합니다',
#  '주문해 주신 것에 대해 감사의 뜻을 전하고 더 좋은 제품으로 보답하겠습니다.',
#  '맛있는 치킨을 싸고 푸짐하게 먹을 수 있는 저희 홍닭을 언제든지 찾아주세요 감사합니다.',
#  '매장은 매우 깨끗했고 고객님도 너무 편하게 계셨는데 제가 너무 급하게 말씀드려서 죄송합니다 다음에 또 이런 실수를 하시면 정말 죄송합니다.',
#  '저희 매장에서 판매하는 간장치킨은 다른 프랜차이즈 치킨보다 조금 단 맛이 강했으면 하는 마음이 들 때도 있지만 고객을 생각하는 마음으로 조금 더 노력하는 그런 가게가 되고 싶습니다.',
#  '저희 떡볶이가 다른 데 비해 아이들이 잘 먹는 편은 아니지만 그래도 좀 덜 맵았으면 하는 마음이 있습니다.',
#  '잘 먹었다고 내일 인사해야지 했는데 그러지 못했다는 게 너무 미안했어요 다음에 또 맛있는 요리 만들어 줄게요',
#  '고객님 주문 감사합니다 더 맛있게 해 주시려면 더 매운 맛으로 주문 받겠습니다 감사합니다',
#  '저희가 최선을 다한다는 것을 보여드리려고 노력하는 블로그가 되도록 노력하겠습니다.',
#  '항상 건강하시고 마무리 잘 하시고 새해 복 많이 받으시요 항상 믿고 구매하는 직구삼이 되시길 바랍니다',
#  '고객님 기대에 미치지 못해 죄송합니다 고객님 께서 말씀대로 잘 알아 보겠습니다 그래도 소중한 답글 감사합니다',
#  '저희가 그램수를 조금 더 추가해 드려도 튀기는 과정에서 기름이 많이 들어가면 부족한 감이 있을 수 있습니다 고객님 소중한 후기 감사합니다',
#  '죄송해요 고객님 두부 빼달라고 하셔서 제가 대신 넣어 드렸구요 다음에도 더 좋은 요리로 찾아 뵐게요 감사합니다',
#  '저희 부자집은 항상 맛있는 부대찌개를 위해 최선을 다해 노력하는 곳이니 걱정하지 않으셔도 됩니다.',
#  '고객님 오늘 하루도 행복만 가득하시길 기원합니다.',
#  '고객님들께 불편을 드려 대단히 죄송합니다 앞으로 더욱 조심하겠습니다 주문해 주셔서 감사합니다',
#  '지금 이벤트 중인 990원 사이드메뉴와 함께 드시면 더 좋은 맛을 낼 수 있는 수삼이 더 맛있게 드실 수 있으실 거예요.',
#  '항상 건강하고 행복한 가정에서 자라길 기원합니다. 다음에 또 좋은 일이 생길 때 찾아오겠습니다.',
#  '저희 블로그 이벤트에 많은 관심을 주셨던 분들께 감사의 마음을 전하며 더 좋은 내용으로 다시 찾아 뵐게요.',
#  '항상 행복하고 건강한 밥상을 위해 노력하겠습니다. 감사합니다.',
#  '준비부터 배달까지 고객님께 닿는 그 모든 과정의 사소한 부분 하나하나 신경 쓰며 감동시켜드리고 싶은 마음 하나로 노력을 다하고 있습니다 믿고 자주 이용해 주세요',
#  '저희는 항상 더 나은 맛과 서비스 개발을 위해 노력하고 있으니 여러분도 건강한 하루를 보내십시오.',
#  '항상 건강에 유의하시고 아픈 곳이 발견될 때마다 치료를 받으시길 기원합니다.',
#  '저희 음식이 기력을 회복하시는데 도움이 되기만 한다면 그것만으로도 너무나 행복합니다 좋은 하루 되세요.',
#  '추운 겨울 몸과 마음 건강 생각해서 늘 좋은 말씀 해 주시는 고객님 감사합니다.',
#  '맛있게 잘 먹었습니다. 다음에도 또 맛있는 요리로 찾아 뵐게요.',
#  '매일 새벽에 장을 봐서 오전 및 오후에 재료를 따로따로 준비해 그날의 김밥 맛을 그날 그날 다르게 하고 있으며 홀 및 배달 메뉴의 질이 다른 것을 만회하기 위해 노력하고 있습니다',
#  '감사합니다 덕분에 잘 사용하겠습니다.',
#  '맛있는 요리를 하기 위해 욕심을 부리다 보니 이렇게 큰 참사가 일어난 것이죠 맛있게 요리하려고 했던 욕심에 정말 죄송합니다.',
#  '고객님의 소중한 식사시간에 불편을 드려 대단히 죄송합니다 앞으로는 더욱 주의를 기울여 주세요 감사합니다',
#  '저희가 더 좋은 요리로 보답할 수 있도록 다음에도 최선을 다해 준비하겠습니다.',
#  '항상 행복한 시간 되세요 감사합니다.',
#  '맛있는 요리 못지않은 맛있는 요리로 항상 행복한 시간 되세요.',
#  '항상 믿고 먹을 수 있도록 최선을 다해 노력하는 만큼 더 좋은 요리로 찾아 뵙겠습니다.',
#  '저희 라화방마라탕 주문해주셨는데 유부가 빠져서 너무 죄송합니다 다음에 요청사항 남겨주시면 서비스로 넣어드릴게요 감사합니다',
#  '항상 찾아주셔서 감사합니다 고객님의 소중한 후기 마음에 새기고 더 노력하겠습니다 다음 주문시 메모 남겨주시면 최대한 입맛에 맞게 보내드리겠습니다 감사합니다',
#  '그럼에도 불구하고 맛있는 식사 대접해주신 고객님께 감사의 마음을 전하고 더 맛있는 요리로 찾아 뵙도록 하겠습니다요.',
#  '오늘도 수고 많으셨고 다음에 또 부탁드릴 것이 있으면 언제든 말씀해주십시오 감사합니다.',
#  '다음부턴 이런일이 발생하지 않도록 주의 하겠습니다 다음부턴 실수로 빠뜨린 것을 제가 빠뜨리지 않도록 하겠습니다',
#  '항상 최고의 고기 맛을 위해 노력하는 신자매 김치찜 김치찌개가 되도록 노력하겠습니다.',
#  '신자매 김치찜 김치찌개는 항상 인기가 많은데 항상 감사의 마음을 전하는 맛있는 찌개가 될 수 있도록 노력하겠습니다.',
#  '항상 최선을 다하는 신자매 김치찜 김치찌개가 되도록 노력하겠습니다.',
#  '신자매 김치찜 김치찌개는 항상 좋은 품질과 좋은 서비스로 보답하는 곳으로 기억되고 있으며 앞으로도 많은 사랑 부탁드립니다.',
#  '항상 아침 저녁으로 고객을 상대로 최선을 다하는 신자매 김치찜 김치찌개가 되도록 노력하겠습니다.',
#  '잘 먹었다고 내일 인사해야지',
#  '이번에는 좀 작았지만 다음에는 더 작은 걸로 사 주세요 저번에 저희가 닭을 많이 잡아주셔서 이번엔 좀 적게 잡았거든요.',
#  '양념이 조금 모자랐어요 고객님 다음에는 더 많이 만들어 주세요 감사합니다',
#  '면가게 야탑점이 더욱 발전하기 위해 노력하겠습니다.',
#  '항상 좋은 요리로 기분 좋은 밥상을 마련해 드릴 것을 약속하겠습니다. 감사합니다.',
#  '항상 좋은 요리로 보답하겠습니다 고객님의 소중한 댓글 하나가 소중한 요리의 힘이 됩니다.',
#  '고객님의 소중한 후기가 힘이 되고 가게에도 많은 도움이 되길 바라는 마음으로 글을 작성하겠습니다.',
#  '폴트버거는 항상 좋은 재료와 정직한 맛을 추구하는 곳으로 변함없이 맛있는 음식을 만들어 낼 것을 약속합니다.',
#  '고객님의 소중한 후기를 잘 봐 주셔서 감사합니다 다음에도 또 맛있는 음식을 만들어 주세요 감사합니다.',
#  '저희 폴트버거를 항상 주문해 주시는 고객님께 감사의 마음을 전하며 더욱 좋은 요리로 보답하겠습니다.',
#  '맛있는 버팔로윙 주문해 주셔서 감사합니다 다음에도 좋은 요리로 찾아 뵐게요 :)',
#  '미국산 쇠고기와 브리오쉬번을 사용한 폴트버거를 맛있게 먹어주신 여러분께 감사의 뜻을 전하고 싶어서 별 4개를 드립니다.',
#  '맛있는 햄버거 만들어 주셔서 감사합니다. 다음 번에도 더 좋은 요리로 찾아 뵐게요.',
#  '혹시라도 피자가 너무 식어서 상태가 안 좋은 경우 매장으로 바로 연락주시면 빠르게 조치를 취해 드리겠습니다.',
#  '잘 먹었다고 내일 인사해야지',
#  '그래도 맛있게 먹어 주니 저도 기분 좋습니다 다음에도 또 맛있는 요리로 찾아 뵐게요',
#  '항상 최고의 선택이 될 수 있도록 최선을 다해 노력하겠습니다 항상 감사합니다',
#  '맛있는 피자와 어울리는 수제맥주까지 앞으로도 좋은 조합의 피맥을 제공해드리도록 노력하겠습니다.',
#  '이번에 드신 고구마크러스트 피자가 조금 아쉬우셨다면 혹시 다른 피자를 찾으신다면 과트로치즈피자도 추천드립니다 앞으로도 자주 이용해주세요 감사합니다',
#  '양이 조금 부족했던 것 같은데 다음에는 더 많이 넣어주세요 여러분 감사합니다 :) 다음에 또 좋은 정보 부탁드립니다.',
#  '자주 이용해 주셔서 대단히 감사합니다 앞으로도 좋은 제품을 더 많이 만들어 주세요.',
#  '저희 랜돌프 뉴욕 페퍼로니를 사랑해주시는 분들께 감사의 뜻을 전하고 싶어서 이렇게 글을 작성하게 되었습니다.',
#  '항상 고객의 만족을 위해 노력하는 랜돌프 비어의 크리미 감바스와 피자를 드시고 계신 분들께 감사의 말씀을 드립니다.',
#  '고객님이 보내주신 사진을 보고 저희도 마음이 아프고 고객님께 더 감사하게 생각하고 오븐 온도를 조금 더 올려 주신다면 더 좋은 요리로 보답하겠습니다.',
#  '저희가 피자를 더 신경써서 보내드렸어야 하는데 그러지 못해 정말 죄송합니다 앞으로 이런 일이 없도록 더 열심히 노력하겠습니다 감사합니다.',
#  '저희 랜돌프 비어를 이용해 주셔서 정말 감사드립니다 맛있게 드실 뿐만 아니라 항상 고객님의 만족을 위해 노력하겠습니다 감사합니다.',
#  '저희 랜돌프 비어를 이용해 주셔서 정말 감사드립니다. 조금 더 자극적일 수 있는 맥주와 함께 한다면 좋을 것 같아요.',
#  '랜돌프 뉴욕 페페로니는 고객님들과의 소통을 통해 더 나은 서비스를 제공해 드릴 것이며 특히 민감한 온도 문제를 해결하기 위해 연구하고 개발하여 더욱 노력하겠습니다.',
#  '죄송해요 여러분 다시 한번 고개 숙여 사과 드립니다 그 소스통 반찬뚜껑이 음식 포장하는 곳에 있어서 떨어져 나갈 수도 있는데 제가 어찌 모른체할 수 있겠습니까',
#  '아 우리나라에서 나는 고추는 매운맛이 강해서 아이들이 잘 안 먹긴 해 근데 베트남 고추라서 더 맛있게 먹을 수 있겠어요',
#  '잘 살펴서 잘 살게요 감사합니다. 제가 놓친 부분이 너무 많습니다.',
#  '감사합니다 바로 드시는 것보다 이렇게 바로 먹는 게 더 맛있을 것 같아요 얼른 처리해 주셔서 감사합니다',
#  '죄송해요 정말 빠른 처리 위해 더 노력하겠습니다 정말 추운 날씨에 고생이 많으세요 정말',
#  '신선해서 다시 파랗게 올라오는 것이니 안심하고 드셔도 됩니다 더 열심히 노력하는 카산도가 되겠습니다 고객님 안심이 붉은 것 때문에 오해가 있으신 것 같아요',
#  '맛있는 카레 산도가 생각날 때 저희 카산도를 찾아주세요 항상 최선을 다해 준비하겠습니다.',
#  '저희 카산도 정본점은 맛있는 카레 산도가 생각날 때마다 최선을 다해 만들겠습니다.',
#  '저희 부성초밥을 믿고 맡겨주신 고객님께 감사의 인사를 전하며 내일도 행복한 하루를 보내십시오.',
#  '시간내서 소중한 댓글 남겨주신 분들 덕분에 맛있는 닭장수 더 맛있게 먹을 수 있었습니다 남은 명절연휴 행복한 시간 되세요',
#  '닭장수를 방문해 주신 고객님께 감사의 뜻을 전하고 싶어서 이렇게 글을 작성하게 되었습니다.',
#  '환절기 건강 유의하시구요 행복한 10월 되시길 바랍니다 닭장수의 맛있는 요리와 멋진 칭찬글 감사드립니다.',
#  '고객님이 요청한 시간보다 더 빨리 배달이 되었다면 감사의 뜻을 전하고 싶은데요. 고맙습니다.',
#  '가을장마가 시작되니 건강유의 하시구요 행복이 가득한 한 주 되시길 바랍니다 닭장수 올림 수고하셨습니다',
#  '더운여름 건강유의 하시구요 행복한 한 주 보내십시오.',
#  '저희 매장 앞에 와 주신 손님들께 감사의 인사를 전하며 다시 한번 맛있는 떡볶이를 만들어 보도록 하겠습니다.',
#  '저희 깨돌이김밥 미금점을 사랑해 주셔서 감사합니다.',
#  '맛있는 만두 잘 먹었다고 내일 인사해야지 너무 오래 기다리게 해서 제가 미안합니다 다음에는 배달 시간 좀 더 신경 써 주세요',
#  '저희 깨돌이김밥 미금점을 방문해 주신 분들께 감사의 말씀을 전하며 앞으로도 더 좋은 요리와 맛있는 요리로 찾아 뵙겠습니다.',
#  '지금 확인해 보니 다른 메뉴도 모두 삭제된 것을 확인할 수 있었고요 고객님께 다시 한 번 사과 드립니다 즐거운 주말 되세요',
#  '잘못을 인정하고 다시 한번 사과드립니다 제가 잘못한 점을 말씀 드릴 때 똑바로 말씀드릴 수 있으려면 먼저 사과를 드려요.',
#  '항상 최선을 다해 좋은 재료를 구입하려 노력 하지만 항상 부족한 것이 저의 한계인 것 같습니다 다음에는 더 좋은 제품으로 찾아 뵙겠습니다.',
#  '최대한 많은 양의 회를 선보이기 위해 노력하고 있는 만큼 최선을 다해 보겠습니다.',
#  '저희집 석화는 통영에서 지인을 통해 직통으로 사서 박스안에 좋은것만 골라서 넣어 드리고 있는데 맛있게 먹어 주셔서 또 한번 감사드립니다',
#  '좋은오후 되세요 오늘도 좋은 일만 가득하세요 감사합니다. 큰 사이즈의 고기를 고집하는 이유는 신선함을 위해 당일 수급을 원칙으로 하고 있기 때문입니다.',
#  '고객만족도를 높이기 위해 더욱 노력하겠습니다 고객님 댁에서 불편을 드려 죄송합니다 고객님의 마음을 진심으로 받겠습니다 감사합니다',
#  '혹 고객님이 지적하신 부분이 있으면 다시 검토해 보고 부족한 부분은 바로 잡아 드리겠습니다. 감사합니다.',
#  '3키로 이상급을 3 4시간 숙성시킨 후 두툼하게 썰어 평소보다 더 맛있게 드실 수 있도록 하겠습니다.',
#  '메인인 회에 충실하다보니 스끼다시는 좀 소홀한것 같습니다 그래도 산지에서도 구하기 힘든 거북손을 거문도에서 지인을 통해 직송하여 스끼다시로 제공하고 있으며 해초류인 꼬',
#  '저희집 대방어는 1 무조건 12키로 이상급 2 모든 부위 골고루 제공 3 당일 잡은 대방어만 사용 4 고객님들의 사랑 덕분에 하루에 2, 3마리의 대방어가 잡히는 실정입니다.',
#  '잘 먹었다고 내일 인사해야지 맛있는 음식 만들어 주셔서 감사합니다.',
#  '별 5개를 받는 그날까지 더욱 더 열과 성을 다해 노력하겠습니다 별 5개가 되는 그 날까지 맛있게 먹어 주셔서 감사합니다',
#  '최근 급격한 물가 상승으로 인해 원재료 값이 많게는 50 이상 오른 품목들이 많아 눈물을 머금고 가격을 조정할 수 밖에 없었던 점을 너그러히 양해해주시기 바랍니다.',
#  '오늘은 행복한 토요일 매장에 오셔서 홀 운영 매장 주변 대로변 주차 가능 매장에서 직접 만든 핫도그나 메뉴들이 배달보다는 훨씬 맛이 좋습니다',
#  '오늘도 행복한 하루를 보내셨는지요? 오늘도 맛있는 요리와 함께 하겠습니다요.',
#  '조금 더 꼼꼼히 확인해서 보내 드리도록 하겠습니다 메리 크리스마스 보내 주세요',
#  '고객님이 맛있게 드시고 남긴 후기를 볼 때면 저희는 힘이 불끈 솟는데요 마라하오 죽전점 여러분들도 한번 방문해 보시면 좋겠어요.',
#  '저희가 항상 기분좋게 먹을 수 있도록 최선을 다해 노력하겠습니다.',
#  '안녕하세요 마라하오죽전점입니다 고객님을 향한 열정만큼은 절대 변함없도록 항상 최선을 다하겠습니다 앞으로 꾸준한 사랑과 관심 부탁드립니다',
#  '고객님 방어 맛있게 드셨는지요 앞으로도 좋은 음식으로 찾아뵐수 있도록 노력하겠습니다 감사합니다.',
#  '새해 복 많이 받으시라는 인사로 신년을 맞이하여 더 좋은 서비스와 서비스로 찾아 뵙겠습니다.',
#  '저희는 회를 냉동하지 않고 생것으로 받기 때문에 고객님들이 회가 드시고 싶어도 드실 수 없는데 이럴 때는 고객님 댁에 있는 회로 대체해 드리겠습니다.',
#  '항상 부족한 점을 고쳐나가는 해남수산이 되도록 노력하겠습니다 감사합니다.',
#  '다양한 스끼다시와 더 푸짐한 회로 항상 최선을 다해 서비스하고 있으니 앞으로도 자주 찾아주세요 감사합니다.',
#  '저희는 회를 항상 일정한 양만 떠서 제공하기 때문에 고객님들이 만족하지 못하시면 다음에 주문하실 때 더 많이 주세요',
#  '맛있는 요리로 앞으로도 많이 만들어 주세요 감사합니다.',
#  '생선류초밥을 추가해도 되지만 가격이 인상되어 소비자 부담이 커질까 걱정되어 고민입니다 더 고민해보고 성장하는 초밥대통령이 되도록 하겠습니다',
#  '행복한 주말 저녁 보내십시오 주문해 주신 상품을 보내 주셔서 감사합니다.',
#  '좋은하루 되세요 오늘은 주문해주신 상품이 잘 나왔어요 덕분에 기분이 좋습니다',
#  '그러게요 배달비 저희도 마음 아픈데 그럼에도 불구하고 찾아와 주셔서 감사합니다 그러게요',
#  '본사에서 메뉴 구성을 새로 바꾸고 있는 중이니 앞으로 더 다양한 초밥을 맛볼 수 있게 해 주시면 감사하겠습니다.',
#  '더 맛있는 초밥을 만들어 더 많은 분들의 사랑을 받는 초밥으로 만들어 보겠습니다.',
#  '소중한 글 잘 봐 주셔서 감사합니다 본사에 문의해보겠습니다.',
#  '저희 초밥대통령을 방문해 주셔서 감사합니다 항상 감사드립니다 내일도 행복한 일만 가득하시길 바랍니다',
#  '네 아이들이 잘 먹을 수 있도록 와사비는 별도로 빼서 준비해 볼게요.',
#  '소중한 평가 감사드립니다. 더 발전된 초밥대통령의 요리가 되기 위해 초밥대통령이 노력하겠습니다.',
#  '더 맛있게 잘 만들어 더 많은 사람들에게 소개해 드리고 싶네요 다음에 또 맛있는 요리로 찾아오겠습니다.',
#  '자주 오는 단골이지만 항상 부족한 점이 해결되었으면 합니다 다음에도 주문할 때는 좀 더 성의를 다해 주세요 감사합니다.',
#  '저희 라쿤핏 바베큐를 많이 사랑해 주세요 :) 저희가 부족한 점을 많이 고쳐 나가면서 더 좋은 맛과 좋은 서비스로 보답할 것을 약속하겠습니다.',
#  '제가 손수 요리하다 보니 손이 많이 가서 제가 좀 더 많이 해 줄게요 다음에 또 맛있는 요리로 찾아 뵐게요',
#  '한 줄로 고객님의 배를 든든하게 해드릴 수 있는 글을 써 주셔서 감사합니다.',
#  '맛있게 먹어 주셔서 감사합니다 맛있는 평가 감사합니다',
#  '저희 비오키친을 찾아주시면 감사하겠습니다. 건강하고 맛있는 다이어트 음식으로 여러분의 몸과 마음을 건강하게 지켜드리겠습니다.',
#  '맛있게 잘 먹었다고 내일 인사해야지 오늘 하루도 행복하고 건강하게 보내요',
#  '감사하게도 이렇게 좋은 일에 기부해 주시고 글까지 써 주시고 정말 감사합니다.',
#  '주말 잘 보내셨는지요 토요일 배달이 늦은 것과 주말 즐겁게 보내 셨는지요',
#  '추운 날씨에도 따뜻하게 드실 수 있도록 정성을 다해 요리하고 있습니다 감사합니다.',
#  '이리 손수 후기까지 써주시고 국밥이 생각날때 종종 찾아주시고 감사합니다 또 이렇게 손수 리뷰까지 써주셔서 감사합니다',
#  '이번 여름 더위에 지치지 마시고 올 여름 건강에도 유의하시고 맛있는 국밥 한그릇 드시게 해 주셔서 감사합니다.',
#  '조금만 더 신경 써서 이런 추운 날씨에 식어야 했는데 대단히 죄송합니다.',
#  '처음부터 끝까지 다 해 주셔서 감사합니다. 제가 댓글 잘 안 쓰는데 고객님들이 저를 너무 좋게 생각해 주셔서요.',
#  '항상 요리 조리 위생 포장 등 더 좋은 모습으로 보답하는 알촌이 되도록 노력하겠습니다.',
#  '저희가 더 잘 할 수 있는 방법을 찾아 더 열심히 해야겠다는 생각이 많이 드신데요 죄송합니다.',
#  '준비하느라 미처 못한 것들이 많은데 다음에 또 만들어주시면 그땐 제가 정성을 다해 만들겠습니다.',
#  '피자 토핑 재료는 다시 한번 점검했고요 혹시 피자가 식으면 누린내가 날 수 있으니까 다른 종류의 햄이나 치즈를 넣어 드셔도 좋습니다.',
#  '홍스는 고객님의 만족을 위해 항상 노력하는 쇼핑몰이 되기 위해 노력하겠습니다.',
#  '만족도가 높아 더 좋은 요리를 만들어 보답하겠습니다 다음에는 더 열심히 해서 여러분의 만족도를 높여 드리겠습니다',
#  '저희 감성커피는 항상 맛있는 커피를 위해 노력하는 곳으로 앞으로도 더욱 노력하겠습니다.',
#  '항상 맛있는 요리를 만들어 주셔서 감사합니다 언제 먹어도 변함없는 맛과 정성으로 보답하겠습니다.',
#  '항상 맛있는 음식을 제공해 드리려고 노력하는 떡형 복대점이 되도록 하겠습니다.',
#  '저희 떡형 복대점을 방문해 주신 고객님께 감사의 뜻을 전하고 더 좋은 요리와 서비스를 제공해 주시기 위해 더욱 노력하겠습니다.',
#  '저희 떡형 복대점을 방문해 주신 고객님께 감사의 뜻을 전하고 더욱 좋은 요리와 서비스로 보답하겠습니다.',
#  '저희 떡형 복대점을 찾아주신 고객님께 감사의 마음을 전하고 더 좋은 요리와 서비스로 보답하겠습니다.',
#  '저희 떡형 복대점이 최고의 선물이 될 것으로 확신합니다.',
#  '맛있는 식사시간 만들어 주셔서 감사합니다 오늘도 좋은 하루 되세요 감사합니다',
#  '좋은 글 감사합니다 좋은 하루 되세요 오늘도 좋은 일만 가득하길 기원합니다.',
#  '오늘도 좋은 하루 되세요 오늘도 소중한 댓글과 함께 멋진 작품을 만들어 주신 여러분께 감사드립니다',
#  '좋은 하루 되세요 오늘 소중한 댓글과 함께 소중한 정보 주셔서 감사합니다.',
#  '좋은 글 써 주셔서 감사합니다 다음엔 더 열심히 써 볼게요 감사합니다',
#  '아 4번메뉴는 나혼자산다 단독메뉴에 황궁자추가하시면 원하시는 매운맛을 드실수있으세요 아',
#  '아 오늘은 고객님이 여러번 스타일을 바꿔서 만든 볶음우동입니다 내일은 더 맛있는 요리로 찾아 뵐게요 감사합니다',
#  '죄송해요 여러분 잘못한 게 너무 많아서 하마터면 다 못 들을 것 같습니다 하하 죄송합니다 여러분',
#  '항상 먹던 맛을 찾아 항상 노력하는 ok반점이 되도록 노력하겠습니다. 감사합니다.',
#  '저희 매장은 저렴한 가격의 중국산 냉동 완제품을 쓰지 않고 고객님이 주문할 때마다 직접 조리하는 수제 타코야키 전문점이므로 3월 한 달 동안 맛있는 음식을 많이 만들어 판매하세요',
#  '저희 직원이 실수로 주문 확인을 제대로 하지 못한 경우가 종종 있는데 다음부터는 이런 실수를 반복하지 않도록 더욱 주의하겠습니다.',
#  '저희 한식 끼를 사랑해 주시는 분들께 감사의 뜻을 전하고 싶어서 이렇게 글을 작성하게 되었습니다.',
#  '저희 윤희횟집을 방문해 주신 고객님께 감사의 뜻을 전하고 별 다섯 개를 드려 죄송합니다 그럼 새해 복 많이 받으시구요',
#  '저희 윤희횟집을 방문해 주신 여러분께 감사의 뜻을 전하고 싶고 앞으로도 고객만족을 위해 더욱 노력하겠습니다 감사합니다.',
#  '저희 윤희횟집을 방문해 주셔서 감사합니다 회가 조금 좋지 못했지만 앞으로는 더 좋은 회를 위해 노력하겠습니다 오늘도 좋은 하루 되세요',
#  '저희 윤희횟집을 방문해 주신 여러분께 감사드립니다 앞으로도 더욱 좋은 서비스와 최선을 다하는 윤희횟집이 되도록 노력하겠습니다.',
#  '저희 윤희횟집을 방문해 주신 여러분께 감사의 말씀을 전하며 더 좋은 요리와 서비스로 찾아 뵙겠습니다.',
#  '저희 윤희횟집을 방문해 주신 여러분께 감사드립니다 별 하나가 빠져서 아쉽기는하지만 앞으로는 고객님께서 더욱더 맛있게 드실 수 있도록 최선을 다해 모시겠습니다 오늘',
#  '저희 윤희횟집을 방문해 주신 여러분께 감사의 뜻을 전하고 싶고 앞으로도 고객만족을 위해 더욱 노력하겠습니다.',
#  '손님들에게 더 좋은 요리를 소개해 드리고 싶어서 이렇게 글을 작성하게 되었습니다.',
#  '시민 족발 보쌈 감자탕이 맛있게 드실 수 있도록 매일 오전 9시만 되면 준비해 둔 댓글과 공감 이벤트를 통해 여러분께 감사의 뜻을 전하고 있다.',
#  '이용해 주셔서 감사합니다. 항상 좋은 맛과 서비스로 보답하는 봄봄이 되도록 노력하겠습니다.',
#  '햄치즈 계란말이 너무 맛있어요 정말 감사합니다 다음에도 또 맛있는 요리로 찾아 뵐게요.',
#  '요즘 날씨가 너무 추워 따뜻한 음료를 마시고 싶다는 생각이 간절했는데 고객님이 불편을 드려 죄송하게도 메뉴를 선택할 때 세부 옵션을 선택하지 못해 드려서 죄송합니다.',
#  '무더운 여름 건강에 유의하시고 또 맛있는 붕어빵 만들어 주세요 감사합니다.',
#  '더 맛있는 요리로 찾아 뵐게요 이번 여름엔 더 맛있게 어떤 요리든 만들어 보겠습니다.',
#  '항상 친절한 매장 운영을 위해 노력하겠습니다.',
#  '직원들 교육할 때 반드시 지켜야 할 것 1. 딸기잼을 너무 많이 만들면 안 된다.',
#  '잘 먹었다고 내일 인사해야지 그 전날 너무 많이 먹었다 그러면 안 된다고 그러지',
#  '고기양이 많지 않아서 1인분에 8000원 하는 보쌈정식도 많은데 가격이 너무 비싸요 제가 보기엔요',
#  '그래도 예쁘게 잘 올려주신 사진 덕분에 제가 마음이 놓였습니다 그럼 이만 사진을 봐 주세요',
#  '오늘 부족했던 부분 많이 보충해주셨는데 또 궁금하신 부분이 있으면 언제든 질문해주시면 성심성의껏 답변해드리겠습니다.',
#  '별 하나가 빠져서 별 다섯개가 된 걸 보면 별 부족이 분명하신 거네요.',
#  '더 노력하는 보둘미역이 되도록 최선을 다해 보겠습니다 맛있는 음식 만들어 주셔서 감사합니다.',
#  '배달용기에 국물을 더 부우시면 국물이 흘러 내리기 때문에 혹시라도 모자라면 댁에서 생수를 조금만 더 넣고 다시 한번 끓여서 드시면 좋습니다',
#  '보통은 1인분에 2인분 정도 먹는 것으로 알고 있는데 많은 분들이 그렇게 적게 주셨다고 하니 다행이네요 맛있게 잘 먹었다고 내일 인사해야지',
#  '맛있게 잘 먹었고 별 다섯 개 드리도록 하겠습니다 맛있게 먹어 주셔서 감사합니다',
#  '죄송해요 여러분 다음에도 또 이용할게요 너무 늦어서 정말 죄송합니다']

# %% [markdown]
# - 저장

# %%
# # review
# train_over_review = pd.DataFrame({"review":over_review})
# train_over_review.to_csv(f'{DATA_PATH}train_over_review.csv', index=False, encoding = "utf-8-sig")

# # reply
# train_over_reply = pd.DataFrame({"reply":over_reply})

# # # concat
# train_over = pd.concat([train_over_review, train_over_reply, train_star["star"]], axis=1)
# train_over.to_csv(f'{DATA_PATH}train_over.csv', index=False, encoding = "utf-8-sig")
# train_over

# %%
# # 엑셀로도 저장해서 확인해보기
# with pd.ExcelWriter("train_over_review.xlsx", engine='openpyxl') as writer:
#     train_over_review.to_excel(writer, sheet_name='시트1', index=False)

# with pd.ExcelWriter("train_over.xlsx", engine='openpyxl') as writer:
#     train_over.to_excel(writer, sheet_name='시트1', index=False)

# %% [markdown]
# - 불러오기

# %%
train_over = pd.read_csv(f'{DATA_PATH}train_over.csv')
train_over
# Out:
#                                                 review  \
# 0    아니 그런데 배달이 20분 넘게 안 와서 전화해서 물었더니 배달 기사님이 비가 와서...
# 1    양이 2만원씩이나하는데 장난으로하는것도 아니고 진짜 이거 2만원주고 사서 먹을 정도...
# 2    커피가 배달되기를 기다린 지 25분이 지나자 커피 배달 예정 시간은 이미 커피를 만...
# 3    김이 많아서 그런것도 있고 단무짠지 김이 많이 없어서 그런지도 모르겠지만 밥이 쉬었...
# 4    처음 먹었을 때 너무 맛있게 먹었던 기억에 다시 찾아 주문하려고 잠실점에 갔는데 역...
# ..                                                 ...
# 721                                       맛있게 잘 먹었습니다.
# 722  시원한 국물이 더 많았으면 국물 맛은 더 시원했을 것 같아요 시원한 국을 시원하게 ...
# 723  맛있어요 포장도 꼼꼼하고 무엇보다 반찬이 짜지 않고 맛있어요 구성이 여러 가지라 더...
# 724                    양이 진짜 많아요 진짜 많이 많이 덕분에 맛있게 먹었어요
# 725  항상 잘 들어주시고 잘 챙겨주셨는데 오늘은 못 드려서 아쉬웠어요 그래도 맛있게 잘 ...
#
#                                                  reply  star
# 0    저희가 미처 생각하지 못한 부분이 있기 때문에 다시 한번 감사의 마음을 전하고 싶습니다.     1
# 1    저희 1988응답하라추억의옛날도시락은 언제나 약속 드린 정량을 지키기 위해 노력하고...     1
# 2       한파로 길이 꽁꽁 얼어 고객님들이 불편을 드려 죄송했는데 주문해 주셔서 감사합니다.     1
# 3    이런 댓글은 본인 가족이나 지인에게 하는데 본인이 아니더라도 주변 사람이 해야 할 ...     1
# 4    잠실점에서 기분이 상하셨었는데 저희가 다시 실수를 한 것 같은데 다시 한번 연락드리...     1
# ..                                                 ...   ...
# 721  더 노력하는 보둘미역이 되도록 최선을 다해 보겠습니다 맛있는 음식 만들어 주셔서 감...     4
# 722  배달용기에 국물을 더 부우시면 국물이 흘러 내리기 때문에 혹시라도 모자라면 댁에서 ...     4
# 723  보통은 1인분에 2인분 정도 먹는 것으로 알고 있는데 많은 분들이 그렇게 적게 주셨...     4
# 724       맛있게 잘 먹었고 별 다섯 개 드리도록 하겠습니다 맛있게 먹어 주셔서 감사합니다     4
# 725              죄송해요 여러분 다음에도 또 이용할게요 너무 늦어서 정말 죄송합니다     4
#
# [726 rows x 3 columns]

# %% [markdown]
# # 기존 + 오버샘플링 concat

# %%
train = pd.concat([train, train_over], axis=0)
train
# Out:
#                                                 review  \
# 1                         리뷰가 늦었네요 맛있게 잘 먹었습니다 또 시킬게요
# 2                    잘 먹었습니다 다만 주문에 있던 펩시콜라는 받지 못했습니다
# 3                                   굿 말이 필요 없는 메뉴 였습니다
# 4                                          맛있어요 양도많구좋음
# 5                                            양많고 맛있었어요
# ..                                                 ...
# 721                                       맛있게 잘 먹었습니다.
# 722  시원한 국물이 더 많았으면 국물 맛은 더 시원했을 것 같아요 시원한 국을 시원하게 ...
# 723  맛있어요 포장도 꼼꼼하고 무엇보다 반찬이 짜지 않고 맛있어요 구성이 여러 가지라 더...
# 724                    양이 진짜 많아요 진짜 많이 많이 덕분에 맛있게 먹었어요
# 725  항상 잘 들어주시고 잘 챙겨주셨는데 오늘은 못 드려서 아쉬웠어요 그래도 맛있게 잘 ...
#
#                                                  reply  star
# 1    좋은 리뷰 덕분에 기분이 행복해지는 것 같아요 고객님께서 맛있다고 말씀 주시니 피로...     5
# 2    소중한 식사 시간에 저희 매장을 찾아 주셔서 감사드립니다 저희를 찾아 주신 만큼 1...     5
# 3    수 많은 매장들을 헤치고 와주셔서 감사합니다 저희 매장의 메뉴를 제대로 즐기신 거 ...     5
# 4    수 많은 매장들을 헤치고 와주셔서 감사합니다 메뉴 그 자체로 행복을 드리고 싶었는데...     5
# 5    저희 매장 찾아주신 것도 감사한데 리뷰까지 감동입니다 고객님들의 배고픔을 저희는 지...     5
# ..                                                 ...   ...
# 721  더 노력하는 보둘미역이 되도록 최선을 다해 보겠습니다 맛있는 음식 만들어 주셔서 감...     4
# 722  배달용기에 국물을 더 부우시면 국물이 흘러 내리기 때문에 혹시라도 모자라면 댁에서 ...     4
# 723  보통은 1인분에 2인분 정도 먹는 것으로 알고 있는데 많은 분들이 그렇게 적게 주셨...     4
# 724       맛있게 잘 먹었고 별 다섯 개 드리도록 하겠습니다 맛있게 먹어 주셔서 감사합니다     4
# 725              죄송해요 여러분 다음에도 또 이용할게요 너무 늦어서 정말 죄송합니다     4
#
# [11228 rows x 3 columns]

# %%
# 별점 분포 확인
train['star'].value_counts().sort_index()
# Out:
# 1     180
# 2     122
# 3     306
# 4     844
# 5    9776
# Name: star, dtype: int64

# %% [markdown]
# ### 가게명 키워드 컬럼화

# %%
# ygy_store_lst = ["1988응답하라추억의옛날도시락-방이점", "워커스커피 로스터스", "떡깨비-가락점", "당치땡-헬리오시티점", "우시장국밥-석촌점",  "고돼지-송파점",  "마라의신마라탕&마라샹궈",  "춘리마라탕-송파점",  "손수경의육회담은연어-가락점",  "무국적식탁-송파점",  "청년치킨-삼전점",  "송파만다린",  "배달의쌀국수-송파점",  "닭강점-헬리오시티점",  "토핑폭탄김치찜&김치찌개-송파점",  "조형훈족발보쌈",  "여왕의브런치",  "모어댄버터",  "플러스82-송파점",  "더티베지",  "잭아저씨족발보쌈-본점",  "육회&연어-미아본점",  "갈비민족-본점",  "구구족-성신여대역점",  "피자보이시나-대학로점",  "왕빈자삼파전-미아본점",  "행복한찜닭-성북점",  "스시사소우",  "저팔계&중국&마라탕&덮밥&요리&전문점",  "명작파스타-성북점",  "올데이파스타-동대문구점",  "대한냉면-성북점",  "인생제육",  "고기듬뿍미트박스-성북점",  "피자스웨그-성북점",  "청춘식당묵은지김치찜",  "삽교원조두리곱창",  "뜸들이다-북서울꿈의숲점",  "더팔당매운오징어&닭발 김치찜",  "우리집반찬도시락-혜화막내딸지점",  "수피자",  "마라쿡",  "김포불닭발",  "헬로팬닭갈비&마약볶음밥",  "대찌 대파생고기김치찌개&정육왕국물두루치기",  "구래상회",  "승도리네곱도리탕",  "자성당",  "수락",  "나인곱창",  "어시장",  "돈까스회관",  "호랑이초밥",  "땡초곱창막창",  "피자이탈리",  "텐텐마라탕",  "과일에반하다",  "삼다수",  "병천토속순대",  "최고남제육명가",  "짱닭치킨",  "걸작떡볶이",  "직화삼겹직구삼",  "짜글이가돼었소",  "부대찌개자신있는집",  "토핑폭탄김치찜&김치찌개-부천점",  "1989마라탕-부천점",  "미친피자-부평점",  "천년닭강정-부천부평점",  "수상한삼겹살-부천점",  "수제죽전문점-본가진죽-본점",  "오늘은 분식",  "이끌림마라탕",  "탐나는피자-부평점",  "고기혁명-부천점",  "라화방마라탕-신중동점",  "전금례닭볶음탕-부천점",  "큰아들백순대",  "공주닭발-부천시청점",  "신자매김치찜&김치찌개",  "짱닭치킨-도촌점",  "이태리면가게-야탑점",  "폴트버거-판교점",  "랜돌프뉴욕페페로니-야탑점",  "홍싸롱-수제돈까스&파스타",  "쇼부덮밥",  "카산도-정자본점",  "부성초밥-미금본점",  "닭장수섭삼계탕&전기구이통닭",  "깨돌이김밥-미금점",  "울진죽변항",  "GTS버거-분당정자점",  "코브라독스-분당미금역점",  "마라하오-죽전점",  "땅끝수산",  "초밥대통령-용인수지점",  "올데이케밥&샐러드",  "야키토리 카마쿠라",  "비오키친-서현본점",  "부산오빠1인국밥-분당점",  "알촌",  "밈피자",  "고씨네카레",  "홍스족발",  "뜸들이다",  "감성커피",  "짚신스시",  "떡형",  "39도시락",  "피제이피자",  "황궁쟁반짜장",  "OK반점",  "모모타코야키&카페",  "꼬알라파이",  "진지덮밥",  "피자프라텔로",  "한식세끼1인김치찜&김치찌개",  "윤희횟집",  "시민보쌈족발&감자탕",  "카페봄봄",  "킹프레소빅와플",  "최가네한쌈",  "창타이누들",  "보돌미역",  "홍대개미"  ]
# store_name = []
# for store in ygy_store_lst:
#     pat = re.split(r'[- &]', store)
#     pat = ''.join(pat)
#     store_name.append(pat)

# short_name = []
# for name in store_name:
#     for length in [2, 3, 4]:
#         cut = name[:length]
#         short_name.append(cut)
#     if name[0].isdigit(): # 숫자로 시작하면 텍스트가 나오는 부분까지 추출
#         cut = name[:6]
#         short_name.append(cut)

# short_name = [name for name in short_name if not name.isdigit()] # 숫자로만 되어 있는 키워드 삭제
# short_name = list(set(short_name))
# print(len(short_name), short_name)

# # short_name 에서 불용어 처리
# drop_name = ['OK','갈비','감성','걸작','고기','공주','과일','김포','대한','땡초','명작','미친','배달','병천','부대','부산','비오','삽교','손수','송파','쇼부','수상','수제','시민','오늘', '오늘은', '우리', '울진', '이끌', '이끌림', '인생', '직화', '진지', '천년', '청년', '청춘', '최고', '큰아', '큰아들', '탐나', '토핑', '행복', '행복한', '헬로', '홍대',]
# short_name = [col for col in short_name if col not in drop_name]
# print(len(short_name),short_name)

# train['store'] = ""
# for name in short_name:
#     train[name] = train['reply'].apply(lambda x: name if name in x else '') # 각 가게 별로 컬럼 추가(그렇지 않으면 덮어쓰기 됨)
#     train['store'] = train.apply(lambda row: row['store'] + ',' + row[name] if row[name] else row['store'], axis=1) # store 컬럼에 컬럼 값 합치기

# train['store'] = train['store'].apply(lambda x: x[1:] if x.startswith(',') else x) # 첫 번째 문자가 콤마인 경우 제거
# train = train.drop(columns=short_name) # 각 가게 별 컬럼 삭제
# train.head()

# %%
# train['review'] = train['review'].astype(str)
# train['reply'] = train['reply'].astype(str)

# %% [markdown]
# - 여기까지 완료된 데이터 저장하기

# %%
# # 전체
# # train.to_csv(f"{DATA_PATH}yogiyo_clean.csv", index=False)

# # 오버샘플
# train.to_csv(f"{DATA_PATH}yogiyo_OV_clean.csv", index=False)

# %% [markdown]
# - 여기까지 완료된 데이터 불러오기

# %%
# # 전체
# train = pd.read_csv(f"{DATA_PATH}yogiyo_clean.csv")

# # 오버샘플
# train = pd.read_csv(f"{DATA_PATH}yogiyo_OV_clean.csv")

# review, reply = train["review"] , train["reply"]
# len(review) , len(reply)
# Out:
# (19776, 19776)

# %% [markdown]
# ### 가게명 키워드 reply에서 삭제

# %%
# # store 값이 있는 행만 가져오기
# train_del = train[train['store'].notna()]
# train_del
# Out:
#                                                   review  \
# 7      제 입맛에 안맞아요 뭔가 독특한 향신료 맛이에요 일반 닭갈비 맛이 아니에요 고기가 ...
# 8      제 입맛에 안맞아요 뭔가 독특한 향신료 맛이에요 일반 닭갈비 맛이 아니에요 고기가 ...
# 9      사장님 처럼 사장님만보기 기능있면좋겠지만만족하지만개선되었으면할때쓰고아니면안시키고말지...
# 14              진짜리뷰안쓰는데 양이 2만원씩내고 먹을양은 절대아닙니다 장난하는것도아니고
# 15     사장님 처럼 사장님만보기 기능있면좋겠지만만족하지만개선되었으면할때쓰고아니면안시키고말지...
# ...                                                  ...
# 19338  앗 리뷰가 늦었네요 요즘처럼 고물가에 더욱 빛나는 곳 입니다 솔직히 저만 알고싶을 ...
# 19351  최가네 한쌈음 한쌈은 항상 감동입니다 파김치 완전완전 세젤맛 먹어본 파김치중에 젤 ...
# 19357            손 많이 가는 음식 푸짐히 먹고싶으신분 모두 주문하세요 후회 없습니다
# 19381  후기 안쓰는데 처음후기 올려봅니다 다른분 후기중에 가격 올려야 되겠다는 댓글에 20...
# 19404  음식 한상 가득해서 너무 잘먹었습니다 보쌈뿐만 아니라 반찬도 너무 맛나요 과일샐러드...
#
#                                                    reply   store
# 7      이쁜 리뷰 감사합니다 고객님 즐거운 식사시간에 불편을 드려 죄송합니다 닭갈비 알밥이...      알촌
# 8      이쁜 리뷰 감사합니다 고객님 즐거운 식사시간에 불편을 드려 죄송합니다 닭갈비 알밥이...      알촌
# 9      저희 윤희 횟집을 찾아주셔서 감사드립니다 고객님께서 저희에게 충고해 주신 것에 대해...      윤희
# 14     솔직한 리뷰 남겨 주셔서 감사합니다 저희 1988응답하라 추억의 옛날 도시락은 언제...  1988응답
# 15     저희 윤희 횟집을 찾아주셔서 감사드립니다 고객님께서 저희에게 충고해 주신 것에 대해...      윤희
# ...                                                  ...     ...
# 19338  아이고 이리 늘 찾아주시고 좋은 말씀들이 최가네를 춤추게 합니다 요즘 배달이든 마트...  최가,최가네
# 19351  파김치가 입맛에 맞으셨다니 다행이네요 고객님께서 파를 너무 많이 보내주셔서 여러분하...  최가,최가네
# 19357  아이고 이리 좋은 말씀이 최가네를 춤추게 하네요 앞으로도 고객님들 마음에 실망하시는...  최가,최가네
# 19381  글초 리뷰 이벤트도 없는데 이리들 귀한 시가 내셔서 좋은 글을 올려주시니 항상 너무...  최가,최가네
# 19404  맛있게 드셔주심에 저희가 너무 감사드립니다 항상 노력하는 최가네가 될 수 있도록 할...  최가,최가네
#
# [4487 rows x 3 columns]

# %%
# # store 를 리스트로 변환(반복문을 위해)
# train_del['store'] = train_del['store'].str.split(',')
# train_del['store']
# Out:
# <ipython-input-130-7ab0f5255dfd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_del['store'] = train_del['store'].str.split(',')
# 7             [알촌]
# 8             [알촌]
# 9             [윤희]
# 14        [1988응답]
# 15            [윤희]
#            ...
# 19338    [최가, 최가네]
# 19351    [최가, 최가네]
# 19357    [최가, 최가네]
# 19381    [최가, 최가네]
# 19404    [최가, 최가네]
# Name: store, Length: 4487, dtype: object

# %%
# del_reply = []
# for reply, store_words in zip(train_del['reply'], train_del['store']):
#     reply_words = reply.split()
#     new_reply_words = []
#     for reply_word in reply_words:
#         if not any(store_word in reply_word for store_word in store_words): # store_words에 있는 단어가 어떤 단어에도 포함되지 않으면 추가
#             new_reply_words.append(reply_word)

#     new_reply = ' '.join(new_reply_words)
#     del_reply.append(new_reply)

# train_del['reply'] = del_reply
# train_del['reply'][19404]
# Out:
# <ipython-input-134-99fbe3f86010>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_del['reply'] = del_reply
# '맛있게 드셔주심에 저희가 너무 감사드립니다 항상 노력하는 될 수 있도록 할게요 좋은 글 남겨주셔서 감사드립니다'

# %%
# # train 셋에 반영
# train[reply] = train_del['reply']
# train[reply][19404]
# Out:
# '맛있게 드셔주심에 저희가 너무 감사드립니다 항상 노력하는 될 수 있도록 할게요 좋은 글 남겨주셔서 감사드립니다'

# %% [markdown]
# ### 지점명 reply에서 삭제

# %%
# pattern = re.compile(r'\S+점')
# train["reply"].apply(lambda x: pattern.sub('', x)) #__점 제거
# Out:
# 0        만족하셨더라면 좋았을걸 저희도 아쉽네요 전복 특에 우는 고명으로 전복 슬라이스가 올...
# 1        안녕하세요 고객님 다시 한번 사과의 말씀 드리고 싶습니다 오늘 직원들과의 미팅을 통...
# 2        죄송해요 고객님 최근 기상악화로 배달대행사에 애로사항이 많다 보니 1시간 2시간이 ...
# 3                            봉구 비어 닭 다리에요 매장에서 인기 많은데 죄송해요
# 4        안녕하세요 고객님 저희 매장 다시 찾아주셨는데 만족드리지 못해 죄송합니다 고의적으로...
#                                ...
# 19771                        사진 잘 찍어주셔서 감사합니다 다음에 또 뵙겠습니다
# 19772                                     맛있게 드셔주셔서 감사합니다
# 19773           허겁지겁 맛있게 드셔주셔서 감사합니다 리뷰 감사합니다 다음에 또 뵙겠습니다
# 19774    요청사항 언제든 환영입니다 맛있게 드셔주셔서 감사합니다 리뷰 감사합니다 다음에 또 ...
# 19775                                     헉 부산에서 처음 감사합니다
# Name: reply, Length: 19776, dtype: object

# %% [markdown]
# - 개별 삭제

# %%
# train[train['reply'].str.contains("당신은 지금 치킨이 당긴다 헬리오 시티점입니다")].index

# remove_keywords = ["당신은 지금 치킨이 당긴다 헬리오 시티점입니다",]
# for keyword in remove_keywords:
#     train['reply'] = train['reply'].str.replace(keyword, '')

# train['reply'][2554]
# Out:
# Int64Index([ 2554,  2573,  2627,  2648,  2704,  2822,  2841,  2905,  3008,
#              3204,
#             ...
#             10448, 10449, 10450, 10451, 10452, 10453, 10454, 10455, 10456,
#             10457],
#            dtype='int64', length=151)

# %% [markdown]
# - 여기까지 완료된 데이터 저장하기

# %%
# # 전체
# # train.to_csv(f"{DATA_PATH}yogiyo_clean.csv", index=False)

# # 오버샘플 + 가게명 삭제
# train.to_csv(f"{DATA_PATH}yogiyo_OV_clean_store_del.csv", index=False)

# %% [markdown]
# ### 여기까지 완료된 데이터 불러오기

# %%
# 전체
# train = pd.read_csv(f"{DATA_PATH}yogiyo_clean.csv")

# 오버샘플 + 가게명 삭제
train = pd.read_csv(f"{DATA_PATH}yogiyo_OV_clean_store_del.csv")

train['review'] = train['review'].astype(str)
train['reply'] = train['reply'].astype(str)
review, reply = train["review"] , train["reply"]
len(review) , len(reply)
# Out:
# (19776, 19776)
